# %% [markdown]
# DMML Assignment-1 | Example runs on Kos and Nips dataset

# %%
import time
from collections import defaultdict


def read_vocab(file_path):
    """ Read the vocabulary file and map word IDs to words. """
    vocab = {}
    with open(file_path, 'r') as f:
        for i, line in enumerate(f, start=1):
            vocab[i] = line.strip()
    return vocab

def read_docword(file_path):
    """ Read the document-word file and store word occurrences efficiently. """
    with open(file_path, 'r') as f:
        D = int(f.readline().strip())  # Number of documents
        W = int(f.readline().strip())  # Number of words
        NNZ = int(f.readline().strip())  # Nonzero entries

        word_docs = defaultdict(set)  # wordID -> set of documents containing it
        for _ in range(NNZ):
            doc_id, word_id, count = map(int, f.readline().strip().split())
            word_docs[word_id].add(doc_id)

    return word_docs

def apriori(word_docs, K, F):
    """ Optimized Apriori algorithm for large datasets. """

    # Step 1: Find frequent 1-itemsets
    freq_itemsets = { (word,): docs for word, docs in word_docs.items() if len(docs) >= F }

    # Step 2: Generate k-itemsets iteratively
    for k in range(2, K + 1):
        candidates = set()
        freq_keys = list(freq_itemsets.keys())  # List of current frequent itemsets

        # Generate candidate itemsets of size k using (k-1)-itemsets
        for i in range(len(freq_keys)):
            for j in range(i + 1, len(freq_keys)):
                a, b = freq_keys[i], freq_keys[j]

                # Merge only if first (k-2) elements are same (Efficient pruning)
                if a[:-1] == b[:-1]:
                    new_itemset = tuple(sorted(set(a) | set(b)))  # Union
                    if len(new_itemset) == k:
                        candidates.add(new_itemset)

        # Count support for candidate itemsets
        new_freq_itemsets = {}
        for c in candidates:
            intersect_docs = set.intersection(*(word_docs[word] for word in c))
            if len(intersect_docs) >= F:
                new_freq_itemsets[c] = intersect_docs

        # If no new frequent itemsets, break early
        if not new_freq_itemsets:
            return []

        freq_itemsets = new_freq_itemsets

    # Convert sets to counts for readability
    return sorted([(itemset, len(docs)) for itemset, docs in freq_itemsets.items()],
                  key=lambda x: x[1], reverse=True)

def main(vocab_file, docword_file, K, F):
    print("Reading dataset...")
    word_docs = read_docword(docword_file)
    vocab = read_vocab(vocab_file)

    print(f"Running Apriori for K={K}, F={F}")
    start_time = time.time()
    frequent_itemsets = apriori(word_docs, K, F)

    elapsed = time.time() - start_time

    print(f"\nTime taken: {elapsed:.2f} seconds")

    if not frequent_itemsets:
        print("\nNo itemsets found.")
    else:
        print(f"\nTotal Frequent K-itemsets Found: {len(frequent_itemsets)}")
        print("Frequent K-itemsets:")
        for itemset, count in frequent_itemsets:
            print(f"Itemset: {tuple(vocab[word] for word in itemset)}, Count: {count}")

# %% [markdown]
# # **NIPS dataset**

# %% [markdown]
# ## K = 2 and F = 1300

# %%
main("vocab.nips.txt", "docword.nips.txt", K=2, F=1300)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1300
#
# Time taken: 0.01 seconds
#
# Total Frequent K-itemsets Found: 10
# Frequent K-itemsets:
# Itemset: ('abstract', 'references'), Count: 1411
# Itemset: ('abstract', 'result'), Count: 1389
# Itemset: ('references', 'result'), Count: 1358
# Itemset: ('abstract', 'function'), Count: 1355
# Itemset: ('abstract', 'neural'), Count: 1343
# Itemset: ('abstract', 'system'), Count: 1329
# Itemset: ('function', 'references'), Count: 1327
# Itemset: ('abstract', 'set'), Count: 1324
# Itemset: ('neural', 'references'), Count: 1314
# Itemset: ('function', 'result'), Count: 1309

# %% [markdown]
# # K = 2 and F = 1200

# %%
main("vocab.nips.txt", "docword.nips.txt", K=2, F=1200)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1200
#
# Time taken: 0.02 seconds
#
# Total Frequent K-itemsets Found: 38
# Frequent K-itemsets:
# Itemset: ('abstract', 'references'), Count: 1411
# Itemset: ('abstract', 'result'), Count: 1389
# Itemset: ('references', 'result'), Count: 1358
# Itemset: ('abstract', 'function'), Count: 1355
# Itemset: ('abstract', 'neural'), Count: 1343
# Itemset: ('abstract', 'system'), Count: 1329
# Itemset: ('function', 'references'), Count: 1327
# Itemset: ('abstract', 'set'), Count: 1324
# Itemset: ('neural', 'references'), Count: 1314
# Itemset: ('function', 'result'), Count: 1309
# Itemset: ('references', 'system'), Count: 1299
# Itemset: ('references', 'set'), Count: 1297
# Itemset: ('neural', 'result'), Count: 1296
# Itemset: ('abstract', 'introduction'), Count: 1291
# Itemset: ('result', 'system'), Count: 1281
# Itemset: ('result', 'set'), Count: 1280
# Itemset: ('abstract', 'network'), Count: 1277
# Itemset: ('abstract', 'number'), Count: 1276
# Itemset: ('function', 'neural'), Count: 1274
# Itemset: ('neural', 'system'), Count: 1264
# Itemset: ('introduction', 'references'), Count: 1256
# Itemset: ('network', 'neural'), Count: 1255
# Itemset: ('function', 'set'), Count: 1255
# Itemset: ('function', 'system'), Count: 1252
# Itemset: ('network', 'references'), Count: 1250
# Itemset: ('number', 'references'), Count: 1248
# Itemset: ('network', 'result'), Count: 1247
# Itemset: ('neural', 'set'), Count: 1243
# Itemset: ('abstract', 'model'), Count: 1242
# Itemset: ('introduction', 'result'), Count: 1242
# Itemset: ('number', 'result'), Count: 1236
# Itemset: ('set', 'system'), Count: 1224
# Itemset: ('model', 'references'), Count: 1215
# Itemset: ('function', 'network'), Count: 1211
# Itemset: ('function', 'introduction'), Count: 1207
# Itemset: ('function', 'number'), Count: 1205
# Itemset: ('introduction', 'neural'), Count: 1202
# Itemset: ('model', 'result'), Count: 1201

# %% [markdown]
# # K = 2 and F = 1100

# %%
main("vocab.nips.txt", "docword.nips.txt", K=2, F=1100)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1100
#
# Time taken: 0.04 seconds
#
# Total Frequent K-itemsets Found: 82
# Frequent K-itemsets:
# Itemset: ('abstract', 'references'), Count: 1411
# Itemset: ('abstract', 'result'), Count: 1389
# Itemset: ('references', 'result'), Count: 1358
# Itemset: ('abstract', 'function'), Count: 1355
# Itemset: ('abstract', 'neural'), Count: 1343
# Itemset: ('abstract', 'system'), Count: 1329
# Itemset: ('function', 'references'), Count: 1327
# Itemset: ('abstract', 'set'), Count: 1324
# Itemset: ('neural', 'references'), Count: 1314
# Itemset: ('function', 'result'), Count: 1309
# Itemset: ('references', 'system'), Count: 1299
# Itemset: ('references', 'set'), Count: 1297
# Itemset: ('neural', 'result'), Count: 1296
# Itemset: ('abstract', 'introduction'), Count: 1291
# Itemset: ('result', 'system'), Count: 1281
# Itemset: ('result', 'set'), Count: 1280
# Itemset: ('abstract', 'network'), Count: 1277
# Itemset: ('abstract', 'number'), Count: 1276
# Itemset: ('function', 'neural'), Count: 1274
# Itemset: ('neural', 'system'), Count: 1264
# Itemset: ('introduction', 'references'), Count: 1256
# Itemset: ('network', 'neural'), Count: 1255
# Itemset: ('function', 'set'), Count: 1255
# Itemset: ('function', 'system'), Count: 1252
# Itemset: ('network', 'references'), Count: 1250
# Itemset: ('number', 'references'), Count: 1248
# Itemset: ('network', 'result'), Count: 1247
# Itemset: ('neural', 'set'), Count: 1243
# Itemset: ('abstract', 'model'), Count: 1242
# Itemset: ('introduction', 'result'), Count: 1242
# Itemset: ('number', 'result'), Count: 1236
# Itemset: ('set', 'system'), Count: 1224
# Itemset: ('model', 'references'), Count: 1215
# Itemset: ('function', 'network'), Count: 1211
# Itemset: ('function', 'introduction'), Count: 1207
# Itemset: ('function', 'number'), Count: 1205
# Itemset: ('introduction', 'neural'), Count: 1202
# Itemset: ('model', 'result'), Count: 1201
# Itemset: ('network', 'system'), Count: 1197
# Itemset: ('number', 'set'), Count: 1195
# Itemset: ('abstract', 'input'), Count: 1192
# Itemset: ('neural', 'number'), Count: 1192
# Itemset: ('abstract', 'problem'), Count: 1187
# Itemset: ('introduction', 'set'), Count: 1186
# Itemset: ('function', 'model'), Count: 1184
# Itemset: ('introduction', 'system'), Count: 1182
# Itemset: ('abstract', 'information'), Count: 1182
# Itemset: ('number', 'system'), Count: 1181
# Itemset: ('network', 'set'), Count: 1181
# Itemset: ('problem', 'references'), Count: 1165
# Itemset: ('input', 'references'), Count: 1164
# Itemset: ('model', 'neural'), Count: 1163
# Itemset: ('information', 'references'), Count: 1159
# Itemset: ('model', 'system'), Count: 1158
# Itemset: ('input', 'result'), Count: 1153
# Itemset: ('model', 'set'), Count: 1147
# Itemset: ('problem', 'result'), Count: 1147
# Itemset: ('introduction', 'network'), Count: 1145
# Itemset: ('input', 'neural'), Count: 1144
# Itemset: ('information', 'result'), Count: 1141
# Itemset: ('introduction', 'number'), Count: 1139
# Itemset: ('network', 'number'), Count: 1133
# Itemset: ('abstract', 'learning'), Count: 1132
# Itemset: ('abstract', 'case'), Count: 1128
# Itemset: ('problem', 'set'), Count: 1128
# Itemset: ('abstract', 'data'), Count: 1128
# Itemset: ('function', 'problem'), Count: 1128
# Itemset: ('function', 'input'), Count: 1127
# Itemset: ('input', 'system'), Count: 1125
# Itemset: ('input', 'network'), Count: 1122
# Itemset: ('information', 'neural'), Count: 1121
# Itemset: ('information', 'system'), Count: 1116
# Itemset: ('neural', 'problem'), Count: 1114
# Itemset: ('learning', 'references'), Count: 1113
# Itemset: ('function', 'information'), Count: 1113
# Itemset: ('introduction', 'model'), Count: 1110
# Itemset: ('model', 'network'), Count: 1108
# Itemset: ('data', 'references'), Count: 1105
# Itemset: ('information', 'set'), Count: 1103
# Itemset: ('abstract', 'paper'), Count: 1102
# Itemset: ('case', 'references'), Count: 1102
# Itemset: ('input', 'set'), Count: 1101

# %% [markdown]
# # K = 2 and F = 1000

# %%
main("vocab.nips.txt", "docword.nips.txt", K=2, F=1000)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1000
#
# Time taken: 0.15 seconds
#
# Total Frequent K-itemsets Found: 179
# Frequent K-itemsets:
# Itemset: ('abstract', 'references'), Count: 1411
# Itemset: ('abstract', 'result'), Count: 1389
# Itemset: ('references', 'result'), Count: 1358
# Itemset: ('abstract', 'function'), Count: 1355
# Itemset: ('abstract', 'neural'), Count: 1343
# Itemset: ('abstract', 'system'), Count: 1329
# Itemset: ('function', 'references'), Count: 1327
# Itemset: ('abstract', 'set'), Count: 1324
# Itemset: ('neural', 'references'), Count: 1314
# Itemset: ('function', 'result'), Count: 1309
# Itemset: ('references', 'system'), Count: 1299
# Itemset: ('references', 'set'), Count: 1297
# Itemset: ('neural', 'result'), Count: 1296
# Itemset: ('abstract', 'introduction'), Count: 1291
# Itemset: ('result', 'system'), Count: 1281
# Itemset: ('result', 'set'), Count: 1280
# Itemset: ('abstract', 'network'), Count: 1277
# Itemset: ('abstract', 'number'), Count: 1276
# Itemset: ('function', 'neural'), Count: 1274
# Itemset: ('neural', 'system'), Count: 1264
# Itemset: ('introduction', 'references'), Count: 1256
# Itemset: ('network', 'neural'), Count: 1255
# Itemset: ('function', 'set'), Count: 1255
# Itemset: ('function', 'system'), Count: 1252
# Itemset: ('network', 'references'), Count: 1250
# Itemset: ('number', 'references'), Count: 1248
# Itemset: ('network', 'result'), Count: 1247
# Itemset: ('neural', 'set'), Count: 1243
# Itemset: ('abstract', 'model'), Count: 1242
# Itemset: ('introduction', 'result'), Count: 1242
# Itemset: ('number', 'result'), Count: 1236
# Itemset: ('set', 'system'), Count: 1224
# Itemset: ('model', 'references'), Count: 1215
# Itemset: ('function', 'network'), Count: 1211
# Itemset: ('function', 'introduction'), Count: 1207
# Itemset: ('function', 'number'), Count: 1205
# Itemset: ('introduction', 'neural'), Count: 1202
# Itemset: ('model', 'result'), Count: 1201
# Itemset: ('network', 'system'), Count: 1197
# Itemset: ('number', 'set'), Count: 1195
# Itemset: ('neural', 'number'), Count: 1192
# Itemset: ('abstract', 'input'), Count: 1192
# Itemset: ('abstract', 'problem'), Count: 1187
# Itemset: ('introduction', 'set'), Count: 1186
# Itemset: ('function', 'model'), Count: 1184
# Itemset: ('introduction', 'system'), Count: 1182
# Itemset: ('abstract', 'information'), Count: 1182
# Itemset: ('number', 'system'), Count: 1181
# Itemset: ('network', 'set'), Count: 1181
# Itemset: ('problem', 'references'), Count: 1165
# Itemset: ('input', 'references'), Count: 1164
# Itemset: ('model', 'neural'), Count: 1163
# Itemset: ('information', 'references'), Count: 1159
# Itemset: ('model', 'system'), Count: 1158
# Itemset: ('input', 'result'), Count: 1153
# Itemset: ('model', 'set'), Count: 1147
# Itemset: ('problem', 'result'), Count: 1147
# Itemset: ('introduction', 'network'), Count: 1145
# Itemset: ('input', 'neural'), Count: 1144
# Itemset: ('information', 'result'), Count: 1141
# Itemset: ('introduction', 'number'), Count: 1139
# Itemset: ('network', 'number'), Count: 1133
# Itemset: ('abstract', 'learning'), Count: 1132
# Itemset: ('abstract', 'data'), Count: 1128
# Itemset: ('function', 'problem'), Count: 1128
# Itemset: ('abstract', 'case'), Count: 1128
# Itemset: ('problem', 'set'), Count: 1128
# Itemset: ('function', 'input'), Count: 1127
# Itemset: ('input', 'system'), Count: 1125
# Itemset: ('input', 'network'), Count: 1122
# Itemset: ('information', 'neural'), Count: 1121
# Itemset: ('information', 'system'), Count: 1116
# Itemset: ('neural', 'problem'), Count: 1114
# Itemset: ('function', 'information'), Count: 1113
# Itemset: ('learning', 'references'), Count: 1113
# Itemset: ('introduction', 'model'), Count: 1110
# Itemset: ('model', 'network'), Count: 1108
# Itemset: ('data', 'references'), Count: 1105
# Itemset: ('information', 'set'), Count: 1103
# Itemset: ('case', 'references'), Count: 1102
# Itemset: ('abstract', 'paper'), Count: 1102
# Itemset: ('input', 'set'), Count: 1101
# Itemset: ('model', 'number'), Count: 1098
# Itemset: ('problem', 'system'), Count: 1097
# Itemset: ('learning', 'result'), Count: 1095
# Itemset: ('abstract', 'order'), Count: 1092
# Itemset: ('case', 'result'), Count: 1091
# Itemset: ('data', 'result'), Count: 1089
# Itemset: ('learning', 'set'), Count: 1081
# Itemset: ('function', 'learning'), Count: 1079
# Itemset: ('abstract', 'large'), Count: 1077
# Itemset: ('number', 'problem'), Count: 1075
# Itemset: ('abstract', 'point'), Count: 1073
# Itemset: ('paper', 'references'), Count: 1072
# Itemset: ('abstract', 'algorithm'), Count: 1071
# Itemset: ('case', 'function'), Count: 1071
# Itemset: ('learning', 'neural'), Count: 1069
# Itemset: ('abstract', 'processing'), Count: 1068
# Itemset: ('introduction', 'problem'), Count: 1065
# Itemset: ('order', 'references'), Count: 1065
# Itemset: ('data', 'neural'), Count: 1062
# Itemset: ('data', 'set'), Count: 1061
# Itemset: ('data', 'function'), Count: 1061
# Itemset: ('network', 'problem'), Count: 1060
# Itemset: ('input', 'introduction'), Count: 1059
# Itemset: ('information', 'number'), Count: 1058
# Itemset: ('paper', 'result'), Count: 1058
# Itemset: ('abstract', 'parameter'), Count: 1057
# Itemset: ('information', 'introduction'), Count: 1057
# Itemset: ('abstract', 'form'), Count: 1055
# Itemset: ('order', 'result'), Count: 1055
# Itemset: ('information', 'network'), Count: 1054
# Itemset: ('input', 'number'), Count: 1053
# Itemset: ('abstract', 'output'), Count: 1052
# Itemset: ('case', 'neural'), Count: 1051
# Itemset: ('abstract', 'values'), Count: 1050
# Itemset: ('algorithm', 'references'), Count: 1050
# Itemset: ('processing', 'references'), Count: 1049
# Itemset: ('point', 'references'), Count: 1048
# Itemset: ('large', 'result'), Count: 1047
# Itemset: ('large', 'references'), Count: 1046
# Itemset: ('case', 'set'), Count: 1045
# Itemset: ('learning', 'system'), Count: 1044
# Itemset: ('function', 'paper'), Count: 1041
# Itemset: ('function', 'order'), Count: 1041
# Itemset: ('algorithm', 'result'), Count: 1039
# Itemset: ('abstract', 'small'), Count: 1038
# Itemset: ('parameter', 'references'), Count: 1038
# Itemset: ('data', 'system'), Count: 1035
# Itemset: ('point', 'result'), Count: 1033
# Itemset: ('processing', 'system'), Count: 1033
# Itemset: ('learning', 'number'), Count: 1031
# Itemset: ('neural', 'order'), Count: 1031
# Itemset: ('form', 'references'), Count: 1030
# Itemset: ('information', 'model'), Count: 1030
# Itemset: ('function', 'point'), Count: 1030
# Itemset: ('input', 'model'), Count: 1029
# Itemset: ('learning', 'network'), Count: 1027
# Itemset: ('output', 'references'), Count: 1027
# Itemset: ('neural', 'paper'), Count: 1027
# Itemset: ('abstract', 'single'), Count: 1026
# Itemset: ('case', 'system'), Count: 1026
# Itemset: ('neural', 'processing'), Count: 1025
# Itemset: ('function', 'parameter'), Count: 1024
# Itemset: ('abstract', 'method'), Count: 1024
# Itemset: ('references', 'values'), Count: 1024
# Itemset: ('algorithm', 'set'), Count: 1021
# Itemset: ('model', 'problem'), Count: 1021
# Itemset: ('processing', 'result'), Count: 1020
# Itemset: ('output', 'result'), Count: 1019
# Itemset: ('form', 'result'), Count: 1019
# Itemset: ('parameter', 'result'), Count: 1018
# Itemset: ('paper', 'set'), Count: 1017
# Itemset: ('order', 'system'), Count: 1015
# Itemset: ('abstract', 'university'), Count: 1014
# Itemset: ('algorithm', 'function'), Count: 1014
# Itemset: ('data', 'introduction'), Count: 1013
# Itemset: ('neural', 'output'), Count: 1012
# Itemset: ('order', 'set'), Count: 1012
# Itemset: ('case', 'introduction'), Count: 1012
# Itemset: ('function', 'large'), Count: 1012
# Itemset: ('result', 'values'), Count: 1011
# Itemset: ('input', 'output'), Count: 1010
# Itemset: ('abstract', 'mean'), Count: 1009
# Itemset: ('paper', 'system'), Count: 1009
# Itemset: ('references', 'small'), Count: 1008
# Itemset: ('introduction', 'learning'), Count: 1008
# Itemset: ('result', 'small'), Count: 1008
# Itemset: ('data', 'network'), Count: 1007
# Itemset: ('form', 'function'), Count: 1007
# Itemset: ('data', 'number'), Count: 1006
# Itemset: ('references', 'single'), Count: 1005
# Itemset: ('method', 'references'), Count: 1005
# Itemset: ('information', 'problem'), Count: 1004
# Itemset: ('large', 'neural'), Count: 1004
# Itemset: ('case', 'number'), Count: 1003
# Itemset: ('function', 'processing'), Count: 1003
# Itemset: ('algorithm', 'neural'), Count: 1002
# Itemset: ('abstract', 'simple'), Count: 1001

# %% [markdown]
# ## K = 2 and F = 900

# %%
main("vocab.nips.txt", "docword.nips.txt", K=2, F=900)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=900
#
# Time taken: 0.29 seconds
#
# Total Frequent K-itemsets Found: 365
# Frequent K-itemsets:
# Itemset: ('abstract', 'references'), Count: 1411
# Itemset: ('abstract', 'result'), Count: 1389
# Itemset: ('references', 'result'), Count: 1358
# Itemset: ('abstract', 'function'), Count: 1355
# Itemset: ('abstract', 'neural'), Count: 1343
# Itemset: ('abstract', 'system'), Count: 1329
# Itemset: ('function', 'references'), Count: 1327
# Itemset: ('abstract', 'set'), Count: 1324
# Itemset: ('neural', 'references'), Count: 1314
# Itemset: ('function', 'result'), Count: 1309
# Itemset: ('references', 'system'), Count: 1299
# Itemset: ('references', 'set'), Count: 1297
# Itemset: ('neural', 'result'), Count: 1296
# Itemset: ('abstract', 'introduction'), Count: 1291
# Itemset: ('result', 'system'), Count: 1281
# Itemset: ('result', 'set'), Count: 1280
# Itemset: ('abstract', 'network'), Count: 1277
# Itemset: ('abstract', 'number'), Count: 1276
# Itemset: ('function', 'neural'), Count: 1274
# Itemset: ('neural', 'system'), Count: 1264
# Itemset: ('introduction', 'references'), Count: 1256
# Itemset: ('network', 'neural'), Count: 1255
# Itemset: ('function', 'set'), Count: 1255
# Itemset: ('function', 'system'), Count: 1252
# Itemset: ('network', 'references'), Count: 1250
# Itemset: ('number', 'references'), Count: 1248
# Itemset: ('network', 'result'), Count: 1247
# Itemset: ('neural', 'set'), Count: 1243
# Itemset: ('abstract', 'model'), Count: 1242
# Itemset: ('introduction', 'result'), Count: 1242
# Itemset: ('number', 'result'), Count: 1236
# Itemset: ('set', 'system'), Count: 1224
# Itemset: ('model', 'references'), Count: 1215
# Itemset: ('function', 'network'), Count: 1211
# Itemset: ('function', 'introduction'), Count: 1207
# Itemset: ('function', 'number'), Count: 1205
# Itemset: ('introduction', 'neural'), Count: 1202
# Itemset: ('model', 'result'), Count: 1201
# Itemset: ('network', 'system'), Count: 1197
# Itemset: ('number', 'set'), Count: 1195
# Itemset: ('neural', 'number'), Count: 1192
# Itemset: ('abstract', 'input'), Count: 1192
# Itemset: ('abstract', 'problem'), Count: 1187
# Itemset: ('introduction', 'set'), Count: 1186
# Itemset: ('function', 'model'), Count: 1184
# Itemset: ('introduction', 'system'), Count: 1182
# Itemset: ('abstract', 'information'), Count: 1182
# Itemset: ('number', 'system'), Count: 1181
# Itemset: ('network', 'set'), Count: 1181
# Itemset: ('problem', 'references'), Count: 1165
# Itemset: ('input', 'references'), Count: 1164
# Itemset: ('model', 'neural'), Count: 1163
# Itemset: ('information', 'references'), Count: 1159
# Itemset: ('model', 'system'), Count: 1158
# Itemset: ('input', 'result'), Count: 1153
# Itemset: ('model', 'set'), Count: 1147
# Itemset: ('problem', 'result'), Count: 1147
# Itemset: ('introduction', 'network'), Count: 1145
# Itemset: ('input', 'neural'), Count: 1144
# Itemset: ('information', 'result'), Count: 1141
# Itemset: ('introduction', 'number'), Count: 1139
# Itemset: ('network', 'number'), Count: 1133
# Itemset: ('abstract', 'learning'), Count: 1132
# Itemset: ('abstract', 'data'), Count: 1128
# Itemset: ('function', 'problem'), Count: 1128
# Itemset: ('abstract', 'case'), Count: 1128
# Itemset: ('problem', 'set'), Count: 1128
# Itemset: ('function', 'input'), Count: 1127
# Itemset: ('input', 'system'), Count: 1125
# Itemset: ('input', 'network'), Count: 1122
# Itemset: ('information', 'neural'), Count: 1121
# Itemset: ('information', 'system'), Count: 1116
# Itemset: ('neural', 'problem'), Count: 1114
# Itemset: ('function', 'information'), Count: 1113
# Itemset: ('learning', 'references'), Count: 1113
# Itemset: ('introduction', 'model'), Count: 1110
# Itemset: ('model', 'network'), Count: 1108
# Itemset: ('data', 'references'), Count: 1105
# Itemset: ('information', 'set'), Count: 1103
# Itemset: ('case', 'references'), Count: 1102
# Itemset: ('abstract', 'paper'), Count: 1102
# Itemset: ('input', 'set'), Count: 1101
# Itemset: ('model', 'number'), Count: 1098
# Itemset: ('problem', 'system'), Count: 1097
# Itemset: ('learning', 'result'), Count: 1095
# Itemset: ('abstract', 'order'), Count: 1092
# Itemset: ('case', 'result'), Count: 1091
# Itemset: ('data', 'result'), Count: 1089
# Itemset: ('learning', 'set'), Count: 1081
# Itemset: ('function', 'learning'), Count: 1079
# Itemset: ('abstract', 'large'), Count: 1077
# Itemset: ('number', 'problem'), Count: 1075
# Itemset: ('abstract', 'point'), Count: 1073
# Itemset: ('paper', 'references'), Count: 1072
# Itemset: ('abstract', 'algorithm'), Count: 1071
# Itemset: ('case', 'function'), Count: 1071
# Itemset: ('learning', 'neural'), Count: 1069
# Itemset: ('abstract', 'processing'), Count: 1068
# Itemset: ('introduction', 'problem'), Count: 1065
# Itemset: ('order', 'references'), Count: 1065
# Itemset: ('data', 'neural'), Count: 1062
# Itemset: ('data', 'set'), Count: 1061
# Itemset: ('data', 'function'), Count: 1061
# Itemset: ('network', 'problem'), Count: 1060
# Itemset: ('input', 'introduction'), Count: 1059
# Itemset: ('information', 'number'), Count: 1058
# Itemset: ('paper', 'result'), Count: 1058
# Itemset: ('abstract', 'parameter'), Count: 1057
# Itemset: ('information', 'introduction'), Count: 1057
# Itemset: ('abstract', 'form'), Count: 1055
# Itemset: ('order', 'result'), Count: 1055
# Itemset: ('information', 'network'), Count: 1054
# Itemset: ('input', 'number'), Count: 1053
# Itemset: ('abstract', 'output'), Count: 1052
# Itemset: ('case', 'neural'), Count: 1051
# Itemset: ('abstract', 'values'), Count: 1050
# Itemset: ('algorithm', 'references'), Count: 1050
# Itemset: ('processing', 'references'), Count: 1049
# Itemset: ('point', 'references'), Count: 1048
# Itemset: ('large', 'result'), Count: 1047
# Itemset: ('large', 'references'), Count: 1046
# Itemset: ('case', 'set'), Count: 1045
# Itemset: ('learning', 'system'), Count: 1044
# Itemset: ('function', 'paper'), Count: 1041
# Itemset: ('function', 'order'), Count: 1041
# Itemset: ('algorithm', 'result'), Count: 1039
# Itemset: ('abstract', 'small'), Count: 1038
# Itemset: ('parameter', 'references'), Count: 1038
# Itemset: ('data', 'system'), Count: 1035
# Itemset: ('point', 'result'), Count: 1033
# Itemset: ('processing', 'system'), Count: 1033
# Itemset: ('learning', 'number'), Count: 1031
# Itemset: ('neural', 'order'), Count: 1031
# Itemset: ('form', 'references'), Count: 1030
# Itemset: ('information', 'model'), Count: 1030
# Itemset: ('function', 'point'), Count: 1030
# Itemset: ('input', 'model'), Count: 1029
# Itemset: ('learning', 'network'), Count: 1027
# Itemset: ('output', 'references'), Count: 1027
# Itemset: ('neural', 'paper'), Count: 1027
# Itemset: ('abstract', 'single'), Count: 1026
# Itemset: ('case', 'system'), Count: 1026
# Itemset: ('neural', 'processing'), Count: 1025
# Itemset: ('function', 'parameter'), Count: 1024
# Itemset: ('abstract', 'method'), Count: 1024
# Itemset: ('references', 'values'), Count: 1024
# Itemset: ('algorithm', 'set'), Count: 1021
# Itemset: ('model', 'problem'), Count: 1021
# Itemset: ('processing', 'result'), Count: 1020
# Itemset: ('output', 'result'), Count: 1019
# Itemset: ('form', 'result'), Count: 1019
# Itemset: ('parameter', 'result'), Count: 1018
# Itemset: ('paper', 'set'), Count: 1017
# Itemset: ('order', 'system'), Count: 1015
# Itemset: ('abstract', 'university'), Count: 1014
# Itemset: ('algorithm', 'function'), Count: 1014
# Itemset: ('data', 'introduction'), Count: 1013
# Itemset: ('neural', 'output'), Count: 1012
# Itemset: ('order', 'set'), Count: 1012
# Itemset: ('case', 'introduction'), Count: 1012
# Itemset: ('function', 'large'), Count: 1012
# Itemset: ('result', 'values'), Count: 1011
# Itemset: ('input', 'output'), Count: 1010
# Itemset: ('abstract', 'mean'), Count: 1009
# Itemset: ('paper', 'system'), Count: 1009
# Itemset: ('references', 'small'), Count: 1008
# Itemset: ('introduction', 'learning'), Count: 1008
# Itemset: ('result', 'small'), Count: 1008
# Itemset: ('data', 'network'), Count: 1007
# Itemset: ('form', 'function'), Count: 1007
# Itemset: ('data', 'number'), Count: 1006
# Itemset: ('references', 'single'), Count: 1005
# Itemset: ('method', 'references'), Count: 1005
# Itemset: ('information', 'problem'), Count: 1004
# Itemset: ('large', 'neural'), Count: 1004
# Itemset: ('case', 'number'), Count: 1003
# Itemset: ('function', 'processing'), Count: 1003
# Itemset: ('algorithm', 'neural'), Count: 1002
# Itemset: ('abstract', 'simple'), Count: 1001
# Itemset: ('neural', 'point'), Count: 999
# Itemset: ('learning', 'problem'), Count: 999
# Itemset: ('output', 'system'), Count: 998
# Itemset: ('method', 'result'), Count: 998
# Itemset: ('function', 'values'), Count: 995
# Itemset: ('case', 'network'), Count: 995
# Itemset: ('result', 'single'), Count: 994
# Itemset: ('function', 'output'), Count: 993
# Itemset: ('references', 'university'), Count: 993
# Itemset: ('large', 'set'), Count: 992
# Itemset: ('neural', 'parameter'), Count: 992
# Itemset: ('parameter', 'set'), Count: 991
# Itemset: ('data', 'model'), Count: 991
# Itemset: ('large', 'system'), Count: 990
# Itemset: ('form', 'neural'), Count: 989
# Itemset: ('algorithm', 'system'), Count: 989
# Itemset: ('point', 'system'), Count: 988
# Itemset: ('point', 'set'), Count: 988
# Itemset: ('introduction', 'paper'), Count: 987
# Itemset: ('abstract', 'similar'), Count: 987
# Itemset: ('number', 'paper'), Count: 987
# Itemset: ('learning', 'model'), Count: 986
# Itemset: ('mean', 'result'), Count: 985
# Itemset: ('network', 'output'), Count: 985
# Itemset: ('information', 'input'), Count: 984
# Itemset: ('processing', 'set'), Count: 984
# Itemset: ('number', 'order'), Count: 984
# Itemset: ('mean', 'references'), Count: 984
# Itemset: ('abstract', 'term'), Count: 983
# Itemset: ('references', 'simple'), Count: 983
# Itemset: ('function', 'method'), Count: 982
# Itemset: ('abstract', 'space'), Count: 982
# Itemset: ('output', 'set'), Count: 981
# Itemset: ('set', 'values'), Count: 978
# Itemset: ('function', 'small'), Count: 978
# Itemset: ('neural', 'values'), Count: 976
# Itemset: ('result', 'university'), Count: 976
# Itemset: ('abstract', 'approach'), Count: 976
# Itemset: ('network', 'paper'), Count: 976
# Itemset: ('form', 'set'), Count: 974
# Itemset: ('parameter', 'system'), Count: 974
# Itemset: ('large', 'number'), Count: 974
# Itemset: ('form', 'system'), Count: 974
# Itemset: ('introduction', 'order'), Count: 974
# Itemset: ('algorithm', 'problem'), Count: 973
# Itemset: ('network', 'processing'), Count: 970
# Itemset: ('network', 'order'), Count: 970
# Itemset: ('function', 'single'), Count: 970
# Itemset: ('input', 'problem'), Count: 969
# Itemset: ('neural', 'small'), Count: 969
# Itemset: ('algorithm', 'number'), Count: 968
# Itemset: ('abstract', 'error'), Count: 967
# Itemset: ('case', 'model'), Count: 967
# Itemset: ('references', 'similar'), Count: 965
# Itemset: ('references', 'term'), Count: 965
# Itemset: ('function', 'university'), Count: 965
# Itemset: ('introduction', 'large'), Count: 965
# Itemset: ('method', 'set'), Count: 964
# Itemset: ('result', 'simple'), Count: 962
# Itemset: ('references', 'space'), Count: 962
# Itemset: ('introduction', 'point'), Count: 962
# Itemset: ('neural', 'single'), Count: 962
# Itemset: ('number', 'point'), Count: 961
# Itemset: ('method', 'neural'), Count: 961
# Itemset: ('algorithm', 'introduction'), Count: 960
# Itemset: ('system', 'values'), Count: 960
# Itemset: ('function', 'mean'), Count: 960
# Itemset: ('set', 'small'), Count: 960
# Itemset: ('information', 'learning'), Count: 960
# Itemset: ('model', 'paper'), Count: 959
# Itemset: ('information', 'processing'), Count: 959
# Itemset: ('small', 'system'), Count: 959
# Itemset: ('data', 'problem'), Count: 957
# Itemset: ('function', 'simple'), Count: 957
# Itemset: ('result', 'similar'), Count: 957
# Itemset: ('large', 'network'), Count: 957
# Itemset: ('result', 'term'), Count: 956
# Itemset: ('introduction', 'processing'), Count: 956
# Itemset: ('function', 'term'), Count: 956
# Itemset: ('algorithm', 'network'), Count: 955
# Itemset: ('neural', 'university'), Count: 955
# Itemset: ('network', 'point'), Count: 954
# Itemset: ('number', 'parameter'), Count: 954
# Itemset: ('approach', 'references'), Count: 954
# Itemset: ('input', 'learning'), Count: 952
# Itemset: ('result', 'space'), Count: 952
# Itemset: ('case', 'problem'), Count: 951
# Itemset: ('number', 'processing'), Count: 950
# Itemset: ('model', 'order'), Count: 949
# Itemset: ('network', 'parameter'), Count: 949
# Itemset: ('single', 'system'), Count: 949
# Itemset: ('introduction', 'parameter'), Count: 948
# Itemset: ('form', 'network'), Count: 948
# Itemset: ('number', 'values'), Count: 947
# Itemset: ('mean', 'neural'), Count: 946
# Itemset: ('approach', 'result'), Count: 946
# Itemset: ('form', 'introduction'), Count: 946
# Itemset: ('error', 'references'), Count: 946
# Itemset: ('data', 'information'), Count: 945
# Itemset: ('set', 'single'), Count: 944
# Itemset: ('paper', 'problem'), Count: 943
# Itemset: ('neural', 'simple'), Count: 942
# Itemset: ('method', 'system'), Count: 942
# Itemset: ('number', 'small'), Count: 941
# Itemset: ('abstract', 'weight'), Count: 941
# Itemset: ('introduction', 'output'), Count: 940
# Itemset: ('error', 'result'), Count: 939
# Itemset: ('introduction', 'values'), Count: 938
# Itemset: ('system', 'university'), Count: 938
# Itemset: ('method', 'number'), Count: 936
# Itemset: ('data', 'input'), Count: 936
# Itemset: ('mean', 'set'), Count: 935
# Itemset: ('introduction', 'small'), Count: 935
# Itemset: ('function', 'space'), Count: 935
# Itemset: ('model', 'parameter'), Count: 935
# Itemset: ('set', 'university'), Count: 934
# Itemset: ('number', 'output'), Count: 934
# Itemset: ('approach', 'set'), Count: 933
# Itemset: ('introduction', 'method'), Count: 933
# Itemset: ('abstract', 'research'), Count: 933
# Itemset: ('function', 'similar'), Count: 932
# Itemset: ('set', 'simple'), Count: 932
# Itemset: ('algorithm', 'learning'), Count: 931
# Itemset: ('simple', 'system'), Count: 929
# Itemset: ('mean', 'system'), Count: 929
# Itemset: ('case', 'information'), Count: 929
# Itemset: ('model', 'processing'), Count: 928
# Itemset: ('form', 'number'), Count: 927
# Itemset: ('network', 'values'), Count: 925
# Itemset: ('approach', 'function'), Count: 924
# Itemset: ('input', 'processing'), Count: 924
# Itemset: ('model', 'point'), Count: 924
# Itemset: ('abstract', 'linear'), Count: 923
# Itemset: ('abstract', 'tion'), Count: 923
# Itemset: ('error', 'set'), Count: 922
# Itemset: ('network', 'small'), Count: 922
# Itemset: ('references', 'weight'), Count: 921
# Itemset: ('form', 'model'), Count: 921
# Itemset: ('network', 'single'), Count: 920
# Itemset: ('abstract', 'general'), Count: 920
# Itemset: ('large', 'model'), Count: 920
# Itemset: ('abstract', 'performance'), Count: 920
# Itemset: ('approach', 'neural'), Count: 919
# Itemset: ('case', 'input'), Count: 919
# Itemset: ('error', 'function'), Count: 919
# Itemset: ('abstract', 'computation'), Count: 919
# Itemset: ('algorithm', 'model'), Count: 918
# Itemset: ('mean', 'number'), Count: 917
# Itemset: ('result', 'weight'), Count: 916
# Itemset: ('point', 'problem'), Count: 916
# Itemset: ('neural', 'term'), Count: 916
# Itemset: ('set', 'term'), Count: 915
# Itemset: ('method', 'network'), Count: 914
# Itemset: ('data', 'learning'), Count: 914
# Itemset: ('references', 'research'), Count: 914
# Itemset: ('set', 'similar'), Count: 914
# Itemset: ('neural', 'similar'), Count: 914
# Itemset: ('error', 'neural'), Count: 913
# Itemset: ('input', 'order'), Count: 913
# Itemset: ('similar', 'system'), Count: 913
# Itemset: ('neural', 'weight'), Count: 912
# Itemset: ('introduction', 'single'), Count: 912
# Itemset: ('system', 'term'), Count: 912
# Itemset: ('abstract', 'training'), Count: 911
# Itemset: ('order', 'problem'), Count: 911
# Itemset: ('network', 'university'), Count: 911
# Itemset: ('number', 'single'), Count: 910
# Itemset: ('neural', 'space'), Count: 910
# Itemset: ('set', 'space'), Count: 910
# Itemset: ('case', 'learning'), Count: 908
# Itemset: ('network', 'weight'), Count: 908
# Itemset: ('model', 'output'), Count: 907
# Itemset: ('introduction', 'mean'), Count: 907
# Itemset: ('information', 'paper'), Count: 907
# Itemset: ('method', 'problem'), Count: 906
# Itemset: ('algorithm', 'information'), Count: 906
# Itemset: ('linear', 'references'), Count: 906
# Itemset: ('number', 'university'), Count: 906
# Itemset: ('abstract', 'non'), Count: 905
# Itemset: ('introduction', 'university'), Count: 904
# Itemset: ('performance', 'references'), Count: 904
# Itemset: ('error', 'system'), Count: 903
# Itemset: ('large', 'problem'), Count: 902
# Itemset: ('model', 'values'), Count: 902
# Itemset: ('approach', 'system'), Count: 901
# Itemset: ('references', 'tion'), Count: 900

# %% [markdown]
# ## K = 2 and F = 800

# %%
main("vocab.nips.txt", "docword.nips.txt", K=2, F=800)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=800
#
# Time taken: 0.80 seconds
#
# Total Frequent K-itemsets Found: 724
# Frequent K-itemsets:
# Itemset: ('abstract', 'references'), Count: 1411
# Itemset: ('abstract', 'result'), Count: 1389
# Itemset: ('references', 'result'), Count: 1358
# Itemset: ('abstract', 'function'), Count: 1355
# Itemset: ('abstract', 'neural'), Count: 1343
# Itemset: ('abstract', 'system'), Count: 1329
# Itemset: ('function', 'references'), Count: 1327
# Itemset: ('abstract', 'set'), Count: 1324
# Itemset: ('neural', 'references'), Count: 1314
# Itemset: ('function', 'result'), Count: 1309
# Itemset: ('references', 'system'), Count: 1299
# Itemset: ('references', 'set'), Count: 1297
# Itemset: ('neural', 'result'), Count: 1296
# Itemset: ('abstract', 'introduction'), Count: 1291
# Itemset: ('result', 'system'), Count: 1281
# Itemset: ('result', 'set'), Count: 1280
# Itemset: ('abstract', 'network'), Count: 1277
# Itemset: ('abstract', 'number'), Count: 1276
# Itemset: ('function', 'neural'), Count: 1274
# Itemset: ('neural', 'system'), Count: 1264
# Itemset: ('introduction', 'references'), Count: 1256
# Itemset: ('network', 'neural'), Count: 1255
# Itemset: ('function', 'set'), Count: 1255
# Itemset: ('function', 'system'), Count: 1252
# Itemset: ('network', 'references'), Count: 1250
# Itemset: ('number', 'references'), Count: 1248
# Itemset: ('network', 'result'), Count: 1247
# Itemset: ('neural', 'set'), Count: 1243
# Itemset: ('abstract', 'model'), Count: 1242
# Itemset: ('introduction', 'result'), Count: 1242
# Itemset: ('number', 'result'), Count: 1236
# Itemset: ('set', 'system'), Count: 1224
# Itemset: ('model', 'references'), Count: 1215
# Itemset: ('function', 'network'), Count: 1211
# Itemset: ('function', 'introduction'), Count: 1207
# Itemset: ('function', 'number'), Count: 1205
# Itemset: ('introduction', 'neural'), Count: 1202
# Itemset: ('model', 'result'), Count: 1201
# Itemset: ('network', 'system'), Count: 1197
# Itemset: ('number', 'set'), Count: 1195
# Itemset: ('neural', 'number'), Count: 1192
# Itemset: ('abstract', 'input'), Count: 1192
# Itemset: ('abstract', 'problem'), Count: 1187
# Itemset: ('introduction', 'set'), Count: 1186
# Itemset: ('function', 'model'), Count: 1184
# Itemset: ('abstract', 'information'), Count: 1182
# Itemset: ('introduction', 'system'), Count: 1182
# Itemset: ('number', 'system'), Count: 1181
# Itemset: ('network', 'set'), Count: 1181
# Itemset: ('problem', 'references'), Count: 1165
# Itemset: ('input', 'references'), Count: 1164
# Itemset: ('model', 'neural'), Count: 1163
# Itemset: ('information', 'references'), Count: 1159
# Itemset: ('model', 'system'), Count: 1158
# Itemset: ('input', 'result'), Count: 1153
# Itemset: ('model', 'set'), Count: 1147
# Itemset: ('problem', 'result'), Count: 1147
# Itemset: ('introduction', 'network'), Count: 1145
# Itemset: ('input', 'neural'), Count: 1144
# Itemset: ('information', 'result'), Count: 1141
# Itemset: ('introduction', 'number'), Count: 1139
# Itemset: ('network', 'number'), Count: 1133
# Itemset: ('abstract', 'learning'), Count: 1132
# Itemset: ('abstract', 'data'), Count: 1128
# Itemset: ('function', 'problem'), Count: 1128
# Itemset: ('problem', 'set'), Count: 1128
# Itemset: ('abstract', 'case'), Count: 1128
# Itemset: ('function', 'input'), Count: 1127
# Itemset: ('input', 'system'), Count: 1125
# Itemset: ('input', 'network'), Count: 1122
# Itemset: ('information', 'neural'), Count: 1121
# Itemset: ('information', 'system'), Count: 1116
# Itemset: ('neural', 'problem'), Count: 1114
# Itemset: ('learning', 'references'), Count: 1113
# Itemset: ('function', 'information'), Count: 1113
# Itemset: ('introduction', 'model'), Count: 1110
# Itemset: ('model', 'network'), Count: 1108
# Itemset: ('data', 'references'), Count: 1105
# Itemset: ('information', 'set'), Count: 1103
# Itemset: ('case', 'references'), Count: 1102
# Itemset: ('abstract', 'paper'), Count: 1102
# Itemset: ('input', 'set'), Count: 1101
# Itemset: ('model', 'number'), Count: 1098
# Itemset: ('problem', 'system'), Count: 1097
# Itemset: ('learning', 'result'), Count: 1095
# Itemset: ('abstract', 'order'), Count: 1092
# Itemset: ('case', 'result'), Count: 1091
# Itemset: ('data', 'result'), Count: 1089
# Itemset: ('learning', 'set'), Count: 1081
# Itemset: ('function', 'learning'), Count: 1079
# Itemset: ('abstract', 'large'), Count: 1077
# Itemset: ('number', 'problem'), Count: 1075
# Itemset: ('abstract', 'point'), Count: 1073
# Itemset: ('paper', 'references'), Count: 1072
# Itemset: ('abstract', 'algorithm'), Count: 1071
# Itemset: ('case', 'function'), Count: 1071
# Itemset: ('learning', 'neural'), Count: 1069
# Itemset: ('abstract', 'processing'), Count: 1068
# Itemset: ('order', 'references'), Count: 1065
# Itemset: ('introduction', 'problem'), Count: 1065
# Itemset: ('data', 'neural'), Count: 1062
# Itemset: ('data', 'function'), Count: 1061
# Itemset: ('data', 'set'), Count: 1061
# Itemset: ('network', 'problem'), Count: 1060
# Itemset: ('input', 'introduction'), Count: 1059
# Itemset: ('information', 'number'), Count: 1058
# Itemset: ('paper', 'result'), Count: 1058
# Itemset: ('abstract', 'parameter'), Count: 1057
# Itemset: ('information', 'introduction'), Count: 1057
# Itemset: ('abstract', 'form'), Count: 1055
# Itemset: ('order', 'result'), Count: 1055
# Itemset: ('information', 'network'), Count: 1054
# Itemset: ('input', 'number'), Count: 1053
# Itemset: ('abstract', 'output'), Count: 1052
# Itemset: ('case', 'neural'), Count: 1051
# Itemset: ('abstract', 'values'), Count: 1050
# Itemset: ('algorithm', 'references'), Count: 1050
# Itemset: ('processing', 'references'), Count: 1049
# Itemset: ('point', 'references'), Count: 1048
# Itemset: ('large', 'result'), Count: 1047
# Itemset: ('large', 'references'), Count: 1046
# Itemset: ('case', 'set'), Count: 1045
# Itemset: ('learning', 'system'), Count: 1044
# Itemset: ('function', 'paper'), Count: 1041
# Itemset: ('function', 'order'), Count: 1041
# Itemset: ('algorithm', 'result'), Count: 1039
# Itemset: ('abstract', 'small'), Count: 1038
# Itemset: ('parameter', 'references'), Count: 1038
# Itemset: ('data', 'system'), Count: 1035
# Itemset: ('point', 'result'), Count: 1033
# Itemset: ('processing', 'system'), Count: 1033
# Itemset: ('learning', 'number'), Count: 1031
# Itemset: ('neural', 'order'), Count: 1031
# Itemset: ('information', 'model'), Count: 1030
# Itemset: ('function', 'point'), Count: 1030
# Itemset: ('form', 'references'), Count: 1030
# Itemset: ('input', 'model'), Count: 1029
# Itemset: ('learning', 'network'), Count: 1027
# Itemset: ('output', 'references'), Count: 1027
# Itemset: ('neural', 'paper'), Count: 1027
# Itemset: ('abstract', 'single'), Count: 1026
# Itemset: ('case', 'system'), Count: 1026
# Itemset: ('neural', 'processing'), Count: 1025
# Itemset: ('references', 'values'), Count: 1024
# Itemset: ('function', 'parameter'), Count: 1024
# Itemset: ('abstract', 'method'), Count: 1024
# Itemset: ('algorithm', 'set'), Count: 1021
# Itemset: ('model', 'problem'), Count: 1021
# Itemset: ('processing', 'result'), Count: 1020
# Itemset: ('form', 'result'), Count: 1019
# Itemset: ('output', 'result'), Count: 1019
# Itemset: ('parameter', 'result'), Count: 1018
# Itemset: ('paper', 'set'), Count: 1017
# Itemset: ('order', 'system'), Count: 1015
# Itemset: ('abstract', 'university'), Count: 1014
# Itemset: ('algorithm', 'function'), Count: 1014
# Itemset: ('data', 'introduction'), Count: 1013
# Itemset: ('neural', 'output'), Count: 1012
# Itemset: ('order', 'set'), Count: 1012
# Itemset: ('case', 'introduction'), Count: 1012
# Itemset: ('function', 'large'), Count: 1012
# Itemset: ('result', 'values'), Count: 1011
# Itemset: ('input', 'output'), Count: 1010
# Itemset: ('abstract', 'mean'), Count: 1009
# Itemset: ('paper', 'system'), Count: 1009
# Itemset: ('introduction', 'learning'), Count: 1008
# Itemset: ('references', 'small'), Count: 1008
# Itemset: ('result', 'small'), Count: 1008
# Itemset: ('data', 'network'), Count: 1007
# Itemset: ('form', 'function'), Count: 1007
# Itemset: ('data', 'number'), Count: 1006
# Itemset: ('method', 'references'), Count: 1005
# Itemset: ('references', 'single'), Count: 1005
# Itemset: ('information', 'problem'), Count: 1004
# Itemset: ('large', 'neural'), Count: 1004
# Itemset: ('function', 'processing'), Count: 1003
# Itemset: ('case', 'number'), Count: 1003
# Itemset: ('algorithm', 'neural'), Count: 1002
# Itemset: ('abstract', 'simple'), Count: 1001
# Itemset: ('learning', 'problem'), Count: 999
# Itemset: ('neural', 'point'), Count: 999
# Itemset: ('method', 'result'), Count: 998
# Itemset: ('output', 'system'), Count: 998
# Itemset: ('function', 'values'), Count: 995
# Itemset: ('case', 'network'), Count: 995
# Itemset: ('result', 'single'), Count: 994
# Itemset: ('references', 'university'), Count: 993
# Itemset: ('function', 'output'), Count: 993
# Itemset: ('neural', 'parameter'), Count: 992
# Itemset: ('large', 'set'), Count: 992
# Itemset: ('parameter', 'set'), Count: 991
# Itemset: ('data', 'model'), Count: 991
# Itemset: ('large', 'system'), Count: 990
# Itemset: ('form', 'neural'), Count: 989
# Itemset: ('algorithm', 'system'), Count: 989
# Itemset: ('point', 'system'), Count: 988
# Itemset: ('point', 'set'), Count: 988
# Itemset: ('introduction', 'paper'), Count: 987
# Itemset: ('abstract', 'similar'), Count: 987
# Itemset: ('number', 'paper'), Count: 987
# Itemset: ('learning', 'model'), Count: 986
# Itemset: ('mean', 'result'), Count: 985
# Itemset: ('network', 'output'), Count: 985
# Itemset: ('information', 'input'), Count: 984
# Itemset: ('processing', 'set'), Count: 984
# Itemset: ('number', 'order'), Count: 984
# Itemset: ('mean', 'references'), Count: 984
# Itemset: ('abstract', 'term'), Count: 983
# Itemset: ('references', 'simple'), Count: 983
# Itemset: ('abstract', 'space'), Count: 982
# Itemset: ('function', 'method'), Count: 982
# Itemset: ('output', 'set'), Count: 981
# Itemset: ('function', 'small'), Count: 978
# Itemset: ('set', 'values'), Count: 978
# Itemset: ('neural', 'values'), Count: 976
# Itemset: ('abstract', 'approach'), Count: 976
# Itemset: ('network', 'paper'), Count: 976
# Itemset: ('result', 'university'), Count: 976
# Itemset: ('large', 'number'), Count: 974
# Itemset: ('introduction', 'order'), Count: 974
# Itemset: ('form', 'set'), Count: 974
# Itemset: ('parameter', 'system'), Count: 974
# Itemset: ('form', 'system'), Count: 974
# Itemset: ('algorithm', 'problem'), Count: 973
# Itemset: ('network', 'order'), Count: 970
# Itemset: ('function', 'single'), Count: 970
# Itemset: ('network', 'processing'), Count: 970
# Itemset: ('input', 'problem'), Count: 969
# Itemset: ('neural', 'small'), Count: 969
# Itemset: ('algorithm', 'number'), Count: 968
# Itemset: ('abstract', 'error'), Count: 967
# Itemset: ('case', 'model'), Count: 967
# Itemset: ('function', 'university'), Count: 965
# Itemset: ('introduction', 'large'), Count: 965
# Itemset: ('references', 'term'), Count: 965
# Itemset: ('references', 'similar'), Count: 965
# Itemset: ('method', 'set'), Count: 964
# Itemset: ('introduction', 'point'), Count: 962
# Itemset: ('references', 'space'), Count: 962
# Itemset: ('neural', 'single'), Count: 962
# Itemset: ('result', 'simple'), Count: 962
# Itemset: ('method', 'neural'), Count: 961
# Itemset: ('number', 'point'), Count: 961
# Itemset: ('system', 'values'), Count: 960
# Itemset: ('function', 'mean'), Count: 960
# Itemset: ('algorithm', 'introduction'), Count: 960
# Itemset: ('information', 'learning'), Count: 960
# Itemset: ('set', 'small'), Count: 960
# Itemset: ('small', 'system'), Count: 959
# Itemset: ('information', 'processing'), Count: 959
# Itemset: ('model', 'paper'), Count: 959
# Itemset: ('function', 'simple'), Count: 957
# Itemset: ('result', 'similar'), Count: 957
# Itemset: ('data', 'problem'), Count: 957
# Itemset: ('large', 'network'), Count: 957
# Itemset: ('result', 'term'), Count: 956
# Itemset: ('introduction', 'processing'), Count: 956
# Itemset: ('function', 'term'), Count: 956
# Itemset: ('algorithm', 'network'), Count: 955
# Itemset: ('neural', 'university'), Count: 955
# Itemset: ('network', 'point'), Count: 954
# Itemset: ('number', 'parameter'), Count: 954
# Itemset: ('approach', 'references'), Count: 954
# Itemset: ('result', 'space'), Count: 952
# Itemset: ('input', 'learning'), Count: 952
# Itemset: ('case', 'problem'), Count: 951
# Itemset: ('number', 'processing'), Count: 950
# Itemset: ('model', 'order'), Count: 949
# Itemset: ('network', 'parameter'), Count: 949
# Itemset: ('single', 'system'), Count: 949
# Itemset: ('introduction', 'parameter'), Count: 948
# Itemset: ('form', 'network'), Count: 948
# Itemset: ('number', 'values'), Count: 947
# Itemset: ('approach', 'result'), Count: 946
# Itemset: ('form', 'introduction'), Count: 946
# Itemset: ('error', 'references'), Count: 946
# Itemset: ('mean', 'neural'), Count: 946
# Itemset: ('data', 'information'), Count: 945
# Itemset: ('set', 'single'), Count: 944
# Itemset: ('paper', 'problem'), Count: 943
# Itemset: ('neural', 'simple'), Count: 942
# Itemset: ('method', 'system'), Count: 942
# Itemset: ('abstract', 'weight'), Count: 941
# Itemset: ('number', 'small'), Count: 941
# Itemset: ('introduction', 'output'), Count: 940
# Itemset: ('error', 'result'), Count: 939
# Itemset: ('introduction', 'values'), Count: 938
# Itemset: ('system', 'university'), Count: 938
# Itemset: ('method', 'number'), Count: 936
# Itemset: ('data', 'input'), Count: 936
# Itemset: ('function', 'space'), Count: 935
# Itemset: ('introduction', 'small'), Count: 935
# Itemset: ('model', 'parameter'), Count: 935
# Itemset: ('mean', 'set'), Count: 935
# Itemset: ('set', 'university'), Count: 934
# Itemset: ('number', 'output'), Count: 934
# Itemset: ('introduction', 'method'), Count: 933
# Itemset: ('abstract', 'research'), Count: 933
# Itemset: ('approach', 'set'), Count: 933
# Itemset: ('function', 'similar'), Count: 932
# Itemset: ('set', 'simple'), Count: 932
# Itemset: ('algorithm', 'learning'), Count: 931
# Itemset: ('simple', 'system'), Count: 929
# Itemset: ('mean', 'system'), Count: 929
# Itemset: ('case', 'information'), Count: 929
# Itemset: ('model', 'processing'), Count: 928
# Itemset: ('form', 'number'), Count: 927
# Itemset: ('network', 'values'), Count: 925
# Itemset: ('input', 'processing'), Count: 924
# Itemset: ('model', 'point'), Count: 924
# Itemset: ('approach', 'function'), Count: 924
# Itemset: ('abstract', 'linear'), Count: 923
# Itemset: ('abstract', 'tion'), Count: 923
# Itemset: ('error', 'set'), Count: 922
# Itemset: ('network', 'small'), Count: 922
# Itemset: ('form', 'model'), Count: 921
# Itemset: ('references', 'weight'), Count: 921
# Itemset: ('abstract', 'general'), Count: 920
# Itemset: ('network', 'single'), Count: 920
# Itemset: ('large', 'model'), Count: 920
# Itemset: ('abstract', 'performance'), Count: 920
# Itemset: ('approach', 'neural'), Count: 919
# Itemset: ('error', 'function'), Count: 919
# Itemset: ('abstract', 'computation'), Count: 919
# Itemset: ('case', 'input'), Count: 919
# Itemset: ('algorithm', 'model'), Count: 918
# Itemset: ('mean', 'number'), Count: 917
# Itemset: ('neural', 'term'), Count: 916
# Itemset: ('point', 'problem'), Count: 916
# Itemset: ('result', 'weight'), Count: 916
# Itemset: ('set', 'term'), Count: 915
# Itemset: ('method', 'network'), Count: 914
# Itemset: ('data', 'learning'), Count: 914
# Itemset: ('references', 'research'), Count: 914
# Itemset: ('neural', 'similar'), Count: 914
# Itemset: ('set', 'similar'), Count: 914
# Itemset: ('error', 'neural'), Count: 913
# Itemset: ('input', 'order'), Count: 913
# Itemset: ('similar', 'system'), Count: 913
# Itemset: ('neural', 'weight'), Count: 912
# Itemset: ('introduction', 'single'), Count: 912
# Itemset: ('system', 'term'), Count: 912
# Itemset: ('network', 'university'), Count: 911
# Itemset: ('abstract', 'training'), Count: 911
# Itemset: ('order', 'problem'), Count: 911
# Itemset: ('number', 'single'), Count: 910
# Itemset: ('neural', 'space'), Count: 910
# Itemset: ('set', 'space'), Count: 910
# Itemset: ('case', 'learning'), Count: 908
# Itemset: ('network', 'weight'), Count: 908
# Itemset: ('model', 'output'), Count: 907
# Itemset: ('introduction', 'mean'), Count: 907
# Itemset: ('information', 'paper'), Count: 907
# Itemset: ('method', 'problem'), Count: 906
# Itemset: ('algorithm', 'information'), Count: 906
# Itemset: ('linear', 'references'), Count: 906
# Itemset: ('number', 'university'), Count: 906
# Itemset: ('abstract', 'non'), Count: 905
# Itemset: ('performance', 'references'), Count: 904
# Itemset: ('introduction', 'university'), Count: 904
# Itemset: ('error', 'system'), Count: 903
# Itemset: ('large', 'problem'), Count: 902
# Itemset: ('model', 'values'), Count: 902
# Itemset: ('approach', 'system'), Count: 901
# Itemset: ('references', 'tion'), Count: 900
# Itemset: ('research', 'result'), Count: 899
# Itemset: ('computation', 'references'), Count: 899
# Itemset: ('general', 'references'), Count: 899
# Itemset: ('function', 'weight'), Count: 899
# Itemset: ('method', 'model'), Count: 898
# Itemset: ('input', 'paper'), Count: 898
# Itemset: ('space', 'system'), Count: 898
# Itemset: ('mean', 'network'), Count: 898
# Itemset: ('number', 'simple'), Count: 898
# Itemset: ('information', 'order'), Count: 897
# Itemset: ('references', 'training'), Count: 897
# Itemset: ('abstract', 'unit'), Count: 895
# Itemset: ('linear', 'result'), Count: 894
# Itemset: ('abstract', 'science'), Count: 893
# Itemset: ('network', 'simple'), Count: 893
# Itemset: ('abstract', 'analysis'), Count: 893
# Itemset: ('set', 'weight'), Count: 893
# Itemset: ('result', 'training'), Count: 893
# Itemset: ('general', 'result'), Count: 892
# Itemset: ('abstract', 'present'), Count: 890
# Itemset: ('abstract', 'vector'), Count: 890
# Itemset: ('performance', 'result'), Count: 890
# Itemset: ('function', 'linear'), Count: 890
# Itemset: ('result', 'tion'), Count: 889
# Itemset: ('introduction', 'simple'), Count: 889
# Itemset: ('problem', 'processing'), Count: 889
# Itemset: ('model', 'single'), Count: 888
# Itemset: ('set', 'training'), Count: 888
# Itemset: ('error', 'number'), Count: 887
# Itemset: ('input', 'large'), Count: 887
# Itemset: ('computation', 'neural'), Count: 887
# Itemset: ('algorithm', 'data'), Count: 885
# Itemset: ('model', 'small'), Count: 885
# Itemset: ('approach', 'number'), Count: 884
# Itemset: ('introduction', 'similar'), Count: 884
# Itemset: ('number', 'term'), Count: 884
# Itemset: ('parameter', 'problem'), Count: 884
# Itemset: ('learning', 'paper'), Count: 884
# Itemset: ('mean', 'model'), Count: 883
# Itemset: ('model', 'university'), Count: 883
# Itemset: ('information', 'point'), Count: 883
# Itemset: ('form', 'problem'), Count: 883
# Itemset: ('case', 'paper'), Count: 882
# Itemset: ('computation', 'result'), Count: 881
# Itemset: ('error', 'network'), Count: 881
# Itemset: ('function', 'general'), Count: 881
# Itemset: ('non', 'references'), Count: 880
# Itemset: ('network', 'term'), Count: 879
# Itemset: ('case', 'data'), Count: 879
# Itemset: ('number', 'space'), Count: 879
# Itemset: ('function', 'tion'), Count: 878
# Itemset: ('problem', 'values'), Count: 878
# Itemset: ('abstract', 'application'), Count: 878
# Itemset: ('abstract', 'pattern'), Count: 877
# Itemset: ('input', 'point'), Count: 877
# Itemset: ('non', 'result'), Count: 877
# Itemset: ('computation', 'function'), Count: 877
# Itemset: ('system', 'weight'), Count: 877
# Itemset: ('input', 'single'), Count: 876
# Itemset: ('approach', 'network'), Count: 876
# Itemset: ('performance', 'set'), Count: 876
# Itemset: ('research', 'system'), Count: 876
# Itemset: ('case', 'order'), Count: 875
# Itemset: ('references', 'science'), Count: 875
# Itemset: ('number', 'similar'), Count: 875
# Itemset: ('introduction', 'term'), Count: 875
# Itemset: ('form', 'input'), Count: 875
# Itemset: ('analysis', 'references'), Count: 874
# Itemset: ('network', 'similar'), Count: 874
# Itemset: ('references', 'unit'), Count: 874
# Itemset: ('linear', 'neural'), Count: 873
# Itemset: ('neural', 'training'), Count: 873
# Itemset: ('model', 'simple'), Count: 873
# Itemset: ('neural', 'research'), Count: 873
# Itemset: ('analysis', 'result'), Count: 873
# Itemset: ('information', 'large'), Count: 873
# Itemset: ('approach', 'introduction'), Count: 872
# Itemset: ('introduction', 'space'), Count: 871
# Itemset: ('form', 'information'), Count: 871
# Itemset: ('information', 'output'), Count: 870
# Itemset: ('references', 'vector'), Count: 870
# Itemset: ('input', 'values'), Count: 869
# Itemset: ('function', 'research'), Count: 869
# Itemset: ('approach', 'problem'), Count: 869
# Itemset: ('output', 'problem'), Count: 869
# Itemset: ('neural', 'performance'), Count: 869
# Itemset: ('input', 'small'), Count: 868
# Itemset: ('algorithm', 'input'), Count: 868
# Itemset: ('input', 'parameter'), Count: 867
# Itemset: ('data', 'paper'), Count: 866
# Itemset: ('abstract', 'computer'), Count: 866
# Itemset: ('model', 'term'), Count: 866
# Itemset: ('performance', 'system'), Count: 866
# Itemset: ('function', 'training'), Count: 865
# Itemset: ('data', 'large'), Count: 865
# Itemset: ('result', 'unit'), Count: 864
# Itemset: ('neural', 'tion'), Count: 864
# Itemset: ('present', 'references'), Count: 863
# Itemset: ('model', 'similar'), Count: 863
# Itemset: ('result', 'science'), Count: 863
# Itemset: ('error', 'introduction'), Count: 863
# Itemset: ('result', 'vector'), Count: 863
# Itemset: ('present', 'result'), Count: 863
# Itemset: ('abstract', 'press'), Count: 862
# Itemset: ('linear', 'set'), Count: 862
# Itemset: ('information', 'parameter'), Count: 862
# Itemset: ('information', 'method'), Count: 862
# Itemset: ('application', 'references'), Count: 861
# Itemset: ('learning', 'order'), Count: 861
# Itemset: ('case', 'point'), Count: 861
# Itemset: ('learning', 'parameter'), Count: 861
# Itemset: ('research', 'set'), Count: 860
# Itemset: ('network', 'space'), Count: 860
# Itemset: ('problem', 'small'), Count: 860
# Itemset: ('problem', 'space'), Count: 860
# Itemset: ('general', 'neural'), Count: 859
# Itemset: ('function', 'performance'), Count: 859
# Itemset: ('network', 'training'), Count: 858
# Itemset: ('neural', 'unit'), Count: 858
# Itemset: ('abstract', 'found'), Count: 858
# Itemset: ('computer', 'references'), Count: 858
# Itemset: ('abstract', 'process'), Count: 858
# Itemset: ('large', 'learning'), Count: 857
# Itemset: ('function', 'non'), Count: 856
# Itemset: ('error', 'problem'), Count: 856
# Itemset: ('computation', 'set'), Count: 855
# Itemset: ('pattern', 'references'), Count: 855
# Itemset: ('data', 'order'), Count: 854
# Itemset: ('data', 'processing'), Count: 854
# Itemset: ('general', 'set'), Count: 854
# Itemset: ('approach', 'model'), Count: 853
# Itemset: ('system', 'tion'), Count: 853
# Itemset: ('data', 'point'), Count: 853
# Itemset: ('application', 'result'), Count: 853
# Itemset: ('learning', 'method'), Count: 853
# Itemset: ('input', 'weight'), Count: 853
# Itemset: ('abstract', 'note'), Count: 852
# Itemset: ('learning', 'values'), Count: 852
# Itemset: ('problem', 'simple'), Count: 852
# Itemset: ('learning', 'point'), Count: 851
# Itemset: ('system', 'training'), Count: 851
# Itemset: ('mean', 'problem'), Count: 851
# Itemset: ('abstract', 'represent'), Count: 851
# Itemset: ('form', 'learning'), Count: 851
# Itemset: ('pattern', 'result'), Count: 851
# Itemset: ('computation', 'system'), Count: 850
# Itemset: ('information', 'values'), Count: 849
# Itemset: ('information', 'single'), Count: 849
# Itemset: ('press', 'references'), Count: 848
# Itemset: ('number', 'weight'), Count: 848
# Itemset: ('data', 'parameter'), Count: 848
# Itemset: ('problem', 'university'), Count: 848
# Itemset: ('learning', 'training'), Count: 848
# Itemset: ('model', 'space'), Count: 848
# Itemset: ('algorithm', 'case'), Count: 847
# Itemset: ('network', 'unit'), Count: 847
# Itemset: ('learning', 'output'), Count: 847
# Itemset: ('number', 'training'), Count: 846
# Itemset: ('data', 'output'), Count: 846
# Itemset: ('function', 'unit'), Count: 846
# Itemset: ('learning', 'processing'), Count: 846
# Itemset: ('set', 'vector'), Count: 846
# Itemset: ('algorithm', 'paper'), Count: 846
# Itemset: ('system', 'unit'), Count: 845
# Itemset: ('information', 'small'), Count: 845
# Itemset: ('number', 'performance'), Count: 845
# Itemset: ('analysis', 'function'), Count: 843
# Itemset: ('case', 'form'), Count: 843
# Itemset: ('case', 'large'), Count: 843
# Itemset: ('function', 'vector'), Count: 843
# Itemset: ('information', 'university'), Count: 843
# Itemset: ('introduction', 'research'), Count: 843
# Itemset: ('linear', 'system'), Count: 843
# Itemset: ('set', 'tion'), Count: 843
# Itemset: ('case', 'parameter'), Count: 843
# Itemset: ('information', 'simple'), Count: 841
# Itemset: ('paper', 'point'), Count: 841
# Itemset: ('general', 'system'), Count: 841
# Itemset: ('algorithm', 'method'), Count: 841
# Itemset: ('computer', 'result'), Count: 840
# Itemset: ('abstract', 'step'), Count: 840
# Itemset: ('error', 'learning'), Count: 839
# Itemset: ('neural', 'pattern'), Count: 838
# Itemset: ('function', 'science'), Count: 838
# Itemset: ('found', 'references'), Count: 838
# Itemset: ('case', 'values'), Count: 838
# Itemset: ('references', 'represent'), Count: 838
# Itemset: ('process', 'references'), Count: 838
# Itemset: ('abstract', 'conclusion'), Count: 838
# Itemset: ('input', 'university'), Count: 837
# Itemset: ('introduction', 'weight'), Count: 837
# Itemset: ('neural', 'vector'), Count: 837
# Itemset: ('network', 'research'), Count: 836
# Itemset: ('problem', 'single'), Count: 836
# Itemset: ('function', 'present'), Count: 836
# Itemset: ('network', 'tion'), Count: 835
# Itemset: ('linear', 'network'), Count: 835
# Itemset: ('found', 'result'), Count: 835
# Itemset: ('application', 'set'), Count: 835
# Itemset: ('abstract', 'high'), Count: 835
# Itemset: ('data', 'method'), Count: 834
# Itemset: ('number', 'research'), Count: 834
# Itemset: ('large', 'small'), Count: 834
# Itemset: ('problem', 'training'), Count: 834
# Itemset: ('application', 'neural'), Count: 833
# Itemset: ('data', 'values'), Count: 833
# Itemset: ('note', 'references'), Count: 832
# Itemset: ('application', 'function'), Count: 832
# Itemset: ('linear', 'number'), Count: 831
# Itemset: ('non', 'set'), Count: 831
# Itemset: ('data', 'small'), Count: 831
# Itemset: ('analysis', 'neural'), Count: 831
# Itemset: ('computation', 'network'), Count: 831
# Itemset: ('network', 'performance'), Count: 830
# Itemset: ('set', 'unit'), Count: 830
# Itemset: ('neural', 'science'), Count: 830
# Itemset: ('neural', 'non'), Count: 830
# Itemset: ('problem', 'term'), Count: 830
# Itemset: ('order', 'paper'), Count: 830
# Itemset: ('introduction', 'linear'), Count: 829
# Itemset: ('general', 'network'), Count: 829
# Itemset: ('analysis', 'set'), Count: 829
# Itemset: ('press', 'result'), Count: 828
# Itemset: ('information', 'mean'), Count: 828
# Itemset: ('input', 'method'), Count: 828
# Itemset: ('present', 'system'), Count: 828
# Itemset: ('general', 'number'), Count: 828
# Itemset: ('output', 'processing'), Count: 828
# Itemset: ('introduction', 'performance'), Count: 827
# Itemset: ('learning', 'weight'), Count: 827
# Itemset: ('approach', 'information'), Count: 827
# Itemset: ('form', 'paper'), Count: 826
# Itemset: ('science', 'set'), Count: 826
# Itemset: ('non', 'system'), Count: 826
# Itemset: ('science', 'system'), Count: 826
# Itemset: ('references', 'step'), Count: 825
# Itemset: ('data', 'form'), Count: 825
# Itemset: ('error', 'input'), Count: 825
# Itemset: ('neural', 'present'), Count: 824
# Itemset: ('algorithm', 'order'), Count: 824
# Itemset: ('function', 'press'), Count: 824
# Itemset: ('problem', 'weight'), Count: 824
# Itemset: ('pattern', 'system'), Count: 824
# Itemset: ('large', 'order'), Count: 824
# Itemset: ('process', 'result'), Count: 823
# Itemset: ('abstract', 'defined'), Count: 823
# Itemset: ('case', 'processing'), Count: 823
# Itemset: ('error', 'model'), Count: 823
# Itemset: ('large', 'point'), Count: 823
# Itemset: ('abstract', 'obtained'), Count: 823
# Itemset: ('algorithm', 'point'), Count: 823
# Itemset: ('computation', 'number'), Count: 822
# Itemset: ('note', 'result'), Count: 822
# Itemset: ('learning', 'space'), Count: 822
# Itemset: ('present', 'set'), Count: 820
# Itemset: ('algorithm', 'processing'), Count: 820
# Itemset: ('function', 'pattern'), Count: 820
# Itemset: ('computation', 'introduction'), Count: 819
# Itemset: ('order', 'parameter'), Count: 819
# Itemset: ('linear', 'model'), Count: 819
# Itemset: ('input', 'similar'), Count: 818
# Itemset: ('introduction', 'training'), Count: 818
# Itemset: ('conclusion', 'references'), Count: 817
# Itemset: ('input', 'simple'), Count: 817
# Itemset: ('learning', 'university'), Count: 817
# Itemset: ('error', 'information'), Count: 817
# Itemset: ('information', 'similar'), Count: 817
# Itemset: ('computer', 'function'), Count: 817
# Itemset: ('order', 'point'), Count: 816
# Itemset: ('input', 'training'), Count: 816
# Itemset: ('high', 'references'), Count: 816
# Itemset: ('algorithm', 'parameter'), Count: 816
# Itemset: ('computer', 'set'), Count: 815
# Itemset: ('represent', 'result'), Count: 815
# Itemset: ('approach', 'learning'), Count: 815
# Itemset: ('input', 'mean'), Count: 815
# Itemset: ('introduction', 'tion'), Count: 815
# Itemset: ('case', 'method'), Count: 814
# Itemset: ('paper', 'parameter'), Count: 814
# Itemset: ('learning', 'small'), Count: 814
# Itemset: ('pattern', 'set'), Count: 814
# Itemset: ('general', 'introduction'), Count: 813
# Itemset: ('information', 'term'), Count: 813
# Itemset: ('analysis', 'system'), Count: 813
# Itemset: ('neural', 'press'), Count: 813
# Itemset: ('model', 'weight'), Count: 813
# Itemset: ('abstract', 'known'), Count: 813
# Itemset: ('abstract', 'section'), Count: 813
# Itemset: ('data', 'error'), Count: 813
# Itemset: ('network', 'pattern'), Count: 813
# Itemset: ('problem', 'similar'), Count: 812
# Itemset: ('algorithm', 'large'), Count: 812
# Itemset: ('application', 'system'), Count: 812
# Itemset: ('method', 'paper'), Count: 812
# Itemset: ('case', 'mean'), Count: 812
# Itemset: ('large', 'paper'), Count: 812
# Itemset: ('found', 'function'), Count: 811
# Itemset: ('abstract', 'consider'), Count: 811
# Itemset: ('conclusion', 'result'), Count: 810
# Itemset: ('function', 'note'), Count: 810
# Itemset: ('computer', 'neural'), Count: 810
# Itemset: ('parameter', 'point'), Count: 810
# Itemset: ('abstract', 'experiment'), Count: 810
# Itemset: ('abstract', 'real'), Count: 810
# Itemset: ('obtained', 'result'), Count: 809
# Itemset: ('case', 'output'), Count: 809
# Itemset: ('case', 'small'), Count: 809
# Itemset: ('paper', 'values'), Count: 809
# Itemset: ('model', 'research'), Count: 809
# Itemset: ('point', 'values'), Count: 808
# Itemset: ('data', 'single'), Count: 808
# Itemset: ('press', 'system'), Count: 808
# Itemset: ('system', 'vector'), Count: 808
# Itemset: ('number', 'tion'), Count: 807
# Itemset: ('analysis', 'number'), Count: 807
# Itemset: ('large', 'parameter'), Count: 807
# Itemset: ('approach', 'data'), Count: 807
# Itemset: ('abstract', 'random'), Count: 807
# Itemset: ('input', 'unit'), Count: 807
# Itemset: ('number', 'unit'), Count: 807
# Itemset: ('case', 'simple'), Count: 807
# Itemset: ('form', 'order'), Count: 807
# Itemset: ('algorithm', 'approach'), Count: 807
# Itemset: ('data', 'mean'), Count: 807
# Itemset: ('high', 'result'), Count: 807
# Itemset: ('number', 'vector'), Count: 806
# Itemset: ('defined', 'references'), Count: 806
# Itemset: ('large', 'values'), Count: 806
# Itemset: ('network', 'vector'), Count: 806
# Itemset: ('neural', 'process'), Count: 806
# Itemset: ('non', 'number'), Count: 806
# Itemset: ('paper', 'processing'), Count: 806
# Itemset: ('input', 'term'), Count: 806
# Itemset: ('order', 'processing'), Count: 805
# Itemset: ('information', 'space'), Count: 805
# Itemset: ('parameter', 'values'), Count: 805
# Itemset: ('introduction', 'unit'), Count: 805
# Itemset: ('introduction', 'vector'), Count: 804
# Itemset: ('analysis', 'introduction'), Count: 804
# Itemset: ('introduction', 'non'), Count: 804
# Itemset: ('computer', 'system'), Count: 803
# Itemset: ('function', 'process'), Count: 803
# Itemset: ('learning', 'simple'), Count: 803
# Itemset: ('computation', 'model'), Count: 803
# Itemset: ('application', 'introduction'), Count: 802
# Itemset: ('learning', 'mean'), Count: 802
# Itemset: ('performance', 'problem'), Count: 802
# Itemset: ('result', 'step'), Count: 802
# Itemset: ('case', 'term'), Count: 802
# Itemset: ('model', 'tion'), Count: 802
# Itemset: ('order', 'output'), Count: 802
# Itemset: ('found', 'neural'), Count: 802
# Itemset: ('abstract', 'zero'), Count: 801
# Itemset: ('learning', 'term'), Count: 801
# Itemset: ('process', 'set'), Count: 801
# Itemset: ('order', 'small'), Count: 801
# Itemset: ('form', 'point'), Count: 801
# Itemset: ('obtained', 'references'), Count: 801
# Itemset: ('algorithm', 'values'), Count: 800

# %% [markdown]
# ## K = 3 and F = 1200

# %%
main("vocab.nips.txt", "docword.nips.txt", K=3, F=1200)
# Out:
# Reading dataset...
# Running Apriori for K=3, F=1200
#
# Time taken: 0.05 seconds
#
# Total Frequent K-itemsets Found: 36
# Frequent K-itemsets:
# Itemset: ('abstract', 'references', 'result'), Count: 1346
# Itemset: ('abstract', 'function', 'references'), Count: 1315
# Itemset: ('abstract', 'neural', 'references'), Count: 1302
# Itemset: ('abstract', 'function', 'result'), Count: 1292
# Itemset: ('abstract', 'references', 'system'), Count: 1289
# Itemset: ('abstract', 'references', 'set'), Count: 1287
# Itemset: ('abstract', 'neural', 'result'), Count: 1280
# Itemset: ('abstract', 'result', 'system'), Count: 1266
# Itemset: ('abstract', 'result', 'set'), Count: 1265
# Itemset: ('function', 'references', 'result'), Count: 1265
# Itemset: ('abstract', 'function', 'neural'), Count: 1254
# Itemset: ('neural', 'references', 'result'), Count: 1251
# Itemset: ('abstract', 'introduction', 'references'), Count: 1250
# Itemset: ('abstract', 'neural', 'system'), Count: 1244
# Itemset: ('abstract', 'number', 'references'), Count: 1239
# Itemset: ('abstract', 'network', 'references'), Count: 1238
# Itemset: ('references', 'result', 'set'), Count: 1238
# Itemset: ('abstract', 'function', 'set'), Count: 1238
# Itemset: ('references', 'result', 'system'), Count: 1236
# Itemset: ('abstract', 'introduction', 'result'), Count: 1235
# Itemset: ('abstract', 'function', 'system'), Count: 1234
# Itemset: ('abstract', 'network', 'neural'), Count: 1233
# Itemset: ('abstract', 'network', 'result'), Count: 1230
# Itemset: ('function', 'neural', 'references'), Count: 1228
# Itemset: ('abstract', 'neural', 'set'), Count: 1223
# Itemset: ('abstract', 'number', 'result'), Count: 1222
# Itemset: ('neural', 'references', 'system'), Count: 1216
# Itemset: ('function', 'references', 'set'), Count: 1213
# Itemset: ('function', 'neural', 'result'), Count: 1209
# Itemset: ('abstract', 'set', 'system'), Count: 1207
# Itemset: ('function', 'references', 'system'), Count: 1206
# Itemset: ('network', 'neural', 'references'), Count: 1206
# Itemset: ('abstract', 'model', 'references'), Count: 1204
# Itemset: ('network', 'references', 'result'), Count: 1203
# Itemset: ('network', 'neural', 'result'), Count: 1202
# Itemset: ('introduction', 'references', 'result'), Count: 1200

# %% [markdown]
# ## K = 4 and F = 1000

# %%
main("vocab.nips.txt", "docword.nips.txt", K=4, F=1000)
# Out:
# Reading dataset...
# Running Apriori for K=4, F=1000
#
# Time taken: 0.78 seconds
#
# Total Frequent K-itemsets Found: 362
# Frequent K-itemsets:
# Itemset: ('abstract', 'function', 'references', 'result'), Count: 1253
# Itemset: ('abstract', 'neural', 'references', 'result'), Count: 1240
# Itemset: ('abstract', 'references', 'result', 'set'), Count: 1229
# Itemset: ('abstract', 'references', 'result', 'system'), Count: 1227
# Itemset: ('abstract', 'function', 'neural', 'references'), Count: 1217
# Itemset: ('abstract', 'neural', 'references', 'system'), Count: 1207
# Itemset: ('abstract', 'function', 'references', 'set'), Count: 1204
# Itemset: ('abstract', 'function', 'references', 'system'), Count: 1197
# Itemset: ('abstract', 'introduction', 'references', 'result'), Count: 1195
# Itemset: ('abstract', 'network', 'neural', 'references'), Count: 1194
# Itemset: ('abstract', 'function', 'neural', 'result'), Count: 1194
# Itemset: ('abstract', 'network', 'references', 'result'), Count: 1192
# Itemset: ('abstract', 'neural', 'references', 'set'), Count: 1188
# Itemset: ('abstract', 'network', 'neural', 'result'), Count: 1187
# Itemset: ('abstract', 'number', 'references', 'result'), Count: 1186
# Itemset: ('abstract', 'neural', 'result', 'system'), Count: 1183
# Itemset: ('abstract', 'function', 'result', 'set'), Count: 1181
# Itemset: ('abstract', 'function', 'result', 'system'), Count: 1174
# Itemset: ('abstract', 'references', 'set', 'system'), Count: 1173
# Itemset: ('function', 'neural', 'references', 'result'), Count: 1169
# Itemset: ('abstract', 'neural', 'result', 'set'), Count: 1167
# Itemset: ('abstract', 'function', 'introduction', 'references'), Count: 1162
# Itemset: ('network', 'neural', 'references', 'result'), Count: 1160
# Itemset: ('function', 'references', 'result', 'set'), Count: 1157
# Itemset: ('abstract', 'function', 'neural', 'system'), Count: 1157
# Itemset: ('abstract', 'function', 'number', 'references'), Count: 1155
# Itemset: ('abstract', 'function', 'network', 'references'), Count: 1155
# Itemset: ('neural', 'references', 'result', 'system'), Count: 1155
# Itemset: ('abstract', 'introduction', 'neural', 'references'), Count: 1155
# Itemset: ('abstract', 'result', 'set', 'system'), Count: 1151
# Itemset: ('abstract', 'function', 'network', 'neural'), Count: 1148
# Itemset: ('function', 'references', 'result', 'system'), Count: 1147
# Itemset: ('abstract', 'number', 'references', 'set'), Count: 1147
# Itemset: ('abstract', 'function', 'neural', 'set'), Count: 1147
# Itemset: ('abstract', 'function', 'network', 'result'), Count: 1146
# Itemset: ('abstract', 'model', 'references', 'result'), Count: 1146
# Itemset: ('abstract', 'function', 'introduction', 'result'), Count: 1145
# Itemset: ('abstract', 'network', 'neural', 'system'), Count: 1144
# Itemset: ('abstract', 'introduction', 'references', 'set'), Count: 1144
# Itemset: ('abstract', 'network', 'references', 'system'), Count: 1143
# Itemset: ('neural', 'references', 'result', 'set'), Count: 1142
# Itemset: ('abstract', 'neural', 'number', 'references'), Count: 1142
# Itemset: ('abstract', 'introduction', 'neural', 'result'), Count: 1139
# Itemset: ('abstract', 'function', 'number', 'result'), Count: 1137
# Itemset: ('abstract', 'introduction', 'references', 'system'), Count: 1137
# Itemset: ('abstract', 'network', 'result', 'system'), Count: 1133
# Itemset: ('abstract', 'number', 'references', 'system'), Count: 1132
# Itemset: ('abstract', 'neural', 'set', 'system'), Count: 1132
# Itemset: ('function', 'neural', 'references', 'system'), Count: 1131
# Itemset: ('abstract', 'number', 'result', 'set'), Count: 1131
# Itemset: ('abstract', 'function', 'model', 'references'), Count: 1129
# Itemset: ('abstract', 'network', 'references', 'set'), Count: 1128
# Itemset: ('abstract', 'introduction', 'result', 'set'), Count: 1128
# Itemset: ('abstract', 'function', 'set', 'system'), Count: 1126
# Itemset: ('abstract', 'neural', 'number', 'result'), Count: 1125
# Itemset: ('function', 'neural', 'references', 'set'), Count: 1124
# Itemset: ('abstract', 'network', 'neural', 'set'), Count: 1124
# Itemset: ('references', 'result', 'set', 'system'), Count: 1124
# Itemset: ('function', 'network', 'neural', 'references'), Count: 1124
# Itemset: ('function', 'network', 'references', 'result'), Count: 1123
# Itemset: ('function', 'network', 'neural', 'result'), Count: 1120
# Itemset: ('abstract', 'introduction', 'result', 'system'), Count: 1120
# Itemset: ('abstract', 'network', 'result', 'set'), Count: 1120
# Itemset: ('network', 'neural', 'references', 'system'), Count: 1118
# Itemset: ('abstract', 'number', 'result', 'system'), Count: 1115
# Itemset: ('function', 'introduction', 'references', 'result'), Count: 1114
# Itemset: ('network', 'neural', 'result', 'system'), Count: 1112
# Itemset: ('function', 'number', 'references', 'result'), Count: 1112
# Itemset: ('function', 'neural', 'result', 'system'), Count: 1111
# Itemset: ('abstract', 'function', 'introduction', 'neural'), Count: 1110
# Itemset: ('abstract', 'function', 'model', 'result'), Count: 1108
# Itemset: ('introduction', 'neural', 'references', 'result'), Count: 1107
# Itemset: ('abstract', 'model', 'neural', 'references'), Count: 1107
# Itemset: ('network', 'references', 'result', 'system'), Count: 1107
# Itemset: ('neural', 'references', 'set', 'system'), Count: 1107
# Itemset: ('number', 'references', 'result', 'set'), Count: 1105
# Itemset: ('function', 'neural', 'result', 'set'), Count: 1105
# Itemset: ('abstract', 'function', 'number', 'set'), Count: 1104
# Itemset: ('abstract', 'input', 'references', 'result'), Count: 1103
# Itemset: ('abstract', 'model', 'references', 'system'), Count: 1103
# Itemset: ('abstract', 'introduction', 'neural', 'system'), Count: 1102
# Itemset: ('network', 'neural', 'references', 'set'), Count: 1101
# Itemset: ('abstract', 'problem', 'references', 'result'), Count: 1101
# Itemset: ('introduction', 'references', 'result', 'set'), Count: 1100
# Itemset: ('function', 'references', 'set', 'system'), Count: 1100
# Itemset: ('neural', 'number', 'references', 'result'), Count: 1099
# Itemset: ('abstract', 'introduction', 'network', 'references'), Count: 1099
# Itemset: ('abstract', 'introduction', 'network', 'neural'), Count: 1099
# Itemset: ('abstract', 'function', 'neural', 'number'), Count: 1099
# Itemset: ('abstract', 'introduction', 'number', 'references'), Count: 1098
# Itemset: ('abstract', 'function', 'introduction', 'set'), Count: 1098
# Itemset: ('network', 'references', 'result', 'set'), Count: 1097
# Itemset: ('abstract', 'information', 'references', 'result'), Count: 1097
# Itemset: ('network', 'neural', 'result', 'set'), Count: 1096
# Itemset: ('abstract', 'model', 'references', 'set'), Count: 1095
# Itemset: ('abstract', 'introduction', 'network', 'result'), Count: 1095
# Itemset: ('abstract', 'function', 'network', 'system'), Count: 1093
# Itemset: ('abstract', 'input', 'neural', 'references'), Count: 1092
# Itemset: ('abstract', 'neural', 'number', 'system'), Count: 1091
# Itemset: ('abstract', 'introduction', 'neural', 'set'), Count: 1091
# Itemset: ('introduction', 'references', 'result', 'system'), Count: 1088
# Itemset: ('neural', 'result', 'set', 'system'), Count: 1088
# Itemset: ('abstract', 'function', 'network', 'set'), Count: 1088
# Itemset: ('abstract', 'function', 'introduction', 'system'), Count: 1087
# Itemset: ('number', 'references', 'result', 'system'), Count: 1087
# Itemset: ('abstract', 'model', 'neural', 'result'), Count: 1086
# Itemset: ('abstract', 'neural', 'number', 'set'), Count: 1086
# Itemset: ('function', 'model', 'references', 'result'), Count: 1085
# Itemset: ('abstract', 'network', 'number', 'references'), Count: 1084
# Itemset: ('abstract', 'introduction', 'number', 'result'), Count: 1084
# Itemset: ('abstract', 'function', 'number', 'system'), Count: 1084
# Itemset: ('abstract', 'problem', 'references', 'set'), Count: 1083
# Itemset: ('function', 'result', 'set', 'system'), Count: 1082
# Itemset: ('abstract', 'function', 'problem', 'references'), Count: 1082
# Itemset: ('abstract', 'model', 'result', 'system'), Count: 1081
# Itemset: ('function', 'introduction', 'neural', 'references'), Count: 1081
# Itemset: ('function', 'number', 'references', 'set'), Count: 1080
# Itemset: ('abstract', 'input', 'neural', 'result'), Count: 1078
# Itemset: ('abstract', 'network', 'neural', 'number'), Count: 1078
# Itemset: ('abstract', 'network', 'number', 'result'), Count: 1078
# Itemset: ('abstract', 'function', 'input', 'references'), Count: 1078
# Itemset: ('function', 'network', 'neural', 'system'), Count: 1077
# Itemset: ('abstract', 'input', 'references', 'system'), Count: 1076
# Itemset: ('abstract', 'information', 'neural', 'references'), Count: 1075
# Itemset: ('function', 'neural', 'number', 'references'), Count: 1075
# Itemset: ('abstract', 'model', 'result', 'set'), Count: 1074
# Itemset: ('abstract', 'number', 'set', 'system'), Count: 1074
# Itemset: ('abstract', 'function', 'model', 'neural'), Count: 1073
# Itemset: ('introduction', 'neural', 'references', 'system'), Count: 1073
# Itemset: ('function', 'introduction', 'references', 'set'), Count: 1072
# Itemset: ('abstract', 'information', 'references', 'system'), Count: 1072
# Itemset: ('abstract', 'input', 'network', 'references'), Count: 1071
# Itemset: ('abstract', 'input', 'network', 'neural'), Count: 1071
# Itemset: ('function', 'neural', 'set', 'system'), Count: 1070
# Itemset: ('abstract', 'introduction', 'set', 'system'), Count: 1070
# Itemset: ('abstract', 'function', 'information', 'references'), Count: 1070
# Itemset: ('abstract', 'network', 'set', 'system'), Count: 1070
# Itemset: ('function', 'network', 'references', 'system'), Count: 1069
# Itemset: ('introduction', 'network', 'neural', 'references'), Count: 1068
# Itemset: ('function', 'network', 'neural', 'set'), Count: 1068
# Itemset: ('function', 'network', 'references', 'set'), Count: 1067
# Itemset: ('abstract', 'introduction', 'model', 'references'), Count: 1067
# Itemset: ('abstract', 'neural', 'problem', 'references'), Count: 1066
# Itemset: ('introduction', 'network', 'neural', 'result'), Count: 1066
# Itemset: ('introduction', 'neural', 'references', 'set'), Count: 1065
# Itemset: ('function', 'introduction', 'neural', 'result'), Count: 1065
# Itemset: ('neural', 'number', 'references', 'system'), Count: 1065
# Itemset: ('function', 'number', 'result', 'set'), Count: 1065
# Itemset: ('abstract', 'function', 'input', 'result'), Count: 1064
# Itemset: ('function', 'network', 'result', 'system'), Count: 1064
# Itemset: ('introduction', 'network', 'references', 'result'), Count: 1064
# Itemset: ('abstract', 'function', 'model', 'system'), Count: 1064
# Itemset: ('abstract', 'function', 'model', 'set'), Count: 1062
# Itemset: ('model', 'neural', 'references', 'result'), Count: 1062
# Itemset: ('function', 'network', 'result', 'set'), Count: 1062
# Itemset: ('neural', 'number', 'references', 'set'), Count: 1062
# Itemset: ('abstract', 'model', 'neural', 'system'), Count: 1061
# Itemset: ('abstract', 'information', 'references', 'set'), Count: 1061
# Itemset: ('abstract', 'input', 'result', 'system'), Count: 1061
# Itemset: ('abstract', 'input', 'network', 'result'), Count: 1061
# Itemset: ('abstract', 'function', 'problem', 'result'), Count: 1060
# Itemset: ('function', 'neural', 'number', 'result'), Count: 1060
# Itemset: ('abstract', 'problem', 'result', 'set'), Count: 1060
# Itemset: ('abstract', 'input', 'neural', 'system'), Count: 1059
# Itemset: ('network', 'neural', 'set', 'system'), Count: 1057
# Itemset: ('function', 'introduction', 'references', 'system'), Count: 1057
# Itemset: ('function', 'number', 'references', 'system'), Count: 1057
# Itemset: ('abstract', 'function', 'introduction', 'network'), Count: 1055
# Itemset: ('abstract', 'input', 'references', 'set'), Count: 1055
# Itemset: ('introduction', 'neural', 'result', 'system'), Count: 1055
# Itemset: ('introduction', 'number', 'references', 'result'), Count: 1055
# Itemset: ('function', 'introduction', 'result', 'set'), Count: 1055
# Itemset: ('model', 'references', 'result', 'system'), Count: 1055
# Itemset: ('abstract', 'model', 'network', 'references'), Count: 1054
# Itemset: ('network', 'neural', 'number', 'references'), Count: 1054
# Itemset: ('network', 'number', 'references', 'result'), Count: 1054
# Itemset: ('abstract', 'information', 'neural', 'result'), Count: 1053
# Itemset: ('abstract', 'function', 'input', 'neural'), Count: 1053
# Itemset: ('abstract', 'function', 'introduction', 'number'), Count: 1052
# Itemset: ('abstract', 'introduction', 'model', 'result'), Count: 1052
# Itemset: ('abstract', 'problem', 'references', 'system'), Count: 1052
# Itemset: ('network', 'neural', 'number', 'result'), Count: 1051
# Itemset: ('abstract', 'learning', 'references', 'result'), Count: 1051
# Itemset: ('function', 'model', 'neural', 'references'), Count: 1051
# Itemset: ('abstract', 'model', 'number', 'references'), Count: 1050
# Itemset: ('abstract', 'introduction', 'number', 'set'), Count: 1050
# Itemset: ('model', 'references', 'result', 'set'), Count: 1050
# Itemset: ('neural', 'number', 'result', 'system'), Count: 1050
# Itemset: ('input', 'neural', 'references', 'result'), Count: 1050
# Itemset: ('neural', 'number', 'result', 'set'), Count: 1049
# Itemset: ('introduction', 'neural', 'result', 'set'), Count: 1049
# Itemset: ('abstract', 'case', 'references', 'result'), Count: 1049
# Itemset: ('abstract', 'information', 'result', 'system'), Count: 1048
# Itemset: ('number', 'references', 'set', 'system'), Count: 1047
# Itemset: ('network', 'references', 'set', 'system'), Count: 1047
# Itemset: ('abstract', 'model', 'network', 'neural'), Count: 1046
# Itemset: ('abstract', 'introduction', 'neural', 'number'), Count: 1046
# Itemset: ('abstract', 'data', 'references', 'result'), Count: 1046
# Itemset: ('abstract', 'function', 'information', 'result'), Count: 1045
# Itemset: ('input', 'network', 'neural', 'references'), Count: 1045
# Itemset: ('abstract', 'introduction', 'network', 'system'), Count: 1045
# Itemset: ('function', 'number', 'result', 'system'), Count: 1044
# Itemset: ('abstract', 'model', 'network', 'result'), Count: 1044
# Itemset: ('introduction', 'references', 'set', 'system'), Count: 1044
# Itemset: ('abstract', 'function', 'problem', 'set'), Count: 1044
# Itemset: ('abstract', 'neural', 'problem', 'result'), Count: 1043
# Itemset: ('function', 'introduction', 'result', 'system'), Count: 1041
# Itemset: ('abstract', 'function', 'network', 'number'), Count: 1041
# Itemset: ('network', 'result', 'set', 'system'), Count: 1041
# Itemset: ('abstract', 'input', 'result', 'set'), Count: 1041
# Itemset: ('abstract', 'information', 'neural', 'system'), Count: 1040
# Itemset: ('function', 'problem', 'references', 'result'), Count: 1040
# Itemset: ('problem', 'references', 'result', 'set'), Count: 1040
# Itemset: ('function', 'model', 'references', 'set'), Count: 1039
# Itemset: ('function', 'model', 'references', 'system'), Count: 1039
# Itemset: ('function', 'input', 'references', 'result'), Count: 1039
# Itemset: ('abstract', 'information', 'result', 'set'), Count: 1038
# Itemset: ('input', 'network', 'neural', 'result'), Count: 1038
# Itemset: ('abstract', 'model', 'neural', 'set'), Count: 1038
# Itemset: ('model', 'neural', 'references', 'system'), Count: 1036
# Itemset: ('abstract', 'learning', 'references', 'set'), Count: 1036
# Itemset: ('abstract', 'function', 'learning', 'references'), Count: 1035
# Itemset: ('number', 'result', 'set', 'system'), Count: 1035
# Itemset: ('input', 'network', 'references', 'result'), Count: 1035
# Itemset: ('abstract', 'introduction', 'network', 'set'), Count: 1035
# Itemset: ('input', 'references', 'result', 'system'), Count: 1034
# Itemset: ('function', 'model', 'neural', 'result'), Count: 1034
# Itemset: ('abstract', 'function', 'input', 'system'), Count: 1033
# Itemset: ('abstract', 'input', 'network', 'system'), Count: 1033
# Itemset: ('abstract', 'function', 'introduction', 'model'), Count: 1033
# Itemset: ('abstract', 'number', 'problem', 'references'), Count: 1032
# Itemset: ('input', 'neural', 'references', 'system'), Count: 1032
# Itemset: ('abstract', 'network', 'number', 'set'), Count: 1032
# Itemset: ('abstract', 'model', 'number', 'result'), Count: 1031
# Itemset: ('abstract', 'input', 'neural', 'set'), Count: 1031
# Itemset: ('function', 'neural', 'number', 'set'), Count: 1030
# Itemset: ('abstract', 'function', 'input', 'network'), Count: 1030
# Itemset: ('information', 'neural', 'references', 'result'), Count: 1030
# Itemset: ('abstract', 'introduction', 'number', 'system'), Count: 1030
# Itemset: ('abstract', 'network', 'number', 'system'), Count: 1030
# Itemset: ('abstract', 'problem', 'result', 'system'), Count: 1029
# Itemset: ('abstract', 'model', 'set', 'system'), Count: 1029
# Itemset: ('abstract', 'case', 'function', 'references'), Count: 1029
# Itemset: ('function', 'introduction', 'neural', 'system'), Count: 1028
# Itemset: ('function', 'input', 'neural', 'references'), Count: 1027
# Itemset: ('function', 'introduction', 'network', 'references'), Count: 1027
# Itemset: ('abstract', 'neural', 'problem', 'set'), Count: 1027
# Itemset: ('abstract', 'function', 'neural', 'problem'), Count: 1027
# Itemset: ('function', 'neural', 'number', 'system'), Count: 1027
# Itemset: ('function', 'introduction', 'network', 'neural'), Count: 1027
# Itemset: ('function', 'problem', 'references', 'set'), Count: 1027
# Itemset: ('introduction', 'result', 'set', 'system'), Count: 1027
# Itemset: ('abstract', 'function', 'information', 'neural'), Count: 1027
# Itemset: ('function', 'introduction', 'neural', 'set'), Count: 1026
# Itemset: ('information', 'references', 'result', 'system'), Count: 1025
# Itemset: ('abstract', 'introduction', 'problem', 'references'), Count: 1025
# Itemset: ('function', 'introduction', 'number', 'references'), Count: 1025
# Itemset: ('introduction', 'network', 'neural', 'system'), Count: 1025
# Itemset: ('introduction', 'number', 'references', 'set'), Count: 1025
# Itemset: ('function', 'information', 'references', 'result'), Count: 1025
# Itemset: ('function', 'model', 'result', 'system'), Count: 1023
# Itemset: ('model', 'network', 'neural', 'references'), Count: 1023
# Itemset: ('function', 'introduction', 'network', 'result'), Count: 1023
# Itemset: ('neural', 'problem', 'references', 'result'), Count: 1023
# Itemset: ('abstract', 'learning', 'neural', 'references'), Count: 1022
# Itemset: ('function', 'model', 'result', 'set'), Count: 1022
# Itemset: ('model', 'network', 'references', 'result'), Count: 1022
# Itemset: ('abstract', 'function', 'information', 'system'), Count: 1021
# Itemset: ('introduction', 'model', 'references', 'result'), Count: 1021
# Itemset: ('abstract', 'information', 'introduction', 'references'), Count: 1021
# Itemset: ('abstract', 'data', 'references', 'set'), Count: 1021
# Itemset: ('introduction', 'neural', 'number', 'references'), Count: 1020
# Itemset: ('function', 'network', 'neural', 'number'), Count: 1019
# Itemset: ('abstract', 'function', 'input', 'set'), Count: 1019
# Itemset: ('input', 'neural', 'result', 'system'), Count: 1019
# Itemset: ('function', 'network', 'number', 'references'), Count: 1019
# Itemset: ('model', 'network', 'neural', 'result'), Count: 1018
# Itemset: ('abstract', 'information', 'neural', 'set'), Count: 1018
# Itemset: ('abstract', 'function', 'model', 'network'), Count: 1018
# Itemset: ('model', 'neural', 'result', 'system'), Count: 1018
# Itemset: ('abstract', 'information', 'number', 'references'), Count: 1018
# Itemset: ('abstract', 'data', 'neural', 'references'), Count: 1018
# Itemset: ('abstract', 'paper', 'references', 'result'), Count: 1018
# Itemset: ('input', 'network', 'neural', 'system'), Count: 1017
# Itemset: ('input', 'references', 'result', 'set'), Count: 1017
# Itemset: ('abstract', 'data', 'function', 'references'), Count: 1017
# Itemset: ('information', 'references', 'result', 'set'), Count: 1017
# Itemset: ('abstract', 'number', 'problem', 'result'), Count: 1017
# Itemset: ('information', 'neural', 'references', 'system'), Count: 1017
# Itemset: ('introduction', 'network', 'references', 'system'), Count: 1017
# Itemset: ('abstract', 'learning', 'result', 'set'), Count: 1016
# Itemset: ('abstract', 'input', 'introduction', 'references'), Count: 1016
# Itemset: ('function', 'input', 'neural', 'result'), Count: 1016
# Itemset: ('abstract', 'case', 'function', 'result'), Count: 1016
# Itemset: ('function', 'network', 'number', 'result'), Count: 1016
# Itemset: ('abstract', 'introduction', 'model', 'neural'), Count: 1015
# Itemset: ('model', 'neural', 'references', 'set'), Count: 1015
# Itemset: ('abstract', 'function', 'model', 'number'), Count: 1015
# Itemset: ('introduction', 'neural', 'set', 'system'), Count: 1015
# Itemset: ('neural', 'number', 'set', 'system'), Count: 1014
# Itemset: ('network', 'neural', 'number', 'system'), Count: 1013
# Itemset: ('abstract', 'input', 'set', 'system'), Count: 1013
# Itemset: ('introduction', 'network', 'neural', 'set'), Count: 1013
# Itemset: ('abstract', 'function', 'learning', 'result'), Count: 1013
# Itemset: ('abstract', 'function', 'information', 'set'), Count: 1013
# Itemset: ('abstract', 'network', 'problem', 'references'), Count: 1012
# Itemset: ('function', 'number', 'set', 'system'), Count: 1012
# Itemset: ('abstract', 'order', 'references', 'result'), Count: 1012
# Itemset: ('function', 'network', 'set', 'system'), Count: 1012
# Itemset: ('introduction', 'network', 'result', 'system'), Count: 1011
# Itemset: ('abstract', 'introduction', 'problem', 'result'), Count: 1011
# Itemset: ('abstract', 'neural', 'problem', 'system'), Count: 1011
# Itemset: ('introduction', 'number', 'result', 'set'), Count: 1011
# Itemset: ('function', 'introduction', 'number', 'result'), Count: 1011
# Itemset: ('network', 'number', 'references', 'set'), Count: 1010
# Itemset: ('introduction', 'network', 'references', 'set'), Count: 1010
# Itemset: ('function', 'neural', 'problem', 'references'), Count: 1010
# Itemset: ('function', 'input', 'network', 'neural'), Count: 1010
# Itemset: ('neural', 'problem', 'references', 'set'), Count: 1010
# Itemset: ('abstract', 'case', 'neural', 'references'), Count: 1010
# Itemset: ('abstract', 'information', 'set', 'system'), Count: 1010
# Itemset: ('function', 'model', 'neural', 'system'), Count: 1009
# Itemset: ('network', 'number', 'result', 'set'), Count: 1009
# Itemset: ('abstract', 'function', 'problem', 'system'), Count: 1009
# Itemset: ('abstract', 'network', 'neural', 'problem'), Count: 1009
# Itemset: ('abstract', 'case', 'references', 'set'), Count: 1009
# Itemset: ('abstract', 'information', 'network', 'references'), Count: 1009
# Itemset: ('network', 'neural', 'number', 'set'), Count: 1009
# Itemset: ('abstract', 'input', 'number', 'references'), Count: 1008
# Itemset: ('input', 'network', 'references', 'system'), Count: 1008
# Itemset: ('model', 'number', 'references', 'result'), Count: 1008
# Itemset: ('input', 'neural', 'references', 'set'), Count: 1008
# Itemset: ('function', 'input', 'references', 'system'), Count: 1007
# Itemset: ('abstract', 'input', 'network', 'set'), Count: 1007
# Itemset: ('abstract', 'problem', 'set', 'system'), Count: 1007
# Itemset: ('abstract', 'model', 'network', 'system'), Count: 1007
# Itemset: ('function', 'information', 'neural', 'references'), Count: 1007
# Itemset: ('abstract', 'introduction', 'model', 'system'), Count: 1007
# Itemset: ('problem', 'references', 'result', 'system'), Count: 1007
# Itemset: ('abstract', 'input', 'introduction', 'result'), Count: 1007
# Itemset: ('abstract', 'information', 'network', 'neural'), Count: 1007
# Itemset: ('network', 'number', 'references', 'system'), Count: 1006
# Itemset: ('function', 'input', 'network', 'references'), Count: 1006
# Itemset: ('introduction', 'network', 'result', 'set'), Count: 1006
# Itemset: ('function', 'problem', 'result', 'set'), Count: 1006
# Itemset: ('introduction', 'neural', 'number', 'result'), Count: 1005
# Itemset: ('abstract', 'information', 'introduction', 'result'), Count: 1005
# Itemset: ('abstract', 'introduction', 'model', 'set'), Count: 1004
# Itemset: ('model', 'references', 'set', 'system'), Count: 1004
# Itemset: ('abstract', 'network', 'problem', 'result'), Count: 1004
# Itemset: ('function', 'introduction', 'model', 'references'), Count: 1004
# Itemset: ('introduction', 'number', 'references', 'system'), Count: 1003
# Itemset: ('abstract', 'information', 'number', 'result'), Count: 1002
# Itemset: ('network', 'number', 'result', 'system'), Count: 1002
# Itemset: ('abstract', 'data', 'result', 'set'), Count: 1002
# Itemset: ('abstract', 'information', 'network', 'result'), Count: 1001
# Itemset: ('function', 'introduction', 'set', 'system'), Count: 1001
# Itemset: ('abstract', 'learning', 'neural', 'result'), Count: 1001
# Itemset: ('abstract', 'function', 'paper', 'references'), Count: 1001
# Itemset: ('function', 'information', 'references', 'system'), Count: 1000
# Itemset: ('abstract', 'learning', 'references', 'system'), Count: 1000
# Itemset: ('abstract', 'function', 'learning', 'set'), Count: 1000

# %% [markdown]
# ## K = 5 and F = 1100

# %%
main("vocab.nips.txt", "docword.nips.txt", K=5, F=1100)
# Out:
# Reading dataset...
# Running Apriori for K=5, F=1100
#
# Time taken: 0.22 seconds
#
# Total Frequent K-itemsets Found: 18
# Frequent K-itemsets:
# Itemset: ('abstract', 'function', 'neural', 'references', 'result'), Count: 1158
# Itemset: ('abstract', 'network', 'neural', 'references', 'result'), Count: 1149
# Itemset: ('abstract', 'function', 'references', 'result', 'set'), Count: 1148
# Itemset: ('abstract', 'neural', 'references', 'result', 'system'), Count: 1147
# Itemset: ('abstract', 'function', 'references', 'result', 'system'), Count: 1138
# Itemset: ('abstract', 'neural', 'references', 'result', 'set'), Count: 1133
# Itemset: ('abstract', 'function', 'neural', 'references', 'system'), Count: 1123
# Itemset: ('abstract', 'references', 'result', 'set', 'system'), Count: 1118
# Itemset: ('abstract', 'function', 'neural', 'references', 'set'), Count: 1115
# Itemset: ('abstract', 'function', 'network', 'neural', 'references'), Count: 1113
# Itemset: ('abstract', 'function', 'network', 'references', 'result'), Count: 1112
# Itemset: ('abstract', 'network', 'neural', 'references', 'system'), Count: 1109
# Itemset: ('abstract', 'function', 'introduction', 'references', 'result'), Count: 1109
# Itemset: ('abstract', 'function', 'network', 'neural', 'result'), Count: 1105
# Itemset: ('abstract', 'function', 'number', 'references', 'result'), Count: 1104
# Itemset: ('abstract', 'introduction', 'neural', 'references', 'result'), Count: 1102
# Itemset: ('abstract', 'neural', 'references', 'set', 'system'), Count: 1100
# Itemset: ('abstract', 'network', 'neural', 'result', 'system'), Count: 1100

# %% [markdown]
# ## K = 7 and F = 900

# %%
main("vocab.nips.txt", "docword.nips.txt", K=7, F=900)
# Out:
# Reading dataset...
# Running Apriori for K=7, F=900
#
# Time taken: 4.40 seconds
#
# Total Frequent K-itemsets Found: 46
# Frequent K-itemsets:
# Itemset: ('abstract', 'function', 'network', 'neural', 'references', 'result', 'system'), Count: 989
# Itemset: ('abstract', 'function', 'network', 'neural', 'references', 'result', 'set'), Count: 985
# Itemset: ('abstract', 'function', 'neural', 'references', 'result', 'set', 'system'), Count: 977
# Itemset: ('abstract', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 976
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'references', 'result'), Count: 949
# Itemset: ('abstract', 'function', 'neural', 'number', 'references', 'result', 'set'), Count: 947
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'references', 'result', 'system'), Count: 946
# Itemset: ('abstract', 'function', 'network', 'neural', 'references', 'set', 'system'), Count: 945
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'references', 'result', 'set'), Count: 944
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'references', 'result'), Count: 942
# Itemset: ('abstract', 'function', 'neural', 'number', 'references', 'result', 'system'), Count: 941
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'references', 'result', 'set'), Count: 941
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'references', 'result', 'system'), Count: 940
# Itemset: ('abstract', 'network', 'neural', 'number', 'references', 'result', 'system'), Count: 938
# Itemset: ('abstract', 'network', 'neural', 'number', 'references', 'result', 'set'), Count: 937
# Itemset: ('abstract', 'function', 'network', 'neural', 'result', 'set', 'system'), Count: 937
# Itemset: ('abstract', 'function', 'network', 'references', 'result', 'set', 'system'), Count: 935
# Itemset: ('abstract', 'introduction', 'neural', 'references', 'result', 'set', 'system'), Count: 933
# Itemset: ('abstract', 'neural', 'number', 'references', 'result', 'set', 'system'), Count: 932
# Itemset: ('abstract', 'input', 'network', 'neural', 'references', 'result', 'system'), Count: 931
# Itemset: ('abstract', 'function', 'number', 'references', 'result', 'set', 'system'), Count: 930
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'references', 'result'), Count: 925
# Itemset: ('abstract', 'function', 'introduction', 'references', 'result', 'set', 'system'), Count: 920
# Itemset: ('function', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 916
# Itemset: ('abstract', 'function', 'model', 'neural', 'references', 'result', 'system'), Count: 913
# Itemset: ('abstract', 'input', 'network', 'neural', 'references', 'result', 'set'), Count: 912
# Itemset: ('abstract', 'function', 'neural', 'number', 'references', 'set', 'system'), Count: 912
# Itemset: ('abstract', 'function', 'introduction', 'number', 'references', 'result', 'set'), Count: 911
# Itemset: ('abstract', 'function', 'network', 'number', 'references', 'result', 'set'), Count: 911
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'references', 'set', 'system'), Count: 911
# Itemset: ('abstract', 'function', 'model', 'network', 'neural', 'references', 'result'), Count: 911
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'references', 'system'), Count: 909
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'references', 'set'), Count: 908
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'references', 'set'), Count: 908
# Itemset: ('abstract', 'function', 'input', 'neural', 'references', 'result', 'system'), Count: 907
# Itemset: ('abstract', 'function', 'introduction', 'network', 'references', 'result', 'set'), Count: 905
# Itemset: ('abstract', 'model', 'network', 'neural', 'references', 'result', 'system'), Count: 905
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'references', 'system'), Count: 903
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'references', 'set', 'system'), Count: 903
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'result', 'set'), Count: 903
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'number', 'references', 'result'), Count: 903
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'result', 'set'), Count: 903
# Itemset: ('abstract', 'function', 'model', 'neural', 'references', 'result', 'set'), Count: 903
# Itemset: ('abstract', 'introduction', 'neural', 'number', 'references', 'result', 'set'), Count: 902
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'result', 'system'), Count: 902
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'references', 'system'), Count: 901

# %% [markdown]
# # K = 8 and F = 800

# %%
main("vocab.nips.txt", "docword.nips.txt", K=8, F=800)
# Out:
# Reading dataset...
# Running Apriori for K=8, F=800
#
# Time taken: 30.00 seconds
#
# Total Frequent K-itemsets Found: 64
# Frequent K-itemsets:
# Itemset: ('abstract', 'function', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 910
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'references', 'result', 'set'), Count: 878
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'references', 'result', 'set'), Count: 876
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'references', 'result', 'system'), Count: 873
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'references', 'result', 'system'), Count: 871
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 871
# Itemset: ('abstract', 'function', 'neural', 'number', 'references', 'result', 'set', 'system'), Count: 870
# Itemset: ('abstract', 'network', 'neural', 'number', 'references', 'result', 'set', 'system'), Count: 867
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'references', 'result', 'set', 'system'), Count: 866
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'references', 'result', 'system'), Count: 863
# Itemset: ('abstract', 'input', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 856
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'references', 'result', 'set'), Count: 852
# Itemset: ('abstract', 'function', 'model', 'network', 'neural', 'references', 'result', 'system'), Count: 845
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'number', 'references', 'result', 'set'), Count: 842
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'number', 'references', 'result', 'set'), Count: 838
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'references', 'set', 'system'), Count: 838
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'references', 'set', 'system'), Count: 837
# Itemset: ('abstract', 'function', 'network', 'neural', 'problem', 'references', 'result', 'set'), Count: 836
# Itemset: ('abstract', 'function', 'input', 'neural', 'references', 'result', 'set', 'system'), Count: 835
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'number', 'references', 'result'), Count: 834
# Itemset: ('abstract', 'function', 'model', 'network', 'neural', 'references', 'result', 'set'), Count: 833
# Itemset: ('abstract', 'function', 'network', 'number', 'references', 'result', 'set', 'system'), Count: 833
# Itemset: ('abstract', 'function', 'network', 'neural', 'number', 'result', 'set', 'system'), Count: 833
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'result', 'set', 'system'), Count: 832
# Itemset: ('abstract', 'function', 'model', 'neural', 'references', 'result', 'set', 'system'), Count: 832
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'number', 'references', 'result', 'system'), Count: 831
# Itemset: ('abstract', 'introduction', 'neural', 'number', 'references', 'result', 'set', 'system'), Count: 830
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'number', 'references', 'result', 'system'), Count: 830
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'references', 'set', 'system'), Count: 829
# Itemset: ('abstract', 'function', 'introduction', 'network', 'references', 'result', 'set', 'system'), Count: 827
# Itemset: ('abstract', 'model', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 823
# Itemset: ('abstract', 'function', 'neural', 'problem', 'references', 'result', 'set', 'system'), Count: 821
# Itemset: ('abstract', 'function', 'introduction', 'number', 'references', 'result', 'set', 'system'), Count: 821
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'result', 'set', 'system'), Count: 821
# Itemset: ('abstract', 'input', 'introduction', 'network', 'neural', 'references', 'result', 'system'), Count: 821
# Itemset: ('abstract', 'network', 'neural', 'problem', 'references', 'result', 'set', 'system'), Count: 820
# Itemset: ('abstract', 'information', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 819
# Itemset: ('abstract', 'function', 'information', 'neural', 'references', 'result', 'set', 'system'), Count: 819
# Itemset: ('abstract', 'function', 'information', 'network', 'neural', 'references', 'result', 'system'), Count: 818
# Itemset: ('abstract', 'input', 'network', 'neural', 'number', 'references', 'result', 'system'), Count: 818
# Itemset: ('abstract', 'function', 'input', 'network', 'references', 'result', 'set', 'system'), Count: 817
# Itemset: ('abstract', 'function', 'network', 'neural', 'problem', 'references', 'result', 'system'), Count: 816
# Itemset: ('abstract', 'function', 'input', 'network', 'neural', 'number', 'references', 'result'), Count: 814
# Itemset: ('abstract', 'function', 'input', 'introduction', 'network', 'neural', 'references', 'result'), Count: 813
# Itemset: ('function', 'network', 'neural', 'number', 'references', 'result', 'set', 'system'), Count: 812
# Itemset: ('abstract', 'input', 'network', 'neural', 'number', 'references', 'result', 'set'), Count: 811
# Itemset: ('function', 'introduction', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 811
# Itemset: ('abstract', 'function', 'information', 'network', 'neural', 'references', 'result', 'set'), Count: 810
# Itemset: ('abstract', 'function', 'learning', 'network', 'neural', 'references', 'result', 'set'), Count: 810
# Itemset: ('abstract', 'function', 'introduction', 'neural', 'number', 'references', 'set', 'system'), Count: 809
# Itemset: ('abstract', 'input', 'introduction', 'network', 'neural', 'references', 'result', 'set'), Count: 809
# Itemset: ('abstract', 'function', 'introduction', 'network', 'number', 'references', 'result', 'set'), Count: 808
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'number', 'references', 'set'), Count: 808
# Itemset: ('abstract', 'function', 'introduction', 'model', 'neural', 'references', 'result', 'system'), Count: 807
# Itemset: ('abstract', 'function', 'introduction', 'model', 'network', 'neural', 'references', 'result'), Count: 806
# Itemset: ('abstract', 'function', 'neural', 'number', 'problem', 'references', 'result', 'set'), Count: 806
# Itemset: ('abstract', 'function', 'model', 'network', 'neural', 'references', 'set', 'system'), Count: 805
# Itemset: ('abstract', 'function', 'introduction', 'network', 'neural', 'number', 'result', 'set'), Count: 804
# Itemset: ('abstract', 'function', 'introduction', 'model', 'neural', 'references', 'result', 'set'), Count: 803
# Itemset: ('abstract', 'introduction', 'model', 'network', 'neural', 'references', 'result', 'system'), Count: 802
# Itemset: ('abstract', 'input', 'network', 'neural', 'output', 'references', 'result', 'system'), Count: 801
# Itemset: ('function', 'input', 'network', 'neural', 'references', 'result', 'set', 'system'), Count: 801
# Itemset: ('abstract', 'function', 'model', 'neural', 'number', 'references', 'result', 'set'), Count: 801
# Itemset: ('abstract', 'introduction', 'network', 'neural', 'number', 'references', 'set', 'system'), Count: 800

# %% [markdown]
# ## K = 10 and F = 800

# %%
main("vocab.nips.txt", "docword.nips.txt", K=10, F=800)
# Out:
# Reading dataset...
# Running Apriori for K=10, F=800
#
# Time taken: 29.61 seconds
#
# No itemsets found.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # KOS dataset

# %% [markdown]
# ## K = 2 and F = 1200

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=1200)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1200
#
# Time taken: 0.01 seconds
#
# Total Frequent K-itemsets Found: 1
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250

# %% [markdown]
# ## K = 2 and F = 1100

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=1100)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1100
#
# Time taken: 0.01 seconds
#
# Total Frequent K-itemsets Found: 2
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195

# %% [markdown]
# ## K = 2 and F = 1000

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=1000)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1000
#
# Time taken: 0.01 seconds
#
# Total Frequent K-itemsets Found: 3
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195
# Itemset: ('general', 'kerry'), Count: 1064

# %% [markdown]
# ## K = 2 and F = 900

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=900)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=900
#
# Time taken: 0.03 seconds
#
# Total Frequent K-itemsets Found: 6
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195
# Itemset: ('general', 'kerry'), Count: 1064
# Itemset: ('bush', 'war'), Count: 994
# Itemset: ('bush', 'democratic'), Count: 937
# Itemset: ('democratic', 'kerry'), Count: 922

# %% [markdown]
# ## K = 2 and F = 800

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=800)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=800
#
# Time taken: 0.03 seconds
#
# Total Frequent K-itemsets Found: 11
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195
# Itemset: ('general', 'kerry'), Count: 1064
# Itemset: ('bush', 'war'), Count: 994
# Itemset: ('bush', 'democratic'), Count: 937
# Itemset: ('democratic', 'kerry'), Count: 922
# Itemset: ('democratic', 'primary'), Count: 894
# Itemset: ('bush', 'poll'), Count: 876
# Itemset: ('bush', 'house'), Count: 873
# Itemset: ('kerry', 'poll'), Count: 845
# Itemset: ('bush', 'president'), Count: 834

# %% [markdown]
# ## K = 2 and F = 700

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=700)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=700
#
# Time taken: 0.05 seconds
#
# Total Frequent K-itemsets Found: 23
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195
# Itemset: ('general', 'kerry'), Count: 1064
# Itemset: ('bush', 'war'), Count: 994
# Itemset: ('bush', 'democratic'), Count: 937
# Itemset: ('democratic', 'kerry'), Count: 922
# Itemset: ('democratic', 'primary'), Count: 894
# Itemset: ('bush', 'poll'), Count: 876
# Itemset: ('bush', 'house'), Count: 873
# Itemset: ('kerry', 'poll'), Count: 845
# Itemset: ('bush', 'president'), Count: 834
# Itemset: ('bush', 'republicans'), Count: 794
# Itemset: ('bush', 'democrats'), Count: 783
# Itemset: ('bush', 'election'), Count: 766
# Itemset: ('democratic', 'general'), Count: 763
# Itemset: ('general', 'poll'), Count: 756
# Itemset: ('democratic', 'poll'), Count: 755
# Itemset: ('administration', 'bush'), Count: 748
# Itemset: ('general', 'war'), Count: 745
# Itemset: ('democratic', 'democrats'), Count: 740
# Itemset: ('bush', 'time'), Count: 726
# Itemset: ('bush', 'media'), Count: 721
# Itemset: ('election', 'general'), Count: 715

# %% [markdown]
# # K = 2 and F = 600

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=600)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=600
#
# Time taken: 0.06 seconds
#
# Total Frequent K-itemsets Found: 54
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195
# Itemset: ('general', 'kerry'), Count: 1064
# Itemset: ('bush', 'war'), Count: 994
# Itemset: ('bush', 'democratic'), Count: 937
# Itemset: ('democratic', 'kerry'), Count: 922
# Itemset: ('democratic', 'primary'), Count: 894
# Itemset: ('bush', 'poll'), Count: 876
# Itemset: ('bush', 'house'), Count: 873
# Itemset: ('kerry', 'poll'), Count: 845
# Itemset: ('bush', 'president'), Count: 834
# Itemset: ('bush', 'republicans'), Count: 794
# Itemset: ('bush', 'democrats'), Count: 783
# Itemset: ('bush', 'election'), Count: 766
# Itemset: ('democratic', 'general'), Count: 763
# Itemset: ('general', 'poll'), Count: 756
# Itemset: ('democratic', 'poll'), Count: 755
# Itemset: ('administration', 'bush'), Count: 748
# Itemset: ('general', 'war'), Count: 745
# Itemset: ('democratic', 'democrats'), Count: 740
# Itemset: ('bush', 'time'), Count: 726
# Itemset: ('bush', 'media'), Count: 721
# Itemset: ('election', 'general'), Count: 715
# Itemset: ('kerry', 'primary'), Count: 695
# Itemset: ('democratic', 'house'), Count: 693
# Itemset: ('kerry', 'war'), Count: 686
# Itemset: ('kerry', 'polls'), Count: 681
# Itemset: ('general', 'republicans'), Count: 678
# Itemset: ('democrats', 'republicans'), Count: 673
# Itemset: ('bush', 'polls'), Count: 660
# Itemset: ('democratic', 'republicans'), Count: 660
# Itemset: ('bush', 'people'), Count: 654
# Itemset: ('bush', 'iraq'), Count: 654
# Itemset: ('bush', 'senate'), Count: 652
# Itemset: ('bush', 'campaign'), Count: 648
# Itemset: ('poll', 'polls'), Count: 644
# Itemset: ('democrats', 'kerry'), Count: 644
# Itemset: ('general', 'house'), Count: 643
# Itemset: ('iraq', 'war'), Count: 642
# Itemset: ('democrats', 'house'), Count: 633
# Itemset: ('poll', 'primary'), Count: 630
# Itemset: ('general', 'polls'), Count: 626
# Itemset: ('house', 'republicans'), Count: 625
# Itemset: ('house', 'war'), Count: 624
# Itemset: ('democrats', 'general'), Count: 624
# Itemset: ('democratic', 'war'), Count: 618
# Itemset: ('kerry', 'republicans'), Count: 618
# Itemset: ('election', 'kerry'), Count: 617
# Itemset: ('house', 'senate'), Count: 616
# Itemset: ('bush', 'bushs'), Count: 611
# Itemset: ('bush', 'primary'), Count: 610
# Itemset: ('kerry', 'media'), Count: 610
# Itemset: ('democratic', 'senate'), Count: 608
# Itemset: ('democratic', 'election'), Count: 606

# %% [markdown]
# ## K = 2 and F = 500

# %%
main("vocab.kos.txt", "docword.kos.txt", K=2, F=500)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=500
#
# Time taken: 0.11 seconds
#
# Total Frequent K-itemsets Found: 101
# Frequent K-itemsets:
# Itemset: ('bush', 'general'), Count: 1250
# Itemset: ('bush', 'kerry'), Count: 1195
# Itemset: ('general', 'kerry'), Count: 1064
# Itemset: ('bush', 'war'), Count: 994
# Itemset: ('bush', 'democratic'), Count: 937
# Itemset: ('democratic', 'kerry'), Count: 922
# Itemset: ('democratic', 'primary'), Count: 894
# Itemset: ('bush', 'poll'), Count: 876
# Itemset: ('bush', 'house'), Count: 873
# Itemset: ('kerry', 'poll'), Count: 845
# Itemset: ('bush', 'president'), Count: 834
# Itemset: ('bush', 'republicans'), Count: 794
# Itemset: ('bush', 'democrats'), Count: 783
# Itemset: ('bush', 'election'), Count: 766
# Itemset: ('democratic', 'general'), Count: 763
# Itemset: ('general', 'poll'), Count: 756
# Itemset: ('democratic', 'poll'), Count: 755
# Itemset: ('administration', 'bush'), Count: 748
# Itemset: ('general', 'war'), Count: 745
# Itemset: ('democratic', 'democrats'), Count: 740
# Itemset: ('bush', 'time'), Count: 726
# Itemset: ('bush', 'media'), Count: 721
# Itemset: ('election', 'general'), Count: 715
# Itemset: ('kerry', 'primary'), Count: 695
# Itemset: ('democratic', 'house'), Count: 693
# Itemset: ('kerry', 'war'), Count: 686
# Itemset: ('kerry', 'polls'), Count: 681
# Itemset: ('general', 'republicans'), Count: 678
# Itemset: ('democrats', 'republicans'), Count: 673
# Itemset: ('bush', 'polls'), Count: 660
# Itemset: ('democratic', 'republicans'), Count: 660
# Itemset: ('bush', 'people'), Count: 654
# Itemset: ('bush', 'iraq'), Count: 654
# Itemset: ('bush', 'senate'), Count: 652
# Itemset: ('bush', 'campaign'), Count: 648
# Itemset: ('poll', 'polls'), Count: 644
# Itemset: ('democrats', 'kerry'), Count: 644
# Itemset: ('general', 'house'), Count: 643
# Itemset: ('iraq', 'war'), Count: 642
# Itemset: ('democrats', 'house'), Count: 633
# Itemset: ('poll', 'primary'), Count: 630
# Itemset: ('general', 'polls'), Count: 626
# Itemset: ('house', 'republicans'), Count: 625
# Itemset: ('house', 'war'), Count: 624
# Itemset: ('democrats', 'general'), Count: 624
# Itemset: ('democratic', 'war'), Count: 618
# Itemset: ('kerry', 'republicans'), Count: 618
# Itemset: ('election', 'kerry'), Count: 617
# Itemset: ('house', 'senate'), Count: 616
# Itemset: ('bush', 'bushs'), Count: 611
# Itemset: ('bush', 'primary'), Count: 610
# Itemset: ('kerry', 'media'), Count: 610
# Itemset: ('democratic', 'senate'), Count: 608
# Itemset: ('democratic', 'election'), Count: 606
# Itemset: ('democratic', 'polls'), Count: 598
# Itemset: ('bush', 'vote'), Count: 593
# Itemset: ('democratic', 'media'), Count: 592
# Itemset: ('general', 'media'), Count: 588
# Itemset: ('house', 'kerry'), Count: 583
# Itemset: ('general', 'senate'), Count: 571
# Itemset: ('general', 'president'), Count: 563
# Itemset: ('democrats', 'poll'), Count: 562
# Itemset: ('bush', 'state'), Count: 560
# Itemset: ('john', 'kerry'), Count: 559
# Itemset: ('media', 'war'), Count: 557
# Itemset: ('bush', 'political'), Count: 556
# Itemset: ('bush', 'john'), Count: 556
# Itemset: ('republicans', 'senate'), Count: 555
# Itemset: ('democrats', 'senate'), Count: 553
# Itemset: ('election', 'poll'), Count: 550
# Itemset: ('house', 'poll'), Count: 546
# Itemset: ('general', 'vote'), Count: 545
# Itemset: ('poll', 'war'), Count: 543
# Itemset: ('poll', 'republicans'), Count: 538
# Itemset: ('democrats', 'war'), Count: 537
# Itemset: ('kerry', 'senate'), Count: 537
# Itemset: ('republicans', 'war'), Count: 537
# Itemset: ('democrats', 'election'), Count: 536
# Itemset: ('campaign', 'kerry'), Count: 534
# Itemset: ('election', 'house'), Count: 533
# Itemset: ('general', 'time'), Count: 531
# Itemset: ('poll', 'senate'), Count: 529
# Itemset: ('kerry', 'vote'), Count: 528
# Itemset: ('bush', 'republican'), Count: 527
# Itemset: ('campaign', 'general'), Count: 524
# Itemset: ('bush', 'national'), Count: 521
# Itemset: ('democrats', 'primary'), Count: 519
# Itemset: ('media', 'poll'), Count: 518
# Itemset: ('campaign', 'democratic'), Count: 517
# Itemset: ('election', 'war'), Count: 517
# Itemset: ('bush', 'states'), Count: 516
# Itemset: ('house', 'media'), Count: 516
# Itemset: ('kerry', 'time'), Count: 516
# Itemset: ('election', 'republicans'), Count: 516
# Itemset: ('bush', 'november'), Count: 514
# Itemset: ('bush', 'news'), Count: 513
# Itemset: ('polls', 'primary'), Count: 511
# Itemset: ('democratic', 'vote'), Count: 508
# Itemset: ('democrats', 'media'), Count: 508
# Itemset: ('kerry', 'president'), Count: 506
# Itemset: ('general', 'primary'), Count: 500

# %% [markdown]
# ## K = 3 and F = 700

# %%
main("vocab.kos.txt", "docword.kos.txt", K=3, F=700)
# Out:
# Reading dataset...
# Running Apriori for K=3, F=700
#
# Time taken: 0.06 seconds
#
# Total Frequent K-itemsets Found: 1
# Frequent K-itemsets:
# Itemset: ('bush', 'general', 'kerry'), Count: 926

# %% [markdown]
# ## K = 4 and F = 550

# %%
main("vocab.kos.txt", "docword.kos.txt", K=4, F=550)
# Out:
# Reading dataset...
# Running Apriori for K=4, F=550
#
# Time taken: 0.15 seconds
#
# Total Frequent K-itemsets Found: 1
# Frequent K-itemsets:
# Itemset: ('bush', 'general', 'kerry', 'poll'), Count: 562

# %% [markdown]
# ## K = 4 and F = 500

# %%
main("vocab.kos.txt", "docword.kos.txt", K=4, F=500)
# Out:
# Reading dataset...
# Running Apriori for K=4, F=500
#
# Time taken: 0.24 seconds
#
# Total Frequent K-itemsets Found: 5
# Frequent K-itemsets:
# Itemset: ('bush', 'general', 'kerry', 'poll'), Count: 562
# Itemset: ('bush', 'democratic', 'general', 'kerry'), Count: 531
# Itemset: ('bush', 'general', 'kerry', 'war'), Count: 517
# Itemset: ('democratic', 'kerry', 'poll', 'primary'), Count: 504
# Itemset: ('bush', 'general', 'kerry', 'polls'), Count: 504

# %% [markdown]
# ## K = 5 and F = **400**

# %%
main("vocab.kos.txt", "docword.kos.txt", K=5, F=400)
# Out:
# Reading dataset...
# Running Apriori for K=5, F=400
#
# Time taken: 0.86 seconds
#
# Total Frequent K-itemsets Found: 5
# Frequent K-itemsets:
# Itemset: ('bush', 'general', 'kerry', 'poll', 'polls'), Count: 437
# Itemset: ('bush', 'democratic', 'democrats', 'general', 'republicans'), Count: 409
# Itemset: ('bush', 'democratic', 'democrats', 'house', 'republicans'), Count: 403
# Itemset: ('democratic', 'kerry', 'poll', 'polls', 'primary'), Count: 400
# Itemset: ('bush', 'democratic', 'general', 'kerry', 'republicans'), Count: 400

# %% [markdown]
# ## K = 7 and F = 350

# %%
main("vocab.kos.txt", "docword.kos.txt", K=7, F=350)
# Out:
# Reading dataset...
# Running Apriori for K=7, F=350
#
# Time taken: 3.29 seconds
#
# Total Frequent K-itemsets Found: 1
# Frequent K-itemsets:
# Itemset: ('bush', 'democratic', 'democrats', 'general', 'house', 'republicans', 'senate'), Count: 351

# %% [markdown]
# ## K = 10 and F = 350

# %%
main("vocab.kos.txt", "docword.kos.txt", K=10, F=350)
# Out:
# Reading dataset...
# Running Apriori for K=10, F=350
#
# Time taken: 4.27 seconds
#
# No itemsets found.
