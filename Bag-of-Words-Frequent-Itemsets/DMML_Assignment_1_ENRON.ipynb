# %% [markdown]
# DMML Assignment - 1 | Example runs on Enron dataset

# %% [markdown]
# ### ENRON dataset

# %%
import time
from collections import defaultdict


def read_vocab(file_path):
    """ Read the vocabulary file and map word IDs to words. """
    vocab = {}
    with open(file_path, 'r') as f:
        for i, line in enumerate(f, start=1):
            vocab[i] = line.strip()
    return vocab

def read_docword(file_path):
    """ Read the document-word file and store word occurrences efficiently. """
    with open(file_path, 'r') as f:
        D = int(f.readline().strip())  # Number of documents
        W = int(f.readline().strip())  # Number of words
        NNZ = int(f.readline().strip())  # Nonzero entries

        word_docs = defaultdict(set)  # wordID -> set of documents containing it
        for _ in range(NNZ):
            doc_id, word_id, count = map(int, f.readline().strip().split())
            word_docs[word_id].add(doc_id)

    return word_docs

def apriori(word_docs, K, F):
    """ Optimized Apriori algorithm for large datasets. """

    # Step 1: Find frequent 1-itemsets
    freq_itemsets = { (word,): docs for word, docs in word_docs.items() if len(docs) >= F }

    # Step 2: Generate k-itemsets iteratively
    for k in range(2, K + 1):
        candidates = set()
        freq_keys = list(freq_itemsets.keys())  # List of current frequent itemsets

        # Generate candidate itemsets of size k using (k-1)-itemsets
        for i in range(len(freq_keys)):
            for j in range(i + 1, len(freq_keys)):
                a, b = freq_keys[i], freq_keys[j]

                # Merge only if first (k-2) elements are same (Efficient pruning)
                if a[:-1] == b[:-1]:
                    new_itemset = tuple(sorted(set(a) | set(b)))  # Union
                    if len(new_itemset) == k:
                        candidates.add(new_itemset)

        # Count support for candidate itemsets
        new_freq_itemsets = {}
        for c in candidates:
            intersect_docs = set.intersection(*(word_docs[word] for word in c))
            if len(intersect_docs) >= F:
                new_freq_itemsets[c] = intersect_docs

        # If no new frequent itemsets, break early
        if not new_freq_itemsets:
            return []

        freq_itemsets = new_freq_itemsets

    # Convert sets to counts for readability
    return sorted([(itemset, len(docs)) for itemset, docs in freq_itemsets.items()],
                  key=lambda x: x[1], reverse=True)

def main(vocab_file, docword_file, K, F):
    print("Reading dataset...")
    word_docs = read_docword(docword_file)
    vocab = read_vocab(vocab_file)

    print(f"Running Apriori for K={K}, F={F}")
    start_time = time.time()
    frequent_itemsets = apriori(word_docs, K, F)

    elapsed = time.time() - start_time

    print(f"\nTime taken: {elapsed:.2f} seconds")

    if not frequent_itemsets:
        print("\nNo itemsets found.")
    else:
        print(f"\nTotal Frequent K-itemsets Found: {len(frequent_itemsets)}")
        print("Frequent K-itemsets:")
        for itemset, count in frequent_itemsets:
            print(f"Itemset: {tuple(vocab[word] for word in itemset)}, Count: {count}")

# %% [markdown]
# ## K = 2 and F = 2000

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=2000)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=2000
#
# Time taken: 9.55 seconds
#
# Total Frequent K-itemsets Found: 18
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008

# %% [markdown]
# ## K = 2 and F = 1900

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1900)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1900
#
# Time taken: 11.16 seconds
#
# Total Frequent K-itemsets Found: 26
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900

# %% [markdown]
# ## K = 2 and F = 1800

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1800)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1800
#
# Time taken: 12.90 seconds
#
# Total Frequent K-itemsets Found: 40
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801

# %% [markdown]
# ## K = 2 and F = 1700

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1700)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1700
#
# Time taken: 14.23 seconds
#
# Total Frequent K-itemsets Found: 69
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701

# %% [markdown]
# ## K = 2 and F = 1600

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1600)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1600
#
# Time taken: 17.29 seconds
#
# Total Frequent K-itemsets Found: 117
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601

# %% [markdown]
# ## K = 2 and F = 1500

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1500)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1500
#
# Time taken: 19.34 seconds
#
# Total Frequent K-itemsets Found: 202
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('california', 'utility'), Count: 1500

# %% [markdown]
# ## K = 2 and F = 1400

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1400)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1400
#
# Time taken: 20.74 seconds
#
# Total Frequent K-itemsets Found: 347
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('california', 'utility'), Count: 1500
# Itemset: ('meeting', 'set'), Count: 1499
# Itemset: ('business', 'financial'), Count: 1499
# Itemset: ('number', 'provide'), Count: 1499
# Itemset: ('companies', 'energy'), Count: 1495
# Itemset: ('point', 'think'), Count: 1494
# Itemset: ('number', 'report'), Count: 1493
# Itemset: ('help', 'power'), Count: 1491
# Itemset: ('bill', 'california'), Count: 1491
# Itemset: ('market', 'position'), Count: 1491
# Itemset: ('market', 'offer'), Count: 1490
# Itemset: ('going', 'number'), Count: 1490
# Itemset: ('california', 'meeting'), Count: 1488
# Itemset: ('company', 'corp'), Count: 1486
# Itemset: ('end', 'number'), Count: 1485
# Itemset: ('energy', 'utility'), Count: 1485
# Itemset: ('meeting', 'review'), Count: 1483
# Itemset: ('electricity', 'market'), Count: 1482
# Itemset: ('california', 'order'), Count: 1482
# Itemset: ('power', 'report'), Count: 1482
# Itemset: ('cost', 'including'), Count: 1481
# Itemset: ('group', 'member'), Count: 1481
# Itemset: ('provide', 'service'), Count: 1481
# Itemset: ('california', 'contract'), Count: 1480
# Itemset: ('feel', 'free'), Count: 1480
# Itemset: ('going', 'plan'), Count: 1480
# Itemset: ('business', 'price'), Count: 1480
# Itemset: ('cost', 'help'), Count: 1479
# Itemset: ('energy', 'part'), Count: 1479
# Itemset: ('including', 'plan'), Count: 1477
# Itemset: ('going', 'group'), Count: 1476
# Itemset: ('cost', 'high'), Count: 1475
# Itemset: ('california', 'provide'), Count: 1474
# Itemset: ('look', 'number'), Count: 1474
# Itemset: ('company', 'part'), Count: 1474
# Itemset: ('deal', 'price'), Count: 1473
# Itemset: ('customer', 'utility'), Count: 1473
# Itemset: ('deal', 'month'), Count: 1472
# Itemset: ('energy', 'including'), Count: 1471
# Itemset: ('cost', 'order'), Count: 1471
# Itemset: ('business', 'issues'), Count: 1470
# Itemset: ('going', 'month'), Count: 1468
# Itemset: ('plan', 'report'), Count: 1467
# Itemset: ('look', 'meeting'), Count: 1466
# Itemset: ('business', 'support'), Count: 1466
# Itemset: ('cost', 'end'), Count: 1466
# Itemset: ('california', 'help'), Count: 1465
# Itemset: ('customer', 'help'), Count: 1465
# Itemset: ('group', 'office'), Count: 1463
# Itemset: ('customer', 'number'), Count: 1463
# Itemset: ('business', 'think'), Count: 1462
# Itemset: ('number', 'power'), Count: 1460
# Itemset: ('business', 'current'), Count: 1459
# Itemset: ('group', 'service'), Count: 1458
# Itemset: ('company', 'financial'), Count: 1457
# Itemset: ('help', 'look'), Count: 1457
# Itemset: ('group', 'support'), Count: 1456
# Itemset: ('end', 'plan'), Count: 1456
# Itemset: ('going', 'market'), Count: 1456
# Itemset: ('california', 'issue'), Count: 1456
# Itemset: ('attached', 'review'), Count: 1455
# Itemset: ('part', 'power'), Count: 1454
# Itemset: ('order', 'service'), Count: 1454
# Itemset: ('california', 'number'), Count: 1454
# Itemset: ('cost', 'utility'), Count: 1453
# Itemset: ('power', 'problem'), Count: 1453
# Itemset: ('contract', 'month'), Count: 1452
# Itemset: ('customer', 'including'), Count: 1451
# Itemset: ('energy', 'help'), Count: 1451
# Itemset: ('energy', 'order'), Count: 1450
# Itemset: ('business', 'process'), Count: 1448
# Itemset: ('site', 'web'), Count: 1446
# Itemset: ('energy', 'issues'), Count: 1446
# Itemset: ('company', 'price'), Count: 1446
# Itemset: ('access', 'customer'), Count: 1445
# Itemset: ('group', 'services'), Count: 1444
# Itemset: ('corp', 'market'), Count: 1441
# Itemset: ('cost', 'prices'), Count: 1439
# Itemset: ('service', 'services'), Count: 1438
# Itemset: ('energy', 'states'), Count: 1438
# Itemset: ('month', 'part'), Count: 1438
# Itemset: ('help', 'report'), Count: 1437
# Itemset: ('meeting', 'report'), Count: 1437
# Itemset: ('including', 'service'), Count: 1437
# Itemset: ('give', 'going'), Count: 1437
# Itemset: ('california', 'high'), Count: 1436
# Itemset: ('high', 'power'), Count: 1436
# Itemset: ('company', 'deal'), Count: 1435
# Itemset: ('cost', 'think'), Count: 1435
# Itemset: ('end', 'help'), Count: 1432
# Itemset: ('group', 'team'), Count: 1430
# Itemset: ('market', 'utilities'), Count: 1429
# Itemset: ('help', 'including'), Count: 1428
# Itemset: ('forward', 'group'), Count: 1428
# Itemset: ('current', 'energy'), Count: 1428
# Itemset: ('price', 'process'), Count: 1427
# Itemset: ('current', 'group'), Count: 1427
# Itemset: ('including', 'month'), Count: 1426
# Itemset: ('meeting', 'working'), Count: 1425
# Itemset: ('california', 'problem'), Count: 1425
# Itemset: ('message', 'receive'), Count: 1425
# Itemset: ('company', 'current'), Count: 1425
# Itemset: ('issue', 'power'), Count: 1424
# Itemset: ('find', 'help'), Count: 1423
# Itemset: ('issue', 'plan'), Count: 1423
# Itemset: ('number', 'point'), Count: 1422
# Itemset: ('energy', 'number'), Count: 1421
# Itemset: ('business', 'order'), Count: 1421
# Itemset: ('attached', 'comment'), Count: 1419
# Itemset: ('going', 'meeting'), Count: 1418
# Itemset: ('including', 'report'), Count: 1418
# Itemset: ('forward', 'going'), Count: 1418
# Itemset: ('business', 'include'), Count: 1417
# Itemset: ('receive', 'review'), Count: 1417
# Itemset: ('power', 'service'), Count: 1417
# Itemset: ('date', 'price'), Count: 1417
# Itemset: ('issues', 'plan'), Count: 1417
# Itemset: ('part', 'plan'), Count: 1416
# Itemset: ('current', 'plan'), Count: 1416
# Itemset: ('gas', 'market'), Count: 1415
# Itemset: ('group', 'include'), Count: 1414
# Itemset: ('cost', 'rate'), Count: 1414
# Itemset: ('bill', 'power'), Count: 1414
# Itemset: ('market', 'public'), Count: 1413
# Itemset: ('energy', 'public'), Count: 1413
# Itemset: ('market', 'trading'), Count: 1411
# Itemset: ('order', 'price'), Count: 1411
# Itemset: ('going', 'power'), Count: 1410
# Itemset: ('cost', 'rates'), Count: 1410
# Itemset: ('think', 'thought'), Count: 1409
# Itemset: ('including', 'provide'), Count: 1408
# Itemset: ('company', 'industry'), Count: 1408
# Itemset: ('end', 'think'), Count: 1408
# Itemset: ('level', 'market'), Count: 1407
# Itemset: ('high', 'month'), Count: 1407
# Itemset: ('look', 'plan'), Count: 1406
# Itemset: ('number', 'order'), Count: 1405
# Itemset: ('california', 'service'), Count: 1405
# Itemset: ('group', 'process'), Count: 1403
# Itemset: ('meeting', 'monday'), Count: 1402
# Itemset: ('cost', 'going'), Count: 1402
# Itemset: ('california', 'including'), Count: 1401
# Itemset: ('office', 'plan'), Count: 1401
# Itemset: ('consumer', 'market'), Count: 1401
# Itemset: ('market', 'rates'), Count: 1400
# Itemset: ('companies', 'group'), Count: 1400

# %% [markdown]
# ## K = 2 and F = 1300

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1300)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1300
#
# Time taken: 23.30 seconds
#
# Total Frequent K-itemsets Found: 576
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('california', 'utility'), Count: 1500
# Itemset: ('meeting', 'set'), Count: 1499
# Itemset: ('business', 'financial'), Count: 1499
# Itemset: ('number', 'provide'), Count: 1499
# Itemset: ('companies', 'energy'), Count: 1495
# Itemset: ('point', 'think'), Count: 1494
# Itemset: ('number', 'report'), Count: 1493
# Itemset: ('help', 'power'), Count: 1491
# Itemset: ('bill', 'california'), Count: 1491
# Itemset: ('market', 'position'), Count: 1491
# Itemset: ('market', 'offer'), Count: 1490
# Itemset: ('going', 'number'), Count: 1490
# Itemset: ('california', 'meeting'), Count: 1488
# Itemset: ('company', 'corp'), Count: 1486
# Itemset: ('end', 'number'), Count: 1485
# Itemset: ('energy', 'utility'), Count: 1485
# Itemset: ('meeting', 'review'), Count: 1483
# Itemset: ('electricity', 'market'), Count: 1482
# Itemset: ('california', 'order'), Count: 1482
# Itemset: ('power', 'report'), Count: 1482
# Itemset: ('cost', 'including'), Count: 1481
# Itemset: ('group', 'member'), Count: 1481
# Itemset: ('provide', 'service'), Count: 1481
# Itemset: ('california', 'contract'), Count: 1480
# Itemset: ('feel', 'free'), Count: 1480
# Itemset: ('going', 'plan'), Count: 1480
# Itemset: ('business', 'price'), Count: 1480
# Itemset: ('cost', 'help'), Count: 1479
# Itemset: ('energy', 'part'), Count: 1479
# Itemset: ('including', 'plan'), Count: 1477
# Itemset: ('going', 'group'), Count: 1476
# Itemset: ('cost', 'high'), Count: 1475
# Itemset: ('california', 'provide'), Count: 1474
# Itemset: ('look', 'number'), Count: 1474
# Itemset: ('company', 'part'), Count: 1474
# Itemset: ('deal', 'price'), Count: 1473
# Itemset: ('customer', 'utility'), Count: 1473
# Itemset: ('deal', 'month'), Count: 1472
# Itemset: ('energy', 'including'), Count: 1471
# Itemset: ('cost', 'order'), Count: 1471
# Itemset: ('business', 'issues'), Count: 1470
# Itemset: ('going', 'month'), Count: 1468
# Itemset: ('plan', 'report'), Count: 1467
# Itemset: ('look', 'meeting'), Count: 1466
# Itemset: ('business', 'support'), Count: 1466
# Itemset: ('cost', 'end'), Count: 1466
# Itemset: ('california', 'help'), Count: 1465
# Itemset: ('customer', 'help'), Count: 1465
# Itemset: ('group', 'office'), Count: 1463
# Itemset: ('customer', 'number'), Count: 1463
# Itemset: ('business', 'think'), Count: 1462
# Itemset: ('number', 'power'), Count: 1460
# Itemset: ('business', 'current'), Count: 1459
# Itemset: ('group', 'service'), Count: 1458
# Itemset: ('company', 'financial'), Count: 1457
# Itemset: ('help', 'look'), Count: 1457
# Itemset: ('group', 'support'), Count: 1456
# Itemset: ('end', 'plan'), Count: 1456
# Itemset: ('going', 'market'), Count: 1456
# Itemset: ('california', 'issue'), Count: 1456
# Itemset: ('attached', 'review'), Count: 1455
# Itemset: ('part', 'power'), Count: 1454
# Itemset: ('order', 'service'), Count: 1454
# Itemset: ('california', 'number'), Count: 1454
# Itemset: ('cost', 'utility'), Count: 1453
# Itemset: ('power', 'problem'), Count: 1453
# Itemset: ('contract', 'month'), Count: 1452
# Itemset: ('customer', 'including'), Count: 1451
# Itemset: ('energy', 'help'), Count: 1451
# Itemset: ('energy', 'order'), Count: 1450
# Itemset: ('business', 'process'), Count: 1448
# Itemset: ('site', 'web'), Count: 1446
# Itemset: ('energy', 'issues'), Count: 1446
# Itemset: ('company', 'price'), Count: 1446
# Itemset: ('access', 'customer'), Count: 1445
# Itemset: ('group', 'services'), Count: 1444
# Itemset: ('corp', 'market'), Count: 1441
# Itemset: ('cost', 'prices'), Count: 1439
# Itemset: ('service', 'services'), Count: 1438
# Itemset: ('energy', 'states'), Count: 1438
# Itemset: ('month', 'part'), Count: 1438
# Itemset: ('help', 'report'), Count: 1437
# Itemset: ('meeting', 'report'), Count: 1437
# Itemset: ('including', 'service'), Count: 1437
# Itemset: ('give', 'going'), Count: 1437
# Itemset: ('california', 'high'), Count: 1436
# Itemset: ('high', 'power'), Count: 1436
# Itemset: ('company', 'deal'), Count: 1435
# Itemset: ('cost', 'think'), Count: 1435
# Itemset: ('end', 'help'), Count: 1432
# Itemset: ('group', 'team'), Count: 1430
# Itemset: ('market', 'utilities'), Count: 1429
# Itemset: ('help', 'including'), Count: 1428
# Itemset: ('forward', 'group'), Count: 1428
# Itemset: ('current', 'energy'), Count: 1428
# Itemset: ('price', 'process'), Count: 1427
# Itemset: ('current', 'group'), Count: 1427
# Itemset: ('including', 'month'), Count: 1426
# Itemset: ('meeting', 'working'), Count: 1425
# Itemset: ('california', 'problem'), Count: 1425
# Itemset: ('message', 'receive'), Count: 1425
# Itemset: ('company', 'current'), Count: 1425
# Itemset: ('issue', 'power'), Count: 1424
# Itemset: ('find', 'help'), Count: 1423
# Itemset: ('issue', 'plan'), Count: 1423
# Itemset: ('number', 'point'), Count: 1422
# Itemset: ('energy', 'number'), Count: 1421
# Itemset: ('business', 'order'), Count: 1421
# Itemset: ('attached', 'comment'), Count: 1419
# Itemset: ('going', 'meeting'), Count: 1418
# Itemset: ('including', 'report'), Count: 1418
# Itemset: ('forward', 'going'), Count: 1418
# Itemset: ('business', 'include'), Count: 1417
# Itemset: ('receive', 'review'), Count: 1417
# Itemset: ('power', 'service'), Count: 1417
# Itemset: ('date', 'price'), Count: 1417
# Itemset: ('issues', 'plan'), Count: 1417
# Itemset: ('part', 'plan'), Count: 1416
# Itemset: ('current', 'plan'), Count: 1416
# Itemset: ('gas', 'market'), Count: 1415
# Itemset: ('group', 'include'), Count: 1414
# Itemset: ('cost', 'rate'), Count: 1414
# Itemset: ('bill', 'power'), Count: 1414
# Itemset: ('market', 'public'), Count: 1413
# Itemset: ('energy', 'public'), Count: 1413
# Itemset: ('market', 'trading'), Count: 1411
# Itemset: ('order', 'price'), Count: 1411
# Itemset: ('going', 'power'), Count: 1410
# Itemset: ('cost', 'rates'), Count: 1410
# Itemset: ('think', 'thought'), Count: 1409
# Itemset: ('including', 'provide'), Count: 1408
# Itemset: ('company', 'industry'), Count: 1408
# Itemset: ('end', 'think'), Count: 1408
# Itemset: ('level', 'market'), Count: 1407
# Itemset: ('high', 'month'), Count: 1407
# Itemset: ('look', 'plan'), Count: 1406
# Itemset: ('number', 'order'), Count: 1405
# Itemset: ('california', 'service'), Count: 1405
# Itemset: ('group', 'process'), Count: 1403
# Itemset: ('meeting', 'monday'), Count: 1402
# Itemset: ('cost', 'going'), Count: 1402
# Itemset: ('california', 'including'), Count: 1401
# Itemset: ('office', 'plan'), Count: 1401
# Itemset: ('consumer', 'market'), Count: 1401
# Itemset: ('market', 'rates'), Count: 1400
# Itemset: ('companies', 'group'), Count: 1400
# Itemset: ('meeting', 'power'), Count: 1399
# Itemset: ('california', 'report'), Count: 1398
# Itemset: ('friday', 'meeting'), Count: 1398
# Itemset: ('market', 'utility'), Count: 1397
# Itemset: ('comment', 'review'), Count: 1397
# Itemset: ('attached', 'file'), Count: 1396
# Itemset: ('energy', 'industry'), Count: 1396
# Itemset: ('issues', 'power'), Count: 1395
# Itemset: ('end', 'going'), Count: 1395
# Itemset: ('look', 'thing'), Count: 1395
# Itemset: ('power', 'think'), Count: 1395
# Itemset: ('business', 'industry'), Count: 1395
# Itemset: ('problem', 'think'), Count: 1395
# Itemset: ('buy', 'market'), Count: 1392
# Itemset: ('business', 'look'), Count: 1392
# Itemset: ('cost', 'pay'), Count: 1392
# Itemset: ('give', 'help'), Count: 1391
# Itemset: ('business', 'end'), Count: 1390
# Itemset: ('corp', 'review'), Count: 1388
# Itemset: ('put', 'think'), Count: 1387
# Itemset: ('business', 'offer'), Count: 1387
# Itemset: ('market', 'supply'), Count: 1387
# Itemset: ('california', 'think'), Count: 1387
# Itemset: ('find', 'market'), Count: 1386
# Itemset: ('company', 'contract'), Count: 1386
# Itemset: ('interest', 'market'), Count: 1385
# Itemset: ('issues', 'think'), Count: 1384
# Itemset: ('meeting', 'process'), Count: 1384
# Itemset: ('market', 'rate'), Count: 1384
# Itemset: ('companies', 'power'), Count: 1383
# Itemset: ('market', 'process'), Count: 1383
# Itemset: ('energy', 'high'), Count: 1382
# Itemset: ('include', 'including'), Count: 1382
# Itemset: ('number', 'price'), Count: 1382
# Itemset: ('deal', 'think'), Count: 1381
# Itemset: ('deal', 'plan'), Count: 1381
# Itemset: ('customer', 'issue'), Count: 1381
# Itemset: ('group', 'order'), Count: 1380
# Itemset: ('group', 'point'), Count: 1380
# Itemset: ('issues', 'provide'), Count: 1379
# Itemset: ('cost', 'report'), Count: 1379
# Itemset: ('help', 'support'), Count: 1379
# Itemset: ('price', 'report'), Count: 1379
# Itemset: ('give', 'number'), Count: 1378
# Itemset: ('high', 'price'), Count: 1378
# Itemset: ('california', 'issues'), Count: 1377
# Itemset: ('meet', 'meeting'), Count: 1377
# Itemset: ('attached', 'meeting'), Count: 1376
# Itemset: ('contract', 'price'), Count: 1376
# Itemset: ('cost', 'current'), Count: 1376
# Itemset: ('energy', 'issue'), Count: 1376
# Itemset: ('provide', 'report'), Count: 1375
# Itemset: ('find', 'think'), Count: 1375
# Itemset: ('deal', 'help'), Count: 1375
# Itemset: ('cost', 'issue'), Count: 1374
# Itemset: ('corp', 'offer'), Count: 1374
# Itemset: ('business', 'working'), Count: 1373
# Itemset: ('group', 'set'), Count: 1373
# Itemset: ('cost', 'deal'), Count: 1372
# Itemset: ('effort', 'group'), Count: 1371
# Itemset: ('deal', 'energy'), Count: 1368
# Itemset: ('bill', 'customer'), Count: 1367
# Itemset: ('current', 'month'), Count: 1366
# Itemset: ('free', 'offer'), Count: 1366
# Itemset: ('going', 'sure'), Count: 1366
# Itemset: ('forward', 'think'), Count: 1365
# Itemset: ('demand', 'power'), Count: 1364
# Itemset: ('end', 'power'), Count: 1364
# Itemset: ('additional', 'market'), Count: 1363
# Itemset: ('market', 'states'), Count: 1363
# Itemset: ('cost', 'states'), Count: 1363
# Itemset: ('customer', 'end'), Count: 1363
# Itemset: ('report', 'service'), Count: 1362
# Itemset: ('group', 'price'), Count: 1362
# Itemset: ('give', 'group'), Count: 1361
# Itemset: ('current', 'report'), Count: 1361
# Itemset: ('access', 'market'), Count: 1361
# Itemset: ('end', 'report'), Count: 1360
# Itemset: ('meeting', 'provide'), Count: 1360
# Itemset: ('bill', 'cost'), Count: 1360
# Itemset: ('group', 'issue'), Count: 1359
# Itemset: ('market', 'risk'), Count: 1359
# Itemset: ('issues', 'number'), Count: 1356
# Itemset: ('date', 'process'), Count: 1356
# Itemset: ('california', 'comment'), Count: 1356
# Itemset: ('plan', 'price'), Count: 1356
# Itemset: ('cost', 'part'), Count: 1355
# Itemset: ('billion', 'company'), Count: 1355
# Itemset: ('help', 'service'), Count: 1355
# Itemset: ('date', 'number'), Count: 1355
# Itemset: ('california', 'point'), Count: 1354
# Itemset: ('price', 'start'), Count: 1354
# Itemset: ('point', 'power'), Count: 1354
# Itemset: ('billion', 'market'), Count: 1353
# Itemset: ('company', 'offer'), Count: 1353
# Itemset: ('end', 'service'), Count: 1353
# Itemset: ('including', 'number'), Count: 1353
# Itemset: ('comment', 'group'), Count: 1352
# Itemset: ('basis', 'contract'), Count: 1351
# Itemset: ('including', 'part'), Count: 1351
# Itemset: ('plan', 'set'), Count: 1349
# Itemset: ('group', 'review'), Count: 1349
# Itemset: ('bill', 'market'), Count: 1348
# Itemset: ('provide', 'services'), Count: 1348
# Itemset: ('business', 'point'), Count: 1348
# Itemset: ('end', 'meeting'), Count: 1348
# Itemset: ('address', 'market'), Count: 1348
# Itemset: ('forward', 'power'), Count: 1347
# Itemset: ('decision', 'market'), Count: 1346
# Itemset: ('corp', 'energy'), Count: 1346
# Itemset: ('market', 'member'), Count: 1345
# Itemset: ('number', 'part'), Count: 1345
# Itemset: ('business', 'issue'), Count: 1344
# Itemset: ('help', 'price'), Count: 1344
# Itemset: ('california', 'end'), Count: 1344
# Itemset: ('california', 'californias'), Count: 1344
# Itemset: ('part', 'report'), Count: 1343
# Itemset: ('customer', 'services'), Count: 1343
# Itemset: ('number', 'set'), Count: 1343
# Itemset: ('issue', 'month'), Count: 1343
# Itemset: ('market', 'sell'), Count: 1342
# Itemset: ('california', 'public'), Count: 1342
# Itemset: ('gas', 'power'), Count: 1342
# Itemset: ('contract', 'deal'), Count: 1341
# Itemset: ('companies', 'month'), Count: 1341
# Itemset: ('contract', 'receive'), Count: 1340
# Itemset: ('offer', 'review'), Count: 1339
# Itemset: ('cost', 'utilities'), Count: 1339
# Itemset: ('help', 'process'), Count: 1339
# Itemset: ('market', 'product'), Count: 1338
# Itemset: ('customer', 'prices'), Count: 1337
# Itemset: ('continue', 'market'), Count: 1337
# Itemset: ('business', 'management'), Count: 1337
# Itemset: ('change', 'company'), Count: 1337
# Itemset: ('energy', 'include'), Count: 1337
# Itemset: ('cost', 'set'), Count: 1336
# Itemset: ('help', 'working'), Count: 1336
# Itemset: ('contract', 'plan'), Count: 1336
# Itemset: ('power', 'public'), Count: 1335
# Itemset: ('help', 'point'), Count: 1335
# Itemset: ('month', 'prices'), Count: 1335
# Itemset: ('customer', 'support'), Count: 1335
# Itemset: ('month', 'provide'), Count: 1335
# Itemset: ('customer', 'part'), Count: 1334
# Itemset: ('price', 'service'), Count: 1332
# Itemset: ('california', 'part'), Count: 1332
# Itemset: ('california', 'rates'), Count: 1332
# Itemset: ('corp', 'receive'), Count: 1332
# Itemset: ('contract', 'group'), Count: 1332
# Itemset: ('help', 'sure'), Count: 1331
# Itemset: ('current', 'provide'), Count: 1331
# Itemset: ('help', 'problem'), Count: 1330
# Itemset: ('contract', 'service'), Count: 1330
# Itemset: ('end', 'price'), Count: 1330
# Itemset: ('meeting', 'month'), Count: 1330
# Itemset: ('cost', 'problem'), Count: 1329
# Itemset: ('order', 'report'), Count: 1328
# Itemset: ('customer', 'pay'), Count: 1327
# Itemset: ('forward', 'number'), Count: 1327
# Itemset: ('energy', 'think'), Count: 1327
# Itemset: ('month', 'point'), Count: 1327
# Itemset: ('business', 'going'), Count: 1327
# Itemset: ('company', 'order'), Count: 1327
# Itemset: ('company', 'end'), Count: 1326
# Itemset: ('cost', 'electricity'), Count: 1326
# Itemset: ('business', 'contract'), Count: 1325
# Itemset: ('business', 'set'), Count: 1325
# Itemset: ('cost', 'point'), Count: 1324
# Itemset: ('customer', 'include'), Count: 1324
# Itemset: ('companies', 'plan'), Count: 1323
# Itemset: ('customer', 'rate'), Count: 1323
# Itemset: ('business', 'result'), Count: 1323
# Itemset: ('rate', 'rates'), Count: 1322
# Itemset: ('message', 'review'), Count: 1322
# Itemset: ('corp', 'group'), Count: 1322
# Itemset: ('business', 'change'), Count: 1322
# Itemset: ('corp', 'power'), Count: 1322
# Itemset: ('energy', 'forward'), Count: 1321
# Itemset: ('pay', 'power'), Count: 1321
# Itemset: ('power', 'rates'), Count: 1320
# Itemset: ('demand', 'energy'), Count: 1320
# Itemset: ('consumer', 'power'), Count: 1320
# Itemset: ('company', 'high'), Count: 1319
# Itemset: ('plan', 'point'), Count: 1319
# Itemset: ('month', 'order'), Count: 1318
# Itemset: ('part', 'service'), Count: 1317
# Itemset: ('current', 'power'), Count: 1317
# Itemset: ('companies', 'customer'), Count: 1316
# Itemset: ('look', 'month'), Count: 1316
# Itemset: ('cost', 'meeting'), Count: 1316
# Itemset: ('customer', 'meeting'), Count: 1316
# Itemset: ('due', 'report'), Count: 1315
# Itemset: ('cost', 'include'), Count: 1315
# Itemset: ('customer', 'offer'), Count: 1314
# Itemset: ('help', 'issues'), Count: 1314
# Itemset: ('help', 'team'), Count: 1314
# Itemset: ('issues', 'report'), Count: 1314
# Itemset: ('investment', 'market'), Count: 1314
# Itemset: ('month', 'problem'), Count: 1313
# Itemset: ('issue', 'think'), Count: 1312
# Itemset: ('meeting', 'point'), Count: 1312
# Itemset: ('energy', 'process'), Count: 1312
# Itemset: ('forward', 'help'), Count: 1312
# Itemset: ('message', 'offer'), Count: 1311
# Itemset: ('california', 'consumer'), Count: 1310
# Itemset: ('company', 'look'), Count: 1310
# Itemset: ('plan', 'support'), Count: 1309
# Itemset: ('going', 'point'), Count: 1309
# Itemset: ('high', 'prices'), Count: 1309
# Itemset: ('order', 'provide'), Count: 1308
# Itemset: ('bill', 'plan'), Count: 1307
# Itemset: ('price', 'think'), Count: 1306
# Itemset: ('issue', 'order'), Count: 1306
# Itemset: ('data', 'process'), Count: 1306
# Itemset: ('date', 'start'), Count: 1306
# Itemset: ('issues', 'order'), Count: 1305
# Itemset: ('energy', 'problem'), Count: 1305
# Itemset: ('california', 'rate'), Count: 1304
# Itemset: ('california', 'going'), Count: 1303
# Itemset: ('power', 'set'), Count: 1303
# Itemset: ('future', 'market'), Count: 1303
# Itemset: ('energy', 'financial'), Count: 1302
# Itemset: ('order', 'plan'), Count: 1302
# Itemset: ('cost', 'issues'), Count: 1301
# Itemset: ('month', 'set'), Count: 1301
# Itemset: ('process', 'provide'), Count: 1301
# Itemset: ('cost', 'look'), Count: 1300
# Itemset: ('think', 'working'), Count: 1300
# Itemset: ('number', 'problem'), Count: 1300

# %% [markdown]
# ## K = 2 and F = 1200

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1200)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1200
#
# Time taken: 32.79 seconds
#
# Total Frequent K-itemsets Found: 964
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('california', 'utility'), Count: 1500
# Itemset: ('meeting', 'set'), Count: 1499
# Itemset: ('business', 'financial'), Count: 1499
# Itemset: ('number', 'provide'), Count: 1499
# Itemset: ('companies', 'energy'), Count: 1495
# Itemset: ('point', 'think'), Count: 1494
# Itemset: ('number', 'report'), Count: 1493
# Itemset: ('market', 'position'), Count: 1491
# Itemset: ('help', 'power'), Count: 1491
# Itemset: ('bill', 'california'), Count: 1491
# Itemset: ('market', 'offer'), Count: 1490
# Itemset: ('going', 'number'), Count: 1490
# Itemset: ('california', 'meeting'), Count: 1488
# Itemset: ('company', 'corp'), Count: 1486
# Itemset: ('end', 'number'), Count: 1485
# Itemset: ('energy', 'utility'), Count: 1485
# Itemset: ('meeting', 'review'), Count: 1483
# Itemset: ('electricity', 'market'), Count: 1482
# Itemset: ('power', 'report'), Count: 1482
# Itemset: ('california', 'order'), Count: 1482
# Itemset: ('cost', 'including'), Count: 1481
# Itemset: ('group', 'member'), Count: 1481
# Itemset: ('provide', 'service'), Count: 1481
# Itemset: ('feel', 'free'), Count: 1480
# Itemset: ('going', 'plan'), Count: 1480
# Itemset: ('california', 'contract'), Count: 1480
# Itemset: ('business', 'price'), Count: 1480
# Itemset: ('energy', 'part'), Count: 1479
# Itemset: ('cost', 'help'), Count: 1479
# Itemset: ('including', 'plan'), Count: 1477
# Itemset: ('going', 'group'), Count: 1476
# Itemset: ('cost', 'high'), Count: 1475
# Itemset: ('california', 'provide'), Count: 1474
# Itemset: ('look', 'number'), Count: 1474
# Itemset: ('company', 'part'), Count: 1474
# Itemset: ('deal', 'price'), Count: 1473
# Itemset: ('customer', 'utility'), Count: 1473
# Itemset: ('deal', 'month'), Count: 1472
# Itemset: ('energy', 'including'), Count: 1471
# Itemset: ('cost', 'order'), Count: 1471
# Itemset: ('business', 'issues'), Count: 1470
# Itemset: ('going', 'month'), Count: 1468
# Itemset: ('plan', 'report'), Count: 1467
# Itemset: ('cost', 'end'), Count: 1466
# Itemset: ('look', 'meeting'), Count: 1466
# Itemset: ('business', 'support'), Count: 1466
# Itemset: ('california', 'help'), Count: 1465
# Itemset: ('customer', 'help'), Count: 1465
# Itemset: ('group', 'office'), Count: 1463
# Itemset: ('customer', 'number'), Count: 1463
# Itemset: ('business', 'think'), Count: 1462
# Itemset: ('number', 'power'), Count: 1460
# Itemset: ('business', 'current'), Count: 1459
# Itemset: ('group', 'service'), Count: 1458
# Itemset: ('company', 'financial'), Count: 1457
# Itemset: ('help', 'look'), Count: 1457
# Itemset: ('group', 'support'), Count: 1456
# Itemset: ('end', 'plan'), Count: 1456
# Itemset: ('going', 'market'), Count: 1456
# Itemset: ('california', 'issue'), Count: 1456
# Itemset: ('attached', 'review'), Count: 1455
# Itemset: ('order', 'service'), Count: 1454
# Itemset: ('part', 'power'), Count: 1454
# Itemset: ('california', 'number'), Count: 1454
# Itemset: ('cost', 'utility'), Count: 1453
# Itemset: ('power', 'problem'), Count: 1453
# Itemset: ('contract', 'month'), Count: 1452
# Itemset: ('customer', 'including'), Count: 1451
# Itemset: ('energy', 'help'), Count: 1451
# Itemset: ('energy', 'order'), Count: 1450
# Itemset: ('business', 'process'), Count: 1448
# Itemset: ('energy', 'issues'), Count: 1446
# Itemset: ('company', 'price'), Count: 1446
# Itemset: ('site', 'web'), Count: 1446
# Itemset: ('access', 'customer'), Count: 1445
# Itemset: ('group', 'services'), Count: 1444
# Itemset: ('corp', 'market'), Count: 1441
# Itemset: ('cost', 'prices'), Count: 1439
# Itemset: ('month', 'part'), Count: 1438
# Itemset: ('service', 'services'), Count: 1438
# Itemset: ('energy', 'states'), Count: 1438
# Itemset: ('help', 'report'), Count: 1437
# Itemset: ('meeting', 'report'), Count: 1437
# Itemset: ('give', 'going'), Count: 1437
# Itemset: ('including', 'service'), Count: 1437
# Itemset: ('california', 'high'), Count: 1436
# Itemset: ('high', 'power'), Count: 1436
# Itemset: ('company', 'deal'), Count: 1435
# Itemset: ('cost', 'think'), Count: 1435
# Itemset: ('end', 'help'), Count: 1432
# Itemset: ('group', 'team'), Count: 1430
# Itemset: ('market', 'utilities'), Count: 1429
# Itemset: ('help', 'including'), Count: 1428
# Itemset: ('forward', 'group'), Count: 1428
# Itemset: ('current', 'energy'), Count: 1428
# Itemset: ('price', 'process'), Count: 1427
# Itemset: ('current', 'group'), Count: 1427
# Itemset: ('including', 'month'), Count: 1426
# Itemset: ('meeting', 'working'), Count: 1425
# Itemset: ('california', 'problem'), Count: 1425
# Itemset: ('message', 'receive'), Count: 1425
# Itemset: ('company', 'current'), Count: 1425
# Itemset: ('issue', 'power'), Count: 1424
# Itemset: ('find', 'help'), Count: 1423
# Itemset: ('issue', 'plan'), Count: 1423
# Itemset: ('number', 'point'), Count: 1422
# Itemset: ('energy', 'number'), Count: 1421
# Itemset: ('business', 'order'), Count: 1421
# Itemset: ('attached', 'comment'), Count: 1419
# Itemset: ('going', 'meeting'), Count: 1418
# Itemset: ('including', 'report'), Count: 1418
# Itemset: ('forward', 'going'), Count: 1418
# Itemset: ('business', 'include'), Count: 1417
# Itemset: ('receive', 'review'), Count: 1417
# Itemset: ('power', 'service'), Count: 1417
# Itemset: ('date', 'price'), Count: 1417
# Itemset: ('issues', 'plan'), Count: 1417
# Itemset: ('part', 'plan'), Count: 1416
# Itemset: ('current', 'plan'), Count: 1416
# Itemset: ('gas', 'market'), Count: 1415
# Itemset: ('group', 'include'), Count: 1414
# Itemset: ('cost', 'rate'), Count: 1414
# Itemset: ('bill', 'power'), Count: 1414
# Itemset: ('energy', 'public'), Count: 1413
# Itemset: ('market', 'public'), Count: 1413
# Itemset: ('market', 'trading'), Count: 1411
# Itemset: ('order', 'price'), Count: 1411
# Itemset: ('going', 'power'), Count: 1410
# Itemset: ('cost', 'rates'), Count: 1410
# Itemset: ('think', 'thought'), Count: 1409
# Itemset: ('end', 'think'), Count: 1408
# Itemset: ('including', 'provide'), Count: 1408
# Itemset: ('company', 'industry'), Count: 1408
# Itemset: ('level', 'market'), Count: 1407
# Itemset: ('high', 'month'), Count: 1407
# Itemset: ('look', 'plan'), Count: 1406
# Itemset: ('number', 'order'), Count: 1405
# Itemset: ('california', 'service'), Count: 1405
# Itemset: ('group', 'process'), Count: 1403
# Itemset: ('cost', 'going'), Count: 1402
# Itemset: ('meeting', 'monday'), Count: 1402
# Itemset: ('california', 'including'), Count: 1401
# Itemset: ('office', 'plan'), Count: 1401
# Itemset: ('consumer', 'market'), Count: 1401
# Itemset: ('market', 'rates'), Count: 1400
# Itemset: ('companies', 'group'), Count: 1400
# Itemset: ('meeting', 'power'), Count: 1399
# Itemset: ('california', 'report'), Count: 1398
# Itemset: ('friday', 'meeting'), Count: 1398
# Itemset: ('market', 'utility'), Count: 1397
# Itemset: ('comment', 'review'), Count: 1397
# Itemset: ('energy', 'industry'), Count: 1396
# Itemset: ('attached', 'file'), Count: 1396
# Itemset: ('power', 'think'), Count: 1395
# Itemset: ('problem', 'think'), Count: 1395
# Itemset: ('issues', 'power'), Count: 1395
# Itemset: ('end', 'going'), Count: 1395
# Itemset: ('look', 'thing'), Count: 1395
# Itemset: ('business', 'industry'), Count: 1395
# Itemset: ('buy', 'market'), Count: 1392
# Itemset: ('business', 'look'), Count: 1392
# Itemset: ('cost', 'pay'), Count: 1392
# Itemset: ('give', 'help'), Count: 1391
# Itemset: ('business', 'end'), Count: 1390
# Itemset: ('corp', 'review'), Count: 1388
# Itemset: ('put', 'think'), Count: 1387
# Itemset: ('business', 'offer'), Count: 1387
# Itemset: ('market', 'supply'), Count: 1387
# Itemset: ('california', 'think'), Count: 1387
# Itemset: ('find', 'market'), Count: 1386
# Itemset: ('company', 'contract'), Count: 1386
# Itemset: ('interest', 'market'), Count: 1385
# Itemset: ('issues', 'think'), Count: 1384
# Itemset: ('meeting', 'process'), Count: 1384
# Itemset: ('market', 'rate'), Count: 1384
# Itemset: ('companies', 'power'), Count: 1383
# Itemset: ('market', 'process'), Count: 1383
# Itemset: ('include', 'including'), Count: 1382
# Itemset: ('energy', 'high'), Count: 1382
# Itemset: ('number', 'price'), Count: 1382
# Itemset: ('deal', 'think'), Count: 1381
# Itemset: ('deal', 'plan'), Count: 1381
# Itemset: ('customer', 'issue'), Count: 1381
# Itemset: ('group', 'order'), Count: 1380
# Itemset: ('group', 'point'), Count: 1380
# Itemset: ('cost', 'report'), Count: 1379
# Itemset: ('help', 'support'), Count: 1379
# Itemset: ('price', 'report'), Count: 1379
# Itemset: ('issues', 'provide'), Count: 1379
# Itemset: ('give', 'number'), Count: 1378
# Itemset: ('high', 'price'), Count: 1378
# Itemset: ('california', 'issues'), Count: 1377
# Itemset: ('meet', 'meeting'), Count: 1377
# Itemset: ('attached', 'meeting'), Count: 1376
# Itemset: ('contract', 'price'), Count: 1376
# Itemset: ('cost', 'current'), Count: 1376
# Itemset: ('energy', 'issue'), Count: 1376
# Itemset: ('find', 'think'), Count: 1375
# Itemset: ('provide', 'report'), Count: 1375
# Itemset: ('deal', 'help'), Count: 1375
# Itemset: ('cost', 'issue'), Count: 1374
# Itemset: ('corp', 'offer'), Count: 1374
# Itemset: ('business', 'working'), Count: 1373
# Itemset: ('group', 'set'), Count: 1373
# Itemset: ('cost', 'deal'), Count: 1372
# Itemset: ('effort', 'group'), Count: 1371
# Itemset: ('deal', 'energy'), Count: 1368
# Itemset: ('bill', 'customer'), Count: 1367
# Itemset: ('going', 'sure'), Count: 1366
# Itemset: ('current', 'month'), Count: 1366
# Itemset: ('free', 'offer'), Count: 1366
# Itemset: ('forward', 'think'), Count: 1365
# Itemset: ('demand', 'power'), Count: 1364
# Itemset: ('end', 'power'), Count: 1364
# Itemset: ('cost', 'states'), Count: 1363
# Itemset: ('additional', 'market'), Count: 1363
# Itemset: ('market', 'states'), Count: 1363
# Itemset: ('customer', 'end'), Count: 1363
# Itemset: ('group', 'price'), Count: 1362
# Itemset: ('report', 'service'), Count: 1362
# Itemset: ('give', 'group'), Count: 1361
# Itemset: ('current', 'report'), Count: 1361
# Itemset: ('access', 'market'), Count: 1361
# Itemset: ('end', 'report'), Count: 1360
# Itemset: ('meeting', 'provide'), Count: 1360
# Itemset: ('bill', 'cost'), Count: 1360
# Itemset: ('group', 'issue'), Count: 1359
# Itemset: ('market', 'risk'), Count: 1359
# Itemset: ('issues', 'number'), Count: 1356
# Itemset: ('plan', 'price'), Count: 1356
# Itemset: ('date', 'process'), Count: 1356
# Itemset: ('california', 'comment'), Count: 1356
# Itemset: ('cost', 'part'), Count: 1355
# Itemset: ('billion', 'company'), Count: 1355
# Itemset: ('help', 'service'), Count: 1355
# Itemset: ('date', 'number'), Count: 1355
# Itemset: ('california', 'point'), Count: 1354
# Itemset: ('price', 'start'), Count: 1354
# Itemset: ('point', 'power'), Count: 1354
# Itemset: ('company', 'offer'), Count: 1353
# Itemset: ('end', 'service'), Count: 1353
# Itemset: ('billion', 'market'), Count: 1353
# Itemset: ('including', 'number'), Count: 1353
# Itemset: ('comment', 'group'), Count: 1352
# Itemset: ('basis', 'contract'), Count: 1351
# Itemset: ('including', 'part'), Count: 1351
# Itemset: ('plan', 'set'), Count: 1349
# Itemset: ('group', 'review'), Count: 1349
# Itemset: ('bill', 'market'), Count: 1348
# Itemset: ('end', 'meeting'), Count: 1348
# Itemset: ('provide', 'services'), Count: 1348
# Itemset: ('business', 'point'), Count: 1348
# Itemset: ('address', 'market'), Count: 1348
# Itemset: ('forward', 'power'), Count: 1347
# Itemset: ('corp', 'energy'), Count: 1346
# Itemset: ('decision', 'market'), Count: 1346
# Itemset: ('number', 'part'), Count: 1345
# Itemset: ('market', 'member'), Count: 1345
# Itemset: ('business', 'issue'), Count: 1344
# Itemset: ('california', 'end'), Count: 1344
# Itemset: ('california', 'californias'), Count: 1344
# Itemset: ('help', 'price'), Count: 1344
# Itemset: ('part', 'report'), Count: 1343
# Itemset: ('issue', 'month'), Count: 1343
# Itemset: ('customer', 'services'), Count: 1343
# Itemset: ('number', 'set'), Count: 1343
# Itemset: ('market', 'sell'), Count: 1342
# Itemset: ('california', 'public'), Count: 1342
# Itemset: ('gas', 'power'), Count: 1342
# Itemset: ('contract', 'deal'), Count: 1341
# Itemset: ('companies', 'month'), Count: 1341
# Itemset: ('contract', 'receive'), Count: 1340
# Itemset: ('help', 'process'), Count: 1339
# Itemset: ('offer', 'review'), Count: 1339
# Itemset: ('cost', 'utilities'), Count: 1339
# Itemset: ('market', 'product'), Count: 1338
# Itemset: ('customer', 'prices'), Count: 1337
# Itemset: ('continue', 'market'), Count: 1337
# Itemset: ('business', 'management'), Count: 1337
# Itemset: ('change', 'company'), Count: 1337
# Itemset: ('energy', 'include'), Count: 1337
# Itemset: ('cost', 'set'), Count: 1336
# Itemset: ('contract', 'plan'), Count: 1336
# Itemset: ('help', 'working'), Count: 1336
# Itemset: ('help', 'point'), Count: 1335
# Itemset: ('month', 'provide'), Count: 1335
# Itemset: ('power', 'public'), Count: 1335
# Itemset: ('month', 'prices'), Count: 1335
# Itemset: ('customer', 'support'), Count: 1335
# Itemset: ('customer', 'part'), Count: 1334
# Itemset: ('price', 'service'), Count: 1332
# Itemset: ('california', 'part'), Count: 1332
# Itemset: ('california', 'rates'), Count: 1332
# Itemset: ('corp', 'receive'), Count: 1332
# Itemset: ('contract', 'group'), Count: 1332
# Itemset: ('help', 'sure'), Count: 1331
# Itemset: ('current', 'provide'), Count: 1331
# Itemset: ('help', 'problem'), Count: 1330
# Itemset: ('meeting', 'month'), Count: 1330
# Itemset: ('contract', 'service'), Count: 1330
# Itemset: ('end', 'price'), Count: 1330
# Itemset: ('cost', 'problem'), Count: 1329
# Itemset: ('order', 'report'), Count: 1328
# Itemset: ('forward', 'number'), Count: 1327
# Itemset: ('month', 'point'), Count: 1327
# Itemset: ('customer', 'pay'), Count: 1327
# Itemset: ('energy', 'think'), Count: 1327
# Itemset: ('business', 'going'), Count: 1327
# Itemset: ('company', 'order'), Count: 1327
# Itemset: ('cost', 'electricity'), Count: 1326
# Itemset: ('company', 'end'), Count: 1326
# Itemset: ('business', 'contract'), Count: 1325
# Itemset: ('business', 'set'), Count: 1325
# Itemset: ('cost', 'point'), Count: 1324
# Itemset: ('customer', 'include'), Count: 1324
# Itemset: ('companies', 'plan'), Count: 1323
# Itemset: ('customer', 'rate'), Count: 1323
# Itemset: ('business', 'result'), Count: 1323
# Itemset: ('rate', 'rates'), Count: 1322
# Itemset: ('message', 'review'), Count: 1322
# Itemset: ('corp', 'group'), Count: 1322
# Itemset: ('business', 'change'), Count: 1322
# Itemset: ('corp', 'power'), Count: 1322
# Itemset: ('pay', 'power'), Count: 1321
# Itemset: ('energy', 'forward'), Count: 1321
# Itemset: ('power', 'rates'), Count: 1320
# Itemset: ('demand', 'energy'), Count: 1320
# Itemset: ('consumer', 'power'), Count: 1320
# Itemset: ('company', 'high'), Count: 1319
# Itemset: ('plan', 'point'), Count: 1319
# Itemset: ('month', 'order'), Count: 1318
# Itemset: ('part', 'service'), Count: 1317
# Itemset: ('current', 'power'), Count: 1317
# Itemset: ('companies', 'customer'), Count: 1316
# Itemset: ('look', 'month'), Count: 1316
# Itemset: ('customer', 'meeting'), Count: 1316
# Itemset: ('cost', 'meeting'), Count: 1316
# Itemset: ('due', 'report'), Count: 1315
# Itemset: ('cost', 'include'), Count: 1315
# Itemset: ('help', 'issues'), Count: 1314
# Itemset: ('help', 'team'), Count: 1314
# Itemset: ('investment', 'market'), Count: 1314
# Itemset: ('customer', 'offer'), Count: 1314
# Itemset: ('issues', 'report'), Count: 1314
# Itemset: ('month', 'problem'), Count: 1313
# Itemset: ('issue', 'think'), Count: 1312
# Itemset: ('meeting', 'point'), Count: 1312
# Itemset: ('energy', 'process'), Count: 1312
# Itemset: ('forward', 'help'), Count: 1312
# Itemset: ('message', 'offer'), Count: 1311
# Itemset: ('california', 'consumer'), Count: 1310
# Itemset: ('company', 'look'), Count: 1310
# Itemset: ('plan', 'support'), Count: 1309
# Itemset: ('going', 'point'), Count: 1309
# Itemset: ('high', 'prices'), Count: 1309
# Itemset: ('order', 'provide'), Count: 1308
# Itemset: ('bill', 'plan'), Count: 1307
# Itemset: ('price', 'think'), Count: 1306
# Itemset: ('data', 'process'), Count: 1306
# Itemset: ('issue', 'order'), Count: 1306
# Itemset: ('date', 'start'), Count: 1306
# Itemset: ('issues', 'order'), Count: 1305
# Itemset: ('energy', 'problem'), Count: 1305
# Itemset: ('california', 'rate'), Count: 1304
# Itemset: ('california', 'going'), Count: 1303
# Itemset: ('power', 'set'), Count: 1303
# Itemset: ('future', 'market'), Count: 1303
# Itemset: ('energy', 'financial'), Count: 1302
# Itemset: ('order', 'plan'), Count: 1302
# Itemset: ('cost', 'issues'), Count: 1301
# Itemset: ('process', 'provide'), Count: 1301
# Itemset: ('month', 'set'), Count: 1301
# Itemset: ('cost', 'look'), Count: 1300
# Itemset: ('think', 'working'), Count: 1300
# Itemset: ('number', 'problem'), Count: 1300
# Itemset: ('effort', 'market'), Count: 1299
# Itemset: ('contract', 'provide'), Count: 1298
# Itemset: ('customer', 'utilities'), Count: 1298
# Itemset: ('help', 'order'), Count: 1298
# Itemset: ('comment', 'meeting'), Count: 1298
# Itemset: ('find', 'group'), Count: 1297
# Itemset: ('power', 'support'), Count: 1297
# Itemset: ('business', 'member'), Count: 1297
# Itemset: ('part', 'provide'), Count: 1297
# Itemset: ('market', 'place'), Count: 1297
# Itemset: ('business', 'corp'), Count: 1296
# Itemset: ('data', 'price'), Count: 1295
# Itemset: ('offer', 'service'), Count: 1295
# Itemset: ('financial', 'power'), Count: 1294
# Itemset: ('current', 'customer'), Count: 1294
# Itemset: ('energy', 'going'), Count: 1294
# Itemset: ('contract', 'number'), Count: 1293
# Itemset: ('customer', 'report'), Count: 1293
# Itemset: ('energy', 'set'), Count: 1293
# Itemset: ('help', 'issue'), Count: 1293
# Itemset: ('company', 'result'), Count: 1292
# Itemset: ('agreement', 'contract'), Count: 1292
# Itemset: ('consumer', 'energy'), Count: 1292
# Itemset: ('including', 'price'), Count: 1291
# Itemset: ('energy', 'support'), Count: 1291
# Itemset: ('plan', 'review'), Count: 1291
# Itemset: ('contract', 'think'), Count: 1291
# Itemset: ('business', 'effort'), Count: 1291
# Itemset: ('customer', 'issues'), Count: 1290
# Itemset: ('financial', 'group'), Count: 1290
# Itemset: ('plan', 'working'), Count: 1290
# Itemset: ('market', 'operation'), Count: 1289
# Itemset: ('corp', 'plan'), Count: 1289
# Itemset: ('help', 'set'), Count: 1288
# Itemset: ('give', 'market'), Count: 1287
# Itemset: ('based', 'cost'), Count: 1287
# Itemset: ('due', 'market'), Count: 1287
# Itemset: ('customer', 'deal'), Count: 1287
# Itemset: ('california', 'federal'), Count: 1287
# Itemset: ('business', 'review'), Count: 1286
# Itemset: ('issue', 'meeting'), Count: 1286
# Itemset: ('help', 'offer'), Count: 1285
# Itemset: ('hour', 'market'), Count: 1285
# Itemset: ('energy', 'supply'), Count: 1284
# Itemset: ('include', 'plan'), Count: 1283
# Itemset: ('include', 'provide'), Count: 1282
# Itemset: ('help', 'receive'), Count: 1282
# Itemset: ('end', 'point'), Count: 1282
# Itemset: ('meeting', 'team'), Count: 1282
# Itemset: ('group', 'problem'), Count: 1282
# Itemset: ('business', 'position'), Count: 1281
# Itemset: ('comment', 'power'), Count: 1280
# Itemset: ('comment', 'provide'), Count: 1280
# Itemset: ('california', 'pay'), Count: 1280
# Itemset: ('give', 'meeting'), Count: 1279
# Itemset: ('end', 'look'), Count: 1279
# Itemset: ('firm', 'market'), Count: 1279
# Itemset: ('power', 'supply'), Count: 1279
# Itemset: ('change', 'plan'), Count: 1278
# Itemset: ('include', 'power'), Count: 1278
# Itemset: ('business', 'team'), Count: 1278
# Itemset: ('energy', 'member'), Count: 1278
# Itemset: ('based', 'group'), Count: 1278
# Itemset: ('contract', 'meeting'), Count: 1278
# Itemset: ('number', 'office'), Count: 1277
# Itemset: ('end', 'part'), Count: 1277
# Itemset: ('price', 'provide'), Count: 1277
# Itemset: ('end', 'issue'), Count: 1277
# Itemset: ('billion', 'energy'), Count: 1277
# Itemset: ('high', 'plan'), Count: 1276
# Itemset: ('generation', 'power'), Count: 1276
# Itemset: ('deal', 'going'), Count: 1276
# Itemset: ('end', 'energy'), Count: 1276
# Itemset: ('business', 'find'), Count: 1276
# Itemset: ('customer', 'rates'), Count: 1275
# Itemset: ('utilities', 'utility'), Count: 1275
# Itemset: ('look', 'power'), Count: 1275
# Itemset: ('include', 'number'), Count: 1274
# Itemset: ('billion', 'power'), Count: 1273
# Itemset: ('contract', 'going'), Count: 1273
# Itemset: ('set', 'think'), Count: 1273
# Itemset: ('number', 'send'), Count: 1273
# Itemset: ('plan', 'process'), Count: 1271
# Itemset: ('group', 'list'), Count: 1270
# Itemset: ('bill', 'month'), Count: 1270
# Itemset: ('company', 'issue'), Count: 1270
# Itemset: ('give', 'look'), Count: 1270
# Itemset: ('business', 'operation'), Count: 1269
# Itemset: ('company', 'prices'), Count: 1267
# Itemset: ('deal', 'number'), Count: 1267
# Itemset: ('market', 'working'), Count: 1267
# Itemset: ('business', 'future'), Count: 1266
# Itemset: ('date', 'meeting'), Count: 1266
# Itemset: ('market', 'past'), Count: 1266
# Itemset: ('california', 'companies'), Count: 1266
# Itemset: ('credit', 'market'), Count: 1265
# Itemset: ('company', 'set'), Count: 1265
# Itemset: ('end', 'provide'), Count: 1265
# Itemset: ('companies', 'cost'), Count: 1264
# Itemset: ('general', 'market'), Count: 1263
# Itemset: ('going', 'problem'), Count: 1263
# Itemset: ('california', 'demand'), Count: 1262
# Itemset: ('bill', 'group'), Count: 1262
# Itemset: ('issue', 'report'), Count: 1262
# Itemset: ('provide', 'support'), Count: 1262
# Itemset: ('going', 'issue'), Count: 1261
# Itemset: ('business', 'give'), Count: 1261
# Itemset: ('help', 'thing'), Count: 1260
# Itemset: ('point', 'price'), Count: 1260
# Itemset: ('market', 'pay'), Count: 1260
# Itemset: ('business', 'forward'), Count: 1259
# Itemset: ('business', 'received'), Count: 1259
# Itemset: ('business', 'high'), Count: 1259
# Itemset: ('generation', 'market'), Count: 1259
# Itemset: ('commission', 'market'), Count: 1259
# Itemset: ('current', 'number'), Count: 1258
# Itemset: ('issue', 'provide'), Count: 1258
# Itemset: ('contract', 'issue'), Count: 1258
# Itemset: ('market', 'world'), Count: 1258
# Itemset: ('customer', 'think'), Count: 1258
# Itemset: ('look', 'point'), Count: 1258
# Itemset: ('company', 'find'), Count: 1258
# Itemset: ('federal', 'market'), Count: 1257
# Itemset: ('including', 'issue'), Count: 1257
# Itemset: ('help', 'list'), Count: 1256
# Itemset: ('including', 'services'), Count: 1256
# Itemset: ('including', 'order'), Count: 1256
# Itemset: ('able', 'help'), Count: 1256
# Itemset: ('look', 'price'), Count: 1255
# Itemset: ('month', 'offer'), Count: 1255
# Itemset: ('electricity', 'price'), Count: 1255
# Itemset: ('companies', 'report'), Count: 1255
# Itemset: ('current', 'help'), Count: 1255
# Itemset: ('provide', 'review'), Count: 1254
# Itemset: ('group', 'place'), Count: 1254
# Itemset: ('end', 'including'), Count: 1254
# Itemset: ('part', 'price'), Count: 1254
# Itemset: ('company', 'meeting'), Count: 1253
# Itemset: ('issue', 'price'), Count: 1253
# Itemset: ('contract', 'end'), Count: 1253
# Itemset: ('end', 'order'), Count: 1253
# Itemset: ('company', 'think'), Count: 1252
# Itemset: ('meeting', 'order'), Count: 1252
# Itemset: ('market', 'office'), Count: 1252
# Itemset: ('cost', 'result'), Count: 1252
# Itemset: ('meeting', 'thursday'), Count: 1252
# Itemset: ('company', 'going'), Count: 1251
# Itemset: ('part', 'think'), Count: 1251
# Itemset: ('member', 'service'), Count: 1251
# Itemset: ('give', 'plan'), Count: 1250
# Itemset: ('month', 'past'), Count: 1250
# Itemset: ('additional', 'business'), Count: 1249
# Itemset: ('change', 'group'), Count: 1249
# Itemset: ('going', 'part'), Count: 1249
# Itemset: ('month', 'result'), Count: 1249
# Itemset: ('issue', 'point'), Count: 1248
# Itemset: ('california', 'commission'), Count: 1248
# Itemset: ('look', 'report'), Count: 1248
# Itemset: ('company', 'interest'), Count: 1247
# Itemset: ('help', 'part'), Count: 1247
# Itemset: ('offer', 'price'), Count: 1247
# Itemset: ('comment', 'issues'), Count: 1246
# Itemset: ('point', 'report'), Count: 1246
# Itemset: ('market', 'put'), Count: 1246
# Itemset: ('data', 'market'), Count: 1246
# Itemset: ('company', 'management'), Count: 1246
# Itemset: ('comment', 'energy'), Count: 1245
# Itemset: ('give', 'month'), Count: 1245
# Itemset: ('number', 'place'), Count: 1245
# Itemset: ('power', 'term'), Count: 1245
# Itemset: ('market', 'receive'), Count: 1244
# Itemset: ('number', 'offer'), Count: 1244
# Itemset: ('number', 'phone'), Count: 1244
# Itemset: ('include', 'service'), Count: 1244
# Itemset: ('meeting', 'place'), Count: 1243
# Itemset: ('financial', 'month'), Count: 1243
# Itemset: ('energy', 'rates'), Count: 1242
# Itemset: ('financial', 'plan'), Count: 1242
# Itemset: ('companies', 'including'), Count: 1242
# Itemset: ('business', 'continue'), Count: 1242
# Itemset: ('plan', 'problem'), Count: 1242
# Itemset: ('company', 'include'), Count: 1241
# Itemset: ('companies', 'service'), Count: 1241
# Itemset: ('hour', 'start'), Count: 1241
# Itemset: ('billion', 'cost'), Count: 1240
# Itemset: ('action', 'california'), Count: 1240
# Itemset: ('member', 'plan'), Count: 1239
# Itemset: ('customer', 'set'), Count: 1239
# Itemset: ('month', 'pay'), Count: 1239
# Itemset: ('agreement', 'company'), Count: 1239
# Itemset: ('number', 'sure'), Count: 1238
# Itemset: ('contract', 'order'), Count: 1238
# Itemset: ('based', 'month'), Count: 1238
# Itemset: ('offer', 'plan'), Count: 1238
# Itemset: ('deal', 'term'), Count: 1238
# Itemset: ('current', 'price'), Count: 1238
# Itemset: ('comment', 'plan'), Count: 1237
# Itemset: ('report', 'result'), Count: 1237
# Itemset: ('high', 'think'), Count: 1237
# Itemset: ('customer', 'high'), Count: 1237
# Itemset: ('list', 'meeting'), Count: 1237
# Itemset: ('based', 'number'), Count: 1236
# Itemset: ('going', 'price'), Count: 1236
# Itemset: ('business', 'program'), Count: 1236
# Itemset: ('issues', 'point'), Count: 1236
# Itemset: ('point', 'provide'), Count: 1236
# Itemset: ('based', 'business'), Count: 1236
# Itemset: ('change', 'number'), Count: 1236
# Itemset: ('look', 'sure'), Count: 1235
# Itemset: ('based', 'customer'), Count: 1235
# Itemset: ('houston', 'meeting'), Count: 1234
# Itemset: ('company', 'member'), Count: 1234
# Itemset: ('energy', 'generation'), Count: 1233
# Itemset: ('federal', 'power'), Count: 1233
# Itemset: ('california', 'deal'), Count: 1233
# Itemset: ('find', 'number'), Count: 1233
# Itemset: ('additional', 'provide'), Count: 1232
# Itemset: ('action', 'market'), Count: 1232
# Itemset: ('bill', 'business'), Count: 1232
# Itemset: ('help', 'high'), Count: 1232
# Itemset: ('management', 'market'), Count: 1232
# Itemset: ('number', 'team'), Count: 1232
# Itemset: ('process', 'start'), Count: 1231
# Itemset: ('date', 'market'), Count: 1231
# Itemset: ('free', 'help'), Count: 1231
# Itemset: ('group', 'result'), Count: 1231
# Itemset: ('comment', 'issue'), Count: 1231
# Itemset: ('deal', 'part'), Count: 1231
# Itemset: ('plan', 'services'), Count: 1231
# Itemset: ('able', 'think'), Count: 1231
# Itemset: ('find', 'month'), Count: 1230
# Itemset: ('energy', 'rate'), Count: 1230
# Itemset: ('process', 'review'), Count: 1230
# Itemset: ('california', 'ferc'), Count: 1230
# Itemset: ('meeting', 'member'), Count: 1230
# Itemset: ('electricity', 'states'), Count: 1230
# Itemset: ('account', 'customer'), Count: 1229
# Itemset: ('group', 'put'), Count: 1229
# Itemset: ('energy', 'term'), Count: 1229
# Itemset: ('energy', 'hour'), Count: 1229
# Itemset: ('business', 'comment'), Count: 1229
# Itemset: ('current', 'including'), Count: 1229
# Itemset: ('californias', 'power'), Count: 1229
# Itemset: ('electricity', 'prices'), Count: 1228
# Itemset: ('business', 'interest'), Count: 1228
# Itemset: ('california', 'supply'), Count: 1227
# Itemset: ('number', 'working'), Count: 1227
# Itemset: ('california', 'current'), Count: 1227
# Itemset: ('deal', 'end'), Count: 1227
# Itemset: ('review', 'think'), Count: 1227
# Itemset: ('current', 'service'), Count: 1227
# Itemset: ('company', 'issues'), Count: 1227
# Itemset: ('give', 'point'), Count: 1226
# Itemset: ('conference', 'meeting'), Count: 1226
# Itemset: ('end', 'give'), Count: 1226
# Itemset: ('energy', 'interest'), Count: 1226
# Itemset: ('buy', 'power'), Count: 1226
# Itemset: ('change', 'report'), Count: 1226
# Itemset: ('company', 'continue'), Count: 1226
# Itemset: ('price', 'set'), Count: 1225
# Itemset: ('group', 'position'), Count: 1225
# Itemset: ('meeting', 'scheduled'), Count: 1225
# Itemset: ('company', 'support'), Count: 1225
# Itemset: ('group', 'industry'), Count: 1225
# Itemset: ('company', 'public'), Count: 1225
# Itemset: ('energy', 'pay'), Count: 1224
# Itemset: ('issue', 'problem'), Count: 1224
# Itemset: ('help', 'include'), Count: 1224
# Itemset: ('energy', 'office'), Count: 1224
# Itemset: ('california', 'set'), Count: 1223
# Itemset: ('business', 'receive'), Count: 1223
# Itemset: ('group', 'high'), Count: 1223
# Itemset: ('energy', 'result'), Count: 1223
# Itemset: ('deal', 'issue'), Count: 1223
# Itemset: ('report', 'set'), Count: 1223
# Itemset: ('energy', 'services'), Count: 1222
# Itemset: ('comment', 'think'), Count: 1222
# Itemset: ('issue', 'part'), Count: 1222
# Itemset: ('date', 'hour'), Count: 1221
# Itemset: ('getting', 'think'), Count: 1221
# Itemset: ('bill', 'company'), Count: 1221
# Itemset: ('energy', 'look'), Count: 1221
# Itemset: ('energy', 'gas'), Count: 1221
# Itemset: ('bill', 'price'), Count: 1220
# Itemset: ('companies', 'provide'), Count: 1220
# Itemset: ('business', 'world'), Count: 1220
# Itemset: ('company', 'future'), Count: 1220
# Itemset: ('power', 'result'), Count: 1220
# Itemset: ('market', 'review'), Count: 1219
# Itemset: ('business', 'place'), Count: 1219
# Itemset: ('energy', 'point'), Count: 1219
# Itemset: ('change', 'service'), Count: 1219
# Itemset: ('deal', 'including'), Count: 1218
# Itemset: ('ferc', 'market'), Count: 1218
# Itemset: ('help', 'send'), Count: 1218
# Itemset: ('issue', 'number'), Count: 1218
# Itemset: ('month', 'working'), Count: 1217
# Itemset: ('provide', 'think'), Count: 1217
# Itemset: ('end', 'problem'), Count: 1217
# Itemset: ('california', 'forward'), Count: 1217
# Itemset: ('business', 'public'), Count: 1216
# Itemset: ('power', 'rate'), Count: 1216
# Itemset: ('due', 'group'), Count: 1216
# Itemset: ('companies', 'price'), Count: 1215
# Itemset: ('high', 'part'), Count: 1215
# Itemset: ('access', 'business'), Count: 1215
# Itemset: ('part', 'point'), Count: 1215
# Itemset: ('business', 'product'), Count: 1214
# Itemset: ('business', 'problem'), Count: 1214
# Itemset: ('able', 'group'), Count: 1214
# Itemset: ('help', 'put'), Count: 1213
# Itemset: ('including', 'think'), Count: 1213
# Itemset: ('find', 'look'), Count: 1213
# Itemset: ('deal', 'look'), Count: 1213
# Itemset: ('additional', 'cost'), Count: 1212
# Itemset: ('contract', 'current'), Count: 1212
# Itemset: ('group', 'thing'), Count: 1212
# Itemset: ('future', 'plan'), Count: 1212
# Itemset: ('end', 'high'), Count: 1212
# Itemset: ('end', 'set'), Count: 1212
# Itemset: ('issues', 'month'), Count: 1212
# Itemset: ('service', 'set'), Count: 1212
# Itemset: ('find', 'going'), Count: 1211
# Itemset: ('hope', 'think'), Count: 1211
# Itemset: ('issues', 'review'), Count: 1211
# Itemset: ('basis', 'review'), Count: 1211
# Itemset: ('place', 'plan'), Count: 1210
# Itemset: ('group', 'public'), Count: 1210
# Itemset: ('business', 'trading'), Count: 1210
# Itemset: ('company', 'investment'), Count: 1210
# Itemset: ('cost', 'forward'), Count: 1210
# Itemset: ('continue', 'energy'), Count: 1210
# Itemset: ('energy', 'federal'), Count: 1210
# Itemset: ('company', 'firm'), Count: 1210
# Itemset: ('issue', 'set'), Count: 1209
# Itemset: ('california', 'corp'), Count: 1209
# Itemset: ('find', 'report'), Count: 1209
# Itemset: ('consumer', 'cost'), Count: 1209
# Itemset: ('companies', 'part'), Count: 1209
# Itemset: ('high', 'number'), Count: 1209
# Itemset: ('look', 'problem'), Count: 1209
# Itemset: ('going', 'put'), Count: 1209
# Itemset: ('houston', 'texas'), Count: 1208
# Itemset: ('company', 'point'), Count: 1208
# Itemset: ('billion', 'california'), Count: 1208
# Itemset: ('create', 'review'), Count: 1208
# Itemset: ('company', 'product'), Count: 1207
# Itemset: ('business', 'free'), Count: 1207
# Itemset: ('industry', 'power'), Count: 1207
# Itemset: ('number', 'thing'), Count: 1207
# Itemset: ('monday', 'tuesday'), Count: 1207
# Itemset: ('business', 'prices'), Count: 1206
# Itemset: ('including', 'offer'), Count: 1206
# Itemset: ('electricity', 'utilities'), Count: 1205
# Itemset: ('issues', 'process'), Count: 1205
# Itemset: ('including', 'issues'), Count: 1205
# Itemset: ('help', 'review'), Count: 1205
# Itemset: ('access', 'service'), Count: 1204
# Itemset: ('access', 'group'), Count: 1204
# Itemset: ('california', 'office'), Count: 1204
# Itemset: ('agreement', 'power'), Count: 1204
# Itemset: ('talk', 'think'), Count: 1204
# Itemset: ('market', 'open'), Count: 1204
# Itemset: ('group', 'offer'), Count: 1204
# Itemset: ('date', 'energy'), Count: 1203
# Itemset: ('deal', 'point'), Count: 1203
# Itemset: ('forward', 'plan'), Count: 1203
# Itemset: ('business', 'firm'), Count: 1203
# Itemset: ('issues', 'problem'), Count: 1203
# Itemset: ('look', 'review'), Count: 1202
# Itemset: ('cost', 'demand'), Count: 1202
# Itemset: ('cost', 'services'), Count: 1202
# Itemset: ('data', 'date'), Count: 1202
# Itemset: ('price', 'utility'), Count: 1202
# Itemset: ('market', 'thing'), Count: 1202
# Itemset: ('continue', 'group'), Count: 1201
# Itemset: ('month', 'support'), Count: 1201
# Itemset: ('create', 'offer'), Count: 1201
# Itemset: ('customer', 'going'), Count: 1201
# Itemset: ('major', 'market'), Count: 1201
# Itemset: ('company', 'office'), Count: 1201
# Itemset: ('future', 'group'), Count: 1200
# Itemset: ('market', 'sales'), Count: 1200
# Itemset: ('list', 'number'), Count: 1200
# Itemset: ('group', 'management'), Count: 1200
# Itemset: ('forward', 'issues'), Count: 1200
# Itemset: ('additional', 'group'), Count: 1200
# Itemset: ('find', 'plan'), Count: 1200

# %% [markdown]
# ## K = 2 and F = 1100

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1100)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1100
#
# Time taken: 38.40 seconds
#
# Total Frequent K-itemsets Found: 1531
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('california', 'utility'), Count: 1500
# Itemset: ('meeting', 'set'), Count: 1499
# Itemset: ('business', 'financial'), Count: 1499
# Itemset: ('number', 'provide'), Count: 1499
# Itemset: ('companies', 'energy'), Count: 1495
# Itemset: ('point', 'think'), Count: 1494
# Itemset: ('number', 'report'), Count: 1493
# Itemset: ('market', 'position'), Count: 1491
# Itemset: ('help', 'power'), Count: 1491
# Itemset: ('bill', 'california'), Count: 1491
# Itemset: ('market', 'offer'), Count: 1490
# Itemset: ('going', 'number'), Count: 1490
# Itemset: ('california', 'meeting'), Count: 1488
# Itemset: ('company', 'corp'), Count: 1486
# Itemset: ('end', 'number'), Count: 1485
# Itemset: ('energy', 'utility'), Count: 1485
# Itemset: ('meeting', 'review'), Count: 1483
# Itemset: ('electricity', 'market'), Count: 1482
# Itemset: ('power', 'report'), Count: 1482
# Itemset: ('california', 'order'), Count: 1482
# Itemset: ('cost', 'including'), Count: 1481
# Itemset: ('group', 'member'), Count: 1481
# Itemset: ('provide', 'service'), Count: 1481
# Itemset: ('feel', 'free'), Count: 1480
# Itemset: ('going', 'plan'), Count: 1480
# Itemset: ('california', 'contract'), Count: 1480
# Itemset: ('business', 'price'), Count: 1480
# Itemset: ('energy', 'part'), Count: 1479
# Itemset: ('cost', 'help'), Count: 1479
# Itemset: ('including', 'plan'), Count: 1477
# Itemset: ('going', 'group'), Count: 1476
# Itemset: ('cost', 'high'), Count: 1475
# Itemset: ('california', 'provide'), Count: 1474
# Itemset: ('look', 'number'), Count: 1474
# Itemset: ('company', 'part'), Count: 1474
# Itemset: ('deal', 'price'), Count: 1473
# Itemset: ('customer', 'utility'), Count: 1473
# Itemset: ('deal', 'month'), Count: 1472
# Itemset: ('energy', 'including'), Count: 1471
# Itemset: ('cost', 'order'), Count: 1471
# Itemset: ('business', 'issues'), Count: 1470
# Itemset: ('going', 'month'), Count: 1468
# Itemset: ('plan', 'report'), Count: 1467
# Itemset: ('cost', 'end'), Count: 1466
# Itemset: ('look', 'meeting'), Count: 1466
# Itemset: ('business', 'support'), Count: 1466
# Itemset: ('california', 'help'), Count: 1465
# Itemset: ('customer', 'help'), Count: 1465
# Itemset: ('group', 'office'), Count: 1463
# Itemset: ('customer', 'number'), Count: 1463
# Itemset: ('business', 'think'), Count: 1462
# Itemset: ('number', 'power'), Count: 1460
# Itemset: ('business', 'current'), Count: 1459
# Itemset: ('group', 'service'), Count: 1458
# Itemset: ('company', 'financial'), Count: 1457
# Itemset: ('help', 'look'), Count: 1457
# Itemset: ('group', 'support'), Count: 1456
# Itemset: ('end', 'plan'), Count: 1456
# Itemset: ('going', 'market'), Count: 1456
# Itemset: ('california', 'issue'), Count: 1456
# Itemset: ('attached', 'review'), Count: 1455
# Itemset: ('order', 'service'), Count: 1454
# Itemset: ('part', 'power'), Count: 1454
# Itemset: ('california', 'number'), Count: 1454
# Itemset: ('cost', 'utility'), Count: 1453
# Itemset: ('power', 'problem'), Count: 1453
# Itemset: ('contract', 'month'), Count: 1452
# Itemset: ('customer', 'including'), Count: 1451
# Itemset: ('energy', 'help'), Count: 1451
# Itemset: ('energy', 'order'), Count: 1450
# Itemset: ('business', 'process'), Count: 1448
# Itemset: ('energy', 'issues'), Count: 1446
# Itemset: ('company', 'price'), Count: 1446
# Itemset: ('site', 'web'), Count: 1446
# Itemset: ('access', 'customer'), Count: 1445
# Itemset: ('group', 'services'), Count: 1444
# Itemset: ('corp', 'market'), Count: 1441
# Itemset: ('cost', 'prices'), Count: 1439
# Itemset: ('month', 'part'), Count: 1438
# Itemset: ('service', 'services'), Count: 1438
# Itemset: ('energy', 'states'), Count: 1438
# Itemset: ('help', 'report'), Count: 1437
# Itemset: ('meeting', 'report'), Count: 1437
# Itemset: ('give', 'going'), Count: 1437
# Itemset: ('including', 'service'), Count: 1437
# Itemset: ('california', 'high'), Count: 1436
# Itemset: ('high', 'power'), Count: 1436
# Itemset: ('company', 'deal'), Count: 1435
# Itemset: ('cost', 'think'), Count: 1435
# Itemset: ('end', 'help'), Count: 1432
# Itemset: ('group', 'team'), Count: 1430
# Itemset: ('market', 'utilities'), Count: 1429
# Itemset: ('help', 'including'), Count: 1428
# Itemset: ('forward', 'group'), Count: 1428
# Itemset: ('current', 'energy'), Count: 1428
# Itemset: ('price', 'process'), Count: 1427
# Itemset: ('current', 'group'), Count: 1427
# Itemset: ('including', 'month'), Count: 1426
# Itemset: ('meeting', 'working'), Count: 1425
# Itemset: ('california', 'problem'), Count: 1425
# Itemset: ('message', 'receive'), Count: 1425
# Itemset: ('company', 'current'), Count: 1425
# Itemset: ('issue', 'power'), Count: 1424
# Itemset: ('find', 'help'), Count: 1423
# Itemset: ('issue', 'plan'), Count: 1423
# Itemset: ('number', 'point'), Count: 1422
# Itemset: ('energy', 'number'), Count: 1421
# Itemset: ('business', 'order'), Count: 1421
# Itemset: ('attached', 'comment'), Count: 1419
# Itemset: ('going', 'meeting'), Count: 1418
# Itemset: ('including', 'report'), Count: 1418
# Itemset: ('forward', 'going'), Count: 1418
# Itemset: ('business', 'include'), Count: 1417
# Itemset: ('receive', 'review'), Count: 1417
# Itemset: ('power', 'service'), Count: 1417
# Itemset: ('date', 'price'), Count: 1417
# Itemset: ('issues', 'plan'), Count: 1417
# Itemset: ('part', 'plan'), Count: 1416
# Itemset: ('current', 'plan'), Count: 1416
# Itemset: ('gas', 'market'), Count: 1415
# Itemset: ('group', 'include'), Count: 1414
# Itemset: ('cost', 'rate'), Count: 1414
# Itemset: ('bill', 'power'), Count: 1414
# Itemset: ('energy', 'public'), Count: 1413
# Itemset: ('market', 'public'), Count: 1413
# Itemset: ('market', 'trading'), Count: 1411
# Itemset: ('order', 'price'), Count: 1411
# Itemset: ('going', 'power'), Count: 1410
# Itemset: ('cost', 'rates'), Count: 1410
# Itemset: ('think', 'thought'), Count: 1409
# Itemset: ('end', 'think'), Count: 1408
# Itemset: ('including', 'provide'), Count: 1408
# Itemset: ('company', 'industry'), Count: 1408
# Itemset: ('level', 'market'), Count: 1407
# Itemset: ('high', 'month'), Count: 1407
# Itemset: ('look', 'plan'), Count: 1406
# Itemset: ('number', 'order'), Count: 1405
# Itemset: ('california', 'service'), Count: 1405
# Itemset: ('group', 'process'), Count: 1403
# Itemset: ('cost', 'going'), Count: 1402
# Itemset: ('meeting', 'monday'), Count: 1402
# Itemset: ('california', 'including'), Count: 1401
# Itemset: ('office', 'plan'), Count: 1401
# Itemset: ('consumer', 'market'), Count: 1401
# Itemset: ('market', 'rates'), Count: 1400
# Itemset: ('companies', 'group'), Count: 1400
# Itemset: ('meeting', 'power'), Count: 1399
# Itemset: ('california', 'report'), Count: 1398
# Itemset: ('friday', 'meeting'), Count: 1398
# Itemset: ('market', 'utility'), Count: 1397
# Itemset: ('comment', 'review'), Count: 1397
# Itemset: ('energy', 'industry'), Count: 1396
# Itemset: ('attached', 'file'), Count: 1396
# Itemset: ('power', 'think'), Count: 1395
# Itemset: ('problem', 'think'), Count: 1395
# Itemset: ('issues', 'power'), Count: 1395
# Itemset: ('end', 'going'), Count: 1395
# Itemset: ('look', 'thing'), Count: 1395
# Itemset: ('business', 'industry'), Count: 1395
# Itemset: ('buy', 'market'), Count: 1392
# Itemset: ('business', 'look'), Count: 1392
# Itemset: ('cost', 'pay'), Count: 1392
# Itemset: ('give', 'help'), Count: 1391
# Itemset: ('business', 'end'), Count: 1390
# Itemset: ('corp', 'review'), Count: 1388
# Itemset: ('put', 'think'), Count: 1387
# Itemset: ('business', 'offer'), Count: 1387
# Itemset: ('market', 'supply'), Count: 1387
# Itemset: ('california', 'think'), Count: 1387
# Itemset: ('find', 'market'), Count: 1386
# Itemset: ('company', 'contract'), Count: 1386
# Itemset: ('interest', 'market'), Count: 1385
# Itemset: ('issues', 'think'), Count: 1384
# Itemset: ('meeting', 'process'), Count: 1384
# Itemset: ('market', 'rate'), Count: 1384
# Itemset: ('companies', 'power'), Count: 1383
# Itemset: ('market', 'process'), Count: 1383
# Itemset: ('include', 'including'), Count: 1382
# Itemset: ('energy', 'high'), Count: 1382
# Itemset: ('number', 'price'), Count: 1382
# Itemset: ('deal', 'think'), Count: 1381
# Itemset: ('deal', 'plan'), Count: 1381
# Itemset: ('customer', 'issue'), Count: 1381
# Itemset: ('group', 'order'), Count: 1380
# Itemset: ('group', 'point'), Count: 1380
# Itemset: ('cost', 'report'), Count: 1379
# Itemset: ('help', 'support'), Count: 1379
# Itemset: ('price', 'report'), Count: 1379
# Itemset: ('issues', 'provide'), Count: 1379
# Itemset: ('give', 'number'), Count: 1378
# Itemset: ('high', 'price'), Count: 1378
# Itemset: ('california', 'issues'), Count: 1377
# Itemset: ('meet', 'meeting'), Count: 1377
# Itemset: ('attached', 'meeting'), Count: 1376
# Itemset: ('contract', 'price'), Count: 1376
# Itemset: ('cost', 'current'), Count: 1376
# Itemset: ('energy', 'issue'), Count: 1376
# Itemset: ('find', 'think'), Count: 1375
# Itemset: ('provide', 'report'), Count: 1375
# Itemset: ('deal', 'help'), Count: 1375
# Itemset: ('cost', 'issue'), Count: 1374
# Itemset: ('corp', 'offer'), Count: 1374
# Itemset: ('business', 'working'), Count: 1373
# Itemset: ('group', 'set'), Count: 1373
# Itemset: ('cost', 'deal'), Count: 1372
# Itemset: ('effort', 'group'), Count: 1371
# Itemset: ('deal', 'energy'), Count: 1368
# Itemset: ('bill', 'customer'), Count: 1367
# Itemset: ('going', 'sure'), Count: 1366
# Itemset: ('current', 'month'), Count: 1366
# Itemset: ('free', 'offer'), Count: 1366
# Itemset: ('forward', 'think'), Count: 1365
# Itemset: ('demand', 'power'), Count: 1364
# Itemset: ('end', 'power'), Count: 1364
# Itemset: ('cost', 'states'), Count: 1363
# Itemset: ('additional', 'market'), Count: 1363
# Itemset: ('market', 'states'), Count: 1363
# Itemset: ('customer', 'end'), Count: 1363
# Itemset: ('group', 'price'), Count: 1362
# Itemset: ('report', 'service'), Count: 1362
# Itemset: ('give', 'group'), Count: 1361
# Itemset: ('current', 'report'), Count: 1361
# Itemset: ('access', 'market'), Count: 1361
# Itemset: ('end', 'report'), Count: 1360
# Itemset: ('meeting', 'provide'), Count: 1360
# Itemset: ('bill', 'cost'), Count: 1360
# Itemset: ('group', 'issue'), Count: 1359
# Itemset: ('market', 'risk'), Count: 1359
# Itemset: ('issues', 'number'), Count: 1356
# Itemset: ('plan', 'price'), Count: 1356
# Itemset: ('date', 'process'), Count: 1356
# Itemset: ('california', 'comment'), Count: 1356
# Itemset: ('cost', 'part'), Count: 1355
# Itemset: ('billion', 'company'), Count: 1355
# Itemset: ('help', 'service'), Count: 1355
# Itemset: ('date', 'number'), Count: 1355
# Itemset: ('california', 'point'), Count: 1354
# Itemset: ('price', 'start'), Count: 1354
# Itemset: ('point', 'power'), Count: 1354
# Itemset: ('company', 'offer'), Count: 1353
# Itemset: ('end', 'service'), Count: 1353
# Itemset: ('billion', 'market'), Count: 1353
# Itemset: ('including', 'number'), Count: 1353
# Itemset: ('comment', 'group'), Count: 1352
# Itemset: ('basis', 'contract'), Count: 1351
# Itemset: ('including', 'part'), Count: 1351
# Itemset: ('plan', 'set'), Count: 1349
# Itemset: ('group', 'review'), Count: 1349
# Itemset: ('bill', 'market'), Count: 1348
# Itemset: ('end', 'meeting'), Count: 1348
# Itemset: ('provide', 'services'), Count: 1348
# Itemset: ('business', 'point'), Count: 1348
# Itemset: ('address', 'market'), Count: 1348
# Itemset: ('forward', 'power'), Count: 1347
# Itemset: ('corp', 'energy'), Count: 1346
# Itemset: ('decision', 'market'), Count: 1346
# Itemset: ('number', 'part'), Count: 1345
# Itemset: ('market', 'member'), Count: 1345
# Itemset: ('business', 'issue'), Count: 1344
# Itemset: ('california', 'end'), Count: 1344
# Itemset: ('california', 'californias'), Count: 1344
# Itemset: ('help', 'price'), Count: 1344
# Itemset: ('part', 'report'), Count: 1343
# Itemset: ('issue', 'month'), Count: 1343
# Itemset: ('customer', 'services'), Count: 1343
# Itemset: ('number', 'set'), Count: 1343
# Itemset: ('market', 'sell'), Count: 1342
# Itemset: ('california', 'public'), Count: 1342
# Itemset: ('gas', 'power'), Count: 1342
# Itemset: ('contract', 'deal'), Count: 1341
# Itemset: ('companies', 'month'), Count: 1341
# Itemset: ('contract', 'receive'), Count: 1340
# Itemset: ('help', 'process'), Count: 1339
# Itemset: ('offer', 'review'), Count: 1339
# Itemset: ('cost', 'utilities'), Count: 1339
# Itemset: ('market', 'product'), Count: 1338
# Itemset: ('customer', 'prices'), Count: 1337
# Itemset: ('continue', 'market'), Count: 1337
# Itemset: ('business', 'management'), Count: 1337
# Itemset: ('change', 'company'), Count: 1337
# Itemset: ('energy', 'include'), Count: 1337
# Itemset: ('cost', 'set'), Count: 1336
# Itemset: ('contract', 'plan'), Count: 1336
# Itemset: ('help', 'working'), Count: 1336
# Itemset: ('help', 'point'), Count: 1335
# Itemset: ('month', 'provide'), Count: 1335
# Itemset: ('power', 'public'), Count: 1335
# Itemset: ('month', 'prices'), Count: 1335
# Itemset: ('customer', 'support'), Count: 1335
# Itemset: ('customer', 'part'), Count: 1334
# Itemset: ('price', 'service'), Count: 1332
# Itemset: ('california', 'part'), Count: 1332
# Itemset: ('california', 'rates'), Count: 1332
# Itemset: ('corp', 'receive'), Count: 1332
# Itemset: ('contract', 'group'), Count: 1332
# Itemset: ('help', 'sure'), Count: 1331
# Itemset: ('current', 'provide'), Count: 1331
# Itemset: ('help', 'problem'), Count: 1330
# Itemset: ('meeting', 'month'), Count: 1330
# Itemset: ('contract', 'service'), Count: 1330
# Itemset: ('end', 'price'), Count: 1330
# Itemset: ('cost', 'problem'), Count: 1329
# Itemset: ('order', 'report'), Count: 1328
# Itemset: ('forward', 'number'), Count: 1327
# Itemset: ('month', 'point'), Count: 1327
# Itemset: ('customer', 'pay'), Count: 1327
# Itemset: ('energy', 'think'), Count: 1327
# Itemset: ('business', 'going'), Count: 1327
# Itemset: ('company', 'order'), Count: 1327
# Itemset: ('cost', 'electricity'), Count: 1326
# Itemset: ('company', 'end'), Count: 1326
# Itemset: ('business', 'contract'), Count: 1325
# Itemset: ('business', 'set'), Count: 1325
# Itemset: ('cost', 'point'), Count: 1324
# Itemset: ('customer', 'include'), Count: 1324
# Itemset: ('companies', 'plan'), Count: 1323
# Itemset: ('customer', 'rate'), Count: 1323
# Itemset: ('business', 'result'), Count: 1323
# Itemset: ('rate', 'rates'), Count: 1322
# Itemset: ('message', 'review'), Count: 1322
# Itemset: ('corp', 'group'), Count: 1322
# Itemset: ('business', 'change'), Count: 1322
# Itemset: ('corp', 'power'), Count: 1322
# Itemset: ('pay', 'power'), Count: 1321
# Itemset: ('energy', 'forward'), Count: 1321
# Itemset: ('power', 'rates'), Count: 1320
# Itemset: ('demand', 'energy'), Count: 1320
# Itemset: ('consumer', 'power'), Count: 1320
# Itemset: ('company', 'high'), Count: 1319
# Itemset: ('plan', 'point'), Count: 1319
# Itemset: ('month', 'order'), Count: 1318
# Itemset: ('part', 'service'), Count: 1317
# Itemset: ('current', 'power'), Count: 1317
# Itemset: ('companies', 'customer'), Count: 1316
# Itemset: ('look', 'month'), Count: 1316
# Itemset: ('customer', 'meeting'), Count: 1316
# Itemset: ('cost', 'meeting'), Count: 1316
# Itemset: ('due', 'report'), Count: 1315
# Itemset: ('cost', 'include'), Count: 1315
# Itemset: ('help', 'issues'), Count: 1314
# Itemset: ('help', 'team'), Count: 1314
# Itemset: ('investment', 'market'), Count: 1314
# Itemset: ('customer', 'offer'), Count: 1314
# Itemset: ('issues', 'report'), Count: 1314
# Itemset: ('month', 'problem'), Count: 1313
# Itemset: ('issue', 'think'), Count: 1312
# Itemset: ('meeting', 'point'), Count: 1312
# Itemset: ('energy', 'process'), Count: 1312
# Itemset: ('forward', 'help'), Count: 1312
# Itemset: ('message', 'offer'), Count: 1311
# Itemset: ('california', 'consumer'), Count: 1310
# Itemset: ('company', 'look'), Count: 1310
# Itemset: ('plan', 'support'), Count: 1309
# Itemset: ('going', 'point'), Count: 1309
# Itemset: ('high', 'prices'), Count: 1309
# Itemset: ('order', 'provide'), Count: 1308
# Itemset: ('bill', 'plan'), Count: 1307
# Itemset: ('price', 'think'), Count: 1306
# Itemset: ('data', 'process'), Count: 1306
# Itemset: ('issue', 'order'), Count: 1306
# Itemset: ('date', 'start'), Count: 1306
# Itemset: ('issues', 'order'), Count: 1305
# Itemset: ('energy', 'problem'), Count: 1305
# Itemset: ('california', 'rate'), Count: 1304
# Itemset: ('california', 'going'), Count: 1303
# Itemset: ('power', 'set'), Count: 1303
# Itemset: ('future', 'market'), Count: 1303
# Itemset: ('energy', 'financial'), Count: 1302
# Itemset: ('order', 'plan'), Count: 1302
# Itemset: ('cost', 'issues'), Count: 1301
# Itemset: ('process', 'provide'), Count: 1301
# Itemset: ('month', 'set'), Count: 1301
# Itemset: ('cost', 'look'), Count: 1300
# Itemset: ('think', 'working'), Count: 1300
# Itemset: ('number', 'problem'), Count: 1300
# Itemset: ('effort', 'market'), Count: 1299
# Itemset: ('contract', 'provide'), Count: 1298
# Itemset: ('customer', 'utilities'), Count: 1298
# Itemset: ('help', 'order'), Count: 1298
# Itemset: ('comment', 'meeting'), Count: 1298
# Itemset: ('find', 'group'), Count: 1297
# Itemset: ('power', 'support'), Count: 1297
# Itemset: ('business', 'member'), Count: 1297
# Itemset: ('part', 'provide'), Count: 1297
# Itemset: ('market', 'place'), Count: 1297
# Itemset: ('business', 'corp'), Count: 1296
# Itemset: ('data', 'price'), Count: 1295
# Itemset: ('offer', 'service'), Count: 1295
# Itemset: ('financial', 'power'), Count: 1294
# Itemset: ('current', 'customer'), Count: 1294
# Itemset: ('energy', 'going'), Count: 1294
# Itemset: ('contract', 'number'), Count: 1293
# Itemset: ('customer', 'report'), Count: 1293
# Itemset: ('energy', 'set'), Count: 1293
# Itemset: ('help', 'issue'), Count: 1293
# Itemset: ('company', 'result'), Count: 1292
# Itemset: ('agreement', 'contract'), Count: 1292
# Itemset: ('consumer', 'energy'), Count: 1292
# Itemset: ('including', 'price'), Count: 1291
# Itemset: ('energy', 'support'), Count: 1291
# Itemset: ('plan', 'review'), Count: 1291
# Itemset: ('contract', 'think'), Count: 1291
# Itemset: ('business', 'effort'), Count: 1291
# Itemset: ('customer', 'issues'), Count: 1290
# Itemset: ('financial', 'group'), Count: 1290
# Itemset: ('plan', 'working'), Count: 1290
# Itemset: ('market', 'operation'), Count: 1289
# Itemset: ('corp', 'plan'), Count: 1289
# Itemset: ('help', 'set'), Count: 1288
# Itemset: ('give', 'market'), Count: 1287
# Itemset: ('based', 'cost'), Count: 1287
# Itemset: ('due', 'market'), Count: 1287
# Itemset: ('customer', 'deal'), Count: 1287
# Itemset: ('california', 'federal'), Count: 1287
# Itemset: ('business', 'review'), Count: 1286
# Itemset: ('issue', 'meeting'), Count: 1286
# Itemset: ('help', 'offer'), Count: 1285
# Itemset: ('hour', 'market'), Count: 1285
# Itemset: ('energy', 'supply'), Count: 1284
# Itemset: ('include', 'plan'), Count: 1283
# Itemset: ('include', 'provide'), Count: 1282
# Itemset: ('help', 'receive'), Count: 1282
# Itemset: ('end', 'point'), Count: 1282
# Itemset: ('meeting', 'team'), Count: 1282
# Itemset: ('group', 'problem'), Count: 1282
# Itemset: ('business', 'position'), Count: 1281
# Itemset: ('comment', 'power'), Count: 1280
# Itemset: ('comment', 'provide'), Count: 1280
# Itemset: ('california', 'pay'), Count: 1280
# Itemset: ('give', 'meeting'), Count: 1279
# Itemset: ('end', 'look'), Count: 1279
# Itemset: ('firm', 'market'), Count: 1279
# Itemset: ('power', 'supply'), Count: 1279
# Itemset: ('change', 'plan'), Count: 1278
# Itemset: ('include', 'power'), Count: 1278
# Itemset: ('business', 'team'), Count: 1278
# Itemset: ('energy', 'member'), Count: 1278
# Itemset: ('based', 'group'), Count: 1278
# Itemset: ('contract', 'meeting'), Count: 1278
# Itemset: ('number', 'office'), Count: 1277
# Itemset: ('end', 'part'), Count: 1277
# Itemset: ('price', 'provide'), Count: 1277
# Itemset: ('end', 'issue'), Count: 1277
# Itemset: ('billion', 'energy'), Count: 1277
# Itemset: ('high', 'plan'), Count: 1276
# Itemset: ('generation', 'power'), Count: 1276
# Itemset: ('deal', 'going'), Count: 1276
# Itemset: ('end', 'energy'), Count: 1276
# Itemset: ('business', 'find'), Count: 1276
# Itemset: ('customer', 'rates'), Count: 1275
# Itemset: ('utilities', 'utility'), Count: 1275
# Itemset: ('look', 'power'), Count: 1275
# Itemset: ('include', 'number'), Count: 1274
# Itemset: ('billion', 'power'), Count: 1273
# Itemset: ('contract', 'going'), Count: 1273
# Itemset: ('set', 'think'), Count: 1273
# Itemset: ('number', 'send'), Count: 1273
# Itemset: ('plan', 'process'), Count: 1271
# Itemset: ('group', 'list'), Count: 1270
# Itemset: ('bill', 'month'), Count: 1270
# Itemset: ('company', 'issue'), Count: 1270
# Itemset: ('give', 'look'), Count: 1270
# Itemset: ('business', 'operation'), Count: 1269
# Itemset: ('company', 'prices'), Count: 1267
# Itemset: ('deal', 'number'), Count: 1267
# Itemset: ('market', 'working'), Count: 1267
# Itemset: ('business', 'future'), Count: 1266
# Itemset: ('date', 'meeting'), Count: 1266
# Itemset: ('market', 'past'), Count: 1266
# Itemset: ('california', 'companies'), Count: 1266
# Itemset: ('credit', 'market'), Count: 1265
# Itemset: ('company', 'set'), Count: 1265
# Itemset: ('end', 'provide'), Count: 1265
# Itemset: ('companies', 'cost'), Count: 1264
# Itemset: ('general', 'market'), Count: 1263
# Itemset: ('going', 'problem'), Count: 1263
# Itemset: ('california', 'demand'), Count: 1262
# Itemset: ('bill', 'group'), Count: 1262
# Itemset: ('issue', 'report'), Count: 1262
# Itemset: ('provide', 'support'), Count: 1262
# Itemset: ('going', 'issue'), Count: 1261
# Itemset: ('business', 'give'), Count: 1261
# Itemset: ('help', 'thing'), Count: 1260
# Itemset: ('point', 'price'), Count: 1260
# Itemset: ('market', 'pay'), Count: 1260
# Itemset: ('business', 'forward'), Count: 1259
# Itemset: ('business', 'received'), Count: 1259
# Itemset: ('business', 'high'), Count: 1259
# Itemset: ('generation', 'market'), Count: 1259
# Itemset: ('commission', 'market'), Count: 1259
# Itemset: ('current', 'number'), Count: 1258
# Itemset: ('issue', 'provide'), Count: 1258
# Itemset: ('contract', 'issue'), Count: 1258
# Itemset: ('market', 'world'), Count: 1258
# Itemset: ('customer', 'think'), Count: 1258
# Itemset: ('look', 'point'), Count: 1258
# Itemset: ('company', 'find'), Count: 1258
# Itemset: ('federal', 'market'), Count: 1257
# Itemset: ('including', 'issue'), Count: 1257
# Itemset: ('help', 'list'), Count: 1256
# Itemset: ('including', 'services'), Count: 1256
# Itemset: ('including', 'order'), Count: 1256
# Itemset: ('able', 'help'), Count: 1256
# Itemset: ('look', 'price'), Count: 1255
# Itemset: ('month', 'offer'), Count: 1255
# Itemset: ('electricity', 'price'), Count: 1255
# Itemset: ('companies', 'report'), Count: 1255
# Itemset: ('current', 'help'), Count: 1255
# Itemset: ('provide', 'review'), Count: 1254
# Itemset: ('group', 'place'), Count: 1254
# Itemset: ('end', 'including'), Count: 1254
# Itemset: ('part', 'price'), Count: 1254
# Itemset: ('company', 'meeting'), Count: 1253
# Itemset: ('issue', 'price'), Count: 1253
# Itemset: ('contract', 'end'), Count: 1253
# Itemset: ('end', 'order'), Count: 1253
# Itemset: ('company', 'think'), Count: 1252
# Itemset: ('meeting', 'order'), Count: 1252
# Itemset: ('market', 'office'), Count: 1252
# Itemset: ('cost', 'result'), Count: 1252
# Itemset: ('meeting', 'thursday'), Count: 1252
# Itemset: ('company', 'going'), Count: 1251
# Itemset: ('part', 'think'), Count: 1251
# Itemset: ('member', 'service'), Count: 1251
# Itemset: ('give', 'plan'), Count: 1250
# Itemset: ('month', 'past'), Count: 1250
# Itemset: ('additional', 'business'), Count: 1249
# Itemset: ('change', 'group'), Count: 1249
# Itemset: ('going', 'part'), Count: 1249
# Itemset: ('month', 'result'), Count: 1249
# Itemset: ('issue', 'point'), Count: 1248
# Itemset: ('california', 'commission'), Count: 1248
# Itemset: ('look', 'report'), Count: 1248
# Itemset: ('company', 'interest'), Count: 1247
# Itemset: ('help', 'part'), Count: 1247
# Itemset: ('offer', 'price'), Count: 1247
# Itemset: ('comment', 'issues'), Count: 1246
# Itemset: ('point', 'report'), Count: 1246
# Itemset: ('market', 'put'), Count: 1246
# Itemset: ('data', 'market'), Count: 1246
# Itemset: ('company', 'management'), Count: 1246
# Itemset: ('comment', 'energy'), Count: 1245
# Itemset: ('give', 'month'), Count: 1245
# Itemset: ('number', 'place'), Count: 1245
# Itemset: ('power', 'term'), Count: 1245
# Itemset: ('market', 'receive'), Count: 1244
# Itemset: ('number', 'offer'), Count: 1244
# Itemset: ('number', 'phone'), Count: 1244
# Itemset: ('include', 'service'), Count: 1244
# Itemset: ('meeting', 'place'), Count: 1243
# Itemset: ('financial', 'month'), Count: 1243
# Itemset: ('energy', 'rates'), Count: 1242
# Itemset: ('financial', 'plan'), Count: 1242
# Itemset: ('companies', 'including'), Count: 1242
# Itemset: ('business', 'continue'), Count: 1242
# Itemset: ('plan', 'problem'), Count: 1242
# Itemset: ('company', 'include'), Count: 1241
# Itemset: ('companies', 'service'), Count: 1241
# Itemset: ('hour', 'start'), Count: 1241
# Itemset: ('billion', 'cost'), Count: 1240
# Itemset: ('action', 'california'), Count: 1240
# Itemset: ('member', 'plan'), Count: 1239
# Itemset: ('customer', 'set'), Count: 1239
# Itemset: ('month', 'pay'), Count: 1239
# Itemset: ('agreement', 'company'), Count: 1239
# Itemset: ('number', 'sure'), Count: 1238
# Itemset: ('contract', 'order'), Count: 1238
# Itemset: ('based', 'month'), Count: 1238
# Itemset: ('offer', 'plan'), Count: 1238
# Itemset: ('deal', 'term'), Count: 1238
# Itemset: ('current', 'price'), Count: 1238
# Itemset: ('comment', 'plan'), Count: 1237
# Itemset: ('report', 'result'), Count: 1237
# Itemset: ('high', 'think'), Count: 1237
# Itemset: ('customer', 'high'), Count: 1237
# Itemset: ('list', 'meeting'), Count: 1237
# Itemset: ('based', 'number'), Count: 1236
# Itemset: ('going', 'price'), Count: 1236
# Itemset: ('business', 'program'), Count: 1236
# Itemset: ('issues', 'point'), Count: 1236
# Itemset: ('point', 'provide'), Count: 1236
# Itemset: ('based', 'business'), Count: 1236
# Itemset: ('change', 'number'), Count: 1236
# Itemset: ('look', 'sure'), Count: 1235
# Itemset: ('based', 'customer'), Count: 1235
# Itemset: ('houston', 'meeting'), Count: 1234
# Itemset: ('company', 'member'), Count: 1234
# Itemset: ('energy', 'generation'), Count: 1233
# Itemset: ('federal', 'power'), Count: 1233
# Itemset: ('california', 'deal'), Count: 1233
# Itemset: ('find', 'number'), Count: 1233
# Itemset: ('additional', 'provide'), Count: 1232
# Itemset: ('action', 'market'), Count: 1232
# Itemset: ('bill', 'business'), Count: 1232
# Itemset: ('help', 'high'), Count: 1232
# Itemset: ('management', 'market'), Count: 1232
# Itemset: ('number', 'team'), Count: 1232
# Itemset: ('process', 'start'), Count: 1231
# Itemset: ('date', 'market'), Count: 1231
# Itemset: ('free', 'help'), Count: 1231
# Itemset: ('group', 'result'), Count: 1231
# Itemset: ('comment', 'issue'), Count: 1231
# Itemset: ('deal', 'part'), Count: 1231
# Itemset: ('plan', 'services'), Count: 1231
# Itemset: ('able', 'think'), Count: 1231
# Itemset: ('find', 'month'), Count: 1230
# Itemset: ('energy', 'rate'), Count: 1230
# Itemset: ('process', 'review'), Count: 1230
# Itemset: ('california', 'ferc'), Count: 1230
# Itemset: ('meeting', 'member'), Count: 1230
# Itemset: ('electricity', 'states'), Count: 1230
# Itemset: ('account', 'customer'), Count: 1229
# Itemset: ('group', 'put'), Count: 1229
# Itemset: ('energy', 'term'), Count: 1229
# Itemset: ('energy', 'hour'), Count: 1229
# Itemset: ('business', 'comment'), Count: 1229
# Itemset: ('current', 'including'), Count: 1229
# Itemset: ('californias', 'power'), Count: 1229
# Itemset: ('electricity', 'prices'), Count: 1228
# Itemset: ('business', 'interest'), Count: 1228
# Itemset: ('california', 'supply'), Count: 1227
# Itemset: ('number', 'working'), Count: 1227
# Itemset: ('california', 'current'), Count: 1227
# Itemset: ('deal', 'end'), Count: 1227
# Itemset: ('review', 'think'), Count: 1227
# Itemset: ('current', 'service'), Count: 1227
# Itemset: ('company', 'issues'), Count: 1227
# Itemset: ('give', 'point'), Count: 1226
# Itemset: ('conference', 'meeting'), Count: 1226
# Itemset: ('end', 'give'), Count: 1226
# Itemset: ('energy', 'interest'), Count: 1226
# Itemset: ('buy', 'power'), Count: 1226
# Itemset: ('change', 'report'), Count: 1226
# Itemset: ('company', 'continue'), Count: 1226
# Itemset: ('price', 'set'), Count: 1225
# Itemset: ('group', 'position'), Count: 1225
# Itemset: ('meeting', 'scheduled'), Count: 1225
# Itemset: ('company', 'support'), Count: 1225
# Itemset: ('group', 'industry'), Count: 1225
# Itemset: ('company', 'public'), Count: 1225
# Itemset: ('energy', 'pay'), Count: 1224
# Itemset: ('issue', 'problem'), Count: 1224
# Itemset: ('help', 'include'), Count: 1224
# Itemset: ('energy', 'office'), Count: 1224
# Itemset: ('california', 'set'), Count: 1223
# Itemset: ('business', 'receive'), Count: 1223
# Itemset: ('group', 'high'), Count: 1223
# Itemset: ('energy', 'result'), Count: 1223
# Itemset: ('deal', 'issue'), Count: 1223
# Itemset: ('report', 'set'), Count: 1223
# Itemset: ('energy', 'services'), Count: 1222
# Itemset: ('comment', 'think'), Count: 1222
# Itemset: ('issue', 'part'), Count: 1222
# Itemset: ('date', 'hour'), Count: 1221
# Itemset: ('getting', 'think'), Count: 1221
# Itemset: ('bill', 'company'), Count: 1221
# Itemset: ('energy', 'look'), Count: 1221
# Itemset: ('energy', 'gas'), Count: 1221
# Itemset: ('bill', 'price'), Count: 1220
# Itemset: ('companies', 'provide'), Count: 1220
# Itemset: ('business', 'world'), Count: 1220
# Itemset: ('company', 'future'), Count: 1220
# Itemset: ('power', 'result'), Count: 1220
# Itemset: ('market', 'review'), Count: 1219
# Itemset: ('business', 'place'), Count: 1219
# Itemset: ('energy', 'point'), Count: 1219
# Itemset: ('change', 'service'), Count: 1219
# Itemset: ('deal', 'including'), Count: 1218
# Itemset: ('ferc', 'market'), Count: 1218
# Itemset: ('help', 'send'), Count: 1218
# Itemset: ('issue', 'number'), Count: 1218
# Itemset: ('month', 'working'), Count: 1217
# Itemset: ('provide', 'think'), Count: 1217
# Itemset: ('end', 'problem'), Count: 1217
# Itemset: ('california', 'forward'), Count: 1217
# Itemset: ('business', 'public'), Count: 1216
# Itemset: ('power', 'rate'), Count: 1216
# Itemset: ('due', 'group'), Count: 1216
# Itemset: ('companies', 'price'), Count: 1215
# Itemset: ('high', 'part'), Count: 1215
# Itemset: ('access', 'business'), Count: 1215
# Itemset: ('part', 'point'), Count: 1215
# Itemset: ('business', 'product'), Count: 1214
# Itemset: ('business', 'problem'), Count: 1214
# Itemset: ('able', 'group'), Count: 1214
# Itemset: ('help', 'put'), Count: 1213
# Itemset: ('including', 'think'), Count: 1213
# Itemset: ('find', 'look'), Count: 1213
# Itemset: ('deal', 'look'), Count: 1213
# Itemset: ('additional', 'cost'), Count: 1212
# Itemset: ('contract', 'current'), Count: 1212
# Itemset: ('group', 'thing'), Count: 1212
# Itemset: ('future', 'plan'), Count: 1212
# Itemset: ('end', 'high'), Count: 1212
# Itemset: ('end', 'set'), Count: 1212
# Itemset: ('issues', 'month'), Count: 1212
# Itemset: ('service', 'set'), Count: 1212
# Itemset: ('find', 'going'), Count: 1211
# Itemset: ('hope', 'think'), Count: 1211
# Itemset: ('issues', 'review'), Count: 1211
# Itemset: ('basis', 'review'), Count: 1211
# Itemset: ('place', 'plan'), Count: 1210
# Itemset: ('group', 'public'), Count: 1210
# Itemset: ('business', 'trading'), Count: 1210
# Itemset: ('company', 'investment'), Count: 1210
# Itemset: ('cost', 'forward'), Count: 1210
# Itemset: ('continue', 'energy'), Count: 1210
# Itemset: ('energy', 'federal'), Count: 1210
# Itemset: ('company', 'firm'), Count: 1210
# Itemset: ('issue', 'set'), Count: 1209
# Itemset: ('california', 'corp'), Count: 1209
# Itemset: ('find', 'report'), Count: 1209
# Itemset: ('consumer', 'cost'), Count: 1209
# Itemset: ('companies', 'part'), Count: 1209
# Itemset: ('high', 'number'), Count: 1209
# Itemset: ('look', 'problem'), Count: 1209
# Itemset: ('going', 'put'), Count: 1209
# Itemset: ('houston', 'texas'), Count: 1208
# Itemset: ('company', 'point'), Count: 1208
# Itemset: ('billion', 'california'), Count: 1208
# Itemset: ('create', 'review'), Count: 1208
# Itemset: ('company', 'product'), Count: 1207
# Itemset: ('business', 'free'), Count: 1207
# Itemset: ('industry', 'power'), Count: 1207
# Itemset: ('number', 'thing'), Count: 1207
# Itemset: ('monday', 'tuesday'), Count: 1207
# Itemset: ('business', 'prices'), Count: 1206
# Itemset: ('including', 'offer'), Count: 1206
# Itemset: ('electricity', 'utilities'), Count: 1205
# Itemset: ('issues', 'process'), Count: 1205
# Itemset: ('including', 'issues'), Count: 1205
# Itemset: ('help', 'review'), Count: 1205
# Itemset: ('access', 'service'), Count: 1204
# Itemset: ('access', 'group'), Count: 1204
# Itemset: ('california', 'office'), Count: 1204
# Itemset: ('agreement', 'power'), Count: 1204
# Itemset: ('talk', 'think'), Count: 1204
# Itemset: ('market', 'open'), Count: 1204
# Itemset: ('group', 'offer'), Count: 1204
# Itemset: ('date', 'energy'), Count: 1203
# Itemset: ('deal', 'point'), Count: 1203
# Itemset: ('forward', 'plan'), Count: 1203
# Itemset: ('business', 'firm'), Count: 1203
# Itemset: ('issues', 'problem'), Count: 1203
# Itemset: ('look', 'review'), Count: 1202
# Itemset: ('cost', 'demand'), Count: 1202
# Itemset: ('cost', 'services'), Count: 1202
# Itemset: ('data', 'date'), Count: 1202
# Itemset: ('price', 'utility'), Count: 1202
# Itemset: ('market', 'thing'), Count: 1202
# Itemset: ('continue', 'group'), Count: 1201
# Itemset: ('month', 'support'), Count: 1201
# Itemset: ('create', 'offer'), Count: 1201
# Itemset: ('customer', 'going'), Count: 1201
# Itemset: ('major', 'market'), Count: 1201
# Itemset: ('company', 'office'), Count: 1201
# Itemset: ('future', 'group'), Count: 1200
# Itemset: ('market', 'sales'), Count: 1200
# Itemset: ('list', 'number'), Count: 1200
# Itemset: ('group', 'management'), Count: 1200
# Itemset: ('forward', 'issues'), Count: 1200
# Itemset: ('additional', 'group'), Count: 1200
# Itemset: ('find', 'plan'), Count: 1200
# Itemset: ('issues', 'look'), Count: 1199
# Itemset: ('based', 'company'), Count: 1199
# Itemset: ('energy', 'operation'), Count: 1199
# Itemset: ('current', 'issues'), Count: 1199
# Itemset: ('company', 'international'), Count: 1198
# Itemset: ('look', 'working'), Count: 1198
# Itemset: ('comment', 'report'), Count: 1197
# Itemset: ('effort', 'energy'), Count: 1197
# Itemset: ('help', 'services'), Count: 1197
# Itemset: ('month', 'states'), Count: 1197
# Itemset: ('group', 'interest'), Count: 1197
# Itemset: ('price', 'utilities'), Count: 1196
# Itemset: ('based', 'plan'), Count: 1196
# Itemset: ('meet', 'plan'), Count: 1196
# Itemset: ('cost', 'decision'), Count: 1196
# Itemset: ('price', 'states'), Count: 1196
# Itemset: ('expected', 'market'), Count: 1195
# Itemset: ('cost', 'public'), Count: 1195
# Itemset: ('plan', 'result'), Count: 1195
# Itemset: ('report', 'team'), Count: 1195
# Itemset: ('companies', 'industry'), Count: 1195
# Itemset: ('look', 'provide'), Count: 1194
# Itemset: ('meeting', 'tuesday'), Count: 1194
# Itemset: ('group', 'operation'), Count: 1194
# Itemset: ('able', 'market'), Count: 1194
# Itemset: ('demand', 'price'), Count: 1193
# Itemset: ('include', 'report'), Count: 1193
# Itemset: ('corp', 'service'), Count: 1192
# Itemset: ('deal', 'provide'), Count: 1192
# Itemset: ('action', 'power'), Count: 1192
# Itemset: ('discussion', 'meeting'), Count: 1191
# Itemset: ('access', 'direct'), Count: 1191
# Itemset: ('pay', 'plan'), Count: 1190
# Itemset: ('corp', 'create'), Count: 1190
# Itemset: ('free', 'market'), Count: 1190
# Itemset: ('states', 'utilities'), Count: 1190
# Itemset: ('based', 'including'), Count: 1190
# Itemset: ('deal', 'report'), Count: 1190
# Itemset: ('development', 'market'), Count: 1190
# Itemset: ('issue', 'service'), Count: 1190
# Itemset: ('forward', 'review'), Count: 1190
# Itemset: ('plan', 'team'), Count: 1189
# Itemset: ('market', 'policy'), Count: 1189
# Itemset: ('address', 'business'), Count: 1189
# Itemset: ('order', 'set'), Count: 1189
# Itemset: ('contract', 'help'), Count: 1189
# Itemset: ('energy', 'natural_gas'), Count: 1188
# Itemset: ('business', 'term'), Count: 1188
# Itemset: ('companies', 'financial'), Count: 1188
# Itemset: ('monday', 'number'), Count: 1188
# Itemset: ('customer', 'problem'), Count: 1188
# Itemset: ('provide', 'result'), Count: 1187
# Itemset: ('find', 'offer'), Count: 1187
# Itemset: ('power', 'services'), Count: 1187
# Itemset: ('comment', 'customer'), Count: 1187
# Itemset: ('deal', 'service'), Count: 1187
# Itemset: ('end', 'issues'), Count: 1186
# Itemset: ('customer', 'result'), Count: 1186
# Itemset: ('higher', 'market'), Count: 1186
# Itemset: ('forward', 'provide'), Count: 1186
# Itemset: ('deal', 'offer'), Count: 1185
# Itemset: ('electric', 'energy'), Count: 1185
# Itemset: ('find', 'power'), Count: 1185
# Itemset: ('business', 'director'), Count: 1184
# Itemset: ('problem', 'report'), Count: 1184
# Itemset: ('customer', 'point'), Count: 1184
# Itemset: ('effort', 'plan'), Count: 1184
# Itemset: ('report', 'services'), Count: 1184
# Itemset: ('cost', 'support'), Count: 1183
# Itemset: ('meeting', 'part'), Count: 1183
# Itemset: ('due', 'month'), Count: 1183
# Itemset: ('current', 'issue'), Count: 1182
# Itemset: ('current', 'end'), Count: 1182
# Itemset: ('current', 'part'), Count: 1182
# Itemset: ('business', 'general'), Count: 1182
# Itemset: ('gas', 'group'), Count: 1181
# Itemset: ('decision', 'power'), Count: 1181
# Itemset: ('price', 'problem'), Count: 1181
# Itemset: ('including', 'point'), Count: 1181
# Itemset: ('address', 'service'), Count: 1181
# Itemset: ('contract', 'set'), Count: 1181
# Itemset: ('company', 'process'), Count: 1181
# Itemset: ('contract', 'point'), Count: 1181
# Itemset: ('date', 'file'), Count: 1181
# Itemset: ('going', 'set'), Count: 1180
# Itemset: ('customer', 'decision'), Count: 1180
# Itemset: ('interest', 'power'), Count: 1180
# Itemset: ('price', 'term'), Count: 1180
# Itemset: ('generator', 'power'), Count: 1179
# Itemset: ('going', 'issues'), Count: 1179
# Itemset: ('final', 'process'), Count: 1179
# Itemset: ('company', 'electricity'), Count: 1178
# Itemset: ('electricity', 'utility'), Count: 1178
# Itemset: ('help', 'office'), Count: 1178
# Itemset: ('commission', 'customer'), Count: 1178
# Itemset: ('california', 'look'), Count: 1178
# Itemset: ('find', 'service'), Count: 1177
# Itemset: ('able', 'number'), Count: 1177
# Itemset: ('date', 'service'), Count: 1177
# Itemset: ('energy', 'firm'), Count: 1176
# Itemset: ('cost', 'due'), Count: 1176
# Itemset: ('contract', 'issues'), Count: 1176
# Itemset: ('additional', 'company'), Count: 1176
# Itemset: ('company', 'general'), Count: 1175
# Itemset: ('friday', 'monday'), Count: 1175
# Itemset: ('issues', 'part'), Count: 1174
# Itemset: ('change', 'month'), Count: 1174
# Itemset: ('current', 'meeting'), Count: 1174
# Itemset: ('company', 'problem'), Count: 1174
# Itemset: ('california', 'summer'), Count: 1174
# Itemset: ('offer', 'think'), Count: 1174
# Itemset: ('contract', 'create'), Count: 1173
# Itemset: ('number', 'result'), Count: 1173
# Itemset: ('address', 'number'), Count: 1173
# Itemset: ('commission', 'energy'), Count: 1172
# Itemset: ('company', 'position'), Count: 1172
# Itemset: ('help', 'received'), Count: 1172
# Itemset: ('start', 'think'), Count: 1172
# Itemset: ('pay', 'price'), Count: 1172
# Itemset: ('month', 'term'), Count: 1171
# Itemset: ('help', 'member'), Count: 1171
# Itemset: ('additional', 'number'), Count: 1171
# Itemset: ('californias', 'energy'), Count: 1171
# Itemset: ('comment', 'cost'), Count: 1170
# Itemset: ('high', 'report'), Count: 1170
# Itemset: ('based', 'power'), Count: 1170
# Itemset: ('corp', 'month'), Count: 1170
# Itemset: ('based', 'price'), Count: 1170
# Itemset: ('believe', 'think'), Count: 1170
# Itemset: ('conference', 'number'), Count: 1170
# Itemset: ('date', 'order'), Count: 1170
# Itemset: ('customer', 'process'), Count: 1170
# Itemset: ('economic', 'market'), Count: 1169
# Itemset: ('end', 'thing'), Count: 1169
# Itemset: ('look', 'part'), Count: 1169
# Itemset: ('capacity', 'market'), Count: 1169
# Itemset: ('effort', 'help'), Count: 1169
# Itemset: ('consumer', 'customer'), Count: 1168
# Itemset: ('change', 'customer'), Count: 1168
# Itemset: ('high', 'service'), Count: 1168
# Itemset: ('business', 'investment'), Count: 1168
# Itemset: ('group', 'houston'), Count: 1168
# Itemset: ('customer', 'electricity'), Count: 1168
# Itemset: ('free', 'service'), Count: 1168
# Itemset: ('access', 'company'), Count: 1167
# Itemset: ('discuss', 'group'), Count: 1167
# Itemset: ('agreement', 'market'), Count: 1166
# Itemset: ('conference', 'market'), Count: 1166
# Itemset: ('based', 'energy'), Count: 1166
# Itemset: ('california', 'include'), Count: 1166
# ...
# Itemset: ('additional', 'plan'), Count: 1157
# Itemset: ('california', 'support'), Count: 1157
# Itemset: ('according', 'market'), Count: 1157
# Itemset: ('company', 'pay'), Count: 1156
# Itemset: ('customer', 'look'), Count: 1156
# Itemset: ('month', 'thing'), Count: 1156
# Itemset: ('market', 'trade'), Count: 1156
# Itemset: ('based', 'california'), Count: 1156
# Itemset: ('hour', 'process'), Count: 1155
# Itemset: ('market', 'option'), Count: 1155
# Itemset: ('including', 'set'), Count: 1155
# Itemset: ('deal', 'meeting'), Count: 1154
# Itemset: ('company', 'past'), Count: 1154
# Itemset: ('company', 'states'), Count: 1154
# Itemset: ('office', 'power'), Count: 1154
# Itemset: ('comment', 'look'), Count: 1154
# Itemset: ('effort', 'power'), Count: 1154
# Itemset: ('help', 'place'), Count: 1154
# Itemset: ('high', 'including'), Count: 1153
# Itemset: ('customer', 'financial'), Count: 1153
# Itemset: ('market', 'view'), Count: 1153
# Itemset: ('address', 'help'), Count: 1152
# Itemset: ('commission', 'power'), Count: 1152
# Itemset: ('part', 'set'), Count: 1152
# Itemset: ('decision', 'plan'), Count: 1152
# Itemset: ('cost', 'offer'), Count: 1151
# Itemset: ('able', 'going'), Count: 1151
# Itemset: ('issues', 'set'), Count: 1151
# Itemset: ('sure', 'thing'), Count: 1151
# Itemset: ('future', 'help'), Count: 1151
# Itemset: ('buy', 'price'), Count: 1151
# Itemset: ('action', 'energy'), Count: 1151
# Itemset: ('including', 'look'), Count: 1151
# Itemset: ('monday', 'plan'), Count: 1151
# Itemset: ('basis', 'corp'), Count: 1151
# Itemset: ('look', 'offer'), Count: 1151
# Itemset: ('lot', 'think'), Count: 1151
# Itemset: ('company', 'federal'), Count: 1150
# Itemset: ('change', 'help'), Count: 1150
# Itemset: ('give', 'report'), Count: 1150
# Itemset: ('group', 'monday'), Count: 1150
# Itemset: ('deal', 'set'), Count: 1149
# Itemset: ('date', 'plan'), Count: 1149
# Itemset: ('demand', 'month'), Count: 1149
# Itemset: ('houston', 'number'), Count: 1149
# Itemset: ('cost', 'process'), Count: 1149
# Itemset: ('corp', 'cost'), Count: 1149
# Itemset: ('bill', 'report'), Count: 1149
# Itemset: ('power', 'summer'), Count: 1149
# Itemset: ('office', 'report'), Count: 1149
# Itemset: ('number', 'process'), Count: 1148
# Itemset: ('agreement', 'plan'), Count: 1148
# Itemset: ('current', 'deal'), Count: 1148
# Itemset: ('contract', 'including'), Count: 1148
# Itemset: ('number', 'services'), Count: 1148
# Itemset: ('address', 'company'), Count: 1147
# Itemset: ('big', 'going'), Count: 1147
# Itemset: ('company', 'utility'), Count: 1147
# Itemset: ('additional', 'customer'), Count: 1147
# Itemset: ('companies', 'help'), Count: 1146
# Itemset: ('end', 'offer'), Count: 1146
# Itemset: ('office', 'provide'), Count: 1146
# Itemset: ('general', 'group'), Count: 1145
# Itemset: ('power', 'sell'), Count: 1145
# Itemset: ('find', 'price'), Count: 1145
# Itemset: ('comment', 'number'), Count: 1144
# Itemset: ('agreement', 'energy'), Count: 1144
# Itemset: ('energy', 'find'), Count: 1144
# Itemset: ('month', 'put'), Count: 1144
# Itemset: ('market', 'received'), Count: 1144
# Itemset: ('financial', 'including'), Count: 1144
# Itemset: ('continue', 'plan'), Count: 1144
# Itemset: ('account', 'market'), Count: 1143
# Itemset: ('decision', 'energy'), Count: 1143
# Itemset: ('friday', 'number'), Count: 1143
# Itemset: ('against', 'market'), Count: 1143
# Itemset: ('give', 'power'), Count: 1143
# Itemset: ('business', 'detail'), Count: 1143
# Itemset: ('group', 'sure'), Count: 1143
# Itemset: ('going', 'place'), Count: 1142
# Itemset: ('friday', 'group'), Count: 1142
# Itemset: ('buy', 'company'), Count: 1142
# Itemset: ('member', 'provide'), Count: 1141
# Itemset: ('company', 'give'), Count: 1141
# Itemset: ('price', 'rates'), Count: 1141
# Itemset: ('deal', 'financial'), Count: 1141
# Itemset: ('group', 'past'), Count: 1141
# Itemset: ('company', 'executive'), Count: 1141
# Itemset: ('business', 'thing'), Count: 1141
# Itemset: ('receive', 'service'), Count: 1141
# Itemset: ('bill', 'pay'), Count: 1141
# Itemset: ('number', 'review'), Count: 1141
# Itemset: ('report', 'support'), Count: 1141
# Itemset: ('able', 'cost'), Count: 1141
# Itemset: ('california', 'decision'), Count: 1140
# Itemset: ('prices', 'utilities'), Count: 1140
# Itemset: ('executive', 'market'), Count: 1140
# Itemset: ('month', 'process'), Count: 1140
# Itemset: ('decision', 'group'), Count: 1140
# Itemset: ('group', 'project'), Count: 1140
# Itemset: ('include', 'part'), Count: 1140
# Itemset: ('end', 'put'), Count: 1140
# Itemset: ('detail', 'market'), Count: 1139
# Itemset: ('continue', 'report'), Count: 1139
# Itemset: ('power', 'review'), Count: 1139
# Itemset: ('believe', 'market'), Count: 1139
# Itemset: ('find', 'order'), Count: 1139
# Itemset: ('provide', 'set'), Count: 1139
# Itemset: ('energy', 'general'), Count: 1139
# Itemset: ('addition', 'market'), Count: 1138
# Itemset: ('companies', 'deal'), Count: 1138
# Itemset: ('getting', 'going'), Count: 1138
# Itemset: ('market', 'money'), Count: 1138
# Itemset: ('result', 'service'), Count: 1138
# Itemset: ('meeting', 'problem'), Count: 1137
# Itemset: ('change', 'price'), Count: 1137
# Itemset: ('customer', 'future'), Count: 1137
# Itemset: ('able', 'plan'), Count: 1137
# Itemset: ('contract', 'part'), Count: 1137
# Itemset: ('industry', 'report'), Count: 1137
# Itemset: ('group', 'term'), Count: 1137
# Itemset: ('financial', 'report'), Count: 1137
# Itemset: ('customer', 'receive'), Count: 1137
# Itemset: ('including', 'prices'), Count: 1137
# Itemset: ('billion', 'business'), Count: 1137
# Itemset: ('message', 'prohibited'), Count: 1136
# Itemset: ('company', 'received'), Count: 1136
# Itemset: ('offer', 'order'), Count: 1136
# Itemset: ('month', 'office'), Count: 1136
# Itemset: ('due', 'plan'), Count: 1136
# Itemset: ('bill', 'issue'), Count: 1136
# Itemset: ('business', 'houston'), Count: 1136
# Itemset: ('global', 'market'), Count: 1135
# Itemset: ('plan', 'put'), Count: 1135
# Itemset: ('order', 'receive'), Count: 1135
# Itemset: ('discuss', 'issues'), Count: 1135
# Itemset: ('andor', 'review'), Count: 1135
# Itemset: ('billion', 'month'), Count: 1135
# Itemset: ('business', 'executive'), Count: 1134
# Itemset: ('agreement', 'service'), Count: 1134
# Itemset: ('market', 'project'), Count: 1134
# Itemset: ('including', 'result'), Count: 1134
# Itemset: ('going', 'high'), Count: 1133
# Itemset: ('change', 'power'), Count: 1133
# Itemset: ('customer', 'term'), Count: 1133
# Itemset: ('bill', 'service'), Count: 1133
# Itemset: ('plan', 'states'), Count: 1133
# Itemset: ('group', 'received'), Count: 1133
# Itemset: ('additional', 'california'), Count: 1133
# Itemset: ('business', 'risk'), Count: 1133
# Itemset: ('order', 'prices'), Count: 1133
# Itemset: ('company', 'sales'), Count: 1133
# Itemset: ('industry', 'month'), Count: 1133
# Itemset: ('including', 'support'), Count: 1133
# Itemset: ('market', 'natural_gas'), Count: 1133
# Itemset: ('click', 'receive'), Count: 1133
# Itemset: ('current', 'support'), Count: 1132
# Itemset: ('date', 'received'), Count: 1132
# Itemset: ('business', 'put'), Count: 1132
# Itemset: ('prices', 'report'), Count: 1132
# Itemset: ('asked', 'think'), Count: 1132
# Itemset: ('energy', 'offer'), Count: 1132
# Itemset: ('deal', 'find'), Count: 1132
# Itemset: ('energy', 'future'), Count: 1131
# Itemset: ('corp', 'report'), Count: 1131
# Itemset: ('find', 'provide'), Count: 1131
# Itemset: ('interest', 'plan'), Count: 1131
# Itemset: ('receive', 'received'), Count: 1131
# Itemset: ('electricity', 'month'), Count: 1130
# Itemset: ('power', 'process'), Count: 1130
# Itemset: ('report', 'think'), Count: 1130
# Itemset: ('number', 'position'), Count: 1130
# Itemset: ('business', 'level'), Count: 1130
# Itemset: ('market', 'solution'), Count: 1130
# Itemset: ('include', 'month'), Count: 1129
# Itemset: ('change', 'energy'), Count: 1129
# Itemset: ('customer', 'date'), Count: 1129
# Itemset: ('market', 'summer'), Count: 1129
# Itemset: ('issues', 'price'), Count: 1129
# Itemset: ('offer', 'power'), Count: 1129
# Itemset: ('contract', 'party'), Count: 1129
# Itemset: ('point', 'service'), Count: 1128
# Itemset: ('amount', 'cost'), Count: 1128
# Itemset: ('company', 'major'), Count: 1128
# Itemset: ('friday', 'market'), Count: 1128
# Itemset: ('change', 'including'), Count: 1128
# Itemset: ('companies', 'corp'), Count: 1128
# Itemset: ('company', 'due'), Count: 1128
# Itemset: ('corp', 'number'), Count: 1128
# Itemset: ('continue', 'power'), Count: 1128
# Itemset: ('financial', 'provide'), Count: 1127
# Itemset: ('number', 'receive'), Count: 1127
# Itemset: ('order', 'part'), Count: 1127
# Itemset: ('look', 'place'), Count: 1127
# Itemset: ('forward', 'price'), Count: 1127
# Itemset: ('meeting', 'thing'), Count: 1127
# Itemset: ('agreement', 'group'), Count: 1126
# Itemset: ('large', 'market'), Count: 1126
# Itemset: ('comment', 'order'), Count: 1125
# Itemset: ('effort', 'month'), Count: 1125
# Itemset: ('business', 'development'), Count: 1125
# Itemset: ('due', 'help'), Count: 1125
# Itemset: ('companies', 'high'), Count: 1125
# Itemset: ('director', 'market'), Count: 1124
# Itemset: ('contract', 'forward'), Count: 1124
# Itemset: ('send', 'think'), Count: 1124
# Itemset: ('billion', 'plan'), Count: 1124
# Itemset: ('power', 'working'), Count: 1124
# Itemset: ('look', 'set'), Count: 1124
# Itemset: ('business', 'due'), Count: 1123
# Itemset: ('cost', 'give'), Count: 1123
# Itemset: ('business', 'meet'), Count: 1123
# Itemset: ('help', 'hope'), Count: 1123
# Itemset: ('california', 'result'), Count: 1123
# Itemset: ('change', 'current'), Count: 1123
# Itemset: ('corp', 'customer'), Count: 1122
# Itemset: ('corp', 'help'), Count: 1122
# Itemset: ('fax', 'phone'), Count: 1122
# Itemset: ('member', 'report'), Count: 1122
# Itemset: ('customer', 'give'), Count: 1122
# Itemset: ('making', 'market'), Count: 1122
# Itemset: ('company', 'term'), Count: 1122
# Itemset: ('able', 'meeting'), Count: 1122
# Itemset: ('gas', 'meeting'), Count: 1121
# Itemset: ('month', 'place'), Count: 1121
# Itemset: ('point', 'sure'), Count: 1121
# Itemset: ('energy', 'review'), Count: 1121
# Itemset: ('cost', 'interest'), Count: 1121
# Itemset: ('give', 'thing'), Count: 1120
# Itemset: ('month', 'services'), Count: 1120
# Itemset: ('cost', 'term'), Count: 1119
# Itemset: ('number', 'put'), Count: 1119
# Itemset: ('end', 'result'), Count: 1119
# Itemset: ('company', 'effort'), Count: 1119
# Itemset: ('customer', 'states'), Count: 1119
# Itemset: ('including', 'public'), Count: 1119
# Itemset: ('contract', 'pay'), Count: 1119
# Itemset: ('issue', 'process'), Count: 1119
# Itemset: ('list', 'report'), Count: 1118
# Itemset: ('provide', 'term'), Count: 1118
# Itemset: ('additional', 'energy'), Count: 1118
# Itemset: ('look', 'service'), Count: 1118
# Itemset: ('place', 'think'), Count: 1118
# Itemset: ('company', 'trading'), Count: 1117
# Itemset: ('effort', 'report'), Count: 1117
# Itemset: ('california', 'generator'), Count: 1117
# Itemset: ('meeting', 'price'), Count: 1117
# Itemset: ('team', 'think'), Count: 1117
# Itemset: ('price', 'rate'), Count: 1117
# Itemset: ('number', 'received'), Count: 1117
# Itemset: ('asked', 'group'), Count: 1117
# Itemset: ('according', 'company'), Count: 1116
# Itemset: ('market', 'period'), Count: 1116
# Itemset: ('electric', 'market'), Count: 1116
# Itemset: ('market', 'move'), Count: 1116
# Itemset: ('public', 'report'), Count: 1116
# Itemset: ('power', 'put'), Count: 1116
# Itemset: ('going', 'provide'), Count: 1116
# Itemset: ('company', 'consumer'), Count: 1116
# Itemset: ('effort', 'meeting'), Count: 1115
# Itemset: ('basis', 'receive'), Count: 1115
# Itemset: ('member', 'month'), Count: 1115
# Itemset: ('board', 'market'), Count: 1115
# Itemset: ('list', 'send'), Count: 1115
# Itemset: ('california', 'term'), Count: 1115
# Itemset: ('commission', 'cost'), Count: 1115
# Itemset: ('customer', 'due'), Count: 1115
# Itemset: ('market', 'recent'), Count: 1115
# Itemset: ('going', 'thought'), Count: 1115
# Itemset: ('services', 'support'), Count: 1114
# Itemset: ('company', 'decision'), Count: 1114
# Itemset: ('group', 'send'), Count: 1114
# Itemset: ('able', 'end'), Count: 1114
# Itemset: ('end', 'place'), Count: 1114
# Itemset: ('california', 'generation'), Count: 1114
# Itemset: ('create', 'receive'), Count: 1114
# Itemset: ('price', 'result'), Count: 1113
# Itemset: ('current', 'order'), Count: 1113
# Itemset: ('general', 'power'), Count: 1113
# Itemset: ('conference', 'energy'), Count: 1113
# Itemset: ('customer', 'position'), Count: 1113
# Itemset: ('customer', 'direct'), Count: 1113
# Itemset: ('business', 'decision'), Count: 1113
# Itemset: ('bill', 'number'), Count: 1113
# Itemset: ('forward', 'working'), Count: 1112
# Itemset: ('level', 'month'), Count: 1112
# Itemset: ('credit', 'customer'), Count: 1112
# Itemset: ('deal', 'issues'), Count: 1112
# Itemset: ('plan', 'term'), Count: 1112
# Itemset: ('decision', 'service'), Count: 1112
# Itemset: ('change', 'end'), Count: 1112
# Itemset: ('able', 'business'), Count: 1111
# Itemset: ('due', 'power'), Count: 1111
# Itemset: ('california', 'effort'), Count: 1111
# Itemset: ('end', 'find'), Count: 1111
# Itemset: ('decision', 'issue'), Count: 1111
# Itemset: ('business', 'past'), Count: 1111
# Itemset: ('bill', 'end'), Count: 1111
# Itemset: ('business', 'friday'), Count: 1111
# Itemset: ('cost', 'financial'), Count: 1111
# Itemset: ('prices', 'rates'), Count: 1110
# Itemset: ('cost', 'put'), Count: 1110
# Itemset: ('high', 'problem'), Count: 1110
# Itemset: ('california', 'industry'), Count: 1110
# Itemset: ('plan', 'project'), Count: 1110
# Itemset: ('bill', 'contract'), Count: 1110
# Itemset: ('part', 'problem'), Count: 1109
# Itemset: ('offer', 'part'), Count: 1109
# Itemset: ('market', 'request'), Count: 1109
# Itemset: ('based', 'help'), Count: 1109
# Itemset: ('change', 'offer'), Count: 1109
# Itemset: ('list', 'market'), Count: 1109
# Itemset: ('power', 'thing'), Count: 1109
# Itemset: ('issue', 'support'), Count: 1109
# Itemset: ('future', 'month'), Count: 1108
# Itemset: ('service', 'think'), Count: 1108
# Itemset: ('including', 'meeting'), Count: 1108
# Itemset: ('comment', 'point'), Count: 1108
# Itemset: ('companies', 'services'), Count: 1108
# Itemset: ('agreement', 'customer'), Count: 1108
# Itemset: ('issue', 'look'), Count: 1108
# Itemset: ('deal', 'high'), Count: 1107
# Itemset: ('company', 'demand'), Count: 1107
# Itemset: ('part', 'result'), Count: 1107
# Itemset: ('buy', 'sell'), Count: 1107
# Itemset: ('high', 'point'), Count: 1107
# Itemset: ('cost', 'supply'), Count: 1107
# Itemset: ('company', 'review'), Count: 1106
# Itemset: ('against', 'power'), Count: 1106
# Itemset: ('amount', 'market'), Count: 1106
# Itemset: ('address', 'plan'), Count: 1106
# Itemset: ('committee', 'energy'), Count: 1105
# Itemset: ('number', 'start'), Count: 1105
# Itemset: ('continue', 'month'), Count: 1105
# Itemset: ('market', 'monday'), Count: 1105
# Itemset: ('month', 'public'), Count: 1105
# Itemset: ('operation', 'plan'), Count: 1105
# Itemset: ('final', 'start'), Count: 1105
# Itemset: ('lower', 'market'), Count: 1105
# Itemset: ('comment', 'help'), Count: 1105
# Itemset: ('based', 'service'), Count: 1105
# Itemset: ('group', 'level'), Count: 1104
# Itemset: ('due', 'provide'), Count: 1104
# Itemset: ('find', 'including'), Count: 1104
# Itemset: ('business', 'date'), Count: 1104
# Itemset: ('group', 'risk'), Count: 1104
# Itemset: ('customer', 'public'), Count: 1103
# Itemset: ('process', 'report'), Count: 1103
# Itemset: ('expected', 'month'), Count: 1103
# Itemset: ('energy', 'past'), Count: 1103
# Itemset: ('additional', 'power'), Count: 1103
# Itemset: ('rate', 'service'), Count: 1103
# Itemset: ('early', 'month'), Count: 1103
# Itemset: ('account', 'service'), Count: 1102
# Itemset: ('month', 'utility'), Count: 1102
# Itemset: ('corp', 'services'), Count: 1102
# Itemset: ('billion', 'companies'), Count: 1102
# Itemset: ('end', 'include'), Count: 1102
# Itemset: ('issues', 'working'), Count: 1102
# Itemset: ('financial', 'services'), Count: 1102
# Itemset: ('received', 'review'), Count: 1101
# Itemset: ('address', 'group'), Count: 1101
# Itemset: ('detail', 'group'), Count: 1101
# Itemset: ('problem', 'set'), Count: 1101
# Itemset: ('problem', 'provide'), Count: 1101
# Itemset: ('material', 'review'), Count: 1101
# Itemset: ('business', 'pay'), Count: 1101
# Itemset: ('cost', 'federal'), Count: 1101
# Itemset: ('commission', 'order'), Count: 1101
# Itemset: ('interest', 'month'), Count: 1100
# Itemset: ('hour', 'power'), Count: 1100
# Itemset: ('public', 'service'), Count: 1100
# Itemset: ('going', 'including'), Count: 1100

# %% [markdown]
# ## K = 2 and F = 1000

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=1000)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=1000
#
# Time taken: 44.42 seconds
#
# Total Frequent K-itemsets Found: 2578
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('california', 'utility'), Count: 1500
# Itemset: ('meeting', 'set'), Count: 1499
# Itemset: ('business', 'financial'), Count: 1499
# Itemset: ('number', 'provide'), Count: 1499
# Itemset: ('companies', 'energy'), Count: 1495
# Itemset: ('point', 'think'), Count: 1494
# Itemset: ('number', 'report'), Count: 1493
# Itemset: ('market', 'position'), Count: 1491
# Itemset: ('help', 'power'), Count: 1491
# Itemset: ('bill', 'california'), Count: 1491
# Itemset: ('market', 'offer'), Count: 1490
# Itemset: ('going', 'number'), Count: 1490
# Itemset: ('california', 'meeting'), Count: 1488
# Itemset: ('company', 'corp'), Count: 1486
# Itemset: ('end', 'number'), Count: 1485
# Itemset: ('energy', 'utility'), Count: 1485
# Itemset: ('meeting', 'review'), Count: 1483
# Itemset: ('electricity', 'market'), Count: 1482
# Itemset: ('power', 'report'), Count: 1482
# Itemset: ('california', 'order'), Count: 1482
# Itemset: ('cost', 'including'), Count: 1481
# Itemset: ('group', 'member'), Count: 1481
# Itemset: ('provide', 'service'), Count: 1481
# Itemset: ('feel', 'free'), Count: 1480
# Itemset: ('going', 'plan'), Count: 1480
# Itemset: ('california', 'contract'), Count: 1480
# Itemset: ('business', 'price'), Count: 1480
# Itemset: ('energy', 'part'), Count: 1479
# Itemset: ('cost', 'help'), Count: 1479
# Itemset: ('including', 'plan'), Count: 1477
# Itemset: ('going', 'group'), Count: 1476
# Itemset: ('cost', 'high'), Count: 1475
# Itemset: ('california', 'provide'), Count: 1474
# Itemset: ('look', 'number'), Count: 1474
# Itemset: ('company', 'part'), Count: 1474
# Itemset: ('deal', 'price'), Count: 1473
# Itemset: ('customer', 'utility'), Count: 1473
# Itemset: ('deal', 'month'), Count: 1472
# Itemset: ('energy', 'including'), Count: 1471
# Itemset: ('cost', 'order'), Count: 1471
# Itemset: ('business', 'issues'), Count: 1470
# Itemset: ('going', 'month'), Count: 1468
# Itemset: ('plan', 'report'), Count: 1467
# Itemset: ('cost', 'end'), Count: 1466
# Itemset: ('look', 'meeting'), Count: 1466
# Itemset: ('business', 'support'), Count: 1466
# Itemset: ('california', 'help'), Count: 1465
# Itemset: ('customer', 'help'), Count: 1465
# Itemset: ('group', 'office'), Count: 1463
# Itemset: ('customer', 'number'), Count: 1463
# Itemset: ('business', 'think'), Count: 1462
# Itemset: ('number', 'power'), Count: 1460
# Itemset: ('business', 'current'), Count: 1459
# Itemset: ('group', 'service'), Count: 1458
# Itemset: ('company', 'financial'), Count: 1457
# Itemset: ('help', 'look'), Count: 1457
# Itemset: ('group', 'support'), Count: 1456
# Itemset: ('end', 'plan'), Count: 1456
# Itemset: ('going', 'market'), Count: 1456
# Itemset: ('california', 'issue'), Count: 1456
# Itemset: ('attached', 'review'), Count: 1455
# Itemset: ('order', 'service'), Count: 1454
# Itemset: ('part', 'power'), Count: 1454
# Itemset: ('california', 'number'), Count: 1454
# Itemset: ('cost', 'utility'), Count: 1453
# Itemset: ('power', 'problem'), Count: 1453
# Itemset: ('contract', 'month'), Count: 1452
# Itemset: ('customer', 'including'), Count: 1451
# Itemset: ('energy', 'help'), Count: 1451
# Itemset: ('energy', 'order'), Count: 1450
# Itemset: ('business', 'process'), Count: 1448
# Itemset: ('energy', 'issues'), Count: 1446
# Itemset: ('company', 'price'), Count: 1446
# Itemset: ('site', 'web'), Count: 1446
# Itemset: ('access', 'customer'), Count: 1445
# Itemset: ('group', 'services'), Count: 1444
# Itemset: ('corp', 'market'), Count: 1441
# Itemset: ('cost', 'prices'), Count: 1439
# Itemset: ('month', 'part'), Count: 1438
# Itemset: ('service', 'services'), Count: 1438
# Itemset: ('energy', 'states'), Count: 1438
# Itemset: ('help', 'report'), Count: 1437
# Itemset: ('meeting', 'report'), Count: 1437
# Itemset: ('give', 'going'), Count: 1437
# Itemset: ('including', 'service'), Count: 1437
# Itemset: ('california', 'high'), Count: 1436
# Itemset: ('high', 'power'), Count: 1436
# Itemset: ('company', 'deal'), Count: 1435
# Itemset: ('cost', 'think'), Count: 1435
# Itemset: ('end', 'help'), Count: 1432
# Itemset: ('group', 'team'), Count: 1430
# Itemset: ('market', 'utilities'), Count: 1429
# Itemset: ('help', 'including'), Count: 1428
# Itemset: ('forward', 'group'), Count: 1428
# Itemset: ('current', 'energy'), Count: 1428
# Itemset: ('price', 'process'), Count: 1427
# Itemset: ('current', 'group'), Count: 1427
# Itemset: ('including', 'month'), Count: 1426
# Itemset: ('meeting', 'working'), Count: 1425
# Itemset: ('california', 'problem'), Count: 1425
# Itemset: ('message', 'receive'), Count: 1425
# Itemset: ('company', 'current'), Count: 1425
# Itemset: ('issue', 'power'), Count: 1424
# Itemset: ('find', 'help'), Count: 1423
# Itemset: ('issue', 'plan'), Count: 1423
# Itemset: ('number', 'point'), Count: 1422
# Itemset: ('energy', 'number'), Count: 1421
# Itemset: ('business', 'order'), Count: 1421
# Itemset: ('attached', 'comment'), Count: 1419
# Itemset: ('going', 'meeting'), Count: 1418
# Itemset: ('including', 'report'), Count: 1418
# Itemset: ('forward', 'going'), Count: 1418
# Itemset: ('business', 'include'), Count: 1417
# Itemset: ('receive', 'review'), Count: 1417
# Itemset: ('power', 'service'), Count: 1417
# Itemset: ('date', 'price'), Count: 1417
# Itemset: ('issues', 'plan'), Count: 1417
# Itemset: ('part', 'plan'), Count: 1416
# Itemset: ('current', 'plan'), Count: 1416
# Itemset: ('gas', 'market'), Count: 1415
# Itemset: ('group', 'include'), Count: 1414
# Itemset: ('cost', 'rate'), Count: 1414
# Itemset: ('bill', 'power'), Count: 1414
# Itemset: ('energy', 'public'), Count: 1413
# Itemset: ('market', 'public'), Count: 1413
# Itemset: ('market', 'trading'), Count: 1411
# Itemset: ('order', 'price'), Count: 1411
# Itemset: ('going', 'power'), Count: 1410
# Itemset: ('cost', 'rates'), Count: 1410
# Itemset: ('think', 'thought'), Count: 1409
# Itemset: ('end', 'think'), Count: 1408
# Itemset: ('including', 'provide'), Count: 1408
# Itemset: ('company', 'industry'), Count: 1408
# Itemset: ('level', 'market'), Count: 1407
# Itemset: ('high', 'month'), Count: 1407
# Itemset: ('look', 'plan'), Count: 1406
# Itemset: ('number', 'order'), Count: 1405
# Itemset: ('california', 'service'), Count: 1405
# Itemset: ('group', 'process'), Count: 1403
# Itemset: ('cost', 'going'), Count: 1402
# Itemset: ('meeting', 'monday'), Count: 1402
# Itemset: ('california', 'including'), Count: 1401
# Itemset: ('office', 'plan'), Count: 1401
# Itemset: ('consumer', 'market'), Count: 1401
# Itemset: ('market', 'rates'), Count: 1400
# Itemset: ('companies', 'group'), Count: 1400
# Itemset: ('meeting', 'power'), Count: 1399
# Itemset: ('california', 'report'), Count: 1398
# Itemset: ('friday', 'meeting'), Count: 1398
# Itemset: ('market', 'utility'), Count: 1397
# Itemset: ('comment', 'review'), Count: 1397
# Itemset: ('energy', 'industry'), Count: 1396
# Itemset: ('attached', 'file'), Count: 1396
# Itemset: ('power', 'think'), Count: 1395
# Itemset: ('problem', 'think'), Count: 1395
# Itemset: ('issues', 'power'), Count: 1395
# Itemset: ('end', 'going'), Count: 1395
# Itemset: ('look', 'thing'), Count: 1395
# Itemset: ('business', 'industry'), Count: 1395
# Itemset: ('buy', 'market'), Count: 1392
# Itemset: ('business', 'look'), Count: 1392
# Itemset: ('cost', 'pay'), Count: 1392
# Itemset: ('give', 'help'), Count: 1391
# Itemset: ('business', 'end'), Count: 1390
# Itemset: ('corp', 'review'), Count: 1388
# Itemset: ('put', 'think'), Count: 1387
# Itemset: ('business', 'offer'), Count: 1387
# Itemset: ('market', 'supply'), Count: 1387
# Itemset: ('california', 'think'), Count: 1387
# Itemset: ('find', 'market'), Count: 1386
# Itemset: ('company', 'contract'), Count: 1386
# Itemset: ('interest', 'market'), Count: 1385
# Itemset: ('issues', 'think'), Count: 1384
# Itemset: ('meeting', 'process'), Count: 1384
# Itemset: ('market', 'rate'), Count: 1384
# Itemset: ('companies', 'power'), Count: 1383
# Itemset: ('market', 'process'), Count: 1383
# Itemset: ('include', 'including'), Count: 1382
# Itemset: ('energy', 'high'), Count: 1382
# Itemset: ('number', 'price'), Count: 1382
# Itemset: ('deal', 'think'), Count: 1381
# Itemset: ('deal', 'plan'), Count: 1381
# Itemset: ('customer', 'issue'), Count: 1381
# Itemset: ('group', 'order'), Count: 1380
# Itemset: ('group', 'point'), Count: 1380
# Itemset: ('cost', 'report'), Count: 1379
# Itemset: ('help', 'support'), Count: 1379
# Itemset: ('price', 'report'), Count: 1379
# Itemset: ('issues', 'provide'), Count: 1379
# Itemset: ('give', 'number'), Count: 1378
# Itemset: ('high', 'price'), Count: 1378
# Itemset: ('california', 'issues'), Count: 1377
# Itemset: ('meet', 'meeting'), Count: 1377
# Itemset: ('attached', 'meeting'), Count: 1376
# Itemset: ('contract', 'price'), Count: 1376
# Itemset: ('cost', 'current'), Count: 1376
# Itemset: ('energy', 'issue'), Count: 1376
# Itemset: ('find', 'think'), Count: 1375
# Itemset: ('provide', 'report'), Count: 1375
# Itemset: ('deal', 'help'), Count: 1375
# Itemset: ('cost', 'issue'), Count: 1374
# Itemset: ('corp', 'offer'), Count: 1374
# Itemset: ('business', 'working'), Count: 1373
# Itemset: ('group', 'set'), Count: 1373
# Itemset: ('cost', 'deal'), Count: 1372
# Itemset: ('effort', 'group'), Count: 1371
# Itemset: ('deal', 'energy'), Count: 1368
# Itemset: ('bill', 'customer'), Count: 1367
# Itemset: ('going', 'sure'), Count: 1366
# Itemset: ('current', 'month'), Count: 1366
# Itemset: ('free', 'offer'), Count: 1366
# Itemset: ('forward', 'think'), Count: 1365
# Itemset: ('demand', 'power'), Count: 1364
# Itemset: ('end', 'power'), Count: 1364
# Itemset: ('cost', 'states'), Count: 1363
# Itemset: ('additional', 'market'), Count: 1363
# Itemset: ('market', 'states'), Count: 1363
# Itemset: ('customer', 'end'), Count: 1363
# Itemset: ('group', 'price'), Count: 1362
# Itemset: ('report', 'service'), Count: 1362
# Itemset: ('give', 'group'), Count: 1361
# Itemset: ('current', 'report'), Count: 1361
# Itemset: ('access', 'market'), Count: 1361
# Itemset: ('end', 'report'), Count: 1360
# Itemset: ('meeting', 'provide'), Count: 1360
# Itemset: ('bill', 'cost'), Count: 1360
# Itemset: ('group', 'issue'), Count: 1359
# Itemset: ('market', 'risk'), Count: 1359
# Itemset: ('issues', 'number'), Count: 1356
# Itemset: ('plan', 'price'), Count: 1356
# Itemset: ('date', 'process'), Count: 1356
# Itemset: ('california', 'comment'), Count: 1356
# Itemset: ('cost', 'part'), Count: 1355
# Itemset: ('billion', 'company'), Count: 1355
# Itemset: ('help', 'service'), Count: 1355
# Itemset: ('date', 'number'), Count: 1355
# Itemset: ('california', 'point'), Count: 1354
# Itemset: ('price', 'start'), Count: 1354
# Itemset: ('point', 'power'), Count: 1354
# Itemset: ('company', 'offer'), Count: 1353
# Itemset: ('end', 'service'), Count: 1353
# Itemset: ('billion', 'market'), Count: 1353
# Itemset: ('including', 'number'), Count: 1353
# Itemset: ('comment', 'group'), Count: 1352
# Itemset: ('basis', 'contract'), Count: 1351
# Itemset: ('including', 'part'), Count: 1351
# Itemset: ('plan', 'set'), Count: 1349
# Itemset: ('group', 'review'), Count: 1349
# Itemset: ('bill', 'market'), Count: 1348
# Itemset: ('end', 'meeting'), Count: 1348
# Itemset: ('provide', 'services'), Count: 1348
# Itemset: ('business', 'point'), Count: 1348
# Itemset: ('address', 'market'), Count: 1348
# Itemset: ('forward', 'power'), Count: 1347
# Itemset: ('corp', 'energy'), Count: 1346
# Itemset: ('decision', 'market'), Count: 1346
# Itemset: ('number', 'part'), Count: 1345
# Itemset: ('market', 'member'), Count: 1345
# Itemset: ('business', 'issue'), Count: 1344
# Itemset: ('california', 'end'), Count: 1344
# Itemset: ('california', 'californias'), Count: 1344
# Itemset: ('help', 'price'), Count: 1344
# Itemset: ('part', 'report'), Count: 1343
# Itemset: ('issue', 'month'), Count: 1343
# Itemset: ('customer', 'services'), Count: 1343
# Itemset: ('number', 'set'), Count: 1343
# Itemset: ('market', 'sell'), Count: 1342
# Itemset: ('california', 'public'), Count: 1342
# Itemset: ('gas', 'power'), Count: 1342
# Itemset: ('contract', 'deal'), Count: 1341
# Itemset: ('companies', 'month'), Count: 1341
# Itemset: ('contract', 'receive'), Count: 1340
# Itemset: ('help', 'process'), Count: 1339
# Itemset: ('offer', 'review'), Count: 1339
# Itemset: ('cost', 'utilities'), Count: 1339
# Itemset: ('market', 'product'), Count: 1338
# Itemset: ('customer', 'prices'), Count: 1337
# Itemset: ('continue', 'market'), Count: 1337
# Itemset: ('business', 'management'), Count: 1337
# Itemset: ('change', 'company'), Count: 1337
# Itemset: ('energy', 'include'), Count: 1337
# Itemset: ('cost', 'set'), Count: 1336
# Itemset: ('contract', 'plan'), Count: 1336
# Itemset: ('help', 'working'), Count: 1336
# Itemset: ('help', 'point'), Count: 1335
# Itemset: ('month', 'provide'), Count: 1335
# Itemset: ('power', 'public'), Count: 1335
# Itemset: ('month', 'prices'), Count: 1335
# Itemset: ('customer', 'support'), Count: 1335
# Itemset: ('customer', 'part'), Count: 1334
# Itemset: ('price', 'service'), Count: 1332
# Itemset: ('california', 'part'), Count: 1332
# Itemset: ('california', 'rates'), Count: 1332
# Itemset: ('corp', 'receive'), Count: 1332
# Itemset: ('contract', 'group'), Count: 1332
# Itemset: ('help', 'sure'), Count: 1331
# Itemset: ('current', 'provide'), Count: 1331
# Itemset: ('help', 'problem'), Count: 1330
# Itemset: ('meeting', 'month'), Count: 1330
# Itemset: ('contract', 'service'), Count: 1330
# Itemset: ('end', 'price'), Count: 1330
# Itemset: ('cost', 'problem'), Count: 1329
# Itemset: ('order', 'report'), Count: 1328
# Itemset: ('forward', 'number'), Count: 1327
# Itemset: ('month', 'point'), Count: 1327
# Itemset: ('customer', 'pay'), Count: 1327
# Itemset: ('energy', 'think'), Count: 1327
# Itemset: ('business', 'going'), Count: 1327
# Itemset: ('company', 'order'), Count: 1327
# Itemset: ('cost', 'electricity'), Count: 1326
# Itemset: ('company', 'end'), Count: 1326
# Itemset: ('business', 'contract'), Count: 1325
# Itemset: ('business', 'set'), Count: 1325
# Itemset: ('cost', 'point'), Count: 1324
# Itemset: ('customer', 'include'), Count: 1324
# Itemset: ('companies', 'plan'), Count: 1323
# Itemset: ('customer', 'rate'), Count: 1323
# Itemset: ('business', 'result'), Count: 1323
# Itemset: ('rate', 'rates'), Count: 1322
# Itemset: ('message', 'review'), Count: 1322
# Itemset: ('corp', 'group'), Count: 1322
# Itemset: ('business', 'change'), Count: 1322
# Itemset: ('corp', 'power'), Count: 1322
# Itemset: ('pay', 'power'), Count: 1321
# Itemset: ('energy', 'forward'), Count: 1321
# Itemset: ('power', 'rates'), Count: 1320
# Itemset: ('demand', 'energy'), Count: 1320
# Itemset: ('consumer', 'power'), Count: 1320
# Itemset: ('company', 'high'), Count: 1319
# Itemset: ('plan', 'point'), Count: 1319
# Itemset: ('month', 'order'), Count: 1318
# Itemset: ('part', 'service'), Count: 1317
# Itemset: ('current', 'power'), Count: 1317
# Itemset: ('companies', 'customer'), Count: 1316
# Itemset: ('look', 'month'), Count: 1316
# Itemset: ('customer', 'meeting'), Count: 1316
# Itemset: ('cost', 'meeting'), Count: 1316
# Itemset: ('due', 'report'), Count: 1315
# Itemset: ('cost', 'include'), Count: 1315
# Itemset: ('help', 'issues'), Count: 1314
# Itemset: ('help', 'team'), Count: 1314
# Itemset: ('investment', 'market'), Count: 1314
# Itemset: ('customer', 'offer'), Count: 1314
# Itemset: ('issues', 'report'), Count: 1314
# Itemset: ('month', 'problem'), Count: 1313
# Itemset: ('issue', 'think'), Count: 1312
# Itemset: ('meeting', 'point'), Count: 1312
# Itemset: ('energy', 'process'), Count: 1312
# Itemset: ('forward', 'help'), Count: 1312
# Itemset: ('message', 'offer'), Count: 1311
# Itemset: ('california', 'consumer'), Count: 1310
# Itemset: ('company', 'look'), Count: 1310
# Itemset: ('plan', 'support'), Count: 1309
# Itemset: ('going', 'point'), Count: 1309
# Itemset: ('high', 'prices'), Count: 1309
# Itemset: ('order', 'provide'), Count: 1308
# Itemset: ('bill', 'plan'), Count: 1307
# Itemset: ('price', 'think'), Count: 1306
# Itemset: ('data', 'process'), Count: 1306
# Itemset: ('issue', 'order'), Count: 1306
# Itemset: ('date', 'start'), Count: 1306
# Itemset: ('issues', 'order'), Count: 1305
# Itemset: ('energy', 'problem'), Count: 1305
# Itemset: ('california', 'rate'), Count: 1304
# Itemset: ('california', 'going'), Count: 1303
# Itemset: ('power', 'set'), Count: 1303
# Itemset: ('future', 'market'), Count: 1303
# Itemset: ('energy', 'financial'), Count: 1302
# Itemset: ('order', 'plan'), Count: 1302
# Itemset: ('cost', 'issues'), Count: 1301
# Itemset: ('process', 'provide'), Count: 1301
# Itemset: ('month', 'set'), Count: 1301
# Itemset: ('cost', 'look'), Count: 1300
# Itemset: ('think', 'working'), Count: 1300
# Itemset: ('number', 'problem'), Count: 1300
# Itemset: ('effort', 'market'), Count: 1299
# Itemset: ('contract', 'provide'), Count: 1298
# Itemset: ('customer', 'utilities'), Count: 1298
# Itemset: ('help', 'order'), Count: 1298
# Itemset: ('comment', 'meeting'), Count: 1298
# Itemset: ('find', 'group'), Count: 1297
# Itemset: ('power', 'support'), Count: 1297
# Itemset: ('business', 'member'), Count: 1297
# Itemset: ('part', 'provide'), Count: 1297
# Itemset: ('market', 'place'), Count: 1297
# Itemset: ('business', 'corp'), Count: 1296
# Itemset: ('data', 'price'), Count: 1295
# Itemset: ('offer', 'service'), Count: 1295
# Itemset: ('financial', 'power'), Count: 1294
# Itemset: ('current', 'customer'), Count: 1294
# Itemset: ('energy', 'going'), Count: 1294
# Itemset: ('contract', 'number'), Count: 1293
# Itemset: ('customer', 'report'), Count: 1293
# Itemset: ('energy', 'set'), Count: 1293
# Itemset: ('help', 'issue'), Count: 1293
# Itemset: ('company', 'result'), Count: 1292
# Itemset: ('agreement', 'contract'), Count: 1292
# Itemset: ('consumer', 'energy'), Count: 1292
# Itemset: ('including', 'price'), Count: 1291
# Itemset: ('energy', 'support'), Count: 1291
# Itemset: ('plan', 'review'), Count: 1291
# Itemset: ('contract', 'think'), Count: 1291
# Itemset: ('business', 'effort'), Count: 1291
# Itemset: ('customer', 'issues'), Count: 1290
# Itemset: ('financial', 'group'), Count: 1290
# Itemset: ('plan', 'working'), Count: 1290
# Itemset: ('market', 'operation'), Count: 1289
# Itemset: ('corp', 'plan'), Count: 1289
# Itemset: ('help', 'set'), Count: 1288
# Itemset: ('give', 'market'), Count: 1287
# Itemset: ('based', 'cost'), Count: 1287
# Itemset: ('due', 'market'), Count: 1287
# Itemset: ('customer', 'deal'), Count: 1287
# Itemset: ('california', 'federal'), Count: 1287
# Itemset: ('business', 'review'), Count: 1286
# Itemset: ('issue', 'meeting'), Count: 1286
# Itemset: ('help', 'offer'), Count: 1285
# Itemset: ('hour', 'market'), Count: 1285
# Itemset: ('energy', 'supply'), Count: 1284
# Itemset: ('include', 'plan'), Count: 1283
# Itemset: ('include', 'provide'), Count: 1282
# Itemset: ('help', 'receive'), Count: 1282
# Itemset: ('end', 'point'), Count: 1282
# Itemset: ('meeting', 'team'), Count: 1282
# Itemset: ('group', 'problem'), Count: 1282
# Itemset: ('business', 'position'), Count: 1281
# Itemset: ('comment', 'power'), Count: 1280
# Itemset: ('comment', 'provide'), Count: 1280
# Itemset: ('california', 'pay'), Count: 1280
# Itemset: ('give', 'meeting'), Count: 1279
# Itemset: ('end', 'look'), Count: 1279
# Itemset: ('firm', 'market'), Count: 1279
# Itemset: ('power', 'supply'), Count: 1279
# Itemset: ('change', 'plan'), Count: 1278
# Itemset: ('include', 'power'), Count: 1278
# Itemset: ('business', 'team'), Count: 1278
# Itemset: ('energy', 'member'), Count: 1278
# Itemset: ('based', 'group'), Count: 1278
# Itemset: ('contract', 'meeting'), Count: 1278
# Itemset: ('number', 'office'), Count: 1277
# Itemset: ('end', 'part'), Count: 1277
# Itemset: ('price', 'provide'), Count: 1277
# Itemset: ('end', 'issue'), Count: 1277
# Itemset: ('billion', 'energy'), Count: 1277
# Itemset: ('high', 'plan'), Count: 1276
# Itemset: ('generation', 'power'), Count: 1276
# Itemset: ('deal', 'going'), Count: 1276
# Itemset: ('end', 'energy'), Count: 1276
# Itemset: ('business', 'find'), Count: 1276
# Itemset: ('customer', 'rates'), Count: 1275
# Itemset: ('utilities', 'utility'), Count: 1275
# Itemset: ('look', 'power'), Count: 1275
# Itemset: ('include', 'number'), Count: 1274
# Itemset: ('billion', 'power'), Count: 1273
# Itemset: ('contract', 'going'), Count: 1273
# Itemset: ('set', 'think'), Count: 1273
# Itemset: ('number', 'send'), Count: 1273
# Itemset: ('plan', 'process'), Count: 1271
# Itemset: ('group', 'list'), Count: 1270
# Itemset: ('bill', 'month'), Count: 1270
# Itemset: ('company', 'issue'), Count: 1270
# Itemset: ('give', 'look'), Count: 1270
# Itemset: ('business', 'operation'), Count: 1269
# Itemset: ('company', 'prices'), Count: 1267
# Itemset: ('deal', 'number'), Count: 1267
# Itemset: ('market', 'working'), Count: 1267
# Itemset: ('business', 'future'), Count: 1266
# Itemset: ('date', 'meeting'), Count: 1266
# Itemset: ('market', 'past'), Count: 1266
# Itemset: ('california', 'companies'), Count: 1266
# Itemset: ('credit', 'market'), Count: 1265
# Itemset: ('company', 'set'), Count: 1265
# Itemset: ('end', 'provide'), Count: 1265
# Itemset: ('companies', 'cost'), Count: 1264
# Itemset: ('general', 'market'), Count: 1263
# Itemset: ('going', 'problem'), Count: 1263
# Itemset: ('california', 'demand'), Count: 1262
# Itemset: ('bill', 'group'), Count: 1262
# Itemset: ('issue', 'report'), Count: 1262
# Itemset: ('provide', 'support'), Count: 1262
# Itemset: ('going', 'issue'), Count: 1261
# Itemset: ('business', 'give'), Count: 1261
# Itemset: ('help', 'thing'), Count: 1260
# Itemset: ('point', 'price'), Count: 1260
# Itemset: ('market', 'pay'), Count: 1260
# Itemset: ('business', 'forward'), Count: 1259
# Itemset: ('business', 'received'), Count: 1259
# Itemset: ('business', 'high'), Count: 1259
# Itemset: ('generation', 'market'), Count: 1259
# Itemset: ('commission', 'market'), Count: 1259
# Itemset: ('current', 'number'), Count: 1258
# Itemset: ('issue', 'provide'), Count: 1258
# Itemset: ('contract', 'issue'), Count: 1258
# Itemset: ('market', 'world'), Count: 1258
# Itemset: ('customer', 'think'), Count: 1258
# Itemset: ('look', 'point'), Count: 1258
# Itemset: ('company', 'find'), Count: 1258
# Itemset: ('federal', 'market'), Count: 1257
# Itemset: ('including', 'issue'), Count: 1257
# Itemset: ('help', 'list'), Count: 1256
# Itemset: ('including', 'services'), Count: 1256
# Itemset: ('including', 'order'), Count: 1256
# Itemset: ('able', 'help'), Count: 1256
# Itemset: ('look', 'price'), Count: 1255
# Itemset: ('month', 'offer'), Count: 1255
# Itemset: ('electricity', 'price'), Count: 1255
# Itemset: ('companies', 'report'), Count: 1255
# Itemset: ('current', 'help'), Count: 1255
# Itemset: ('provide', 'review'), Count: 1254
# Itemset: ('group', 'place'), Count: 1254
# Itemset: ('end', 'including'), Count: 1254
# Itemset: ('part', 'price'), Count: 1254
# Itemset: ('company', 'meeting'), Count: 1253
# Itemset: ('issue', 'price'), Count: 1253
# Itemset: ('contract', 'end'), Count: 1253
# Itemset: ('end', 'order'), Count: 1253
# Itemset: ('company', 'think'), Count: 1252
# Itemset: ('meeting', 'order'), Count: 1252
# Itemset: ('market', 'office'), Count: 1252
# Itemset: ('cost', 'result'), Count: 1252
# Itemset: ('meeting', 'thursday'), Count: 1252
# Itemset: ('company', 'going'), Count: 1251
# Itemset: ('part', 'think'), Count: 1251
# Itemset: ('member', 'service'), Count: 1251
# Itemset: ('give', 'plan'), Count: 1250
# Itemset: ('month', 'past'), Count: 1250
# Itemset: ('additional', 'business'), Count: 1249
# Itemset: ('change', 'group'), Count: 1249
# Itemset: ('going', 'part'), Count: 1249
# Itemset: ('month', 'result'), Count: 1249
# Itemset: ('issue', 'point'), Count: 1248
# Itemset: ('california', 'commission'), Count: 1248
# Itemset: ('look', 'report'), Count: 1248
# Itemset: ('company', 'interest'), Count: 1247
# Itemset: ('help', 'part'), Count: 1247
# Itemset: ('offer', 'price'), Count: 1247
# Itemset: ('comment', 'issues'), Count: 1246
# Itemset: ('point', 'report'), Count: 1246
# Itemset: ('market', 'put'), Count: 1246
# Itemset: ('data', 'market'), Count: 1246
# Itemset: ('company', 'management'), Count: 1246
# Itemset: ('comment', 'energy'), Count: 1245
# Itemset: ('give', 'month'), Count: 1245
# Itemset: ('number', 'place'), Count: 1245
# Itemset: ('power', 'term'), Count: 1245
# Itemset: ('market', 'receive'), Count: 1244
# Itemset: ('number', 'offer'), Count: 1244
# Itemset: ('number', 'phone'), Count: 1244
# Itemset: ('include', 'service'), Count: 1244
# Itemset: ('meeting', 'place'), Count: 1243
# Itemset: ('financial', 'month'), Count: 1243
# Itemset: ('energy', 'rates'), Count: 1242
# Itemset: ('financial', 'plan'), Count: 1242
# Itemset: ('companies', 'including'), Count: 1242
# Itemset: ('business', 'continue'), Count: 1242
# Itemset: ('plan', 'problem'), Count: 1242
# Itemset: ('company', 'include'), Count: 1241
# Itemset: ('companies', 'service'), Count: 1241
# Itemset: ('hour', 'start'), Count: 1241
# Itemset: ('billion', 'cost'), Count: 1240
# Itemset: ('action', 'california'), Count: 1240
# Itemset: ('member', 'plan'), Count: 1239
# Itemset: ('customer', 'set'), Count: 1239
# Itemset: ('month', 'pay'), Count: 1239
# Itemset: ('agreement', 'company'), Count: 1239
# Itemset: ('number', 'sure'), Count: 1238
# Itemset: ('contract', 'order'), Count: 1238
# Itemset: ('based', 'month'), Count: 1238
# Itemset: ('offer', 'plan'), Count: 1238
# Itemset: ('deal', 'term'), Count: 1238
# Itemset: ('current', 'price'), Count: 1238
# Itemset: ('comment', 'plan'), Count: 1237
# Itemset: ('report', 'result'), Count: 1237
# Itemset: ('high', 'think'), Count: 1237
# Itemset: ('customer', 'high'), Count: 1237
# Itemset: ('list', 'meeting'), Count: 1237
# Itemset: ('based', 'number'), Count: 1236
# Itemset: ('going', 'price'), Count: 1236
# Itemset: ('business', 'program'), Count: 1236
# Itemset: ('issues', 'point'), Count: 1236
# Itemset: ('point', 'provide'), Count: 1236
# Itemset: ('based', 'business'), Count: 1236
# Itemset: ('change', 'number'), Count: 1236
# Itemset: ('look', 'sure'), Count: 1235
# Itemset: ('based', 'customer'), Count: 1235
# Itemset: ('houston', 'meeting'), Count: 1234
# Itemset: ('company', 'member'), Count: 1234
# Itemset: ('energy', 'generation'), Count: 1233
# Itemset: ('federal', 'power'), Count: 1233
# Itemset: ('california', 'deal'), Count: 1233
# Itemset: ('find', 'number'), Count: 1233
# Itemset: ('additional', 'provide'), Count: 1232
# Itemset: ('action', 'market'), Count: 1232
# Itemset: ('bill', 'business'), Count: 1232
# Itemset: ('help', 'high'), Count: 1232
# Itemset: ('management', 'market'), Count: 1232
# Itemset: ('number', 'team'), Count: 1232
# Itemset: ('process', 'start'), Count: 1231
# Itemset: ('date', 'market'), Count: 1231
# Itemset: ('free', 'help'), Count: 1231
# Itemset: ('group', 'result'), Count: 1231
# Itemset: ('comment', 'issue'), Count: 1231
# Itemset: ('deal', 'part'), Count: 1231
# Itemset: ('plan', 'services'), Count: 1231
# Itemset: ('able', 'think'), Count: 1231
# Itemset: ('find', 'month'), Count: 1230
# Itemset: ('energy', 'rate'), Count: 1230
# Itemset: ('process', 'review'), Count: 1230
# Itemset: ('california', 'ferc'), Count: 1230
# Itemset: ('meeting', 'member'), Count: 1230
# Itemset: ('electricity', 'states'), Count: 1230
# Itemset: ('account', 'customer'), Count: 1229
# Itemset: ('group', 'put'), Count: 1229
# Itemset: ('energy', 'term'), Count: 1229
# Itemset: ('energy', 'hour'), Count: 1229
# Itemset: ('business', 'comment'), Count: 1229
# Itemset: ('current', 'including'), Count: 1229
# Itemset: ('californias', 'power'), Count: 1229
# Itemset: ('electricity', 'prices'), Count: 1228
# Itemset: ('business', 'interest'), Count: 1228
# Itemset: ('california', 'supply'), Count: 1227
# Itemset: ('number', 'working'), Count: 1227
# Itemset: ('california', 'current'), Count: 1227
# Itemset: ('deal', 'end'), Count: 1227
# Itemset: ('review', 'think'), Count: 1227
# Itemset: ('current', 'service'), Count: 1227
# Itemset: ('company', 'issues'), Count: 1227
# Itemset: ('give', 'point'), Count: 1226
# Itemset: ('conference', 'meeting'), Count: 1226
# Itemset: ('end', 'give'), Count: 1226
# Itemset: ('energy', 'interest'), Count: 1226
# Itemset: ('buy', 'power'), Count: 1226
# Itemset: ('change', 'report'), Count: 1226
# Itemset: ('company', 'continue'), Count: 1226
# Itemset: ('price', 'set'), Count: 1225
# Itemset: ('group', 'position'), Count: 1225
# Itemset: ('meeting', 'scheduled'), Count: 1225
# Itemset: ('company', 'support'), Count: 1225
# Itemset: ('group', 'industry'), Count: 1225
# Itemset: ('company', 'public'), Count: 1225
# Itemset: ('energy', 'pay'), Count: 1224
# Itemset: ('issue', 'problem'), Count: 1224
# Itemset: ('help', 'include'), Count: 1224
# Itemset: ('energy', 'office'), Count: 1224
# Itemset: ('california', 'set'), Count: 1223
# Itemset: ('group', 'high'), Count: 1223
# Itemset: ('energy', 'result'), Count: 1223
# Itemset: ('deal', 'issue'), Count: 1223
# Itemset: ('business', 'receive'), Count: 1223
# Itemset: ('report', 'set'), Count: 1223
# Itemset: ('energy', 'services'), Count: 1222
# Itemset: ('comment', 'think'), Count: 1222
# Itemset: ('issue', 'part'), Count: 1222
# Itemset: ('date', 'hour'), Count: 1221
# Itemset: ('getting', 'think'), Count: 1221
# Itemset: ('bill', 'company'), Count: 1221
# Itemset: ('energy', 'look'), Count: 1221
# Itemset: ('energy', 'gas'), Count: 1221
# Itemset: ('bill', 'price'), Count: 1220
# Itemset: ('companies', 'provide'), Count: 1220
# Itemset: ('business', 'world'), Count: 1220
# Itemset: ('company', 'future'), Count: 1220
# Itemset: ('power', 'result'), Count: 1220
# Itemset: ('market', 'review'), Count: 1219
# Itemset: ('business', 'place'), Count: 1219
# Itemset: ('energy', 'point'), Count: 1219
# Itemset: ('change', 'service'), Count: 1219
# Itemset: ('deal', 'including'), Count: 1218
# Itemset: ('ferc', 'market'), Count: 1218
# Itemset: ('help', 'send'), Count: 1218
# Itemset: ('issue', 'number'), Count: 1218
# Itemset: ('month', 'working'), Count: 1217
# Itemset: ('provide', 'think'), Count: 1217
# Itemset: ('end', 'problem'), Count: 1217
# Itemset: ('california', 'forward'), Count: 1217
# Itemset: ('business', 'public'), Count: 1216
# Itemset: ('power', 'rate'), Count: 1216
# Itemset: ('due', 'group'), Count: 1216
# Itemset: ('companies', 'price'), Count: 1215
# Itemset: ('high', 'part'), Count: 1215
# Itemset: ('access', 'business'), Count: 1215
# Itemset: ('part', 'point'), Count: 1215
# Itemset: ('business', 'product'), Count: 1214
# Itemset: ('business', 'problem'), Count: 1214
# Itemset: ('able', 'group'), Count: 1214
# Itemset: ('help', 'put'), Count: 1213
# Itemset: ('including', 'think'), Count: 1213
# Itemset: ('find', 'look'), Count: 1213
# Itemset: ('deal', 'look'), Count: 1213
# Itemset: ('additional', 'cost'), Count: 1212
# Itemset: ('contract', 'current'), Count: 1212
# Itemset: ('group', 'thing'), Count: 1212
# Itemset: ('future', 'plan'), Count: 1212
# Itemset: ('end', 'high'), Count: 1212
# Itemset: ('end', 'set'), Count: 1212
# Itemset: ('issues', 'month'), Count: 1212
# Itemset: ('service', 'set'), Count: 1212
# Itemset: ('find', 'going'), Count: 1211
# Itemset: ('hope', 'think'), Count: 1211
# Itemset: ('issues', 'review'), Count: 1211
# Itemset: ('basis', 'review'), Count: 1211
# Itemset: ('place', 'plan'), Count: 1210
# Itemset: ('group', 'public'), Count: 1210
# Itemset: ('business', 'trading'), Count: 1210
# Itemset: ('company', 'investment'), Count: 1210
# Itemset: ('cost', 'forward'), Count: 1210
# Itemset: ('continue', 'energy'), Count: 1210
# Itemset: ('energy', 'federal'), Count: 1210
# Itemset: ('company', 'firm'), Count: 1210
# Itemset: ('issue', 'set'), Count: 1209
# Itemset: ('california', 'corp'), Count: 1209
# Itemset: ('find', 'report'), Count: 1209
# Itemset: ('consumer', 'cost'), Count: 1209
# Itemset: ('companies', 'part'), Count: 1209
# Itemset: ('high', 'number'), Count: 1209
# Itemset: ('look', 'problem'), Count: 1209
# Itemset: ('going', 'put'), Count: 1209
# Itemset: ('houston', 'texas'), Count: 1208
# Itemset: ('company', 'point'), Count: 1208
# Itemset: ('billion', 'california'), Count: 1208
# Itemset: ('create', 'review'), Count: 1208
# Itemset: ('company', 'product'), Count: 1207
# Itemset: ('business', 'free'), Count: 1207
# Itemset: ('industry', 'power'), Count: 1207
# Itemset: ('number', 'thing'), Count: 1207
# Itemset: ('monday', 'tuesday'), Count: 1207
# Itemset: ('business', 'prices'), Count: 1206
# Itemset: ('including', 'offer'), Count: 1206
# Itemset: ('electricity', 'utilities'), Count: 1205
# Itemset: ('issues', 'process'), Count: 1205
# Itemset: ('including', 'issues'), Count: 1205
# Itemset: ('help', 'review'), Count: 1205
# Itemset: ('access', 'service'), Count: 1204
# Itemset: ('access', 'group'), Count: 1204
# Itemset: ('california', 'office'), Count: 1204
# Itemset: ('agreement', 'power'), Count: 1204
# Itemset: ('talk', 'think'), Count: 1204
# Itemset: ('market', 'open'), Count: 1204
# Itemset: ('group', 'offer'), Count: 1204
# Itemset: ('date', 'energy'), Count: 1203
# Itemset: ('deal', 'point'), Count: 1203
# Itemset: ('forward', 'plan'), Count: 1203
# Itemset: ('business', 'firm'), Count: 1203
# Itemset: ('issues', 'problem'), Count: 1203
# Itemset: ('look', 'review'), Count: 1202
# Itemset: ('cost', 'demand'), Count: 1202
# Itemset: ('cost', 'services'), Count: 1202
# Itemset: ('data', 'date'), Count: 1202
# Itemset: ('price', 'utility'), Count: 1202
# Itemset: ('market', 'thing'), Count: 1202
# Itemset: ('continue', 'group'), Count: 1201
# Itemset: ('month', 'support'), Count: 1201
# Itemset: ('create', 'offer'), Count: 1201
# Itemset: ('customer', 'going'), Count: 1201
# Itemset: ('major', 'market'), Count: 1201
# Itemset: ('company', 'office'), Count: 1201
# Itemset: ('future', 'group'), Count: 1200
# Itemset: ('market', 'sales'), Count: 1200
# Itemset: ('list', 'number'), Count: 1200
# Itemset: ('group', 'management'), Count: 1200
# Itemset: ('forward', 'issues'), Count: 1200
# Itemset: ('additional', 'group'), Count: 1200
# Itemset: ('find', 'plan'), Count: 1200
# Itemset: ('issues', 'look'), Count: 1199
# Itemset: ('based', 'company'), Count: 1199
# Itemset: ('energy', 'operation'), Count: 1199
# Itemset: ('current', 'issues'), Count: 1199
# Itemset: ('company', 'international'), Count: 1198
# Itemset: ('look', 'working'), Count: 1198
# Itemset: ('comment', 'report'), Count: 1197
# Itemset: ('effort', 'energy'), Count: 1197
# Itemset: ('help', 'services'), Count: 1197
# Itemset: ('month', 'states'), Count: 1197
# Itemset: ('group', 'interest'), Count: 1197
# Itemset: ('price', 'utilities'), Count: 1196
# Itemset: ('based', 'plan'), Count: 1196
# Itemset: ('meet', 'plan'), Count: 1196
# Itemset: ('cost', 'decision'), Count: 1196
# Itemset: ('price', 'states'), Count: 1196
# Itemset: ('expected', 'market'), Count: 1195
# Itemset: ('cost', 'public'), Count: 1195
# Itemset: ('plan', 'result'), Count: 1195
# Itemset: ('report', 'team'), Count: 1195
# Itemset: ('companies', 'industry'), Count: 1195
# Itemset: ('look', 'provide'), Count: 1194
# Itemset: ('meeting', 'tuesday'), Count: 1194
# Itemset: ('group', 'operation'), Count: 1194
# Itemset: ('able', 'market'), Count: 1194
# Itemset: ('demand', 'price'), Count: 1193
# Itemset: ('include', 'report'), Count: 1193
# Itemset: ('corp', 'service'), Count: 1192
# Itemset: ('deal', 'provide'), Count: 1192
# Itemset: ('action', 'power'), Count: 1192
# Itemset: ('discussion', 'meeting'), Count: 1191
# Itemset: ('access', 'direct'), Count: 1191
# Itemset: ('pay', 'plan'), Count: 1190
# Itemset: ('corp', 'create'), Count: 1190
# Itemset: ('free', 'market'), Count: 1190
# Itemset: ('states', 'utilities'), Count: 1190
# Itemset: ('based', 'including'), Count: 1190
# Itemset: ('deal', 'report'), Count: 1190
# Itemset: ('development', 'market'), Count: 1190
# Itemset: ('issue', 'service'), Count: 1190
# Itemset: ('forward', 'review'), Count: 1190
# Itemset: ('plan', 'team'), Count: 1189
# Itemset: ('market', 'policy'), Count: 1189
# Itemset: ('address', 'business'), Count: 1189
# Itemset: ('order', 'set'), Count: 1189
# Itemset: ('contract', 'help'), Count: 1189
# Itemset: ('energy', 'natural_gas'), Count: 1188
# Itemset: ('business', 'term'), Count: 1188
# Itemset: ('companies', 'financial'), Count: 1188
# Itemset: ('monday', 'number'), Count: 1188
# Itemset: ('customer', 'problem'), Count: 1188
# Itemset: ('provide', 'result'), Count: 1187
# Itemset: ('find', 'offer'), Count: 1187
# Itemset: ('power', 'services'), Count: 1187
# Itemset: ('comment', 'customer'), Count: 1187
# Itemset: ('deal', 'service'), Count: 1187
# Itemset: ('end', 'issues'), Count: 1186
# Itemset: ('customer', 'result'), Count: 1186
# Itemset: ('higher', 'market'), Count: 1186
# Itemset: ('forward', 'provide'), Count: 1186
# Itemset: ('deal', 'offer'), Count: 1185
# Itemset: ('electric', 'energy'), Count: 1185
# Itemset: ('find', 'power'), Count: 1185
# Itemset: ('business', 'director'), Count: 1184
# Itemset: ('problem', 'report'), Count: 1184
# Itemset: ('customer', 'point'), Count: 1184
# Itemset: ('effort', 'plan'), Count: 1184
# Itemset: ('report', 'services'), Count: 1184
# Itemset: ('cost', 'support'), Count: 1183
# Itemset: ('meeting', 'part'), Count: 1183
# Itemset: ('due', 'month'), Count: 1183
# Itemset: ('current', 'issue'), Count: 1182
# Itemset: ('current', 'end'), Count: 1182
# Itemset: ('current', 'part'), Count: 1182
# Itemset: ('business', 'general'), Count: 1182
# Itemset: ('gas', 'group'), Count: 1181
# Itemset: ('decision', 'power'), Count: 1181
# Itemset: ('price', 'problem'), Count: 1181
# Itemset: ('including', 'point'), Count: 1181
# Itemset: ('address', 'service'), Count: 1181
# Itemset: ('contract', 'set'), Count: 1181
# Itemset: ('company', 'process'), Count: 1181
# Itemset: ('contract', 'point'), Count: 1181
# Itemset: ('date', 'file'), Count: 1181
# Itemset: ('going', 'set'), Count: 1180
# Itemset: ('customer', 'decision'), Count: 1180
# Itemset: ('interest', 'power'), Count: 1180
# Itemset: ('price', 'term'), Count: 1180
# Itemset: ('generator', 'power'), Count: 1179
# Itemset: ('going', 'issues'), Count: 1179
# Itemset: ('final', 'process'), Count: 1179
# Itemset: ('company', 'electricity'), Count: 1178
# Itemset: ('electricity', 'utility'), Count: 1178
# Itemset: ('help', 'office'), Count: 1178
# Itemset: ('commission', 'customer'), Count: 1178
# Itemset: ('california', 'look'), Count: 1178
# Itemset: ('find', 'service'), Count: 1177
# Itemset: ('able', 'number'), Count: 1177
# Itemset: ('date', 'service'), Count: 1177
# Itemset: ('energy', 'firm'), Count: 1176
# Itemset: ('cost', 'due'), Count: 1176
# Itemset: ('contract', 'issues'), Count: 1176
# Itemset: ('additional', 'company'), Count: 1176
# Itemset: ('company', 'general'), Count: 1175
# Itemset: ('friday', 'monday'), Count: 1175
# Itemset: ('issues', 'part'), Count: 1174
# Itemset: ('change', 'month'), Count: 1174
# Itemset: ('current', 'meeting'), Count: 1174
# Itemset: ('company', 'problem'), Count: 1174
# Itemset: ('california', 'summer'), Count: 1174
# Itemset: ('offer', 'think'), Count: 1174
# Itemset: ('contract', 'create'), Count: 1173
# Itemset: ('number', 'result'), Count: 1173
# Itemset: ('address', 'number'), Count: 1173
# Itemset: ('commission', 'energy'), Count: 1172
# Itemset: ('company', 'position'), Count: 1172
# Itemset: ('help', 'received'), Count: 1172
# Itemset: ('start', 'think'), Count: 1172
# Itemset: ('pay', 'price'), Count: 1172
# Itemset: ('month', 'term'), Count: 1171
# Itemset: ('help', 'member'), Count: 1171
# Itemset: ('additional', 'number'), Count: 1171
# Itemset: ('californias', 'energy'), Count: 1171
# Itemset: ('comment', 'cost'), Count: 1170
# Itemset: ('high', 'report'), Count: 1170
# Itemset: ('based', 'power'), Count: 1170
# Itemset: ('corp', 'month'), Count: 1170
# Itemset: ('based', 'price'), Count: 1170
# Itemset: ('believe', 'think'), Count: 1170
# Itemset: ('conference', 'number'), Count: 1170
# Itemset: ('date', 'order'), Count: 1170
# Itemset: ('customer', 'process'), Count: 1170
# Itemset: ('economic', 'market'), Count: 1169
# Itemset: ('end', 'thing'), Count: 1169
# Itemset: ('look', 'part'), Count: 1169
# Itemset: ('capacity', 'market'), Count: 1169
# Itemset: ('effort', 'help'), Count: 1169
# Itemset: ('consumer', 'customer'), Count: 1168
# Itemset: ('change', 'customer'), Count: 1168
# Itemset: ('high', 'service'), Count: 1168
# Itemset: ('business', 'investment'), Count: 1168
# Itemset: ('group', 'houston'), Count: 1168
# Itemset: ('customer', 'electricity'), Count: 1168
# Itemset: ('free', 'service'), Count: 1168
# Itemset: ('access', 'company'), Count: 1167
# Itemset: ('discuss', 'group'), Count: 1167
# Itemset: ('agreement', 'market'), Count: 1166
# Itemset: ('conference', 'market'), Count: 1166
# Itemset: ('based', 'energy'), Count: 1166
# Itemset: ('california', 'include'), Count: 1166
# ...
# Itemset: ('plant', 'power'), Count: 1027
# Itemset: ('corp', 'deal'), Count: 1027
# Itemset: ('going', 'position'), Count: 1027
# Itemset: ('california', 'solution'), Count: 1027
# Itemset: ('additional', 'end'), Count: 1027
# Itemset: ('official', 'power'), Count: 1027
# Itemset: ('deal', 'office'), Count: 1027
# Itemset: ('bill', 'issues'), Count: 1027
# Itemset: ('plan', 'utilities'), Count: 1027
# Itemset: ('houston', 'plan'), Count: 1027
# Itemset: ('firm', 'service'), Count: 1027
# Itemset: ('think', 'trying'), Count: 1027
# Itemset: ('bill', 'prices'), Count: 1027
# Itemset: ('electricity', 'federal'), Count: 1027
# Itemset: ('ago', 'month'), Count: 1026
# Itemset: ('expected', 'plan'), Count: 1026
# Itemset: ('look', 'looking'), Count: 1026
# Itemset: ('financial', 'number'), Count: 1026
# Itemset: ('company', 'utilities'), Count: 1026
# Itemset: ('discuss', 'number'), Count: 1026
# Itemset: ('customer', 'interest'), Count: 1026
# Itemset: ('business', 'rate'), Count: 1026
# Itemset: ('addition', 'business'), Count: 1026
# Itemset: ('general', 'report'), Count: 1026
# Itemset: ('corp', 'party'), Count: 1026
# Itemset: ('office', 'team'), Count: 1026
# Itemset: ('committee', 'meeting'), Count: 1026
# Itemset: ('including', 'investment'), Count: 1025
# Itemset: ('group', 'open'), Count: 1025
# Itemset: ('energy', 'management'), Count: 1025
# Itemset: ('conference', 'group'), Count: 1025
# Itemset: ('corp', 'meeting'), Count: 1025
# Itemset: ('bill', 'high'), Count: 1025
# Itemset: ('cost', 'increase'), Count: 1025
# Itemset: ('energy', 'put'), Count: 1025
# Itemset: ('federal', 'prices'), Count: 1025
# Itemset: ('management', 'meeting'), Count: 1025
# Itemset: ('contract', 'states'), Count: 1025
# Itemset: ('company', 'credit'), Count: 1025
# Itemset: ('january', 'market'), Count: 1025
# Itemset: ('future', 'provide'), Count: 1025
# Itemset: ('place', 'price'), Count: 1024
# Itemset: ('group', 'start'), Count: 1024
# Itemset: ('able', 'provide'), Count: 1024
# Itemset: ('include', 'point'), Count: 1024
# Itemset: ('big', 'number'), Count: 1024
# Itemset: ('think', 'try'), Count: 1024
# Itemset: ('cost', 'review'), Count: 1024
# Itemset: ('issue', 'rate'), Count: 1024
# Itemset: ('meeting', 'morning'), Count: 1024
# Itemset: ('companies', 'end'), Count: 1024
# Itemset: ('price', 'risk'), Count: 1024
# Itemset: ('position', 'support'), Count: 1023
# Itemset: ('future', 'issue'), Count: 1023
# Itemset: ('california', 'change'), Count: 1023
# Itemset: ('additional', 'current'), Count: 1023
# Itemset: ('help', 'line'), Count: 1023
# Itemset: ('address', 'issues'), Count: 1023
# Itemset: ('part', 'states'), Count: 1023
# Itemset: ('order', 'process'), Count: 1023
# Itemset: ('action', 'meeting'), Count: 1023
# Itemset: ('against', 'point'), Count: 1023
# Itemset: ('rate', 'utility'), Count: 1023
# Itemset: ('place', 'service'), Count: 1023
# Itemset: ('customer', 'supply'), Count: 1023
# Itemset: ('meeting', 'result'), Count: 1023
# Itemset: ('company', 'development'), Count: 1023
# Itemset: ('energy', 'solution'), Count: 1023
# Itemset: ('cost', 'line'), Count: 1023
# Itemset: ('federal', 'service'), Count: 1023
# Itemset: ('able', 'point'), Count: 1022
# Itemset: ('comment', 'set'), Count: 1022
# Itemset: ('end', 'pay'), Count: 1022
# Itemset: ('put', 'thing'), Count: 1022
# Itemset: ('month', 'review'), Count: 1022
# Itemset: ('message', 'think'), Count: 1022
# Itemset: ('final', 'hour'), Count: 1022
# Itemset: ('demand', 'high'), Count: 1022
# Itemset: ('including', 'states'), Count: 1022
# Itemset: ('ill', 'think'), Count: 1021
# Itemset: ('company', 'thing'), Count: 1021
# Itemset: ('give', 'put'), Count: 1021
# Itemset: ('decision', 'think'), Count: 1021
# Itemset: ('companies', 'result'), Count: 1021
# Itemset: ('issues', 'member'), Count: 1021
# Itemset: ('big', 'thing'), Count: 1021
# Itemset: ('early', 'end'), Count: 1021
# Itemset: ('contract', 'find'), Count: 1021
# Itemset: ('meeting', 'project'), Count: 1021
# Itemset: ('management', 'provide'), Count: 1020
# Itemset: ('free', 'plan'), Count: 1020
# Itemset: ('federal', 'price'), Count: 1020
# Itemset: ('address', 'offer'), Count: 1020
# Itemset: ('cost', 'proposal'), Count: 1020
# Itemset: ('change', 'point'), Count: 1020
# Itemset: ('major', 'plan'), Count: 1020
# Itemset: ('offer', 'online'), Count: 1020
# Itemset: ('business', 'president'), Count: 1020
# Itemset: ('additional', 'issue'), Count: 1020
# Itemset: ('fact', 'market'), Count: 1019
# Itemset: ('asked', 'cost'), Count: 1019
# Itemset: ('deal', 'pay'), Count: 1019
# Itemset: ('group', 'manager'), Count: 1019
# Itemset: ('billion', 'deal'), Count: 1019
# Itemset: ('month', 'summer'), Count: 1019
# Itemset: ('part', 'thing'), Count: 1019
# Itemset: ('able', 'energy'), Count: 1019
# Itemset: ('california', 'continue'), Count: 1019
# Itemset: ('end', 'position'), Count: 1019
# Itemset: ('group', 'thought'), Count: 1019
# Itemset: ('office', 'process'), Count: 1019
# Itemset: ('big', 'help'), Count: 1019
# Itemset: ('term', 'think'), Count: 1018
# Itemset: ('look', 'process'), Count: 1018
# Itemset: ('future', 'number'), Count: 1018
# Itemset: ('control', 'market'), Count: 1018
# Itemset: ('help', 'public'), Count: 1018
# Itemset: ('detail', 'meeting'), Count: 1018
# Itemset: ('contract', 'evidence'), Count: 1018
# Itemset: ('bill', 'consumer'), Count: 1018
# Itemset: ('asked', 'business'), Count: 1018
# Itemset: ('business', 'states'), Count: 1018
# Itemset: ('find', 'issue'), Count: 1018
# Itemset: ('provide', 'public'), Count: 1018
# Itemset: ('company', 'stock'), Count: 1018
# Itemset: ('believe', 'power'), Count: 1018
# Itemset: ('business', 'online'), Count: 1018
# Itemset: ('electricity', 'plan'), Count: 1017
# Itemset: ('agreement', 'california'), Count: 1017
# Itemset: ('cost', 'sure'), Count: 1017
# Itemset: ('look', 'monday'), Count: 1017
# Itemset: ('include', 'issue'), Count: 1017
# Itemset: ('management', 'services'), Count: 1017
# Itemset: ('credit', 'price'), Count: 1017
# Itemset: ('houston', 'market'), Count: 1017
# Itemset: ('give', 'working'), Count: 1017
# Itemset: ('prices', 'service'), Count: 1017
# Itemset: ('past', 'think'), Count: 1017
# Itemset: ('point', 'working'), Count: 1017
# Itemset: ('provide', 'utility'), Count: 1017
# Itemset: ('international', 'service'), Count: 1017
# Itemset: ('change', 'prices'), Count: 1016
# Itemset: ('company', 'law'), Count: 1016
# Itemset: ('include', 'offer'), Count: 1016
# Itemset: ('major', 'power'), Count: 1016
# Itemset: ('contract', 'electricity'), Count: 1016
# Itemset: ('prices', 'set'), Count: 1016
# Itemset: ('market', 'provided'), Count: 1016
# Itemset: ('change', 'think'), Count: 1016
# Itemset: ('basis', 'create'), Count: 1016
# Itemset: ('level', 'service'), Count: 1016
# Itemset: ('asked', 'going'), Count: 1016
# Itemset: ('based', 'issues'), Count: 1016
# Itemset: ('group', 'making'), Count: 1016
# Itemset: ('law', 'power'), Count: 1016
# Itemset: ('operation', 'services'), Count: 1016
# Itemset: ('end', 'office'), Count: 1016
# Itemset: ('meet', 'think'), Count: 1016
# Itemset: ('companies', 'set'), Count: 1016
# Itemset: ('include', 'member'), Count: 1016
# Itemset: ('member', 'order'), Count: 1015
# Itemset: ('companies', 'investment'), Count: 1015
# Itemset: ('commission', 'decision'), Count: 1015
# Itemset: ('companies', 'issue'), Count: 1015
# Itemset: ('government', 'market'), Count: 1015
# Itemset: ('asked', 'plan'), Count: 1015
# Itemset: ('forward', 'give'), Count: 1015
# Itemset: ('comment', 'draft'), Count: 1015
# Itemset: ('monday', 'power'), Count: 1015
# Itemset: ('point', 'result'), Count: 1014
# Itemset: ('capital', 'market'), Count: 1014
# Itemset: ('continue', 'part'), Count: 1014
# Itemset: ('material', 'receive'), Count: 1014
# Itemset: ('end', 'past'), Count: 1014
# Itemset: ('offer', 'product'), Count: 1014
# Itemset: ('firm', 'price'), Count: 1014
# Itemset: ('additional', 'price'), Count: 1014
# Itemset: ('give', 'including'), Count: 1014
# Itemset: ('office', 'review'), Count: 1014
# Itemset: ('number', 'past'), Count: 1014
# Itemset: ('power', 'received'), Count: 1014
# Itemset: ('future', 'including'), Count: 1014
# Itemset: ('month', 'sure'), Count: 1014
# Itemset: ('federal', 'month'), Count: 1013
# Itemset: ('effort', 'think'), Count: 1013
# Itemset: ('additional', 'support'), Count: 1013
# Itemset: ('companies', 'order'), Count: 1013
# Itemset: ('cost', 'gas'), Count: 1013
# Itemset: ('future', 'report'), Count: 1013
# Itemset: ('current', 'industry'), Count: 1013
# Itemset: ('agreement', 'term'), Count: 1013
# Itemset: ('power', 'purchase'), Count: 1012
# Itemset: ('contract', 'position'), Count: 1012
# Itemset: ('big', 'month'), Count: 1012
# Itemset: ('think', 'told'), Count: 1012
# Itemset: ('help', 'job'), Count: 1012
# Itemset: ('issue', 'position'), Count: 1012
# Itemset: ('credit', 'number'), Count: 1012
# Itemset: ('due', 'order'), Count: 1012
# Itemset: ('law', 'market'), Count: 1012
# Itemset: ('bill', 'think'), Count: 1012
# Itemset: ('according', 'power'), Count: 1012
# Itemset: ('public', 'states'), Count: 1012
# Itemset: ('andor', 'message'), Count: 1012
# Itemset: ('interest', 'service'), Count: 1012
# Itemset: ('market', 'online'), Count: 1012
# Itemset: ('rates', 'utilities'), Count: 1012
# Itemset: ('review', 'set'), Count: 1012
# Itemset: ('help', 'term'), Count: 1011
# Itemset: ('federal', 'including'), Count: 1011
# Itemset: ('bill', 'rate'), Count: 1011
# Itemset: ('office', 'service'), Count: 1011
# Itemset: ('bill', 'set'), Count: 1011
# Itemset: ('interest', 'provide'), Count: 1011
# Itemset: ('order', 'pay'), Count: 1011
# Itemset: ('major', 'report'), Count: 1011
# Itemset: ('didnt', 'think'), Count: 1010
# Itemset: ('going', 'pay'), Count: 1010
# Itemset: ('pay', 'states'), Count: 1010
# Itemset: ('higher', 'power'), Count: 1010
# Itemset: ('part', 'services'), Count: 1010
# Itemset: ('contract', 'process'), Count: 1010
# Itemset: ('according', 'energy'), Count: 1010
# Itemset: ('deal', 'support'), Count: 1010
# Itemset: ('office', 'set'), Count: 1010
# Itemset: ('addition', 'power'), Count: 1010
# Itemset: ('order', 'place'), Count: 1010
# Itemset: ('going', 'monday'), Count: 1010
# Itemset: ('power', 'proposal'), Count: 1010
# Itemset: ('agreement', 'issues'), Count: 1010
# Itemset: ('able', 'including'), Count: 1010
# Itemset: ('customer', 'working'), Count: 1009
# Itemset: ('financial', 'support'), Count: 1009
# Itemset: ('group', 'large'), Count: 1009
# Itemset: ('group', 'mark'), Count: 1009
# Itemset: ('electricity', 'group'), Count: 1009
# Itemset: ('financial', 'investment'), Count: 1009
# Itemset: ('line', 'number'), Count: 1009
# Itemset: ('mark', 'market'), Count: 1009
# Itemset: ('month', 'official'), Count: 1009
# Itemset: ('look', 'thought'), Count: 1009
# Itemset: ('andor', 'receive'), Count: 1009
# Itemset: ('industry', 'part'), Count: 1008
# Itemset: ('issues', 'services'), Count: 1008
# Itemset: ('end', 'term'), Count: 1008
# Itemset: ('include', 'set'), Count: 1008
# Itemset: ('click', 'free'), Count: 1008
# Itemset: ('list', 'service'), Count: 1008
# Itemset: ('prices', 'think'), Count: 1008
# Itemset: ('corp', 'financial'), Count: 1008
# Itemset: ('market', 'proposed'), Count: 1008
# Itemset: ('billion', 'prices'), Count: 1008
# Itemset: ('order', 'public'), Count: 1008
# Itemset: ('received', 'report'), Count: 1008
# Itemset: ('file', 'process'), Count: 1008
# Itemset: ('discuss', 'plan'), Count: 1008
# Itemset: ('companies', 'support'), Count: 1008
# Itemset: ('issue', 'term'), Count: 1008
# Itemset: ('access', 'number'), Count: 1008
# Itemset: ('business', 'close'), Count: 1007
# Itemset: ('including', 'program'), Count: 1007
# Itemset: ('amount', 'business'), Count: 1007
# Itemset: ('date', 'free'), Count: 1007
# Itemset: ('decision', 'price'), Count: 1007
# Itemset: ('commission', 'issue'), Count: 1007
# Itemset: ('member', 'team'), Count: 1007
# Itemset: ('office', 'services'), Count: 1007
# Itemset: ('effort', 'issues'), Count: 1007
# Itemset: ('market', 'transaction'), Count: 1007
# Itemset: ('part', 'working'), Count: 1007
# Itemset: ('address', 'customer'), Count: 1006
# Itemset: ('customer', 'free'), Count: 1006
# Itemset: ('prices', 'provide'), Count: 1006
# Itemset: ('point', 'support'), Count: 1006
# Itemset: ('energy', 'proposal'), Count: 1006
# Itemset: ('early', 'help'), Count: 1006
# Itemset: ('provide', 'request'), Count: 1006
# Itemset: ('end', 'expected'), Count: 1006
# Itemset: ('look', 'start'), Count: 1006
# Itemset: ('end', 'review'), Count: 1006
# Itemset: ('getting', 'look'), Count: 1006
# Itemset: ('comment', 'contract'), Count: 1006
# Itemset: ('forward', 'sure'), Count: 1005
# Itemset: ('friday', 'look'), Count: 1005
# Itemset: ('daily', 'market'), Count: 1005
# Itemset: ('bill', 'companies'), Count: 1005
# Itemset: ('later', 'market'), Count: 1005
# Itemset: ('federal', 'report'), Count: 1005
# Itemset: ('international', 'plan'), Count: 1005
# Itemset: ('order', 'rates'), Count: 1005
# Itemset: ('issue', 'working'), Count: 1005
# Itemset: ('cost', 'purchase'), Count: 1005
# Itemset: ('end', 'level'), Count: 1005
# Itemset: ('electricity', 'public'), Count: 1005
# Itemset: ('free', 'look'), Count: 1005
# Itemset: ('based', 'order'), Count: 1005
# Itemset: ('detail', 'number'), Count: 1005
# Itemset: ('access', 'power'), Count: 1005
# Itemset: ('companies', 'electricity'), Count: 1005
# Itemset: ('prohibited', 'receive'), Count: 1005
# Itemset: ('billion', 'report'), Count: 1005
# Itemset: ('place', 'point'), Count: 1005
# Itemset: ('due', 'set'), Count: 1004
# Itemset: ('additional', 'issues'), Count: 1004
# Itemset: ('going', 'run'), Count: 1004
# Itemset: ('customer', 'federal'), Count: 1004
# Itemset: ('amount', 'due'), Count: 1004
# Itemset: ('company', 'natural_gas'), Count: 1004
# Itemset: ('price', 'product'), Count: 1004
# Itemset: ('based', 'look'), Count: 1004
# Itemset: ('business', 'solution'), Count: 1004
# Itemset: ('pay', 'utility'), Count: 1004
# Itemset: ('contract', 'services'), Count: 1003
# Itemset: ('electricity', 'supply'), Count: 1003
# Itemset: ('big', 'cost'), Count: 1003
# Itemset: ('end', 'rate'), Count: 1003
# Itemset: ('access', 'including'), Count: 1003
# Itemset: ('service', 'world'), Count: 1003
# Itemset: ('executive', 'group'), Count: 1003
# Itemset: ('against', 'think'), Count: 1003
# Itemset: ('contract', 'result'), Count: 1003
# Itemset: ('prices', 'rate'), Count: 1003
# Itemset: ('business', 'federal'), Count: 1003
# Itemset: ('company', 'expect'), Count: 1003
# Itemset: ('current', 'interest'), Count: 1003
# Itemset: ('group', 'international'), Count: 1003
# Itemset: ('level', 'number'), Count: 1003
# Itemset: ('cost', 'project'), Count: 1003
# Itemset: ('financial', 'part'), Count: 1002
# Itemset: ('cost', 'date'), Count: 1002
# Itemset: ('high', 'result'), Count: 1002
# Itemset: ('meet', 'number'), Count: 1002
# Itemset: ('company', 'supply'), Count: 1002
# Itemset: ('help', 'interest'), Count: 1002
# Itemset: ('asked', 'energy'), Count: 1002
# Itemset: ('order', 'states'), Count: 1002
# Itemset: ('addition', 'customer'), Count: 1002
# Itemset: ('electricity', 'rates'), Count: 1002
# Itemset: ('company', 'network'), Count: 1002
# Itemset: ('help', 'level'), Count: 1002
# Itemset: ('issue', 'rates'), Count: 1002
# Itemset: ('business', 'expected'), Count: 1002
# Itemset: ('current', 'problem'), Count: 1002
# Itemset: ('going', 'try'), Count: 1002
# Itemset: ('offer', 'set'), Count: 1001
# Itemset: ('amount', 'month'), Count: 1001
# Itemset: ('group', 'major'), Count: 1001
# Itemset: ('continue', 'service'), Count: 1001
# Itemset: ('cost', 'summer'), Count: 1001
# Itemset: ('rates', 'states'), Count: 1001
# Itemset: ('access', 'report'), Count: 1001
# Itemset: ('change', 'issue'), Count: 1001
# Itemset: ('higher', 'prices'), Count: 1001
# Itemset: ('number', 'rate'), Count: 1001
# Itemset: ('california', 'case'), Count: 1001
# Itemset: ('against', 'energy'), Count: 1001
# Itemset: ('amount', 'number'), Count: 1001
# Itemset: ('point', 'process'), Count: 1001
# Itemset: ('business', 'event'), Count: 1001
# Itemset: ('big', 'look'), Count: 1001
# Itemset: ('support', 'working'), Count: 1001
# Itemset: ('discuss', 'think'), Count: 1001
# Itemset: ('bill', 'rates'), Count: 1000
# Itemset: ('attend', 'meeting'), Count: 1000
# Itemset: ('customer', 'program'), Count: 1000
# Itemset: ('california', 'sure'), Count: 1000
# Itemset: ('pay', 'rates'), Count: 1000
# Itemset: ('future', 'part'), Count: 1000
# Itemset: ('corp', 'going'), Count: 1000
# Itemset: ('energy', 'power_plant'), Count: 1000
# Itemset: ('process', 'working'), Count: 1000

# %% [markdown]
# ## K = 2 and F = 900

# %%
main("vocab.enron.txt", "docword.enron.txt", K=2, F=900)
# Out:
# Reading dataset...
# Running Apriori for K=2, F=900
#
# Time taken: 56.21 seconds
#
# Total Frequent K-itemsets Found: 4424
# Frequent K-itemsets:
# Itemset: ('market', 'power'), Count: 2545
# Itemset: ('energy', 'power'), Count: 2536
# Itemset: ('energy', 'market'), Count: 2481
# Itemset: ('market', 'price'), Count: 2295
# Itemset: ('business', 'market'), Count: 2291
# Itemset: ('california', 'energy'), Count: 2280
# Itemset: ('california', 'power'), Count: 2274
# Itemset: ('california', 'market'), Count: 2258
# Itemset: ('company', 'market'), Count: 2169
# Itemset: ('going', 'think'), Count: 2151
# Itemset: ('business', 'company'), Count: 2124
# Itemset: ('cost', 'market'), Count: 2095
# Itemset: ('group', 'market'), Count: 2087
# Itemset: ('market', 'prices'), Count: 2078
# Itemset: ('group', 'meeting'), Count: 2077
# Itemset: ('customer', 'market'), Count: 2062
# Itemset: ('market', 'month'), Count: 2037
# Itemset: ('energy', 'price'), Count: 2008
# Itemset: ('business', 'group'), Count: 1978
# Itemset: ('cost', 'power'), Count: 1959
# Itemset: ('company', 'energy'), Count: 1948
# Itemset: ('forward', 'look'), Count: 1944
# Itemset: ('power', 'price'), Count: 1928
# Itemset: ('offer', 'receive'), Count: 1925
# Itemset: ('market', 'report'), Count: 1920
# Itemset: ('meeting', 'plan'), Count: 1900
# Itemset: ('group', 'plan'), Count: 1886
# Itemset: ('business', 'energy'), Count: 1886
# Itemset: ('business', 'plan'), Count: 1885
# Itemset: ('cost', 'customer'), Count: 1861
# Itemset: ('california', 'cost'), Count: 1856
# Itemset: ('group', 'help'), Count: 1842
# Itemset: ('market', 'service'), Count: 1841
# Itemset: ('market', 'order'), Count: 1839
# Itemset: ('companies', 'company'), Count: 1835
# Itemset: ('cost', 'energy'), Count: 1831
# Itemset: ('market', 'plan'), Count: 1819
# Itemset: ('look', 'think'), Count: 1816
# Itemset: ('customer', 'service'), Count: 1805
# Itemset: ('help', 'market'), Count: 1801
# Itemset: ('group', 'number'), Count: 1795
# Itemset: ('company', 'group'), Count: 1794
# Itemset: ('including', 'market'), Count: 1787
# Itemset: ('price', 'prices'), Count: 1779
# Itemset: ('business', 'power'), Count: 1779
# Itemset: ('market', 'provide'), Count: 1776
# Itemset: ('energy', 'group'), Count: 1774
# Itemset: ('issues', 'meeting'), Count: 1767
# Itemset: ('cost', 'price'), Count: 1761
# Itemset: ('california', 'price'), Count: 1755
# Itemset: ('discuss', 'meeting'), Count: 1754
# Itemset: ('company', 'plan'), Count: 1753
# Itemset: ('customer', 'power'), Count: 1751
# Itemset: ('group', 'power'), Count: 1749
# Itemset: ('current', 'market'), Count: 1747
# Itemset: ('issues', 'market'), Count: 1743
# Itemset: ('business', 'month'), Count: 1743
# Itemset: ('company', 'power'), Count: 1740
# Itemset: ('customer', 'energy'), Count: 1732
# Itemset: ('business', 'help'), Count: 1727
# Itemset: ('cost', 'month'), Count: 1727
# Itemset: ('high', 'market'), Count: 1720
# Itemset: ('companies', 'market'), Count: 1719
# Itemset: ('group', 'report'), Count: 1716
# Itemset: ('group', 'think'), Count: 1716
# Itemset: ('month', 'power'), Count: 1711
# Itemset: ('thing', 'think'), Count: 1709
# Itemset: ('business', 'report'), Count: 1707
# Itemset: ('market', 'services'), Count: 1701
# Itemset: ('california', 'customer'), Count: 1699
# Itemset: ('business', 'customer'), Count: 1696
# Itemset: ('company', 'month'), Count: 1693
# Itemset: ('business', 'provide'), Count: 1691
# Itemset: ('energy', 'plan'), Count: 1689
# Itemset: ('market', 'part'), Count: 1686
# Itemset: ('help', 'think'), Count: 1681
# Itemset: ('market', 'think'), Count: 1681
# Itemset: ('help', 'number'), Count: 1680
# Itemset: ('company', 'service'), Count: 1680
# Itemset: ('deal', 'market'), Count: 1678
# Itemset: ('contract', 'market'), Count: 1677
# Itemset: ('market', 'number'), Count: 1672
# Itemset: ('electricity', 'power'), Count: 1671
# Itemset: ('company', 'customer'), Count: 1654
# Itemset: ('cost', 'plan'), Count: 1651
# Itemset: ('group', 'working'), Count: 1648
# Itemset: ('business', 'number'), Count: 1645
# Itemset: ('going', 'thing'), Count: 1642
# Itemset: ('meeting', 'number'), Count: 1641
# Itemset: ('month', 'plan'), Count: 1640
# Itemset: ('company', 'report'), Count: 1639
# Itemset: ('customer', 'order'), Count: 1634
# Itemset: ('end', 'market'), Count: 1632
# Itemset: ('issue', 'market'), Count: 1629
# Itemset: ('california', 'plan'), Count: 1628
# Itemset: ('electricity', 'energy'), Count: 1622
# Itemset: ('group', 'month'), Count: 1620
# Itemset: ('california', 'electricity'), Count: 1619
# Itemset: ('help', 'plan'), Count: 1618
# Itemset: ('california', 'company'), Count: 1616
# Itemset: ('business', 'cost'), Count: 1616
# Itemset: ('meeting', 'think'), Count: 1616
# Itemset: ('business', 'california'), Count: 1615
# Itemset: ('cost', 'number'), Count: 1614
# Itemset: ('energy', 'month'), Count: 1613
# Itemset: ('market', 'meeting'), Count: 1613
# Itemset: ('energy', 'report'), Count: 1613
# Itemset: ('company', 'cost'), Count: 1611
# Itemset: ('contract', 'corp'), Count: 1608
# Itemset: ('business', 'service'), Count: 1608
# Itemset: ('contract', 'energy'), Count: 1607
# Itemset: ('plan', 'power'), Count: 1605
# Itemset: ('cost', 'service'), Count: 1604
# Itemset: ('number', 'plan'), Count: 1602
# Itemset: ('number', 'think'), Count: 1602
# Itemset: ('power', 'prices'), Count: 1602
# Itemset: ('industry', 'market'), Count: 1601
# Itemset: ('business', 'meeting'), Count: 1598
# Itemset: ('customer', 'provide'), Count: 1596
# Itemset: ('contract', 'cost'), Count: 1595
# Itemset: ('meeting', 'office'), Count: 1594
# Itemset: ('power', 'utilities'), Count: 1593
# Itemset: ('group', 'provide'), Count: 1590
# Itemset: ('number', 'service'), Count: 1589
# Itemset: ('business', 'companies'), Count: 1587
# Itemset: ('california', 'states'), Count: 1583
# Itemset: ('business', 'including'), Count: 1583
# Itemset: ('customer', 'group'), Count: 1583
# Itemset: ('customer', 'price'), Count: 1581
# Itemset: ('energy', 'provide'), Count: 1581
# Itemset: ('energy', 'prices'), Count: 1580
# Itemset: ('month', 'number'), Count: 1579
# Itemset: ('company', 'help'), Count: 1578
# Itemset: ('california', 'month'), Count: 1574
# Itemset: ('forward', 'meeting'), Count: 1574
# Itemset: ('california', 'group'), Count: 1572
# Itemset: ('financial', 'market'), Count: 1569
# Itemset: ('sure', 'think'), Count: 1569
# Itemset: ('month', 'price'), Count: 1566
# Itemset: ('california', 'utilities'), Count: 1566
# Itemset: ('look', 'market'), Count: 1565
# Itemset: ('power', 'utility'), Count: 1564
# Itemset: ('customer', 'plan'), Count: 1564
# Itemset: ('month', 'think'), Count: 1563
# Itemset: ('help', 'provide'), Count: 1561
# Itemset: ('market', 'result'), Count: 1559
# Itemset: ('group', 'issues'), Count: 1558
# Itemset: ('company', 'including'), Count: 1557
# Itemset: ('going', 'look'), Count: 1556
# Itemset: ('market', 'problem'), Count: 1555
# Itemset: ('order', 'power'), Count: 1555
# Itemset: ('help', 'month'), Count: 1554
# Itemset: ('plan', 'provide'), Count: 1554
# Itemset: ('business', 'deal'), Count: 1552
# Itemset: ('business', 'services'), Count: 1552
# Itemset: ('contract', 'power'), Count: 1552
# Itemset: ('market', 'point'), Count: 1550
# Itemset: ('cost', 'group'), Count: 1550
# Itemset: ('energy', 'meeting'), Count: 1549
# Itemset: ('business', 'part'), Count: 1548
# Itemset: ('include', 'market'), Count: 1547
# Itemset: ('california', 'prices'), Count: 1546
# Itemset: ('end', 'month'), Count: 1546
# Itemset: ('market', 'support'), Count: 1544
# Itemset: ('company', 'provide'), Count: 1541
# Itemset: ('demand', 'market'), Count: 1540
# Itemset: ('contract', 'customer'), Count: 1540
# Itemset: ('contract', 'review'), Count: 1535
# Itemset: ('month', 'report'), Count: 1535
# Itemset: ('forward', 'market'), Count: 1535
# Itemset: ('bill', 'energy'), Count: 1535
# Itemset: ('based', 'market'), Count: 1534
# Itemset: ('company', 'services'), Count: 1532
# Itemset: ('comment', 'market'), Count: 1530
# Itemset: ('group', 'including'), Count: 1529
# Itemset: ('group', 'part'), Count: 1529
# Itemset: ('market', 'term'), Count: 1529
# Itemset: ('cost', 'provide'), Count: 1528
# Itemset: ('group', 'look'), Count: 1527
# Itemset: ('give', 'think'), Count: 1525
# Itemset: ('plan', 'think'), Count: 1522
# Itemset: ('going', 'help'), Count: 1522
# Itemset: ('deal', 'power'), Count: 1521
# Itemset: ('power', 'states'), Count: 1520
# Itemset: ('company', 'number'), Count: 1519
# Itemset: ('change', 'market'), Count: 1519
# Itemset: ('deal', 'group'), Count: 1518
# Itemset: ('including', 'power'), Count: 1516
# Itemset: ('month', 'service'), Count: 1513
# Itemset: ('market', 'set'), Count: 1512
# Itemset: ('issue', 'issues'), Count: 1511
# Itemset: ('contract', 'offer'), Count: 1511
# Itemset: ('end', 'group'), Count: 1511
# Itemset: ('energy', 'service'), Count: 1509
# Itemset: ('power', 'provide'), Count: 1509
# Itemset: ('customer', 'month'), Count: 1509
# Itemset: ('hour', 'price'), Count: 1504
# Itemset: ('business', 'office'), Count: 1503
# Itemset: ('energy', 'utilities'), Count: 1501
# Itemset: ('help', 'meeting'), Count: 1501
# Itemset: ('california', 'utility'), Count: 1500
# Itemset: ('plan', 'service'), Count: 1500
# Itemset: ('meeting', 'set'), Count: 1499
# Itemset: ('business', 'financial'), Count: 1499
# Itemset: ('number', 'provide'), Count: 1499
# Itemset: ('companies', 'energy'), Count: 1495
# Itemset: ('point', 'think'), Count: 1494
# Itemset: ('number', 'report'), Count: 1493
# Itemset: ('market', 'position'), Count: 1491
# Itemset: ('bill', 'california'), Count: 1491
# Itemset: ('help', 'power'), Count: 1491
# Itemset: ('market', 'offer'), Count: 1490
# Itemset: ('going', 'number'), Count: 1490
# Itemset: ('california', 'meeting'), Count: 1488
# Itemset: ('company', 'corp'), Count: 1486
# Itemset: ('end', 'number'), Count: 1485
# Itemset: ('energy', 'utility'), Count: 1485
# Itemset: ('meeting', 'review'), Count: 1483
# Itemset: ('electricity', 'market'), Count: 1482
# Itemset: ('power', 'report'), Count: 1482
# Itemset: ('california', 'order'), Count: 1482
# Itemset: ('provide', 'service'), Count: 1481
# Itemset: ('cost', 'including'), Count: 1481
# Itemset: ('group', 'member'), Count: 1481
# Itemset: ('feel', 'free'), Count: 1480
# Itemset: ('california', 'contract'), Count: 1480
# Itemset: ('going', 'plan'), Count: 1480
# Itemset: ('business', 'price'), Count: 1480
# Itemset: ('energy', 'part'), Count: 1479
# Itemset: ('cost', 'help'), Count: 1479
# Itemset: ('including', 'plan'), Count: 1477
# Itemset: ('going', 'group'), Count: 1476
# Itemset: ('cost', 'high'), Count: 1475
# Itemset: ('california', 'provide'), Count: 1474
# Itemset: ('look', 'number'), Count: 1474
# Itemset: ('company', 'part'), Count: 1474
# Itemset: ('deal', 'price'), Count: 1473
# Itemset: ('customer', 'utility'), Count: 1473
# Itemset: ('deal', 'month'), Count: 1472
# Itemset: ('energy', 'including'), Count: 1471
# Itemset: ('cost', 'order'), Count: 1471
# Itemset: ('business', 'issues'), Count: 1470
# Itemset: ('going', 'month'), Count: 1468
# Itemset: ('plan', 'report'), Count: 1467
# Itemset: ('look', 'meeting'), Count: 1466
# Itemset: ('cost', 'end'), Count: 1466
# Itemset: ('business', 'support'), Count: 1466
# Itemset: ('california', 'help'), Count: 1465
# Itemset: ('customer', 'help'), Count: 1465
# Itemset: ('group', 'office'), Count: 1463
# Itemset: ('customer', 'number'), Count: 1463
# Itemset: ('business', 'think'), Count: 1462
# Itemset: ('number', 'power'), Count: 1460
# Itemset: ('business', 'current'), Count: 1459
# Itemset: ('group', 'service'), Count: 1458
# Itemset: ('company', 'financial'), Count: 1457
# Itemset: ('help', 'look'), Count: 1457
# Itemset: ('end', 'plan'), Count: 1456
# Itemset: ('group', 'support'), Count: 1456
# Itemset: ('going', 'market'), Count: 1456
# Itemset: ('california', 'issue'), Count: 1456
# Itemset: ('attached', 'review'), Count: 1455
# Itemset: ('part', 'power'), Count: 1454
# Itemset: ('order', 'service'), Count: 1454
# Itemset: ('california', 'number'), Count: 1454
# Itemset: ('cost', 'utility'), Count: 1453
# Itemset: ('power', 'problem'), Count: 1453
# Itemset: ('contract', 'month'), Count: 1452
# Itemset: ('customer', 'including'), Count: 1451
# Itemset: ('energy', 'help'), Count: 1451
# Itemset: ('energy', 'order'), Count: 1450
# Itemset: ('business', 'process'), Count: 1448
# Itemset: ('energy', 'issues'), Count: 1446
# Itemset: ('site', 'web'), Count: 1446
# Itemset: ('company', 'price'), Count: 1446
# Itemset: ('access', 'customer'), Count: 1445
# Itemset: ('group', 'services'), Count: 1444
# Itemset: ('corp', 'market'), Count: 1441
# Itemset: ('cost', 'prices'), Count: 1439
# Itemset: ('service', 'services'), Count: 1438
# Itemset: ('energy', 'states'), Count: 1438
# Itemset: ('month', 'part'), Count: 1438
# Itemset: ('help', 'report'), Count: 1437
# Itemset: ('meeting', 'report'), Count: 1437
# Itemset: ('give', 'going'), Count: 1437
# Itemset: ('including', 'service'), Count: 1437
# Itemset: ('california', 'high'), Count: 1436
# Itemset: ('high', 'power'), Count: 1436
# Itemset: ('company', 'deal'), Count: 1435
# Itemset: ('cost', 'think'), Count: 1435
# Itemset: ('end', 'help'), Count: 1432
# Itemset: ('group', 'team'), Count: 1430
# Itemset: ('market', 'utilities'), Count: 1429
# Itemset: ('help', 'including'), Count: 1428
# Itemset: ('current', 'energy'), Count: 1428
# Itemset: ('forward', 'group'), Count: 1428
# Itemset: ('price', 'process'), Count: 1427
# Itemset: ('current', 'group'), Count: 1427
# Itemset: ('including', 'month'), Count: 1426
# Itemset: ('meeting', 'working'), Count: 1425
# Itemset: ('message', 'receive'), Count: 1425
# Itemset: ('california', 'problem'), Count: 1425
# Itemset: ('company', 'current'), Count: 1425
# Itemset: ('issue', 'power'), Count: 1424
# Itemset: ('find', 'help'), Count: 1423
# Itemset: ('issue', 'plan'), Count: 1423
# Itemset: ('number', 'point'), Count: 1422
# Itemset: ('energy', 'number'), Count: 1421
# Itemset: ('business', 'order'), Count: 1421
# Itemset: ('attached', 'comment'), Count: 1419
# Itemset: ('going', 'meeting'), Count: 1418
# Itemset: ('including', 'report'), Count: 1418
# Itemset: ('forward', 'going'), Count: 1418
# Itemset: ('business', 'include'), Count: 1417
# Itemset: ('receive', 'review'), Count: 1417
# Itemset: ('power', 'service'), Count: 1417
# Itemset: ('date', 'price'), Count: 1417
# Itemset: ('issues', 'plan'), Count: 1417
# Itemset: ('part', 'plan'), Count: 1416
# Itemset: ('current', 'plan'), Count: 1416
# Itemset: ('gas', 'market'), Count: 1415
# Itemset: ('group', 'include'), Count: 1414
# Itemset: ('cost', 'rate'), Count: 1414
# Itemset: ('bill', 'power'), Count: 1414
# Itemset: ('market', 'public'), Count: 1413
# Itemset: ('energy', 'public'), Count: 1413
# Itemset: ('market', 'trading'), Count: 1411
# Itemset: ('order', 'price'), Count: 1411
# Itemset: ('going', 'power'), Count: 1410
# Itemset: ('cost', 'rates'), Count: 1410
# Itemset: ('think', 'thought'), Count: 1409
# Itemset: ('end', 'think'), Count: 1408
# Itemset: ('including', 'provide'), Count: 1408
# Itemset: ('company', 'industry'), Count: 1408
# Itemset: ('level', 'market'), Count: 1407
# Itemset: ('high', 'month'), Count: 1407
# Itemset: ('look', 'plan'), Count: 1406
# Itemset: ('number', 'order'), Count: 1405
# Itemset: ('california', 'service'), Count: 1405
# Itemset: ('group', 'process'), Count: 1403
# Itemset: ('meeting', 'monday'), Count: 1402
# Itemset: ('cost', 'going'), Count: 1402
# Itemset: ('california', 'including'), Count: 1401
# Itemset: ('office', 'plan'), Count: 1401
# Itemset: ('consumer', 'market'), Count: 1401
# Itemset: ('market', 'rates'), Count: 1400
# Itemset: ('companies', 'group'), Count: 1400
# Itemset: ('meeting', 'power'), Count: 1399
# Itemset: ('california', 'report'), Count: 1398
# Itemset: ('friday', 'meeting'), Count: 1398
# Itemset: ('comment', 'review'), Count: 1397
# Itemset: ('market', 'utility'), Count: 1397
# Itemset: ('energy', 'industry'), Count: 1396
# Itemset: ('attached', 'file'), Count: 1396
# Itemset: ('power', 'think'), Count: 1395
# Itemset: ('problem', 'think'), Count: 1395
# Itemset: ('business', 'industry'), Count: 1395
# Itemset: ('issues', 'power'), Count: 1395
# Itemset: ('end', 'going'), Count: 1395
# Itemset: ('look', 'thing'), Count: 1395
# Itemset: ('buy', 'market'), Count: 1392
# Itemset: ('business', 'look'), Count: 1392
# Itemset: ('cost', 'pay'), Count: 1392
# Itemset: ('give', 'help'), Count: 1391
# Itemset: ('business', 'end'), Count: 1390
# Itemset: ('corp', 'review'), Count: 1388
# Itemset: ('put', 'think'), Count: 1387
# Itemset: ('business', 'offer'), Count: 1387
# Itemset: ('market', 'supply'), Count: 1387
# Itemset: ('california', 'think'), Count: 1387
# Itemset: ('find', 'market'), Count: 1386
# Itemset: ('company', 'contract'), Count: 1386
# Itemset: ('interest', 'market'), Count: 1385
# Itemset: ('issues', 'think'), Count: 1384
# Itemset: ('meeting', 'process'), Count: 1384
# Itemset: ('market', 'rate'), Count: 1384
# Itemset: ('companies', 'power'), Count: 1383
# Itemset: ('market', 'process'), Count: 1383
# Itemset: ('include', 'including'), Count: 1382
# Itemset: ('energy', 'high'), Count: 1382
# Itemset: ('number', 'price'), Count: 1382
# Itemset: ('deal', 'think'), Count: 1381
# Itemset: ('customer', 'issue'), Count: 1381
# Itemset: ('deal', 'plan'), Count: 1381
# Itemset: ('group', 'point'), Count: 1380
# Itemset: ('group', 'order'), Count: 1380
# Itemset: ('help', 'support'), Count: 1379
# Itemset: ('cost', 'report'), Count: 1379
# Itemset: ('price', 'report'), Count: 1379
# Itemset: ('issues', 'provide'), Count: 1379
# Itemset: ('high', 'price'), Count: 1378
# Itemset: ('give', 'number'), Count: 1378
# Itemset: ('california', 'issues'), Count: 1377
# Itemset: ('meet', 'meeting'), Count: 1377
# Itemset: ('energy', 'issue'), Count: 1376
# Itemset: ('attached', 'meeting'), Count: 1376
# Itemset: ('contract', 'price'), Count: 1376
# Itemset: ('cost', 'current'), Count: 1376
# Itemset: ('find', 'think'), Count: 1375
# Itemset: ('provide', 'report'), Count: 1375
# Itemset: ('deal', 'help'), Count: 1375
# Itemset: ('corp', 'offer'), Count: 1374
# Itemset: ('cost', 'issue'), Count: 1374
# Itemset: ('business', 'working'), Count: 1373
# Itemset: ('group', 'set'), Count: 1373
# Itemset: ('cost', 'deal'), Count: 1372
# Itemset: ('effort', 'group'), Count: 1371
# Itemset: ('deal', 'energy'), Count: 1368
# Itemset: ('bill', 'customer'), Count: 1367
# Itemset: ('free', 'offer'), Count: 1366
# Itemset: ('going', 'sure'), Count: 1366
# Itemset: ('current', 'month'), Count: 1366
# Itemset: ('forward', 'think'), Count: 1365
# Itemset: ('demand', 'power'), Count: 1364
# Itemset: ('end', 'power'), Count: 1364
# Itemset: ('cost', 'states'), Count: 1363
# Itemset: ('additional', 'market'), Count: 1363
# Itemset: ('customer', 'end'), Count: 1363
# Itemset: ('market', 'states'), Count: 1363
# Itemset: ('group', 'price'), Count: 1362
# Itemset: ('report', 'service'), Count: 1362
# Itemset: ('current', 'report'), Count: 1361
# Itemset: ('access', 'market'), Count: 1361
# Itemset: ('give', 'group'), Count: 1361
# Itemset: ('end', 'report'), Count: 1360
# Itemset: ('meeting', 'provide'), Count: 1360
# Itemset: ('bill', 'cost'), Count: 1360
# Itemset: ('group', 'issue'), Count: 1359
# Itemset: ('market', 'risk'), Count: 1359
# Itemset: ('issues', 'number'), Count: 1356
# Itemset: ('date', 'process'), Count: 1356
# Itemset: ('california', 'comment'), Count: 1356
# Itemset: ('plan', 'price'), Count: 1356
# Itemset: ('cost', 'part'), Count: 1355
# Itemset: ('billion', 'company'), Count: 1355
# Itemset: ('help', 'service'), Count: 1355
# Itemset: ('date', 'number'), Count: 1355
# Itemset: ('california', 'point'), Count: 1354
# Itemset: ('price', 'start'), Count: 1354
# Itemset: ('point', 'power'), Count: 1354
# Itemset: ('billion', 'market'), Count: 1353
# Itemset: ('including', 'number'), Count: 1353
# Itemset: ('company', 'offer'), Count: 1353
# Itemset: ('end', 'service'), Count: 1353
# Itemset: ('comment', 'group'), Count: 1352
# Itemset: ('including', 'part'), Count: 1351
# Itemset: ('basis', 'contract'), Count: 1351
# Itemset: ('plan', 'set'), Count: 1349
# Itemset: ('group', 'review'), Count: 1349
# Itemset: ('bill', 'market'), Count: 1348
# Itemset: ('address', 'market'), Count: 1348
# Itemset: ('end', 'meeting'), Count: 1348
# Itemset: ('provide', 'services'), Count: 1348
# Itemset: ('business', 'point'), Count: 1348
# Itemset: ('forward', 'power'), Count: 1347
# Itemset: ('corp', 'energy'), Count: 1346
# Itemset: ('decision', 'market'), Count: 1346
# Itemset: ('number', 'part'), Count: 1345
# Itemset: ('market', 'member'), Count: 1345
# Itemset: ('business', 'issue'), Count: 1344
# Itemset: ('california', 'end'), Count: 1344
# Itemset: ('california', 'californias'), Count: 1344
# Itemset: ('help', 'price'), Count: 1344
# Itemset: ('issue', 'month'), Count: 1343
# Itemset: ('number', 'set'), Count: 1343
# Itemset: ('part', 'report'), Count: 1343
# Itemset: ('customer', 'services'), Count: 1343
# Itemset: ('gas', 'power'), Count: 1342
# Itemset: ('market', 'sell'), Count: 1342
# Itemset: ('california', 'public'), Count: 1342
# Itemset: ('contract', 'deal'), Count: 1341
# Itemset: ('companies', 'month'), Count: 1341
# Itemset: ('contract', 'receive'), Count: 1340
# Itemset: ('help', 'process'), Count: 1339
# Itemset: ('offer', 'review'), Count: 1339
# Itemset: ('cost', 'utilities'), Count: 1339
# Itemset: ('market', 'product'), Count: 1338
# Itemset: ('customer', 'prices'), Count: 1337
# Itemset: ('continue', 'market'), Count: 1337
# Itemset: ('business', 'management'), Count: 1337
# Itemset: ('change', 'company'), Count: 1337
# Itemset: ('energy', 'include'), Count: 1337
# Itemset: ('cost', 'set'), Count: 1336
# Itemset: ('contract', 'plan'), Count: 1336
# Itemset: ('help', 'working'), Count: 1336
# Itemset: ('help', 'point'), Count: 1335
# Itemset: ('month', 'prices'), Count: 1335
# Itemset: ('customer', 'support'), Count: 1335
# Itemset: ('month', 'provide'), Count: 1335
# Itemset: ('power', 'public'), Count: 1335
# Itemset: ('customer', 'part'), Count: 1334
# Itemset: ('california', 'rates'), Count: 1332
# Itemset: ('price', 'service'), Count: 1332
# Itemset: ('california', 'part'), Count: 1332
# Itemset: ('corp', 'receive'), Count: 1332
# Itemset: ('contract', 'group'), Count: 1332
# Itemset: ('help', 'sure'), Count: 1331
# Itemset: ('current', 'provide'), Count: 1331
# Itemset: ('help', 'problem'), Count: 1330
# Itemset: ('contract', 'service'), Count: 1330
# Itemset: ('meeting', 'month'), Count: 1330
# Itemset: ('end', 'price'), Count: 1330
# Itemset: ('cost', 'problem'), Count: 1329
# Itemset: ('order', 'report'), Count: 1328
# Itemset: ('forward', 'number'), Count: 1327
# Itemset: ('month', 'point'), Count: 1327
# Itemset: ('customer', 'pay'), Count: 1327
# Itemset: ('energy', 'think'), Count: 1327
# Itemset: ('business', 'going'), Count: 1327
# Itemset: ('company', 'order'), Count: 1327
# Itemset: ('cost', 'electricity'), Count: 1326
# Itemset: ('company', 'end'), Count: 1326
# Itemset: ('business', 'set'), Count: 1325
# Itemset: ('business', 'contract'), Count: 1325
# Itemset: ('cost', 'point'), Count: 1324
# Itemset: ('customer', 'include'), Count: 1324
# Itemset: ('customer', 'rate'), Count: 1323
# Itemset: ('companies', 'plan'), Count: 1323
# Itemset: ('business', 'result'), Count: 1323
# Itemset: ('rate', 'rates'), Count: 1322
# Itemset: ('message', 'review'), Count: 1322
# Itemset: ('corp', 'group'), Count: 1322
# Itemset: ('business', 'change'), Count: 1322
# Itemset: ('corp', 'power'), Count: 1322
# Itemset: ('pay', 'power'), Count: 1321
# Itemset: ('energy', 'forward'), Count: 1321
# Itemset: ('power', 'rates'), Count: 1320
# Itemset: ('demand', 'energy'), Count: 1320
# Itemset: ('consumer', 'power'), Count: 1320
# Itemset: ('company', 'high'), Count: 1319
# Itemset: ('plan', 'point'), Count: 1319
# Itemset: ('month', 'order'), Count: 1318
# Itemset: ('part', 'service'), Count: 1317
# Itemset: ('current', 'power'), Count: 1317
# Itemset: ('look', 'month'), Count: 1316
# Itemset: ('customer', 'meeting'), Count: 1316
# Itemset: ('cost', 'meeting'), Count: 1316
# Itemset: ('companies', 'customer'), Count: 1316
# Itemset: ('cost', 'include'), Count: 1315
# Itemset: ('due', 'report'), Count: 1315
# Itemset: ('customer', 'offer'), Count: 1314
# Itemset: ('help', 'issues'), Count: 1314
# Itemset: ('help', 'team'), Count: 1314
# Itemset: ('investment', 'market'), Count: 1314
# Itemset: ('issues', 'report'), Count: 1314
# Itemset: ('month', 'problem'), Count: 1313
# Itemset: ('issue', 'think'), Count: 1312
# Itemset: ('meeting', 'point'), Count: 1312
# Itemset: ('energy', 'process'), Count: 1312
# Itemset: ('forward', 'help'), Count: 1312
# Itemset: ('message', 'offer'), Count: 1311
# Itemset: ('company', 'look'), Count: 1310
# Itemset: ('california', 'consumer'), Count: 1310
# Itemset: ('plan', 'support'), Count: 1309
# Itemset: ('going', 'point'), Count: 1309
# Itemset: ('high', 'prices'), Count: 1309
# Itemset: ('order', 'provide'), Count: 1308
# Itemset: ('bill', 'plan'), Count: 1307
# Itemset: ('price', 'think'), Count: 1306
# Itemset: ('data', 'process'), Count: 1306
# Itemset: ('issue', 'order'), Count: 1306
# Itemset: ('date', 'start'), Count: 1306
# Itemset: ('issues', 'order'), Count: 1305
# Itemset: ('energy', 'problem'), Count: 1305
# Itemset: ('california', 'rate'), Count: 1304
# Itemset: ('power', 'set'), Count: 1303
# Itemset: ('future', 'market'), Count: 1303
# Itemset: ('california', 'going'), Count: 1303
# Itemset: ('energy', 'financial'), Count: 1302
# Itemset: ('order', 'plan'), Count: 1302
# Itemset: ('cost', 'issues'), Count: 1301
# Itemset: ('process', 'provide'), Count: 1301
# Itemset: ('month', 'set'), Count: 1301
# Itemset: ('cost', 'look'), Count: 1300
# Itemset: ('think', 'working'), Count: 1300
# Itemset: ('number', 'problem'), Count: 1300
# Itemset: ('effort', 'market'), Count: 1299
# Itemset: ('help', 'order'), Count: 1298
# Itemset: ('comment', 'meeting'), Count: 1298
# Itemset: ('contract', 'provide'), Count: 1298
# Itemset: ('customer', 'utilities'), Count: 1298
# Itemset: ('find', 'group'), Count: 1297
# Itemset: ('business', 'member'), Count: 1297
# Itemset: ('part', 'provide'), Count: 1297
# Itemset: ('power', 'support'), Count: 1297
# Itemset: ('market', 'place'), Count: 1297
# Itemset: ('business', 'corp'), Count: 1296
# Itemset: ('data', 'price'), Count: 1295
# Itemset: ('offer', 'service'), Count: 1295
# Itemset: ('energy', 'going'), Count: 1294
# Itemset: ('financial', 'power'), Count: 1294
# Itemset: ('current', 'customer'), Count: 1294
# Itemset: ('customer', 'report'), Count: 1293
# Itemset: ('contract', 'number'), Count: 1293
# Itemset: ('energy', 'set'), Count: 1293
# Itemset: ('help', 'issue'), Count: 1293
# Itemset: ('agreement', 'contract'), Count: 1292
# Itemset: ('company', 'result'), Count: 1292
# Itemset: ('consumer', 'energy'), Count: 1292
# Itemset: ('including', 'price'), Count: 1291
# Itemset: ('business', 'effort'), Count: 1291
# Itemset: ('energy', 'support'), Count: 1291
# Itemset: ('plan', 'review'), Count: 1291
# Itemset: ('contract', 'think'), Count: 1291
# Itemset: ('customer', 'issues'), Count: 1290
# Itemset: ('financial', 'group'), Count: 1290
# Itemset: ('plan', 'working'), Count: 1290
# Itemset: ('corp', 'plan'), Count: 1289
# Itemset: ('market', 'operation'), Count: 1289
# Itemset: ('help', 'set'), Count: 1288
# Itemset: ('based', 'cost'), Count: 1287
# Itemset: ('customer', 'deal'), Count: 1287
# Itemset: ('give', 'market'), Count: 1287
# Itemset: ('due', 'market'), Count: 1287
# Itemset: ('california', 'federal'), Count: 1287
# Itemset: ('issue', 'meeting'), Count: 1286
# Itemset: ('business', 'review'), Count: 1286
# Itemset: ('hour', 'market'), Count: 1285
# Itemset: ('help', 'offer'), Count: 1285
# Itemset: ('energy', 'supply'), Count: 1284
# Itemset: ('include', 'plan'), Count: 1283
# Itemset: ('group', 'problem'), Count: 1282
# Itemset: ('include', 'provide'), Count: 1282
# Itemset: ('help', 'receive'), Count: 1282
# Itemset: ('end', 'point'), Count: 1282
# Itemset: ('meeting', 'team'), Count: 1282
# Itemset: ('business', 'position'), Count: 1281
# Itemset: ('comment', 'power'), Count: 1280
# Itemset: ('comment', 'provide'), Count: 1280
# Itemset: ('california', 'pay'), Count: 1280
# Itemset: ('give', 'meeting'), Count: 1279
# Itemset: ('firm', 'market'), Count: 1279
# Itemset: ('power', 'supply'), Count: 1279
# Itemset: ('end', 'look'), Count: 1279
# Itemset: ('change', 'plan'), Count: 1278
# Itemset: ('based', 'group'), Count: 1278
# Itemset: ('contract', 'meeting'), Count: 1278
# Itemset: ('include', 'power'), Count: 1278
# Itemset: ('business', 'team'), Count: 1278
# Itemset: ('energy', 'member'), Count: 1278
# Itemset: ('end', 'part'), Count: 1277
# Itemset: ('number', 'office'), Count: 1277
# Itemset: ('price', 'provide'), Count: 1277
# Itemset: ('end', 'issue'), Count: 1277
# Itemset: ('billion', 'energy'), Count: 1277
# Itemset: ('high', 'plan'), Count: 1276
# Itemset: ('generation', 'power'), Count: 1276
# Itemset: ('deal', 'going'), Count: 1276
# Itemset: ('end', 'energy'), Count: 1276
# Itemset: ('business', 'find'), Count: 1276
# Itemset: ('customer', 'rates'), Count: 1275
# Itemset: ('look', 'power'), Count: 1275
# Itemset: ('utilities', 'utility'), Count: 1275
# Itemset: ('include', 'number'), Count: 1274
# Itemset: ('billion', 'power'), Count: 1273
# Itemset: ('number', 'send'), Count: 1273
# Itemset: ('contract', 'going'), Count: 1273
# Itemset: ('set', 'think'), Count: 1273
# Itemset: ('plan', 'process'), Count: 1271
# Itemset: ('group', 'list'), Count: 1270
# Itemset: ('bill', 'month'), Count: 1270
# Itemset: ('company', 'issue'), Count: 1270
# Itemset: ('give', 'look'), Count: 1270
# Itemset: ('business', 'operation'), Count: 1269
# Itemset: ('market', 'working'), Count: 1267
# Itemset: ('company', 'prices'), Count: 1267
# Itemset: ('deal', 'number'), Count: 1267
# Itemset: ('business', 'future'), Count: 1266
# Itemset: ('market', 'past'), Count: 1266
# Itemset: ('date', 'meeting'), Count: 1266
# Itemset: ('california', 'companies'), Count: 1266
# Itemset: ('credit', 'market'), Count: 1265
# Itemset: ('company', 'set'), Count: 1265
# Itemset: ('end', 'provide'), Count: 1265
# Itemset: ('companies', 'cost'), Count: 1264
# Itemset: ('going', 'problem'), Count: 1263
# Itemset: ('general', 'market'), Count: 1263
# Itemset: ('bill', 'group'), Count: 1262
# Itemset: ('provide', 'support'), Count: 1262
# Itemset: ('california', 'demand'), Count: 1262
# Itemset: ('issue', 'report'), Count: 1262
# Itemset: ('going', 'issue'), Count: 1261
# Itemset: ('business', 'give'), Count: 1261
# Itemset: ('help', 'thing'), Count: 1260
# Itemset: ('point', 'price'), Count: 1260
# Itemset: ('market', 'pay'), Count: 1260
# Itemset: ('business', 'forward'), Count: 1259
# Itemset: ('business', 'high'), Count: 1259
# Itemset: ('business', 'received'), Count: 1259
# Itemset: ('generation', 'market'), Count: 1259
# Itemset: ('commission', 'market'), Count: 1259
# Itemset: ('look', 'point'), Count: 1258
# Itemset: ('company', 'find'), Count: 1258
# Itemset: ('current', 'number'), Count: 1258
# Itemset: ('issue', 'provide'), Count: 1258
# Itemset: ('contract', 'issue'), Count: 1258
# Itemset: ('market', 'world'), Count: 1258
# Itemset: ('customer', 'think'), Count: 1258
# Itemset: ('federal', 'market'), Count: 1257
# Itemset: ('including', 'issue'), Count: 1257
# Itemset: ('including', 'order'), Count: 1256
# Itemset: ('able', 'help'), Count: 1256
# Itemset: ('help', 'list'), Count: 1256
# Itemset: ('including', 'services'), Count: 1256
# Itemset: ('electricity', 'price'), Count: 1255
# Itemset: ('companies', 'report'), Count: 1255
# Itemset: ('look', 'price'), Count: 1255
# Itemset: ('month', 'offer'), Count: 1255
# Itemset: ('current', 'help'), Count: 1255
# Itemset: ('provide', 'review'), Count: 1254
# Itemset: ('group', 'place'), Count: 1254
# Itemset: ('part', 'price'), Count: 1254
# Itemset: ('end', 'including'), Count: 1254
# Itemset: ('company', 'meeting'), Count: 1253
# Itemset: ('issue', 'price'), Count: 1253
# Itemset: ('contract', 'end'), Count: 1253
# Itemset: ('end', 'order'), Count: 1253
# Itemset: ('company', 'think'), Count: 1252
# Itemset: ('meeting', 'order'), Count: 1252
# Itemset: ('cost', 'result'), Count: 1252
# Itemset: ('meeting', 'thursday'), Count: 1252
# Itemset: ('market', 'office'), Count: 1252
# Itemset: ('company', 'going'), Count: 1251
# Itemset: ('part', 'think'), Count: 1251
# Itemset: ('member', 'service'), Count: 1251
# Itemset: ('give', 'plan'), Count: 1250
# Itemset: ('month', 'past'), Count: 1250
# Itemset: ('additional', 'business'), Count: 1249
# Itemset: ('change', 'group'), Count: 1249
# Itemset: ('going', 'part'), Count: 1249
# Itemset: ('month', 'result'), Count: 1249
# Itemset: ('issue', 'point'), Count: 1248
# Itemset: ('california', 'commission'), Count: 1248
# Itemset: ('look', 'report'), Count: 1248
# Itemset: ('company', 'interest'), Count: 1247
# Itemset: ('help', 'part'), Count: 1247
# Itemset: ('offer', 'price'), Count: 1247
# Itemset: ('comment', 'issues'), Count: 1246
# Itemset: ('point', 'report'), Count: 1246
# Itemset: ('market', 'put'), Count: 1246
# Itemset: ('data', 'market'), Count: 1246
# Itemset: ('company', 'management'), Count: 1246
# Itemset: ('comment', 'energy'), Count: 1245
# Itemset: ('power', 'term'), Count: 1245
# Itemset: ('give', 'month'), Count: 1245
# Itemset: ('number', 'place'), Count: 1245
# Itemset: ('include', 'service'), Count: 1244
# Itemset: ('market', 'receive'), Count: 1244
# Itemset: ('number', 'offer'), Count: 1244
# Itemset: ('number', 'phone'), Count: 1244
# Itemset: ('meeting', 'place'), Count: 1243
# Itemset: ('financial', 'month'), Count: 1243
# Itemset: ('energy', 'rates'), Count: 1242
# Itemset: ('financial', 'plan'), Count: 1242
# Itemset: ('companies', 'including'), Count: 1242
# Itemset: ('business', 'continue'), Count: 1242
# Itemset: ('plan', 'problem'), Count: 1242
# Itemset: ('company', 'include'), Count: 1241
# Itemset: ('hour', 'start'), Count: 1241
# Itemset: ('companies', 'service'), Count: 1241
# Itemset: ('billion', 'cost'), Count: 1240
# Itemset: ('action', 'california'), Count: 1240
# Itemset: ('member', 'plan'), Count: 1239
# Itemset: ('agreement', 'company'), Count: 1239
# Itemset: ('customer', 'set'), Count: 1239
# Itemset: ('month', 'pay'), Count: 1239
# Itemset: ('based', 'month'), Count: 1238
# Itemset: ('offer', 'plan'), Count: 1238
# Itemset: ('deal', 'term'), Count: 1238
# Itemset: ('current', 'price'), Count: 1238
# Itemset: ('number', 'sure'), Count: 1238
# Itemset: ('contract', 'order'), Count: 1238
# Itemset: ('comment', 'plan'), Count: 1237
# Itemset: ('report', 'result'), Count: 1237
# Itemset: ('high', 'think'), Count: 1237
# Itemset: ('customer', 'high'), Count: 1237
# Itemset: ('list', 'meeting'), Count: 1237
# Itemset: ('based', 'number'), Count: 1236
# Itemset: ('going', 'price'), Count: 1236
# Itemset: ('business', 'program'), Count: 1236
# Itemset: ('point', 'provide'), Count: 1236
# Itemset: ('issues', 'point'), Count: 1236
# Itemset: ('based', 'business'), Count: 1236
# Itemset: ('change', 'number'), Count: 1236
# Itemset: ('look', 'sure'), Count: 1235
# Itemset: ('based', 'customer'), Count: 1235
# Itemset: ('houston', 'meeting'), Count: 1234
# Itemset: ('company', 'member'), Count: 1234
# Itemset: ('energy', 'generation'), Count: 1233
# Itemset: ('federal', 'power'), Count: 1233
# Itemset: ('california', 'deal'), Count: 1233
# Itemset: ('find', 'number'), Count: 1233
# Itemset: ('additional', 'provide'), Count: 1232
# Itemset: ('help', 'high'), Count: 1232
# Itemset: ('number', 'team'), Count: 1232
# Itemset: ('action', 'market'), Count: 1232
# Itemset: ('bill', 'business'), Count: 1232
# Itemset: ('management', 'market'), Count: 1232
# Itemset: ('process', 'start'), Count: 1231
# Itemset: ('date', 'market'), Count: 1231
# Itemset: ('group', 'result'), Count: 1231
# Itemset: ('comment', 'issue'), Count: 1231
# Itemset: ('plan', 'services'), Count: 1231
# Itemset: ('able', 'think'), Count: 1231
# Itemset: ('free', 'help'), Count: 1231
# Itemset: ('deal', 'part'), Count: 1231
# Itemset: ('find', 'month'), Count: 1230
# Itemset: ('energy', 'rate'), Count: 1230
# Itemset: ('california', 'ferc'), Count: 1230
# Itemset: ('meeting', 'member'), Count: 1230
# Itemset: ('process', 'review'), Count: 1230
# Itemset: ('electricity', 'states'), Count: 1230
# Itemset: ('account', 'customer'), Count: 1229
# Itemset: ('group', 'put'), Count: 1229
# Itemset: ('energy', 'term'), Count: 1229
# Itemset: ('current', 'including'), Count: 1229
# Itemset: ('energy', 'hour'), Count: 1229
# Itemset: ('business', 'comment'), Count: 1229
# Itemset: ('californias', 'power'), Count: 1229
# Itemset: ('electricity', 'prices'), Count: 1228
# Itemset: ('business', 'interest'), Count: 1228
# Itemset: ('number', 'working'), Count: 1227
# Itemset: ('review', 'think'), Count: 1227
# Itemset: ('current', 'service'), Count: 1227
# Itemset: ('company', 'issues'), Count: 1227
# Itemset: ('california', 'supply'), Count: 1227
# Itemset: ('california', 'current'), Count: 1227
# Itemset: ('deal', 'end'), Count: 1227
# Itemset: ('give', 'point'), Count: 1226
# Itemset: ('conference', 'meeting'), Count: 1226
# Itemset: ('end', 'give'), Count: 1226
# Itemset: ('company', 'continue'), Count: 1226
# Itemset: ('energy', 'interest'), Count: 1226
# Itemset: ('buy', 'power'), Count: 1226
# Itemset: ('change', 'report'), Count: 1226
# Itemset: ('price', 'set'), Count: 1225
# Itemset: ('group', 'position'), Count: 1225
# Itemset: ('meeting', 'scheduled'), Count: 1225
# Itemset: ('company', 'support'), Count: 1225
# Itemset: ('group', 'industry'), Count: 1225
# Itemset: ('company', 'public'), Count: 1225
# Itemset: ('help', 'include'), Count: 1224
# Itemset: ('energy', 'pay'), Count: 1224
# Itemset: ('issue', 'problem'), Count: 1224
# Itemset: ('energy', 'office'), Count: 1224
# Itemset: ('california', 'set'), Count: 1223
# Itemset: ('energy', 'result'), Count: 1223
# Itemset: ('report', 'set'), Count: 1223
# Itemset: ('business', 'receive'), Count: 1223
# Itemset: ('group', 'high'), Count: 1223
# Itemset: ('deal', 'issue'), Count: 1223
# Itemset: ('energy', 'services'), Count: 1222
# Itemset: ('comment', 'think'), Count: 1222
# Itemset: ('issue', 'part'), Count: 1222
# Itemset: ('date', 'hour'), Count: 1221
# Itemset: ('getting', 'think'), Count: 1221
# Itemset: ('bill', 'company'), Count: 1221
# Itemset: ('energy', 'look'), Count: 1221
# Itemset: ('energy', 'gas'), Count: 1221
# Itemset: ('companies', 'provide'), Count: 1220
# Itemset: ('business', 'world'), Count: 1220
# Itemset: ('power', 'result'), Count: 1220
# Itemset: ('bill', 'price'), Count: 1220
# Itemset: ('company', 'future'), Count: 1220
# Itemset: ('market', 'review'), Count: 1219
# Itemset: ('energy', 'point'), Count: 1219
# Itemset: ('change', 'service'), Count: 1219
# Itemset: ('business', 'place'), Count: 1219
# Itemset: ('ferc', 'market'), Count: 1218
# Itemset: ('help', 'send'), Count: 1218
# Itemset: ('deal', 'including'), Count: 1218
# Itemset: ('issue', 'number'), Count: 1218
# Itemset: ('month', 'working'), Count: 1217
# Itemset: ('provide', 'think'), Count: 1217
# Itemset: ('end', 'problem'), Count: 1217
# Itemset: ('california', 'forward'), Count: 1217
# Itemset: ('business', 'public'), Count: 1216
# Itemset: ('power', 'rate'), Count: 1216
# Itemset: ('due', 'group'), Count: 1216
# Itemset: ('companies', 'price'), Count: 1215
# Itemset: ('access', 'business'), Count: 1215
# Itemset: ('part', 'point'), Count: 1215
# Itemset: ('high', 'part'), Count: 1215
# Itemset: ('business', 'product'), Count: 1214
# Itemset: ('able', 'group'), Count: 1214
# Itemset: ('business', 'problem'), Count: 1214
# Itemset: ('find', 'look'), Count: 1213
# Itemset: ('deal', 'look'), Count: 1213
# Itemset: ('help', 'put'), Count: 1213
# Itemset: ('including', 'think'), Count: 1213
# Itemset: ('future', 'plan'), Count: 1212
# Itemset: ('end', 'high'), Count: 1212
# Itemset: ('end', 'set'), Count: 1212
# Itemset: ('issues', 'month'), Count: 1212
# Itemset: ('additional', 'cost'), Count: 1212
# Itemset: ('contract', 'current'), Count: 1212
# Itemset: ('group', 'thing'), Count: 1212
# Itemset: ('service', 'set'), Count: 1212
# Itemset: ('hope', 'think'), Count: 1211
# Itemset: ('find', 'going'), Count: 1211
# Itemset: ('issues', 'review'), Count: 1211
# Itemset: ('basis', 'review'), Count: 1211
# Itemset: ('business', 'trading'), Count: 1210
# Itemset: ('place', 'plan'), Count: 1210
# Itemset: ('group', 'public'), Count: 1210
# Itemset: ('company', 'investment'), Count: 1210
# Itemset: ('cost', 'forward'), Count: 1210
# Itemset: ('continue', 'energy'), Count: 1210
# Itemset: ('energy', 'federal'), Count: 1210
# Itemset: ('company', 'firm'), Count: 1210
# Itemset: ('issue', 'set'), Count: 1209
# Itemset: ('companies', 'part'), Count: 1209
# Itemset: ('high', 'number'), Count: 1209
# Itemset: ('look', 'problem'), Count: 1209
# Itemset: ('california', 'corp'), Count: 1209
# Itemset: ('find', 'report'), Count: 1209
# Itemset: ('consumer', 'cost'), Count: 1209
# Itemset: ('going', 'put'), Count: 1209
# Itemset: ('houston', 'texas'), Count: 1208
# Itemset: ('company', 'point'), Count: 1208
# Itemset: ('billion', 'california'), Count: 1208
# Itemset: ('create', 'review'), Count: 1208
# Itemset: ('company', 'product'), Count: 1207
# Itemset: ('business', 'free'), Count: 1207
# Itemset: ('industry', 'power'), Count: 1207
# Itemset: ('number', 'thing'), Count: 1207
# Itemset: ('monday', 'tuesday'), Count: 1207
# Itemset: ('including', 'offer'), Count: 1206
# Itemset: ('business', 'prices'), Count: 1206
# Itemset: ('electricity', 'utilities'), Count: 1205
# Itemset: ('issues', 'process'), Count: 1205
# Itemset: ('including', 'issues'), Count: 1205
# Itemset: ('help', 'review'), Count: 1205
# Itemset: ('access', 'service'), Count: 1204
# Itemset: ('california', 'office'), Count: 1204
# Itemset: ('talk', 'think'), Count: 1204
# Itemset: ('market', 'open'), Count: 1204
# Itemset: ('group', 'offer'), Count: 1204
# Itemset: ('access', 'group'), Count: 1204
# Itemset: ('agreement', 'power'), Count: 1204
# Itemset: ('date', 'energy'), Count: 1203
# Itemset: ('deal', 'point'), Count: 1203
# Itemset: ('forward', 'plan'), Count: 1203
# Itemset: ('business', 'firm'), Count: 1203
# Itemset: ('issues', 'problem'), Count: 1203
# Itemset: ('cost', 'services'), Count: 1202
# Itemset: ('data', 'date'), Count: 1202
# Itemset: ('price', 'utility'), Count: 1202
# Itemset: ('market', 'thing'), Count: 1202
# Itemset: ('look', 'review'), Count: 1202
# Itemset: ('cost', 'demand'), Count: 1202
# Itemset: ('continue', 'group'), Count: 1201
# Itemset: ('customer', 'going'), Count: 1201
# Itemset: ('major', 'market'), Count: 1201
# Itemset: ('company', 'office'), Count: 1201
# Itemset: ('month', 'support'), Count: 1201
# Itemset: ('create', 'offer'), Count: 1201
# Itemset: ('market', 'sales'), Count: 1200
# Itemset: ('list', 'number'), Count: 1200
# Itemset: ('additional', 'group'), Count: 1200
# Itemset: ('future', 'group'), Count: 1200
# Itemset: ('group', 'management'), Count: 1200
# Itemset: ('forward', 'issues'), Count: 1200
# Itemset: ('find', 'plan'), Count: 1200
# Itemset: ('based', 'company'), Count: 1199
# Itemset: ('energy', 'operation'), Count: 1199
# Itemset: ('issues', 'look'), Count: 1199
# Itemset: ('current', 'issues'), Count: 1199
# Itemset: ('company', 'international'), Count: 1198
# Itemset: ('look', 'working'), Count: 1198
# Itemset: ('month', 'states'), Count: 1197
# Itemset: ('comment', 'report'), Count: 1197
# Itemset: ('effort', 'energy'), Count: 1197
# Itemset: ('help', 'services'), Count: 1197
# Itemset: ('group', 'interest'), Count: 1197
# Itemset: ('price', 'utilities'), Count: 1196
# Itemset: ('based', 'plan'), Count: 1196
# Itemset: ('meet', 'plan'), Count: 1196
# Itemset: ('price', 'states'), Count: 1196
# Itemset: ('cost', 'decision'), Count: 1196
# Itemset: ('expected', 'market'), Count: 1195
# Itemset: ('cost', 'public'), Count: 1195
# Itemset: ('plan', 'result'), Count: 1195
# Itemset: ('report', 'team'), Count: 1195
# Itemset: ('companies', 'industry'), Count: 1195
# Itemset: ('group', 'operation'), Count: 1194
# Itemset: ('able', 'market'), Count: 1194
# Itemset: ('look', 'provide'), Count: 1194
# Itemset: ('meeting', 'tuesday'), Count: 1194
# Itemset: ('demand', 'price'), Count: 1193
# Itemset: ('include', 'report'), Count: 1193
# Itemset: ('corp', 'service'), Count: 1192
# Itemset: ('action', 'power'), Count: 1192
# Itemset: ('deal', 'provide'), Count: 1192
# Itemset: ('access', 'direct'), Count: 1191
# Itemset: ('discussion', 'meeting'), Count: 1191
# Itemset: ('pay', 'plan'), Count: 1190
# Itemset: ('states', 'utilities'), Count: 1190
# Itemset: ('issue', 'service'), Count: 1190
# Itemset: ('forward', 'review'), Count: 1190
# Itemset: ('corp', 'create'), Count: 1190
# Itemset: ('free', 'market'), Count: 1190
# Itemset: ('based', 'including'), Count: 1190
# Itemset: ('deal', 'report'), Count: 1190
# Itemset: ('development', 'market'), Count: 1190
# Itemset: ('market', 'policy'), Count: 1189
# Itemset: ('address', 'business'), Count: 1189
# Itemset: ('order', 'set'), Count: 1189
# Itemset: ('plan', 'team'), Count: 1189
# Itemset: ('contract', 'help'), Count: 1189
# Itemset: ('companies', 'financial'), Count: 1188
# Itemset: ('monday', 'number'), Count: 1188
# Itemset: ('customer', 'problem'), Count: 1188
# Itemset: ('energy', 'natural_gas'), Count: 1188
# Itemset: ('business', 'term'), Count: 1188
# Itemset: ('provide', 'result'), Count: 1187
# Itemset: ('power', 'services'), Count: 1187
# Itemset: ('deal', 'service'), Count: 1187
# Itemset: ('find', 'offer'), Count: 1187
# Itemset: ('comment', 'customer'), Count: 1187
# Itemset: ('customer', 'result'), Count: 1186
# Itemset: ('forward', 'provide'), Count: 1186
# Itemset: ('end', 'issues'), Count: 1186
# Itemset: ('higher', 'market'), Count: 1186
# Itemset: ('electric', 'energy'), Count: 1185
# Itemset: ('find', 'power'), Count: 1185
# Itemset: ('deal', 'offer'), Count: 1185
# Itemset: ('customer', 'point'), Count: 1184
# Itemset: ('report', 'services'), Count: 1184
# Itemset: ('business', 'director'), Count: 1184
# Itemset: ('problem', 'report'), Count: 1184
# Itemset: ('effort', 'plan'), Count: 1184
# Itemset: ('meeting', 'part'), Count: 1183
# Itemset: ('cost', 'support'), Count: 1183
# Itemset: ('due', 'month'), Count: 1183
# Itemset: ('business', 'general'), Count: 1182
# Itemset: ('current', 'issue'), Count: 1182
# Itemset: ('current', 'end'), Count: 1182
# Itemset: ('current', 'part'), Count: 1182
# Itemset: ('gas', 'group'), Count: 1181
# Itemset: ('decision', 'power'), Count: 1181
# Itemset: ('including', 'point'), Count: 1181
# Itemset: ('company', 'process'), Count: 1181
# Itemset: ('contract', 'point'), Count: 1181
# Itemset: ('price', 'problem'), Count: 1181
# Itemset: ('address', 'service'), Count: 1181
# Itemset: ('contract', 'set'), Count: 1181
# Itemset: ('date', 'file'), Count: 1181
# Itemset: ('price', 'term'), Count: 1180
# Itemset: ('going', 'set'), Count: 1180
# Itemset: ('customer', 'decision'), Count: 1180
# Itemset: ('interest', 'power'), Count: 1180
# Itemset: ('generator', 'power'), Count: 1179
# Itemset: ('going', 'issues'), Count: 1179
# Itemset: ('final', 'process'), Count: 1179
# Itemset: ('company', 'electricity'), Count: 1178
# Itemset: ('commission', 'customer'), Count: 1178
# Itemset: ('california', 'look'), Count: 1178
# Itemset: ('electricity', 'utility'), Count: 1178
# Itemset: ('help', 'office'), Count: 1178
# Itemset: ('able', 'number'), Count: 1177
# Itemset: ('find', 'service'), Count: 1177
# Itemset: ('date', 'service'), Count: 1177
# Itemset: ('contract', 'issues'), Count: 1176
# Itemset: ('additional', 'company'), Count: 1176
# Itemset: ('energy', 'firm'), Count: 1176
# Itemset: ('cost', 'due'), Count: 1176
# Itemset: ('company', 'general'), Count: 1175
# Itemset: ('friday', 'monday'), Count: 1175
# Itemset: ('issues', 'part'), Count: 1174
# Itemset: ('change', 'month'), Count: 1174
# Itemset: ('current', 'meeting'), Count: 1174
# Itemset: ('offer', 'think'), Count: 1174
# Itemset: ('company', 'problem'), Count: 1174
# Itemset: ('california', 'summer'), Count: 1174
# Itemset: ('contract', 'create'), Count: 1173
# Itemset: ('address', 'number'), Count: 1173
# Itemset: ('number', 'result'), Count: 1173
# Itemset: ('commission', 'energy'), Count: 1172
# Itemset: ('company', 'position'), Count: 1172
# Itemset: ('help', 'received'), Count: 1172
# Itemset: ('start', 'think'), Count: 1172
# Itemset: ('pay', 'price'), Count: 1172
# Itemset: ('month', 'term'), Count: 1171
# Itemset: ('help', 'member'), Count: 1171
# Itemset: ('additional', 'number'), Count: 1171
# Itemset: ('californias', 'energy'), Count: 1171
# Itemset: ('comment', 'cost'), Count: 1170
# Itemset: ('conference', 'number'), Count: 1170
# Itemset: ('high', 'report'), Count: 1170
# Itemset: ('based', 'power'), Count: 1170
# Itemset: ('corp', 'month'), Count: 1170
# Itemset: ('based', 'price'), Count: 1170
# Itemset: ('believe', 'think'), Count: 1170
# Itemset: ('date', 'order'), Count: 1170
# Itemset: ('customer', 'process'), Count: 1170
# Itemset: ('economic', 'market'), Count: 1169
# Itemset: ('end', 'thing'), Count: 1169
# Itemset: ('look', 'part'), Count: 1169
# Itemset: ('capacity', 'market'), Count: 1169
# Itemset: ('effort', 'help'), Count: 1169
# Itemset: ('change', 'customer'), Count: 1168
# Itemset: ('high', 'service'), Count: 1168
# Itemset: ('group', 'houston'), Count: 1168
# Itemset: ('consumer', 'customer'), Count: 1168
# Itemset: ('business', 'investment'), Count: 1168
# Itemset: ('customer', 'electricity'), Count: 1168
# Itemset: ('free', 'service'), Count: 1168
# Itemset: ('access', 'company'), Count: 1167
# Itemset: ('discuss', 'group'), Count: 1167
# Itemset: ('agreement', 'market'), Count: 1166
# Itemset: ('california', 'include'), Count: 1166
# Itemset: ('forward', 'point'), Count: 1166
# Itemset: ('meeting', 'wednesday'), Count: 1166
# ...
# Itemset: ('offer', 'property'), Count: 918
# Itemset: ('date', 'report'), Count: 918
# Itemset: ('number', 'show'), Count: 918
# Itemset: ('deal', 'risk'), Count: 918
# Itemset: ('corp', 'prices'), Count: 918
# Itemset: ('companies', 'major'), Count: 917
# Itemset: ('detail', 'offer'), Count: 917
# Itemset: ('asked', 'point'), Count: 917
# Itemset: ('continue', 'process'), Count: 917
# Itemset: ('offer', 'program'), Count: 917
# Itemset: ('company', 'option'), Count: 917
# Itemset: ('billion', 'federal'), Count: 917
# Itemset: ('high', 'major'), Count: 917
# Itemset: ('business', 'commercial'), Count: 917
# Itemset: ('corp', 'electricity'), Count: 917
# Itemset: ('david', 'group'), Count: 917
# Itemset: ('end', 'receive'), Count: 917
# Itemset: ('business', 'mark'), Count: 917
# Itemset: ('list', 'team'), Count: 917
# Itemset: ('member', 'receive'), Count: 917
# Itemset: ('energy', 'june'), Count: 917
# Itemset: ('group', 'message'), Count: 917
# Itemset: ('group', 'wednesday'), Count: 917
# Itemset: ('full', 'help'), Count: 917
# Itemset: ('due', 'part'), Count: 917
# Itemset: ('part', 'sure'), Count: 917
# Itemset: ('free', 'web'), Count: 917
# Itemset: ('industry', 'issues'), Count: 917
# Itemset: ('cost', 'making'), Count: 917
# Itemset: ('company', 'electric'), Count: 916
# Itemset: ('part', 'rates'), Count: 916
# Itemset: ('month', 'move'), Count: 916
# Itemset: ('corp', 'international'), Count: 916
# Itemset: ('demand', 'end'), Count: 916
# Itemset: ('action', 'service'), Count: 916
# Itemset: ('industry', 'order'), Count: 916
# Itemset: ('increase', 'plan'), Count: 916
# Itemset: ('part', 'supply'), Count: 916
# Itemset: ('meeting', 'proposed'), Count: 916
# Itemset: ('future', 'think'), Count: 916
# Itemset: ('held', 'market'), Count: 916
# Itemset: ('end', 'utility'), Count: 916
# Itemset: ('business', 'later'), Count: 916
# Itemset: ('believe', 'price'), Count: 916
# Itemset: ('power', 'transmission'), Count: 916
# Itemset: ('generator', 'utilities'), Count: 916
# Itemset: ('based', 'change'), Count: 916
# Itemset: ('able', 'find'), Count: 916
# Itemset: ('discuss', 'issue'), Count: 916
# Itemset: ('corp', 'industry'), Count: 916
# Itemset: ('address', 'services'), Count: 916
# Itemset: ('going', 'term'), Count: 916
# Itemset: ('large', 'plan'), Count: 916
# Itemset: ('california', 'discuss'), Count: 915
# Itemset: ('bill', 'general'), Count: 915
# Itemset: ('decision', 'result'), Count: 915
# Itemset: ('company', 'sure'), Count: 915
# Itemset: ('access', 'current'), Count: 915
# Itemset: ('due', 'result'), Count: 915
# Itemset: ('going', 'jeff'), Count: 915
# Itemset: ('close', 'group'), Count: 915
# Itemset: ('put', 'working'), Count: 915
# Itemset: ('comment', 'public'), Count: 915
# Itemset: ('additional', 'process'), Count: 915
# Itemset: ('interest', 'look'), Count: 915
# Itemset: ('continue', 'problem'), Count: 915
# Itemset: ('account', 'change'), Count: 915
# Itemset: ('large', 'number'), Count: 915
# Itemset: ('action', 'high'), Count: 915
# Itemset: ('chairman', 'plan'), Count: 915
# Itemset: ('against', 'customer'), Count: 914
# Itemset: ('account', 'cost'), Count: 914
# Itemset: ('access', 'support'), Count: 914
# Itemset: ('against', 'pay'), Count: 914
# Itemset: ('public', 'support'), Count: 914
# Itemset: ('believe', 'meeting'), Count: 914
# Itemset: ('california', 'plant'), Count: 914
# Itemset: ('deal', 'team'), Count: 914
# Itemset: ('received', 'send'), Count: 914
# Itemset: ('consumer', 'help'), Count: 914
# Itemset: ('government', 'plan'), Count: 914
# Itemset: ('official', 'states'), Count: 914
# Itemset: ('market', 'supplier'), Count: 914
# Itemset: ('power', 'proposed'), Count: 914
# Itemset: ('month', 'total'), Count: 914
# Itemset: ('companies', 'look'), Count: 914
# Itemset: ('demand', 'service'), Count: 914
# Itemset: ('line', 'price'), Count: 914
# Itemset: ('meeting', 'offer'), Count: 913
# Itemset: ('end', 'utilities'), Count: 913
# Itemset: ('end', 'public'), Count: 913
# Itemset: ('board', 'energy'), Count: 913
# Itemset: ('power', 'unit'), Count: 913
# Itemset: ('able', 'high'), Count: 913
# Itemset: ('prices', 'term'), Count: 913
# Itemset: ('case', 'month'), Count: 913
# Itemset: ('cost', 'investment'), Count: 913
# Itemset: ('find', 'received'), Count: 913
# Itemset: ('request', 'service'), Count: 913
# Itemset: ('offer', 'world'), Count: 913
# Itemset: ('current', 'public'), Count: 913
# Itemset: ('attached', 'report'), Count: 913
# Itemset: ('member', 'office'), Count: 913
# Itemset: ('attached', 'provide'), Count: 913
# Itemset: ('help', 'told'), Count: 913
# Itemset: ('level', 'problem'), Count: 913
# Itemset: ('corp', 'issues'), Count: 913
# Itemset: ('list', 'review'), Count: 913
# Itemset: ('number', 'operation'), Count: 913
# Itemset: ('provide', 'put'), Count: 913
# Itemset: ('cost', 'plant'), Count: 912
# Itemset: ('board', 'power'), Count: 912
# Itemset: ('general', 'meeting'), Count: 912
# Itemset: ('open', 'service'), Count: 912
# Itemset: ('director', 'including'), Count: 912
# Itemset: ('law', 'states'), Count: 912
# Itemset: ('market', 'senior'), Count: 912
# Itemset: ('bill', 'find'), Count: 912
# Itemset: ('message', 'party'), Count: 912
# Itemset: ('company', 'potential'), Count: 912
# Itemset: ('give', 'start'), Count: 912
# Itemset: ('action', 'number'), Count: 912
# Itemset: ('end', 'industry'), Count: 912
# Itemset: ('industry', 'public'), Count: 912
# Itemset: ('contract', 'firm'), Count: 912
# Itemset: ('market', 'trying'), Count: 912
# Itemset: ('percent', 'power'), Count: 912
# Itemset: ('contract', 'public'), Count: 912
# Itemset: ('group', 'total'), Count: 912
# Itemset: ('job', 'number'), Count: 912
# Itemset: ('believe', 'part'), Count: 912
# Itemset: ('energy', 'press'), Count: 912
# Itemset: ('californias', 'price'), Count: 912
# Itemset: ('industry', 'result'), Count: 912
# Itemset: ('friday', 'provide'), Count: 911
# Itemset: ('cost', 'request'), Count: 911
# Itemset: ('basis', 'number'), Count: 911
# Itemset: ('effort', 'high'), Count: 911
# Itemset: ('cost', 'option'), Count: 911
# Itemset: ('able', 'order'), Count: 911
# Itemset: ('result', 'services'), Count: 911
# Itemset: ('member', 'working'), Count: 911
# Itemset: ('company', 'view'), Count: 911
# Itemset: ('including', 'international'), Count: 911
# Itemset: ('look', 'term'), Count: 911
# Itemset: ('market', 'share'), Count: 911
# Itemset: ('cost', 'short'), Count: 911
# Itemset: ('financial', 'set'), Count: 911
# Itemset: ('according', 'companies'), Count: 911
# Itemset: ('problem', 'rate'), Count: 911
# Itemset: ('group', 'official'), Count: 911
# Itemset: ('business', 'fund'), Count: 911
# Itemset: ('group', 'trying'), Count: 911
# Itemset: ('provide', 'sure'), Count: 911
# Itemset: ('california', 'open'), Count: 911
# Itemset: ('companies', 'supply'), Count: 910
# Itemset: ('part', 'rate'), Count: 910
# Itemset: ('federal', 'provide'), Count: 910
# Itemset: ('financial', 'high'), Count: 910
# Itemset: ('set', 'term'), Count: 910
# Itemset: ('product', 'provide'), Count: 910
# Itemset: ('consumer', 'problem'), Count: 910
# Itemset: ('high', 'place'), Count: 910
# Itemset: ('level', 'look'), Count: 910
# Itemset: ('power', 'tuesday'), Count: 910
# Itemset: ('customer', 'president'), Count: 910
# Itemset: ('contract', 'project'), Count: 910
# Itemset: ('power', 'short'), Count: 910
# Itemset: ('large', 'price'), Count: 910
# Itemset: ('help', 'trying'), Count: 910
# Itemset: ('group', 'hour'), Count: 910
# Itemset: ('order', 'term'), Count: 910
# Itemset: ('likely', 'think'), Count: 910
# Itemset: ('program', 'report'), Count: 910
# Itemset: ('give', 'include'), Count: 910
# Itemset: ('data', 'month'), Count: 910
# Itemset: ('based', 'due'), Count: 909
# Itemset: ('capacity', 'cost'), Count: 909
# Itemset: ('consumer', 'rates'), Count: 909
# Itemset: ('amount', 'including'), Count: 909
# Itemset: ('end', 'interest'), Count: 909
# Itemset: ('offer', 'thing'), Count: 909
# Itemset: ('help', 'hour'), Count: 909
# Itemset: ('energy', 'list'), Count: 909
# Itemset: ('find', 'include'), Count: 909
# Itemset: ('continue', 'office'), Count: 909
# Itemset: ('bill', 'office'), Count: 909
# Itemset: ('power', 'receive'), Count: 909
# Itemset: ('contract', 'place'), Count: 909
# Itemset: ('including', 'thing'), Count: 909
# Itemset: ('think', 'top'), Count: 909
# Itemset: ('concern', 'energy'), Count: 909
# Itemset: ('deal', 'states'), Count: 909
# Itemset: ('issues', 'rate'), Count: 909
# Itemset: ('earlier', 'power'), Count: 909
# Itemset: ('cost', 'june'), Count: 909
# Itemset: ('market', 'november'), Count: 909
# Itemset: ('bill', 'due'), Count: 909
# Itemset: ('end', 'major'), Count: 909
# Itemset: ('firm', 'report'), Count: 909
# Itemset: ('deal', 'member'), Count: 909
# Itemset: ('hope', 'number'), Count: 909
# Itemset: ('change', 'due'), Count: 909
# Itemset: ('firm', 'provide'), Count: 909
# Itemset: ('board', 'california'), Count: 908
# Itemset: ('continue', 'set'), Count: 908
# Itemset: ('government', 'power'), Count: 908
# Itemset: ('attached', 'look'), Count: 908
# Itemset: ('file', 'final'), Count: 908
# Itemset: ('current', 'management'), Count: 908
# Itemset: ('data', 'file'), Count: 908
# Itemset: ('cost', 'return'), Count: 908
# Itemset: ('level', 'support'), Count: 908
# Itemset: ('meeting', 'term'), Count: 908
# Itemset: ('electricity', 'service'), Count: 908
# Itemset: ('due', 'pay'), Count: 907
# Itemset: ('late', 'month'), Count: 907
# Itemset: ('offer', 'top'), Count: 907
# Itemset: ('according', 'including'), Count: 907
# Itemset: ('price', 'world'), Count: 907
# Itemset: ('company', 'global'), Count: 907
# Itemset: ('bill', 'effort'), Count: 907
# Itemset: ('address', 'current'), Count: 907
# Itemset: ('point', 'start'), Count: 907
# Itemset: ('price', 'sure'), Count: 907
# Itemset: ('address', 'set'), Count: 907
# Itemset: ('called', 'group'), Count: 907
# Itemset: ('chief', 'companies'), Count: 907
# Itemset: ('expected', 'number'), Count: 907
# Itemset: ('company', 'largest'), Count: 907
# Itemset: ('average', 'month'), Count: 907
# Itemset: ('prices', 'thing'), Count: 907
# Itemset: ('energy', 'percent'), Count: 907
# Itemset: ('companies', 'process'), Count: 907
# Itemset: ('future', 'support'), Count: 906
# Itemset: ('center', 'company'), Count: 906
# Itemset: ('believe', 'california'), Count: 906
# Itemset: ('provide', 'supply'), Count: 906
# Itemset: ('general', 'price'), Count: 906
# Itemset: ('line', 'part'), Count: 906
# Itemset: ('number', 'risk'), Count: 906
# Itemset: ('company', 'control'), Count: 906
# Itemset: ('find', 'put'), Count: 906
# Itemset: ('issue', 'received'), Count: 906
# Itemset: ('commission', 'states'), Count: 906
# Itemset: ('attached', 'energy'), Count: 906
# Itemset: ('review', 'team'), Count: 906
# Itemset: ('california', 'increase'), Count: 906
# Itemset: ('doesnt', 'think'), Count: 906
# Itemset: ('friday', 'review'), Count: 906
# Itemset: ('fact', 'power'), Count: 906
# Itemset: ('agreed', 'group'), Count: 906
# Itemset: ('address', 'received'), Count: 906
# Itemset: ('addition', 'include'), Count: 906
# Itemset: ('existing', 'market'), Count: 906
# Itemset: ('company', 'hour'), Count: 905
# Itemset: ('market', 'thought'), Count: 905
# Itemset: ('access', 'meeting'), Count: 905
# Itemset: ('plan', 'required'), Count: 905
# Itemset: ('business', 'official'), Count: 905
# Itemset: ('include', 'office'), Count: 905
# Itemset: ('help', 'utilities'), Count: 905
# Itemset: ('number', 'told'), Count: 905
# Itemset: ('evidence', 'offer'), Count: 905
# Itemset: ('demand', 'utility'), Count: 905
# Itemset: ('comment', 'send'), Count: 905
# Itemset: ('access', 'address'), Count: 905
# Itemset: ('energy', 'tuesday'), Count: 905
# Itemset: ('deal', 'firm'), Count: 905
# Itemset: ('industry', 'world'), Count: 905
# Itemset: ('development', 'month'), Count: 905
# Itemset: ('buy', 'report'), Count: 904
# Itemset: ('business', 'commission'), Count: 904
# Itemset: ('paid', 'pay'), Count: 904
# Itemset: ('business', 'home'), Count: 904
# Itemset: ('amount', 'order'), Count: 904
# Itemset: ('gas', 'look'), Count: 904
# Itemset: ('market', 'real'), Count: 904
# Itemset: ('find', 'office'), Count: 904
# Itemset: ('deal', 'detail'), Count: 904
# Itemset: ('company', 'told'), Count: 904
# Itemset: ('daily', 'report'), Count: 904
# Itemset: ('money', 'part'), Count: 904
# Itemset: ('job', 'report'), Count: 904
# Itemset: ('full', 'provide'), Count: 904
# Itemset: ('account', 'report'), Count: 904
# Itemset: ('business', 'run'), Count: 904
# Itemset: ('energy', 'event'), Count: 904
# Itemset: ('problem', 'review'), Count: 904
# Itemset: ('monday', 'point'), Count: 904
# Itemset: ('project', 'working'), Count: 904
# Itemset: ('business', 'purchase'), Count: 904
# Itemset: ('decision', 'process'), Count: 903
# Itemset: ('law', 'month'), Count: 903
# Itemset: ('comment', 'date'), Count: 903
# Itemset: ('high', 'term'), Count: 903
# Itemset: ('early', 'energy'), Count: 903
# Itemset: ('agreement', 'based'), Count: 903
# Itemset: ('bill', 'give'), Count: 903
# Itemset: ('power', 'talk'), Count: 903
# Itemset: ('full', 'power'), Count: 903
# Itemset: ('change', 'continue'), Count: 903
# Itemset: ('discuss', 'energy'), Count: 903
# Itemset: ('number', 'tuesday'), Count: 903
# Itemset: ('support', 'term'), Count: 903
# Itemset: ('development', 'including'), Count: 903
# Itemset: ('business', 'conference'), Count: 903
# Itemset: ('later', 'meeting'), Count: 903
# Itemset: ('access', 'contract'), Count: 903
# Itemset: ('member', 'received'), Count: 903
# Itemset: ('future', 'point'), Count: 903
# Itemset: ('agreement', 'companies'), Count: 902
# Itemset: ('deal', 'electricity'), Count: 902
# Itemset: ('free', 'power'), Count: 902
# Itemset: ('communication', 'market'), Count: 902
# Itemset: ('point', 'received'), Count: 902
# Itemset: ('contract', 'property'), Count: 902
# Itemset: ('low', 'market'), Count: 902
# Itemset: ('energy', 'needed'), Count: 902
# Itemset: ('meet', 'report'), Count: 902
# Itemset: ('market', 'profit'), Count: 902
# Itemset: ('cost', 'detail'), Count: 902
# Itemset: ('industry', 'issue'), Count: 902
# Itemset: ('mean', 'plan'), Count: 902
# Itemset: ('action', 'going'), Count: 902
# Itemset: ('california', 'told'), Count: 902
# Itemset: ('report', 'send'), Count: 902
# Itemset: ('case', 'look'), Count: 902
# Itemset: ('supply', 'utility'), Count: 902
# Itemset: ('believe', 'deal'), Count: 902
# Itemset: ('going', 'money'), Count: 902
# Itemset: ('group', 'increase'), Count: 902
# Itemset: ('direct', 'number'), Count: 902
# Itemset: ('consumer', 'federal'), Count: 902
# Itemset: ('past', 'set'), Count: 902
# Itemset: ('including', 'making'), Count: 902
# Itemset: ('point', 'services'), Count: 902
# Itemset: ('find', 'support'), Count: 902
# Itemset: ('look', 'pay'), Count: 902
# Itemset: ('current', 'development'), Count: 902
# Itemset: ('office', 'place'), Count: 902
# Itemset: ('electricity', 'power_plant'), Count: 901
# Itemset: ('number', 'open'), Count: 901
# Itemset: ('include', 'industry'), Count: 901
# Itemset: ('customer', 'web'), Count: 901
# Itemset: ('major', 'price'), Count: 901
# Itemset: ('business', 'higher'), Count: 901
# Itemset: ('give', 'support'), Count: 901
# Itemset: ('date', 'office'), Count: 901
# Itemset: ('based', 'find'), Count: 901
# Itemset: ('corp', 'prohibited'), Count: 901
# Itemset: ('financial', 'look'), Count: 901
# Itemset: ('development', 'report'), Count: 901
# Itemset: ('buy', 'financial'), Count: 901
# Itemset: ('change', 'financial'), Count: 901
# Itemset: ('date', 'including'), Count: 901
# Itemset: ('company', 'trade'), Count: 901
# Itemset: ('financial', 'meeting'), Count: 901
# Itemset: ('report', 'sales'), Count: 901
# Itemset: ('manager', 'report'), Count: 901
# Itemset: ('future', 'problem'), Count: 901
# Itemset: ('found', 'price'), Count: 901
# Itemset: ('large', 'month'), Count: 900
# Itemset: ('cost', 'development'), Count: 900
# Itemset: ('additional', 'companies'), Count: 900
# Itemset: ('chief', 'power'), Count: 900
# Itemset: ('energy', 'washington'), Count: 900
# Itemset: ('business', 'capital'), Count: 900
# Itemset: ('including', 'project'), Count: 900
# Itemset: ('number', 'talk'), Count: 900
# Itemset: ('issues', 'prices'), Count: 900
# Itemset: ('direct', 'provide'), Count: 900
# Itemset: ('january', 'service'), Count: 900
# Itemset: ('california', 'major'), Count: 900
# Itemset: ('forward', 'part'), Count: 900
# Itemset: ('hope', 'meeting'), Count: 900
# Itemset: ('california', 'january'), Count: 900
# Itemset: ('access', 'include'), Count: 900
# Itemset: ('contract', 'future'), Count: 900
# Itemset: ('date', 'going'), Count: 900
# Itemset: ('june', 'power'), Count: 900

# %% [markdown]
# ## K = 3 and F = 1500

# %%
main("vocab.enron.txt", "docword.enron.txt", K=3, F=1500)
# Out:
# Reading dataset...
# Running Apriori for K=3, F=1500
#
# Time taken: 22.21 seconds
#
# Total Frequent K-itemsets Found: 3
# Frequent K-itemsets:
# Itemset: ('energy', 'market', 'power'), Count: 1764
# Itemset: ('california', 'energy', 'power'), Count: 1667
# Itemset: ('california', 'market', 'power'), Count: 1602

# %% [markdown]
# ## K = 4 and F = 1200

# %%
main("vocab.enron.txt", "docword.enron.txt", K=4, F=1200)
# Out:
# Reading dataset...
# Running Apriori for K=4, F=1200
#
# Time taken: 40.47 seconds
#
# Total Frequent K-itemsets Found: 2
# Frequent K-itemsets:
# Itemset: ('california', 'energy', 'market', 'power'), Count: 1256
# Itemset: ('energy', 'market', 'power', 'price'), Count: 1210

# %% [markdown]
# ## K = 5 and F = 800

# %%
main("vocab.enron.txt", "docword.enron.txt", K=5, F=800)
# Out:
# Reading dataset...
# Running Apriori for K=5, F=800
#
# Time taken: 221.84 seconds
#
# Total Frequent K-itemsets Found: 162
# Frequent K-itemsets:
# Itemset: ('california', 'electricity', 'energy', 'market', 'power'), Count: 976
# Itemset: ('california', 'energy', 'market', 'power', 'price'), Count: 972
# Itemset: ('california', 'energy', 'market', 'power', 'prices'), Count: 959
# Itemset: ('california', 'cost', 'electricity', 'energy', 'power'), Count: 958
# Itemset: ('california', 'cost', 'energy', 'market', 'power'), Count: 953
# Itemset: ('california', 'electricity', 'energy', 'power', 'states'), Count: 945
# Itemset: ('energy', 'market', 'power', 'price', 'prices'), Count: 936
# Itemset: ('california', 'market', 'power', 'price', 'prices'), Count: 934
# Itemset: ('california', 'electricity', 'energy', 'power', 'prices'), Count: 922
# Itemset: ('cost', 'energy', 'market', 'power', 'price'), Count: 922
# Itemset: ('electricity', 'energy', 'market', 'power', 'price'), Count: 915
# Itemset: ('california', 'electricity', 'energy', 'power', 'price'), Count: 914
# Itemset: ('electricity', 'energy', 'market', 'power', 'prices'), Count: 912
# Itemset: ('cost', 'energy', 'market', 'power', 'prices'), Count: 911
# Itemset: ('cost', 'electricity', 'energy', 'market', 'power'), Count: 908
# Itemset: ('california', 'cost', 'energy', 'power', 'states'), Count: 908
# Itemset: ('california', 'cost', 'market', 'power', 'price'), Count: 908
# Itemset: ('california', 'electricity', 'market', 'power', 'prices'), Count: 906
# Itemset: ('california', 'electricity', 'market', 'power', 'price'), Count: 901
# Itemset: ('cost', 'market', 'power', 'price', 'prices'), Count: 895
# Itemset: ('california', 'energy', 'market', 'power', 'states'), Count: 893
# Itemset: ('california', 'energy', 'power', 'price', 'prices'), Count: 893
# Itemset: ('california', 'cost', 'electricity', 'market', 'power'), Count: 892
# Itemset: ('california', 'cost', 'energy', 'power', 'price'), Count: 892
# Itemset: ('california', 'electricity', 'energy', 'power', 'utilities'), Count: 891
# Itemset: ('california', 'cost', 'energy', 'power', 'utilities'), Count: 889
# Itemset: ('california', 'cost', 'market', 'power', 'prices'), Count: 882
# Itemset: ('california', 'cost', 'electricity', 'power', 'states'), Count: 882
# Itemset: ('electricity', 'market', 'power', 'price', 'prices'), Count: 880
# Itemset: ('california', 'cost', 'energy', 'power', 'prices'), Count: 879
# Itemset: ('california', 'energy', 'market', 'price', 'prices'), Count: 877
# Itemset: ('electricity', 'energy', 'power', 'price', 'prices'), Count: 872
# Itemset: ('cost', 'energy', 'power', 'price', 'prices'), Count: 870
# Itemset: ('california', 'electricity', 'market', 'power', 'states'), Count: 870
# Itemset: ('california', 'electricity', 'power', 'states', 'utilities'), Count: 869
# Itemset: ('california', 'energy', 'power', 'states', 'utilities'), Count: 867
# Itemset: ('california', 'electricity', 'power', 'price', 'prices'), Count: 865
# Itemset: ('cost', 'electricity', 'energy', 'power', 'price'), Count: 864
# Itemset: ('cost', 'electricity', 'energy', 'power', 'prices'), Count: 863
# Itemset: ('cost', 'electricity', 'energy', 'power', 'states'), Count: 863
# Itemset: ('california', 'cost', 'electricity', 'power', 'utilities'), Count: 863
# Itemset: ('california', 'energy', 'market', 'power', 'utilities'), Count: 862
# Itemset: ('cost', 'energy', 'market', 'price', 'prices'), Count: 860
# Itemset: ('california', 'cost', 'electricity', 'power', 'prices'), Count: 860
# Itemset: ('electricity', 'energy', 'market', 'power', 'states'), Count: 858
# Itemset: ('california', 'electricity', 'energy', 'market', 'prices'), Count: 858
# Itemset: ('california', 'energy', 'market', 'month', 'power'), Count: 858
# Itemset: ('california', 'electricity', 'energy', 'month', 'power'), Count: 856
# Itemset: ('california', 'electricity', 'market', 'power', 'utilities'), Count: 855
# Itemset: ('california', 'cost', 'energy', 'market', 'price'), Count: 854
# Itemset: ('california', 'electricity', 'energy', 'market', 'price'), Count: 853
# Itemset: ('california', 'energy', 'power', 'prices', 'states'), Count: 852
# Itemset: ('california', 'cost', 'market', 'power', 'utilities'), Count: 852
# Itemset: ('california', 'energy', 'power', 'price', 'states'), Count: 851
# Itemset: ('california', 'cost', 'market', 'power', 'states'), Count: 851
# Itemset: ('california', 'electricity', 'power', 'prices', 'states'), Count: 850
# Itemset: ('california', 'cost', 'energy', 'month', 'power'), Count: 850
# Itemset: ('california', 'cost', 'electricity', 'power', 'price'), Count: 849
# Itemset: ('cost', 'electricity', 'market', 'power', 'price'), Count: 847
# Itemset: ('california', 'market', 'power', 'price', 'states'), Count: 846
# Itemset: ('california', 'cost', 'electricity', 'energy', 'market'), Count: 845
# Itemset: ('cost', 'energy', 'market', 'power', 'states'), Count: 845
# Itemset: ('california', 'cost', 'power', 'price', 'prices'), Count: 845
# Itemset: ('california', 'electricity', 'energy', 'power', 'utility'), Count: 845
# Itemset: ('california', 'cost', 'market', 'month', 'power'), Count: 843
# Itemset: ('cost', 'electricity', 'energy', 'power', 'utilities'), Count: 842
# Itemset: ('california', 'californias', 'electricity', 'energy', 'power'), Count: 841
# Itemset: ('electricity', 'energy', 'market', 'power', 'utilities'), Count: 841
# Itemset: ('electricity', 'energy', 'market', 'price', 'prices'), Count: 841
# Itemset: ('california', 'cost', 'power', 'states', 'utilities'), Count: 840
# Itemset: ('cost', 'electricity', 'market', 'power', 'prices'), Count: 840
# Itemset: ('business', 'companies', 'company', 'market', 'month'), Count: 840
# Itemset: ('cost', 'energy', 'market', 'month', 'power'), Count: 839
# Itemset: ('california', 'cost', 'market', 'price', 'prices'), Count: 838
# Itemset: ('cost', 'energy', 'market', 'power', 'utilities'), Count: 838
# Itemset: ('california', 'market', 'power', 'prices', 'states'), Count: 838
# Itemset: ('california', 'electricity', 'power', 'price', 'states'), Count: 837
# Itemset: ('california', 'cost', 'energy', 'market', 'prices'), Count: 835
# Itemset: ('energy', 'market', 'month', 'power', 'price'), Count: 832
# Itemset: ('california', 'electricity', 'market', 'price', 'prices'), Count: 832
# Itemset: ('california', 'cost', 'electricity', 'energy', 'states'), Count: 831
# Itemset: ('billion', 'california', 'electricity', 'energy', 'power'), Count: 831
# Itemset: ('california', 'electricity', 'energy', 'price', 'prices'), Count: 830
# Itemset: ('california', 'company', 'energy', 'market', 'power'), Count: 830
# Itemset: ('california', 'market', 'power', 'states', 'utilities'), Count: 830
# Itemset: ('california', 'market', 'power', 'price', 'utilities'), Count: 828
# Itemset: ('company', 'electricity', 'energy', 'market', 'power'), Count: 828
# Itemset: ('electricity', 'energy', 'power', 'prices', 'states'), Count: 827
# Itemset: ('energy', 'market', 'month', 'power', 'prices'), Count: 827
# Itemset: ('electricity', 'energy', 'market', 'month', 'power'), Count: 825
# Itemset: ('energy', 'high', 'market', 'power', 'price'), Count: 825
# Itemset: ('california', 'market', 'month', 'power', 'price'), Count: 825
# Itemset: ('electricity', 'energy', 'power', 'states', 'utilities'), Count: 825
# Itemset: ('california', 'energy', 'high', 'market', 'power'), Count: 824
# Itemset: ('california', 'cost', 'energy', 'power', 'utility'), Count: 824
# Itemset: ('california', 'energy', 'month', 'power', 'prices'), Count: 824
# Itemset: ('energy', 'market', 'power', 'price', 'states'), Count: 823
# Itemset: ('cost', 'electricity', 'energy', 'month', 'power'), Count: 823
# Itemset: ('energy', 'market', 'power', 'price', 'utilities'), Count: 822
# Itemset: ('california', 'market', 'power', 'prices', 'utilities'), Count: 822
# Itemset: ('business', 'companies', 'company', 'group', 'market'), Count: 821
# Itemset: ('business', 'company', 'energy', 'market', 'power'), Count: 820
# Itemset: ('electricity', 'energy', 'power', 'price', 'states'), Count: 820
# Itemset: ('high', 'market', 'power', 'price', 'prices'), Count: 819
# Itemset: ('cost', 'electricity', 'power', 'price', 'prices'), Count: 819
# Itemset: ('cost', 'electricity', 'energy', 'market', 'price'), Count: 819
# Itemset: ('california', 'electricity', 'power', 'prices', 'utilities'), Count: 818
# Itemset: ('energy', 'high', 'market', 'power', 'prices'), Count: 818
# Itemset: ('cost', 'market', 'month', 'power', 'price'), Count: 817
# Itemset: ('california', 'high', 'market', 'power', 'price'), Count: 817
# Itemset: ('california', 'power', 'price', 'prices', 'states'), Count: 816
# Itemset: ('california', 'high', 'market', 'power', 'prices'), Count: 816
# Itemset: ('california', 'energy', 'month', 'power', 'states'), Count: 816
# Itemset: ('california', 'cost', 'electricity', 'month', 'power'), Count: 815
# Itemset: ('california', 'cost', 'electricity', 'energy', 'prices'), Count: 814
# Itemset: ('california', 'cost', 'energy', 'market', 'states'), Count: 814
# Itemset: ('california', 'energy', 'power', 'price', 'utilities'), Count: 814
# Itemset: ('california', 'cost', 'electricity', 'energy', 'price'), Count: 813
# Itemset: ('california', 'cost', 'energy', 'price', 'prices'), Count: 813
# Itemset: ('cost', 'customer', 'energy', 'market', 'power'), Count: 812
# Itemset: ('california', 'electricity', 'energy', 'federal', 'power'), Count: 812
# Itemset: ('california', 'cost', 'power', 'prices', 'states'), Count: 812
# Itemset: ('california', 'company', 'electricity', 'energy', 'power'), Count: 812
# Itemset: ('california', 'market', 'month', 'power', 'prices'), Count: 812
# Itemset: ('california', 'electricity', 'power', 'price', 'utilities'), Count: 811
# Itemset: ('cost', 'energy', 'power', 'states', 'utilities'), Count: 810
# Itemset: ('california', 'cost', 'customer', 'energy', 'power'), Count: 810
# Itemset: ('california', 'energy', 'month', 'power', 'price'), Count: 810
# Itemset: ('energy', 'market', 'power', 'prices', 'states'), Count: 810
# Itemset: ('cost', 'energy', 'high', 'market', 'power'), Count: 809
# Itemset: ('california', 'electricity', 'market', 'month', 'power'), Count: 809
# Itemset: ('cost', 'energy', 'power', 'price', 'utilities'), Count: 809
# Itemset: ('california', 'californias', 'electricity', 'power', 'states'), Count: 808
# Itemset: ('california', 'energy', 'power', 'prices', 'utilities'), Count: 808
# Itemset: ('california', 'electricity', 'energy', 'market', 'states'), Count: 808
# Itemset: ('electricity', 'energy', 'high', 'market', 'power'), Count: 808
# Itemset: ('electricity', 'market', 'power', 'prices', 'states'), Count: 807
# Itemset: ('electricity', 'energy', 'month', 'power', 'prices'), Count: 807
# Itemset: ('california', 'energy', 'market', 'power', 'utility'), Count: 806
# Itemset: ('electricity', 'market', 'power', 'price', 'states'), Count: 805
# Itemset: ('california', 'cost', 'power', 'price', 'states'), Count: 805
# Itemset: ('cost', 'electricity', 'market', 'power', 'states'), Count: 805
# Itemset: ('energy', 'market', 'power', 'prices', 'utilities'), Count: 805
# Itemset: ('california', 'energy', 'high', 'power', 'prices'), Count: 805
# Itemset: ('cost', 'electricity', 'energy', 'market', 'prices'), Count: 805
# Itemset: ('california', 'electricity', 'energy', 'prices', 'states'), Count: 804
# Itemset: ('market', 'month', 'power', 'price', 'prices'), Count: 804
# Itemset: ('electricity', 'energy', 'power', 'price', 'utilities'), Count: 803
# Itemset: ('cost', 'high', 'market', 'power', 'price'), Count: 803
# Itemset: ('electricity', 'energy', 'power', 'prices', 'utilities'), Count: 802
# Itemset: ('california', 'cost', 'electricity', 'market', 'price'), Count: 802
# Itemset: ('california', 'cost', 'power', 'price', 'utilities'), Count: 802
# Itemset: ('market', 'power', 'price', 'prices', 'states'), Count: 802
# Itemset: ('bill', 'california', 'electricity', 'energy', 'power'), Count: 802
# Itemset: ('cost', 'market', 'power', 'price', 'utilities'), Count: 802
# Itemset: ('california', 'electricity', 'month', 'power', 'states'), Count: 801
# Itemset: ('cost', 'energy', 'power', 'price', 'states'), Count: 801
# Itemset: ('california', 'cost', 'electricity', 'energy', 'utilities'), Count: 801
# Itemset: ('california', 'californias', 'cost', 'energy', 'power'), Count: 801
# Itemset: ('cost', 'energy', 'power', 'prices', 'states'), Count: 801
# Itemset: ('business', 'companies', 'company', 'including', 'market'), Count: 800
# Itemset: ('cost', 'energy', 'month', 'power', 'prices'), Count: 800

# %% [markdown]
# ## K = 7 and F = 700

# %%
main("vocab.enron.txt", "docword.enron.txt", K=7, F=700)
# Out:
# Reading dataset...
# Running Apriori for K=7, F=700
#
# Time taken: 514.36 seconds
#
# Total Frequent K-itemsets Found: 15
# Frequent K-itemsets:
# Itemset: ('california', 'electricity', 'energy', 'market', 'power', 'price', 'prices'), Count: 746
# Itemset: ('california', 'cost', 'electricity', 'energy', 'market', 'power', 'price'), Count: 731
# Itemset: ('california', 'cost', 'electricity', 'energy', 'market', 'power', 'prices'), Count: 730
# Itemset: ('california', 'cost', 'energy', 'market', 'power', 'price', 'prices'), Count: 724
# Itemset: ('cost', 'electricity', 'energy', 'market', 'power', 'price', 'prices'), Count: 723
# Itemset: ('california', 'cost', 'electricity', 'energy', 'market', 'power', 'states'), Count: 718
# Itemset: ('california', 'cost', 'electricity', 'energy', 'power', 'price', 'prices'), Count: 717
# Itemset: ('california', 'cost', 'electricity', 'energy', 'power', 'prices', 'states'), Count: 711
# Itemset: ('basis', 'contract', 'corp', 'create', 'offer', 'party', 'review'), Count: 709
# Itemset: ('california', 'cost', 'electricity', 'energy', 'power', 'states', 'utilities'), Count: 707
# Itemset: ('california', 'cost', 'electricity', 'market', 'power', 'price', 'prices'), Count: 706
# Itemset: ('contract', 'corp', 'create', 'offer', 'party', 'receive', 'review'), Count: 705
# Itemset: ('california', 'electricity', 'energy', 'market', 'power', 'price', 'states'), Count: 705
# Itemset: ('california', 'electricity', 'energy', 'market', 'power', 'prices', 'states'), Count: 704
# Itemset: ('california', 'cost', 'electricity', 'energy', 'power', 'price', 'states'), Count: 700

# %% [markdown]
# ## K = 10 and F = 900

# %%
main("vocab.enron.txt", "docword.enron.txt", K=10, F=900)
# Out:
# Reading dataset...
# Running Apriori for K=10, F=900
#
# Time taken: 119.89 seconds
#
# No itemsets found.
